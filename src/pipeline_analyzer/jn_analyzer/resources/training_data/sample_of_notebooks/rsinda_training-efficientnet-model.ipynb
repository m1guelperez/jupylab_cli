# %% [markdown]
# # Training EfficientNet For bird_song

# %% [markdown]
# ## Credits
#
# * https://www.kaggle.com/ttahara/training-birdsong-baseline-resnest50-fast
#
# ## Inference Notebook
#
# * https://www.kaggle.com/rsinda/ensemble-resnest50-efficient-net

# %% [markdown]
# ### import libraries

# %%
# %%bash
# pip install ../input/pytorch-pfn-extras/pytorch-pfn-extras-0.2.1/
# Out:
# Processing /kaggle/input/pytorch-pfn-extras/pytorch-pfn-extras-0.2.1
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from pytorch-pfn-extras==0.2.1) (1.18.5)
# Requirement already satisfied: torch in /opt/conda/lib/python3.7/site-packages (from pytorch-pfn-extras==0.2.1) (1.5.1)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch->pytorch-pfn-extras==0.2.1) (0.18.2)
# Building wheels for collected packages: pytorch-pfn-extras
#   Building wheel for pytorch-pfn-extras (setup.py): started
#   Building wheel for pytorch-pfn-extras (setup.py): finished with status 'done'
#   Created wheel for pytorch-pfn-extras: filename=pytorch_pfn_extras-0.2.1-py3-none-any.whl size=61392 sha256=6e52379414995d5b74c7d92744b569d6d52eaa4c2ca3b0da58a22ca4c855163a
#   Stored in directory: /root/.cache/pip/wheels/4b/6d/96/1a021d23511ce1a377638f67ba1b0d8d1832fbcd3f0c6c1442
# Successfully built pytorch-pfn-extras
# Installing collected packages: pytorch-pfn-extras
# Successfully installed pytorch-pfn-extras-0.2.1

# %%
import os
import os
import sys
sys.path = [
    '../input/efficientnet-pytorch/EfficientNet-PyTorch/EfficientNet-PyTorch-master',
] + sys.path
import gc
import time
import shutil
import random
import warnings
import typing as tp
from pathlib import Path
from contextlib import contextmanager

import yaml
from joblib import delayed, Parallel

import cv2
import librosa
import audioread
import soundfile as sf

import numpy as np
import pandas as pd

from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
# import resnest.torch as resnest_torch

import pytorch_pfn_extras as ppe
from pytorch_pfn_extras.training import extensions as ppe_extensions

pd.options.display.max_rows = 500
pd.options.display.max_columns = 500

# %%
Path("/root/.cache/torch/checkpoints").mkdir(parents=True)

# %%
# !cp ../input/efficientnet-pytorch/efficientnet-b4-e116e8b3.pth /root/.cache/torch/checkpoints/

# %% [markdown]
# ### define utilities

# %%
def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  # type: ignore
#     torch.backends.cudnn.deterministic = True  # type: ignore
#     torch.backends.cudnn.benchmark = True  # type: ignore
    

@contextmanager
def timer(name: str) -> None:
    """Timer Util"""
    t0 = time.time()
    print("[{}] start".format(name))
    yield
    print("[{}] done in {:.0f} s".format(name, time.time() - t0))

# %% [markdown]
# ### read data

# %%
ROOT = Path.cwd().parent
INPUT_ROOT = ROOT / "input"
RAW_DATA = INPUT_ROOT / "birdsong-recognition"
TRAIN_AUDIO_DIR = RAW_DATA / "train_audio"
TRAIN_RESAMPLED_AUDIO_DIRS = [
  INPUT_ROOT / "birdsong-resampled-train-audio-{:0>2}".format(i)  for i in range(5)
]
TEST_AUDIO_DIR = RAW_DATA / "test_audio"

# %%
train = pd.read_csv(TRAIN_RESAMPLED_AUDIO_DIRS[0] / "train_mod.csv")

# %%
train.head().T
# Out:
#                                                                          0  \
# rating                                                                 3.5
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                          1 (mono)
# date                                                            2013-05-25
# pitch                                                        Not specified
# duration                                                                25
# filename                                                      XC134874.mp3
# speed                                                        Not specified
# species                                                   Alder Flycatcher
# number_of_notes                                              Not specified
# title                        XC134874 Alder Flycatcher (Empidonax alnorum)
# secondary_labels         ['Empidonax minimus_Least Flycatcher', 'Leioth...
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                       Grey Cloud Dunes SNA, Washington, Minnesota
# latitude                                                            44.793
# sampling_rate                                                   48000 (Hz)
# type                                                                  call
# elevation                                                            220 m
# description              Two short segments of fairly quiet *pip* calls...
# bitrate_of_mp3                                                192000 (bps)
# file_type                                                              mp3
# volume                                                       Not specified
# background               American Yellow Warbler (Setophaga aestiva); L...
# xc_id                                                               134874
# url                                      https://www.xeno-canto.org/134874
# country                                                      United States
# author                                                    Jonathon Jongsma
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                          -92.962
# length                                                       Not specified
# time                                                                  8:00
# recordist                                                 Jonathon Jongsma
# license                        Creative Commons Attribution-ShareAlike 3.0
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC134874.wav
# resampled_channels                                                1 (mono)
#
#                                                                          1  \
# rating                                                                   4
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                        2 (stereo)
# date                                                            2013-05-27
# pitch                                                                 both
# duration                                                                36
# filename                                                      XC135454.mp3
# speed                                                                 both
# species                                                   Alder Flycatcher
# number_of_notes                                                        1-3
# title                        XC135454 Alder Flycatcher (Empidonax alnorum)
# secondary_labels                                                        []
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                  Carver's Gap Parking area, Roan Mountain Stat...
# latitude                                                           36.1065
# sampling_rate                                                   44100 (Hz)
# type                                                            call, song
# elevation                                                           1700 m
# description              At least three birds seen here moving around s...
# bitrate_of_mp3                                                128000 (bps)
# file_type                                                              mp3
# volume                                                               level
# background                                                             NaN
# xc_id                                                               135454
# url                                      https://www.xeno-canto.org/135454
# country                                                      United States
# author                                                         Mike Nelson
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                         -82.1106
# length                                                              0-3(s)
# time                                                                 08:30
# recordist                                                      Mike Nelson
# license                  Creative Commons Attribution-NonCommercial-Sha...
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC135454.wav
# resampled_channels                                                1 (mono)
#
#                                                                          2  \
# rating                                                                   4
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                        2 (stereo)
# date                                                            2013-05-27
# pitch                                                                 both
# duration                                                                39
# filename                                                      XC135455.mp3
# speed                                                                 both
# species                                                   Alder Flycatcher
# number_of_notes                                                        1-3
# title                        XC135455 Alder Flycatcher (Empidonax alnorum)
# secondary_labels                                                        []
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                  Carver's Gap Parking area, Roan Mountain Stat...
# latitude                                                           36.1065
# sampling_rate                                                   44100 (Hz)
# type                                                            call, song
# elevation                                                           1700 m
# description              At least three birds seen chasing each other a...
# bitrate_of_mp3                                                128000 (bps)
# file_type                                                              mp3
# volume                                                               level
# background                                                             NaN
# xc_id                                                               135455
# url                                      https://www.xeno-canto.org/135455
# country                                                      United States
# author                                                         Mike Nelson
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                         -82.1106
# length                                                              0-3(s)
# time                                                                 08:30
# recordist                                                      Mike Nelson
# license                  Creative Commons Attribution-NonCommercial-Sha...
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC135455.wav
# resampled_channels                                                1 (mono)
#
#                                                                          3  \
# rating                                                                 3.5
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                        2 (stereo)
# date                                                            2013-05-27
# pitch                                                                 both
# duration                                                                33
# filename                                                      XC135456.mp3
# speed                                                                 both
# species                                                   Alder Flycatcher
# number_of_notes                                                        1-3
# title                        XC135456 Alder Flycatcher (Empidonax alnorum)
# secondary_labels         ['Dumetella carolinensis_Gray Catbird', 'Bomby...
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                  Carver's Gap Parking area, Roan Mountain Stat...
# latitude                                                           36.1065
# sampling_rate                                                   44100 (Hz)
# type                                                            call, song
# elevation                                                           1700 m
# description              img:http://www.flickr.com/photos/madbirder/888...
# bitrate_of_mp3                                                128000 (bps)
# file_type                                                              mp3
# volume                                                               level
# background               Grey Catbird (Dumetella carolinensis); Cedar W...
# xc_id                                                               135456
# url                                      https://www.xeno-canto.org/135456
# country                                                      United States
# author                                                         Mike Nelson
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                         -82.1106
# length                                                              0-3(s)
# time                                                                 08:30
# recordist                                                      Mike Nelson
# license                  Creative Commons Attribution-NonCommercial-Sha...
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC135456.wav
# resampled_channels                                                1 (mono)
#
#                                                                          4
# rating                                                                   4
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                        2 (stereo)
# date                                                            2013-05-27
# pitch                                                                 both
# duration                                                                36
# filename                                                      XC135457.mp3
# speed                                                                level
# species                                                   Alder Flycatcher
# number_of_notes                                                        1-3
# title                        XC135457 Alder Flycatcher (Empidonax alnorum)
# secondary_labels                                                        []
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                  Carver's Gap Parking area, Roan Mountain Stat...
# latitude                                                           36.1065
# sampling_rate                                                   44100 (Hz)
# type                                                            call, song
# elevation                                                           1700 m
# description              img:http://www.flickr.com/photos/madbirder/888...
# bitrate_of_mp3                                                128000 (bps)
# file_type                                                              mp3
# volume                                                               level
# background                                                             NaN
# xc_id                                                               135457
# url                                      https://www.xeno-canto.org/135457
# country                                                      United States
# author                                                         Mike Nelson
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                         -82.1106
# length                                                              0-3(s)
# time                                                                 08:30
# recordist                                                      Mike Nelson
# license                  Creative Commons Attribution-NonCommercial-Sha...
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC135457.wav
# resampled_channels                                                1 (mono)

# %%
if not TEST_AUDIO_DIR.exists():
    TEST_AUDIO_DIR = INPUT_ROOT / "birdcall-check" / "test_audio"
    test = pd.read_csv(INPUT_ROOT / "birdcall-check" / "test.csv")
else:
    test = pd.read_csv(RAW_DATA / "test.csv")

# %%
test.head().T
# Out:
#                                                   0  \
# site                                         site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_5
# seconds                                           5
# audio_id           41e6fe6504a34bf6846938ba78d13df1
#
#                                                    1  \
# site                                          site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_10
# seconds                                           10
# audio_id            41e6fe6504a34bf6846938ba78d13df1
#
#                                                    2  \
# site                                          site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_15
# seconds                                           15
# audio_id            41e6fe6504a34bf6846938ba78d13df1
#
#                                                    3  \
# site                                          site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_20
# seconds                                           20
# audio_id            41e6fe6504a34bf6846938ba78d13df1
#
#                                                    4
# site                                          site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_25
# seconds                                           25
# audio_id            41e6fe6504a34bf6846938ba78d13df1

# %% [markdown]
# ### settings

# %%
settings_str = """
globals:
  seed: 1213
  device: cuda
  num_epochs: 40
  output_dir: /kaggle/training_output/
  use_fold: 0
  target_sr: 32000

dataset:
  name: SpectrogramDataset
  params:
    img_size: 256
    melspectrogram_parameters:
      n_mels: 128
      fmin: 20
      fmax: 16000
    
split:
  name: StratifiedKFold
  params:
    n_splits: 5
    random_state: 42
    shuffle: True

loader:
  train:
    batch_size: 32
    shuffle: True
    num_workers: 2
    pin_memory: True
    drop_last: True
  val:
    batch_size: 48
    shuffle: False
    num_workers: 2
    pin_memory: True
    drop_last: False

model:
  name: E_net
  params:
    pretrained: True
    n_classes: 264

loss:
  name: BCEWithLogitsLoss
  params: {}

optimizer:
  name: Adam
  params:
    lr: 0.001

scheduler:
  name: CosineAnnealingLR
  params:
    T_max: 10
"""

# %%
settings = yaml.safe_load(settings_str)

# %%
# if not torch.cuda.is_available():
#     settings["globals"]["device"] = "cpu"

# %%
for k, v in settings.items():
    print("[{}]".format(k))
    print(v)
# Out:
# [globals]
# {'seed': 1213, 'device': 'cuda', 'num_epochs': 40, 'output_dir': '/kaggle/training_output/', 'use_fold': 0, 'target_sr': 32000}
# [dataset]
# {'name': 'SpectrogramDataset', 'params': {'img_size': 256, 'melspectrogram_parameters': {'n_mels': 128, 'fmin': 20, 'fmax': 16000}}}
# [split]
# {'name': 'StratifiedKFold', 'params': {'n_splits': 5, 'random_state': 42, 'shuffle': True}}
# [loader]
# {'train': {'batch_size': 32, 'shuffle': True, 'num_workers': 2, 'pin_memory': True, 'drop_last': True}, 'val': {'batch_size': 48, 'shuffle': False, 'num_workers': 2, 'pin_memory': True, 'drop_last': False}}
# [model]
# {'name': 'E_net', 'params': {'pretrained': True, 'n_classes': 264}}
# [loss]
# {'name': 'BCEWithLogitsLoss', 'params': {}}
# [optimizer]
# {'name': 'Adam', 'params': {'lr': 0.001}}
# [scheduler]
# {'name': 'CosineAnnealingLR', 'params': {'T_max': 10}}

# %% [markdown]
# ### preprocess audio data
#
# Code is forked from: https://github.com/koukyo1994/kaggle-birdcall-resnet-baseline-training/blob/master/input/birdsong-recognition/prepare.py
#
# I modified this partially.
#
# However, in this notebook, I used uploaded resampled audio because this preprocessing is too heavy for kaggle notebook.

# %%
def resample(ebird_code: str,filename: str, target_sr: int):    
    audio_dir = TRAIN_AUDIO_DIR
    resample_dir = TRAIN_RESAMPLED_DIR
    ebird_dir = resample_dir / ebird_code
    
    try:
        y, _ = librosa.load(
            audio_dir / ebird_code / filename,
            sr=target_sr, mono=True, res_type="kaiser_fast")

        filename = filename.replace(".mp3", ".wav")
        sf.write(ebird_dir / filename, y, samplerate=target_sr)
    except Exception as e:
        print(e)
        with open("skipped.txt", "a") as f:
            file_path = str(audio_dir / ebird_code / filename)
            f.write(file_path + "\n")

# %%
# train_org = train.copy()
# TRAIN_RESAMPLED_DIR = Path("/kaggle/processed_data/train_audio_resampled")
# TRAIN_RESAMPLED_DIR.mkdir(parents=True)

# for ebird_code in train.ebird_code.unique():
#     ebird_dir = TRAIN_RESAMPLED_DIR / ebird_code
#     ebird_dir.mkdir()

# warnings.simplefilter("ignore")
# train_audio_infos = train[["ebird_code", "filename"]].values.tolist()
# Parallel(n_jobs=NUM_THREAD, verbose=10)(
#     delayed(resample)(ebird_code, file_name, TARGET_SR) for ebird_code, file_name in train_audio_infos)

# train["resampled_sampling_rate"] = TARGET_SR
# train["resampled_filename"] = train["filename"].map(
#     lambda x: x.replace(".mp3", ".wav"))
# train["resampled_channels"] = "1 (mono)"

# %% [markdown]
# ## Definition

# %% [markdown]
# ### Dataset
# * forked from: https://github.com/koukyo1994/kaggle-birdcall-resnet-baseline-training/blob/master/src/dataset.py
# * modified partialy

# %%
BIRD_CODE = {
    'aldfly': 0, 'ameavo': 1, 'amebit': 2, 'amecro': 3, 'amegfi': 4,
    'amekes': 5, 'amepip': 6, 'amered': 7, 'amerob': 8, 'amewig': 9,
    'amewoo': 10, 'amtspa': 11, 'annhum': 12, 'astfly': 13, 'baisan': 14,
    'baleag': 15, 'balori': 16, 'banswa': 17, 'barswa': 18, 'bawwar': 19,
    'belkin1': 20, 'belspa2': 21, 'bewwre': 22, 'bkbcuc': 23, 'bkbmag1': 24,
    'bkbwar': 25, 'bkcchi': 26, 'bkchum': 27, 'bkhgro': 28, 'bkpwar': 29,
    'bktspa': 30, 'blkpho': 31, 'blugrb1': 32, 'blujay': 33, 'bnhcow': 34,
    'boboli': 35, 'bongul': 36, 'brdowl': 37, 'brebla': 38, 'brespa': 39,
    'brncre': 40, 'brnthr': 41, 'brthum': 42, 'brwhaw': 43, 'btbwar': 44,
    'btnwar': 45, 'btywar': 46, 'buffle': 47, 'buggna': 48, 'buhvir': 49,
    'bulori': 50, 'bushti': 51, 'buwtea': 52, 'buwwar': 53, 'cacwre': 54,
    'calgul': 55, 'calqua': 56, 'camwar': 57, 'cangoo': 58, 'canwar': 59,
    'canwre': 60, 'carwre': 61, 'casfin': 62, 'caster1': 63, 'casvir': 64,
    'cedwax': 65, 'chispa': 66, 'chiswi': 67, 'chswar': 68, 'chukar': 69,
    'clanut': 70, 'cliswa': 71, 'comgol': 72, 'comgra': 73, 'comloo': 74,
    'commer': 75, 'comnig': 76, 'comrav': 77, 'comred': 78, 'comter': 79,
    'comyel': 80, 'coohaw': 81, 'coshum': 82, 'cowscj1': 83, 'daejun': 84,
    'doccor': 85, 'dowwoo': 86, 'dusfly': 87, 'eargre': 88, 'easblu': 89,
    'easkin': 90, 'easmea': 91, 'easpho': 92, 'eastow': 93, 'eawpew': 94,
    'eucdov': 95, 'eursta': 96, 'evegro': 97, 'fiespa': 98, 'fiscro': 99,
    'foxspa': 100, 'gadwal': 101, 'gcrfin': 102, 'gnttow': 103, 'gnwtea': 104,
    'gockin': 105, 'gocspa': 106, 'goleag': 107, 'grbher3': 108, 'grcfly': 109,
    'greegr': 110, 'greroa': 111, 'greyel': 112, 'grhowl': 113, 'grnher': 114,
    'grtgra': 115, 'grycat': 116, 'gryfly': 117, 'haiwoo': 118, 'hamfly': 119,
    'hergul': 120, 'herthr': 121, 'hoomer': 122, 'hoowar': 123, 'horgre': 124,
    'horlar': 125, 'houfin': 126, 'houspa': 127, 'houwre': 128, 'indbun': 129,
    'juntit1': 130, 'killde': 131, 'labwoo': 132, 'larspa': 133, 'lazbun': 134,
    'leabit': 135, 'leafly': 136, 'leasan': 137, 'lecthr': 138, 'lesgol': 139,
    'lesnig': 140, 'lesyel': 141, 'lewwoo': 142, 'linspa': 143, 'lobcur': 144,
    'lobdow': 145, 'logshr': 146, 'lotduc': 147, 'louwat': 148, 'macwar': 149,
    'magwar': 150, 'mallar3': 151, 'marwre': 152, 'merlin': 153, 'moublu': 154,
    'mouchi': 155, 'moudov': 156, 'norcar': 157, 'norfli': 158, 'norhar2': 159,
    'normoc': 160, 'norpar': 161, 'norpin': 162, 'norsho': 163, 'norwat': 164,
    'nrwswa': 165, 'nutwoo': 166, 'olsfly': 167, 'orcwar': 168, 'osprey': 169,
    'ovenbi1': 170, 'palwar': 171, 'pasfly': 172, 'pecsan': 173, 'perfal': 174,
    'phaino': 175, 'pibgre': 176, 'pilwoo': 177, 'pingro': 178, 'pinjay': 179,
    'pinsis': 180, 'pinwar': 181, 'plsvir': 182, 'prawar': 183, 'purfin': 184,
    'pygnut': 185, 'rebmer': 186, 'rebnut': 187, 'rebsap': 188, 'rebwoo': 189,
    'redcro': 190, 'redhea': 191, 'reevir1': 192, 'renpha': 193, 'reshaw': 194,
    'rethaw': 195, 'rewbla': 196, 'ribgul': 197, 'rinduc': 198, 'robgro': 199,
    'rocpig': 200, 'rocwre': 201, 'rthhum': 202, 'ruckin': 203, 'rudduc': 204,
    'rufgro': 205, 'rufhum': 206, 'rusbla': 207, 'sagspa1': 208, 'sagthr': 209,
    'savspa': 210, 'saypho': 211, 'scatan': 212, 'scoori': 213, 'semplo': 214,
    'semsan': 215, 'sheowl': 216, 'shshaw': 217, 'snobun': 218, 'snogoo': 219,
    'solsan': 220, 'sonspa': 221, 'sora': 222, 'sposan': 223, 'spotow': 224,
    'stejay': 225, 'swahaw': 226, 'swaspa': 227, 'swathr': 228, 'treswa': 229,
    'truswa': 230, 'tuftit': 231, 'tunswa': 232, 'veery': 233, 'vesspa': 234,
    'vigswa': 235, 'warvir': 236, 'wesblu': 237, 'wesgre': 238, 'weskin': 239,
    'wesmea': 240, 'wessan': 241, 'westan': 242, 'wewpew': 243, 'whbnut': 244,
    'whcspa': 245, 'whfibi': 246, 'whtspa': 247, 'whtswi': 248, 'wilfly': 249,
    'wilsni1': 250, 'wiltur': 251, 'winwre3': 252, 'wlswar': 253, 'wooduc': 254,
    'wooscj2': 255, 'woothr': 256, 'y00475': 257, 'yebfly': 258, 'yebsap': 259,
    'yehbla': 260, 'yelwar': 261, 'yerwar': 262, 'yetvir': 263
}

INV_BIRD_CODE = {v: k for k, v in BIRD_CODE.items()}

# %%
PERIOD = 5

def mono_to_color(
    X: np.ndarray, mean=None, std=None,
    norm_max=None, norm_min=None, eps=1e-6
):
    # Stack X as [X,X,X]
    X = np.stack([X, X, X], axis=-1)

    # Standardize
    mean = mean or X.mean()
    X = X - mean
    std = std or X.std()
    Xstd = X / (std + eps)
    _min, _max = Xstd.min(), Xstd.max()
    norm_max = norm_max or _max
    norm_min = norm_min or _min
    if (_max - _min) > eps:
        # Normalize to [0, 255]
        V = Xstd
        V[V < norm_min] = norm_min
        V[V > norm_max] = norm_max
        V = 255 * (V - norm_min) / (norm_max - norm_min)
        V = V.astype(np.uint8)
    else:
        # Just zero
        V = np.zeros_like(Xstd, dtype=np.uint8)
    return V

class SpectrogramDataset(data.Dataset):
    def __init__(
        self,
        file_list: tp.List[tp.List[str]], img_size=224,
        waveform_transforms=None, spectrogram_transforms=None, melspectrogram_parameters={}
    ):
        self.file_list = file_list  # list of list: [file_path, ebird_code]
        self.img_size = img_size
        self.waveform_transforms = waveform_transforms
        self.spectrogram_transforms = spectrogram_transforms
        self.melspectrogram_parameters = melspectrogram_parameters

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx: int):
        wav_path, ebird_code = self.file_list[idx]

        y, sr = sf.read(wav_path)

        if self.waveform_transforms:
            y = self.waveform_transforms(y)
        else:
            len_y = len(y)
            effective_length = sr * PERIOD
            if len_y < effective_length:
                new_y = np.zeros(effective_length, dtype=y.dtype)
                start = np.random.randint(effective_length - len_y)
                new_y[start:start + len_y] = y
                y = new_y.astype(np.float32)
            elif len_y > effective_length:
                start = np.random.randint(len_y - effective_length)
                y = y[start:start + effective_length].astype(np.float32)
            else:
                y = y.astype(np.float32)

        melspec = librosa.feature.melspectrogram(y, sr=sr, **self.melspectrogram_parameters)
        melspec = librosa.power_to_db(melspec).astype(np.float32)

        if self.spectrogram_transforms:
            melspec = self.spectrogram_transforms(melspec)
        else:
            pass

        image = mono_to_color(melspec)
        height, width, _ = image.shape
#         image = cv2.resize(image, (int(width * self.img_size / height), self.img_size))
        image = cv2.resize(image,  (self.img_size, self.img_size))
        image = np.moveaxis(image, 2, 0)
        image = (image / 255.0).astype(np.float32)

#         labels = np.zeros(len(BIRD_CODE), dtype="i")
        labels = np.zeros(len(BIRD_CODE), dtype="f")
        labels[BIRD_CODE[ebird_code]] = 1

        return image, labels

# %% [markdown]
# ### Training Utility

# %%
def get_loaders_for_training(
    args_dataset: tp.Dict, args_loader: tp.Dict,
    train_file_list: tp.List[str], val_file_list: tp.List[str]
):
    # # make dataset
    train_dataset = SpectrogramDataset(train_file_list, **args_dataset)
    val_dataset = SpectrogramDataset(val_file_list, **args_dataset)
    # # make dataloader
    train_loader = data.DataLoader(train_dataset, **args_loader["train"])
    val_loader = data.DataLoader(val_dataset, **args_loader["val"])
    
    return train_loader, val_loader

# %%
from efficientnet_pytorch import model as enet
pretrained_model = {
    'efficientnet-b2': '../input/efficientnet-pytorch/efficientnet-b2-27687264.pth'
}

enet_type = 'efficientnet-b2'

device = torch.device('cuda')

# %%
class enetv2(nn.Module):
    def __init__(self, backbone):
        super(enetv2, self).__init__()
        self.enet = enet.EfficientNet.from_name(backbone)
        self.enet.load_state_dict(torch.load(pretrained_model[backbone]))

        self.myfc = nn.Sequential(
        nn.Linear(self.enet._fc.in_features,512), nn.ReLU(), nn.Dropout(p=0.2),
        nn.Linear(512, 264))
        
        self.enet._fc = nn.Identity()

    def extract(self, x):
        return self.enet(x)

    def forward(self, x):
        x = self.extract(x)
#         print(x.shape)
        x = self.myfc(x)
        return x

# %%
def get_model(args: tp.Dict):
    model =enetv2(enet_type)
    model = model.to(device)
        
    return model

# %%
from tqdm import tqdm_notebook

# %%
def train_loop(
    manager, args, model, device,
    train_loader, optimizer, scheduler, loss_func
):
    """Run minibatch training loop"""
    while not manager.stop_trigger:
        model.train()
        bar =tqdm_notebook(enumerate(train_loader), total = len(train_loader))
        
        for batch_idx, (data, target) in bar:
            with manager.run_iteration():
                data, target = data.to(device), target.to(device)
                optimizer.zero_grad()
                output = model(data)
                loss = loss_func(output, target)
                ppe.reporting.report({'train/loss': loss.item()})
                loss.backward()
                optimizer.step()
                scheduler.step()

def eval_for_batch(
    args, model, device,
    data, target, loss_func, eval_func_dict={}
):
    """
    Run evaliation for valid
    
    This function is applied to each batch of val loader.
    """
    model.eval()
    data, target = data.to(device), target.to(device)
    output = model(data)
    # Final result will be average of averages of the same size
    val_loss = loss_func(output, target).item()
    ppe.reporting.report({'val/loss': val_loss})
    
    for eval_name, eval_func in eval_func_dict.items():
        eval_value = eval_func(output, target).item()
        ppe.reporting.report({"val/{}".format(eval_aame): eval_value})

# %%
def set_extensions(
    manager, args, model, device, test_loader, optimizer,
    loss_func, eval_func_dict={}
):
    """set extensions for PPE"""
        
    my_extensions = [
        # # observe, report
        ppe_extensions.observe_lr(optimizer=optimizer),
        # ppe_extensions.ParameterStatistics(model, prefix='model'),
        # ppe_extensions.VariableStatisticsPlot(model),
        ppe_extensions.LogReport(),
        ppe_extensions.PlotReport(['train/loss', 'val/loss'], 'epoch', filename='loss.png'),
        ppe_extensions.PlotReport(['lr',], 'epoch', filename='lr.png'),
        ppe_extensions.PrintReport([
            'epoch', 'iteration', 'lr', 'train/loss', 'val/loss', "elapsed_time"]),
#         ppe_extensions.ProgressBar(update_interval=100),

        # # evaluation
        (
            ppe_extensions.Evaluator(
                test_loader, model,
                eval_func=lambda data, target:
                    eval_for_batch(args, model, device, data, target, loss_func, eval_func_dict),
                progress_bar=True),
            (1, "epoch"),
        ),
        # # save model snapshot.
        (
            ppe_extensions.snapshot(
                target=model, filename="snapshot_epoch_{.updater.epoch}.pth"),
            ppe.training.triggers.MinValueTrigger(key="val/loss", trigger=(1, 'epoch'))
        ),
    ]
           
    # # set extensions to manager
    for ext in my_extensions:
        if isinstance(ext, tuple):
            manager.extend(ext[0], trigger=ext[1])
        else:
            manager.extend(ext)
        
    return manager

# %% [markdown]
# ## Training

# %% [markdown]
# ### prepare data

# %% [markdown]
# #### get wav file path

# %%
tmp_list = []
for audio_d in TRAIN_RESAMPLED_AUDIO_DIRS:
    if not audio_d.exists():
        continue
    for ebird_d in audio_d.iterdir():
        if ebird_d.is_file():
            continue
        for wav_f in ebird_d.iterdir():
            tmp_list.append([ebird_d.name, wav_f.name, wav_f.as_posix()])
            
train_wav_path_exist = pd.DataFrame(
    tmp_list, columns=["ebird_code", "resampled_filename", "file_path"])

del tmp_list

train_all = pd.merge(
    train, train_wav_path_exist, on=["ebird_code", "resampled_filename"], how="inner")

print(train.shape)
print(train_wav_path_exist.shape)
print(train_all.shape)
# Out:
# (21375, 38)
# (21375, 3)
# (21375, 39)

# %%
train_all.head()
# Out:
#    rating playback_used ebird_code    channels        date          pitch  \
# 0     3.5            no     aldfly    1 (mono)  2013-05-25  Not specified
# 1     4.0            no     aldfly  2 (stereo)  2013-05-27           both
# 2     4.0            no     aldfly  2 (stereo)  2013-05-27           both
# 3     3.5            no     aldfly  2 (stereo)  2013-05-27           both
# 4     4.0            no     aldfly  2 (stereo)  2013-05-27           both
#
#    duration      filename          speed           species number_of_notes  \
# 0        25  XC134874.mp3  Not specified  Alder Flycatcher   Not specified
# 1        36  XC135454.mp3           both  Alder Flycatcher             1-3
# 2        39  XC135455.mp3           both  Alder Flycatcher             1-3
# 3        33  XC135456.mp3           both  Alder Flycatcher             1-3
# 4        36  XC135457.mp3          level  Alder Flycatcher             1-3
#
#                                            title  \
# 0  XC134874 Alder Flycatcher (Empidonax alnorum)
# 1  XC135454 Alder Flycatcher (Empidonax alnorum)
# 2  XC135455 Alder Flycatcher (Empidonax alnorum)
# 3  XC135456 Alder Flycatcher (Empidonax alnorum)
# 4  XC135457 Alder Flycatcher (Empidonax alnorum)
#
#                                     secondary_labels bird_seen  \
# 0  ['Empidonax minimus_Least Flycatcher', 'Leioth...       yes
# 1                                                 []       yes
# 2                                                 []       yes
# 3  ['Dumetella carolinensis_Gray Catbird', 'Bomby...       yes
# 4                                                 []       yes
#
#             sci_name                                           location  \
# 0  Empidonax alnorum        Grey Cloud Dunes SNA, Washington, Minnesota
# 1  Empidonax alnorum   Carver's Gap Parking area, Roan Mountain Stat...
# 2  Empidonax alnorum   Carver's Gap Parking area, Roan Mountain Stat...
# 3  Empidonax alnorum   Carver's Gap Parking area, Roan Mountain Stat...
# 4  Empidonax alnorum   Carver's Gap Parking area, Roan Mountain Stat...
#
#   latitude sampling_rate        type elevation  \
# 0   44.793    48000 (Hz)        call     220 m
# 1  36.1065    44100 (Hz)  call, song    1700 m
# 2  36.1065    44100 (Hz)  call, song    1700 m
# 3  36.1065    44100 (Hz)  call, song    1700 m
# 4  36.1065    44100 (Hz)  call, song    1700 m
#
#                                          description bitrate_of_mp3 file_type  \
# 0  Two short segments of fairly quiet *pip* calls...   192000 (bps)       mp3
# 1  At least three birds seen here moving around s...   128000 (bps)       mp3
# 2  At least three birds seen chasing each other a...   128000 (bps)       mp3
# 3  img:http://www.flickr.com/photos/madbirder/888...   128000 (bps)       mp3
# 4  img:http://www.flickr.com/photos/madbirder/888...   128000 (bps)       mp3
#
#           volume                                         background   xc_id  \
# 0  Not specified  American Yellow Warbler (Setophaga aestiva); L...  134874
# 1          level                                                NaN  135454
# 2          level                                                NaN  135455
# 3          level  Grey Catbird (Dumetella carolinensis); Cedar W...  135456
# 4          level                                                NaN  135457
#
#                                  url        country            author  \
# 0  https://www.xeno-canto.org/134874  United States  Jonathon Jongsma
# 1  https://www.xeno-canto.org/135454  United States       Mike Nelson
# 2  https://www.xeno-canto.org/135455  United States       Mike Nelson
# 3  https://www.xeno-canto.org/135456  United States       Mike Nelson
# 4  https://www.xeno-canto.org/135457  United States       Mike Nelson
#
#                         primary_label longitude         length   time  \
# 0  Empidonax alnorum_Alder Flycatcher   -92.962  Not specified   8:00
# 1  Empidonax alnorum_Alder Flycatcher  -82.1106         0-3(s)  08:30
# 2  Empidonax alnorum_Alder Flycatcher  -82.1106         0-3(s)  08:30
# 3  Empidonax alnorum_Alder Flycatcher  -82.1106         0-3(s)  08:30
# 4  Empidonax alnorum_Alder Flycatcher  -82.1106         0-3(s)  08:30
#
#           recordist                                            license  \
# 0  Jonathon Jongsma        Creative Commons Attribution-ShareAlike 3.0
# 1       Mike Nelson  Creative Commons Attribution-NonCommercial-Sha...
# 2       Mike Nelson  Creative Commons Attribution-NonCommercial-Sha...
# 3       Mike Nelson  Creative Commons Attribution-NonCommercial-Sha...
# 4       Mike Nelson  Creative Commons Attribution-NonCommercial-Sha...
#
#    resampled_sampling_rate resampled_filename resampled_channels  \
# 0                    32000       XC134874.wav           1 (mono)
# 1                    32000       XC135454.wav           1 (mono)
# 2                    32000       XC135455.wav           1 (mono)
# 3                    32000       XC135456.wav           1 (mono)
# 4                    32000       XC135457.wav           1 (mono)
#
#                                            file_path
# 0  /kaggle/input/birdsong-resampled-train-audio-0...
# 1  /kaggle/input/birdsong-resampled-train-audio-0...
# 2  /kaggle/input/birdsong-resampled-train-audio-0...
# 3  /kaggle/input/birdsong-resampled-train-audio-0...
# 4  /kaggle/input/birdsong-resampled-train-audio-0...

# %% [markdown]
# #### split data

# %%
# # for test run
# test_run_idx = sorted(np.random.choice(len(train_all), len(train_all) // 10, replace=False))
# train_all = train_all.iloc[test_run_idx, :].reset_index(drop=True)
# settings["globals"]["num_epochs"] = 20
# settings["scheduler"]["params"]["T_max"] = 4

# %%
skf = StratifiedKFold(**settings["split"]["params"])

train_all["fold"] = -1
for fold_id, (train_index, val_index) in enumerate(skf.split(train_all, train_all["ebird_code"])):
    train_all.iloc[val_index, -1] = fold_id
    
# # check the propotion
fold_proportion = pd.pivot_table(train_all, index="ebird_code", columns="fold", values="xc_id", aggfunc=len)
print(fold_proportion.shape)
# Out:
# (264, 5)

# %%
fold_proportion
# Out:
# fold         0   1   2   3   4
# ebird_code
# aldfly      20  20  20  20  20
# ameavo       8   8   8   7   7
# amebit       9   9   8   9   9
# amecro      20  20  20  20  20
# amegfi      20  20  20  20  20
# amekes      15  15  15  15  15
# amepip      20  20  20  20  20
# amered      20  20  20  20  20
# amerob      20  20  20  20  20
# amewig       6   6   7   7   7
# amewoo      17  17  17  16  16
# amtspa      15  15  14  15  15
# annhum      20  20  20  20  20
# astfly      20  20  20  20  20
# baisan      11  11  11  11  11
# baleag       7   7   7   7   7
# balori      20  20  20  20  20
# banswa      20  20  20  20  20
# barswa      20  20  20  20  20
# bawwar      15  14  15  15  15
# belkin1     13  14  14  14  14
# belspa2     16  15  15  15  15
# bewwre      20  20  20  20  20
# bkbcuc       9  10  10  10   9
# bkbmag1     12  12  12  12  12
# bkbwar      20  20  20  20  20
# bkcchi      20  20  20  20  20
# bkchum      14  14  13  13  14
# bkhgro      20  20  20  20  20
# bkpwar      20  20  20  20  20
# bktspa      19  18  19  19  19
# blkpho      20  20  20  20  20
# blugrb1     20  20  20  20  20
# blujay      20  20  20  20  20
# bnhcow      20  20  20  20  20
# boboli      20  20  20  20  20
# bongul       8   8   8   8   8
# brdowl      20  20  20  20  20
# brebla       9  10  10  10  10
# brespa      20  20  20  20  20
# brncre      20  20  20  20  20
# brnthr      20  20  20  20  20
# brthum      20  20  20  20  19
# brwhaw      15  15  15  14  15
# btbwar      15  15  15  15  15
# btnwar      20  20  20  20  20
# btywar      19  19  19  20  19
# buffle       3   3   3   3   3
# buggna      20  20  20  20  20
# buhvir      20  20  20  20  20
# bulori      20  20  20  20  20
# bushti      20  20  20  20  20
# buwtea      11  11  10  10  11
# buwwar      19  19  20  20  19
# cacwre      20  20  20  20  20
# calgul       8   8   8   8   8
# calqua      18  18  18  18  18
# camwar      15  15  15  15  16
# cangoo      20  20  20  20  20
# canwar      20  20  20  20  20
# canwre      20  20  20  20  20
# carwre      20  20  20  20  20
# casfin      16  15  15  15  15
# caster1     20  20  20  20  20
# casvir      18  18  18  18  18
# cedwax      17  18  18  18  18
# chispa      20  20  20  20  20
# chiswi       6   6   6   6   5
# chswar      20  20  20  20  20
# chukar       6   6   6   6   6
# clanut      16  16  16  15  16
# cliswa      13  13  13  13  13
# comgol      17  17  17  18  18
# comgra      20  20  20  20  20
# comloo      14  13  13  13  13
# commer      16  17  17  16  16
# comnig      17  17  17  18  17
# comrav      20  20  20  20  20
# comred      20  20  20  20  20
# comter      20  20  20  20  20
# comyel      20  20  20  20  20
# coohaw      18  18  18  18  18
# coshum       4   4   4   3   4
# cowscj1     14  14  13  14  14
# daejun      20  20  20  20  20
# doccor       7   6   7   7   7
# dowwoo      20  20  20  20  20
# dusfly      19  20  20  20  19
# eargre       8   7   7   7   8
# easblu      19  20  19  19  19
# easkin      16  16  17  17  16
# easmea      20  20  20  20  20
# easpho      18  18  18  18  19
# eastow      20  20  20  20  20
# eawpew      20  20  20  20  20
# eucdov      20  20  20  20  20
# eursta       8   8   8   8   8
# evegro      20  20  20  20  20
# fiespa      20  20  20  20  20
# fiscro      18  18  17  17  17
# foxspa      20  20  20  20  20
# gadwal      20  20  20  20  20
# gcrfin       6   6   7   6   6
# gnttow      20  20  20  20  20
# gnwtea      20  20  20  20  20
# gockin      20  20  20  20  20
# gocspa      14  14  14  14  14
# goleag      10  10  10  10  10
# grbher3     14  14  14  15  15
# grcfly      20  20  20  20  20
# greegr      20  20  20  20  20
# greroa      18  18  18  18  18
# greyel      20  20  20  20  20
# grhowl      20  20  20  20  20
# grnher      14  13  13  13  13
# grtgra      20  20  20  20  20
# grycat      16  17  17  16  16
# gryfly      16  16  16  17  16
# haiwoo      20  20  20  20  20
# hamfly      20  20  20  20  20
# hergul      20  20  20  20  20
# herthr      20  20  20  20  20
# hoomer       4   4   4   3   4
# hoowar      20  20  20  20  20
# horgre      13  13  13  14  14
# horlar      20  20  20  20  20
# houfin      20  20  20  20  20
# houspa      20  20  20  20  20
# houwre      20  20  20  20  20
# indbun      20  20  20  20  20
# juntit1     14  14  14  14  13
# killde      20  20  20  20  20
# labwoo      17  17  17  17  17
# larspa      19  19  19  19  19
# lazbun      20  19  19  19  20
# leabit      18  19  18  18  18
# leafly      19  19  19  19  19
# leasan      15  14  15  15  15
# lecthr       4   4   4   4   4
# lesgol      20  20  20  20  20
# lesnig       8   9   9   8   8
# lesyel      20  20  20  20  20
# lewwoo       6   5   5   6   6
# linspa      20  20  20  20  20
# lobcur      13  14  13  13  13
# lobdow      15  15  15  15  15
# logshr      20  20  20  20  20
# lotduc      12  12  12  12  12
# louwat      20  20  20  20  20
# macwar      20  20  20  20  20
# magwar      20  20  20  20  20
# mallar3     20  20  20  20  20
# marwre      20  20  20  20  20
# merlin      11  11  12  12  11
# moublu       6   6   6   6   6
# mouchi      20  20  20  20  20
# moudov      20  20  20  20  20
# norcar      20  20  20  20  20
# norfli      20  20  20  20  20
# norhar2      6   6   6   5   6
# normoc      20  20  20  20  20
# norpar      20  20  20  20  20
# norpin       8   8   7   8   8
# norsho      13  13  13  13  13
# norwat      20  20  20  20  20
# nrwswa       6   6   6   6   6
# nutwoo       9   8   9   9   9
# olsfly      20  20  20  20  20
# orcwar      20  20  20  20  20
# osprey      20  20  20  20  20
# ovenbi1     20  20  20  20  20
# palwar       9  10   9   9   9
# pasfly      20  20  20  20  20
# pecsan      13  13  14  13  13
# perfal      20  20  20  20  20
# phaino      12  12  12  12  12
# pibgre      20  20  20  20  20
# pilwoo      20  20  20  20  20
# pingro      19  18  18  19  19
# pinjay      10  11  10  10  10
# pinsis      20  20  20  20  20
# pinwar      20  20  20  20  20
# plsvir      18  18  19  19  18
# prawar      14  14  14  14  14
# purfin      20  20  20  20  20
# pygnut      12  12  12  12  12
# rebmer       6   6   6   5   6
# rebnut      20  20  20  20  20
# rebsap       6   6   6   7   7
# rebwoo      20  20  20  20  20
# redcro      20  20  20  20  20
# redhea       2   2   2   2   1
# reevir1     20  20  20  20  20
# renpha      15  15  15  14  15
# reshaw      15  14  14  15  15
# rethaw      18  19  19  19  18
# rewbla      20  20  20  20  20
# ribgul      13  13  13  13  14
# rinduc       5   5   5   5   5
# robgro      20  20  20  20  20
# rocpig      20  20  20  20  20
# rocwre      16  16  16  15  15
# rthhum       6   6   6   7   6
# ruckin      20  20  20  20  20
# rudduc       5   5   4   4   5
# rufgro       5   4   5   5   5
# rufhum      11  12  12  12  12
# rusbla      12  12  11  11  11
# sagspa1      6   6   6   6   6
# sagthr       7   7   7   7   7
# savspa      20  20  20  20  20
# saypho      11  11  11  11  11
# scatan      19  18  19  19  19
# scoori      20  20  20  20  20
# semplo      12  13  13  13  13
# semsan      14  14  14  14  14
# sheowl      12  12  11  11  11
# shshaw       4   4   5   5   4
# snobun      20  20  20  20  20
# snogoo      16  15  15  15  16
# solsan      18  19  19  19  19
# sonspa      20  20  20  20  20
# sora        20  20  20  20  20
# sposan      19  19  19  18  18
# spotow      20  20  20  20  20
# stejay      20  20  20  20  20
# swahaw       5   5   5   6   5
# swaspa      20  20  20  20  20
# swathr      20  20  20  20  20
# treswa      17  17  17  17  17
# truswa       8   8   7   7   8
# tuftit      20  20  20  20  20
# tunswa      13  12  13  13  13
# veery       20  20  20  20  20
# vesspa      20  20  20  20  20
# vigswa      10  11  11  10  10
# warvir      20  20  20  20  20
# wesblu       7   7   7   7   7
# wesgre       8   7   7   8   8
# weskin      16  17  17  17  16
# wesmea      20  20  20  20  20
# wessan       6   6   6   6   6
# westan      20  20  20  20  20
# wewpew      20  20  20  20  20
# whbnut      20  20  20  20  20
# whcspa      20  20  20  20  20
# whfibi       7   7   6   6   7
# whtspa      20  20  20  20  20
# whtswi       7   7   8   7   7
# wilfly      20  20  20  20  20
# wilsni1     20  20  20  20  20
# wiltur       9   9   9  10   9
# winwre3     20  20  20  20  20
# wlswar      20  20  20  20  20
# wooduc       8   8   8   8   8
# wooscj2     18  18  18  17  18
# woothr      20  20  20  20  20
# y00475      20  20  20  20  20
# yebfly      20  20  20  20  20
# yebsap      13  12  12  13  13
# yehbla      11  12  12  11  11
# yelwar      18  18  17  18  18
# yerwar      20  20  20  20  20
# yetvir      19  19  20  20  20

# %%
use_fold = settings["globals"]["use_fold"]
train_file_list = train_all.query("fold != @use_fold")[["file_path", "ebird_code"]].values.tolist()
val_file_list = train_all.query("fold == @use_fold")[["file_path", "ebird_code"]].values.tolist()

print("[fold {}] train: {}, val: {}".format(use_fold, len(train_file_list), len(val_file_list)))
# Out:
# [fold 0] train: 17100, val: 4275

# %% [markdown]
# ## run training

# %%
set_seed(settings["globals"]["seed"])
device = torch.device(settings["globals"]["device"])
output_dir = Path(settings["globals"]["output_dir"])

# # # get loader
train_loader, val_loader = get_loaders_for_training(
    settings["dataset"]["params"], settings["loader"], train_file_list, val_file_list)

# # # get model
model = get_model(settings["model"])
model = model.to(device)

# # # get optimizer
optimizer = getattr(
    torch.optim, settings["optimizer"]["name"]
)(model.parameters(), **settings["optimizer"]["params"])

# # # get scheduler
scheduler = getattr(
    torch.optim.lr_scheduler, settings["scheduler"]["name"]
)(optimizer, **settings["scheduler"]["params"])

# # # get loss
loss_func = getattr(nn, settings["loss"]["name"])(**settings["loss"]["params"])

# # # create training manager
trigger = None

manager = ppe.training.ExtensionsManager(
    model, optimizer, settings["globals"]["num_epochs"],
    iters_per_epoch=len(train_loader),
    stop_trigger=trigger,
    out_dir=output_dir
)

# # # set manager extensions
manager = set_extensions(
    manager, settings, model, device,
    val_loader, optimizer, loss_func,
)

# %%
# # runtraining
train_loop(
    manager, settings, model, device,
    train_loader, optimizer, scheduler, loss_func)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=534.0), HTML(value='')))
# epoch       iteration   lr          train/loss  val/loss    elapsed_time
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [..................................................]  1.11%
#          1 iterations
#     9.5433 iters/sec. Estimated time to finish: 0:00:09.325883.
# validation [#.................................................]  2.22%
#          2 iterations
#    0.91161 iters/sec. Estimated time to finish: 0:01:36.532129.
# validation [#.................................................]  3.33%
#          3 iterations
#     1.2987 iters/sec. Estimated time to finish: 0:01:06.991222.
# validation [##................................................]  4.44%
#          4 iterations
#    0.88189 iters/sec. Estimated time to finish: 0:01:37.517967.
# validation [##................................................]  5.56%
#          5 iterations
#      1.072 iters/sec. Estimated time to finish: 0:01:19.287729.
# validation [###...............................................]  6.67%
#          6 iterations
#    0.91028 iters/sec. Estimated time to finish: 0:01:32.279776.
# validation [###...............................................]  7.78%
#          7 iterations
#     1.0456 iters/sec. Estimated time to finish: 0:01:19.383455.
# validation [####..............................................]  8.89%
#          8 iterations
#    0.93926 iters/sec. Estimated time to finish: 0:01:27.303138.
# validation [#####.............................................] 10.00%
#          9 iterations
#     1.0433 iters/sec. Estimated time to finish: 0:01:17.641325.
# validation [#####.............................................] 11.11%
#         10 iterations
#    0.96102 iters/sec. Estimated time to finish: 0:01:23.244698.
# validation [######............................................] 12.22%
#         11 iterations
#     1.0463 iters/sec. Estimated time to finish: 0:01:15.503169.
# validation [######............................................] 13.33%
#         12 iterations
#    0.96001 iters/sec. Estimated time to finish: 0:01:21.248866.
# validation [#######...........................................] 14.44%
#         13 iterations
#     1.0313 iters/sec. Estimated time to finish: 0:01:14.659450.
# validation [#######...........................................] 15.56%
#         14 iterations
#    0.92395 iters/sec. Estimated time to finish: 0:01:22.255944.
# validation [########..........................................] 16.67%
#         15 iterations
#    0.98139 iters/sec. Estimated time to finish: 0:01:16.421864.
# validation [########..........................................] 17.78%
#         16 iterations
#    0.90117 iters/sec. Estimated time to finish: 0:01:22.115506.
# validation [#########.........................................] 18.89%
#         17 iterations
#    0.95189 iters/sec. Estimated time to finish: 0:01:16.689904.
# validation [##########........................................] 20.00%
#         18 iterations
#    0.91903 iters/sec. Estimated time to finish: 0:01:18.343796.
# validation [##########........................................] 21.11%
#         19 iterations
#    0.96489 iters/sec. Estimated time to finish: 0:01:13.583298.
# validation [###########.......................................] 22.22%
#         20 iterations
#    0.92514 iters/sec. Estimated time to finish: 0:01:15.664208.
# validation [###########.......................................] 23.33%
#         21 iterations
#    0.96623 iters/sec. Estimated time to finish: 0:01:11.411439.
# validation [############......................................] 24.44%
#         22 iterations
#    0.92595 iters/sec. Estimated time to finish: 0:01:13.438235.
# validation [############......................................] 25.56%
#         23 iterations
#    0.96324 iters/sec. Estimated time to finish: 0:01:09.556892.
# validation [#############.....................................] 26.67%
#         24 iterations
#    0.87899 iters/sec. Estimated time to finish: 0:01:15.085917.
# validation [#############.....................................] 27.78%
#         25 iterations
#    0.91134 iters/sec. Estimated time to finish: 0:01:11.323194.
# validation [##############....................................] 28.89%
#         26 iterations
#    0.86429 iters/sec. Estimated time to finish: 0:01:14.049312.
# validation [###############...................................] 30.00%
#         27 iterations
#    0.89407 iters/sec. Estimated time to finish: 0:01:10.464128.
# validation [###############...................................] 31.11%
#         28 iterations
#    0.87136 iters/sec. Estimated time to finish: 0:01:11.153042.
# validation [################..................................] 32.22%
#         29 iterations
#    0.89948 iters/sec. Estimated time to finish: 0:01:07.816640.
# validation [################..................................] 33.33%
#         30 iterations
#    0.87325 iters/sec. Estimated time to finish: 0:01:08.708809.
# validation [#################.................................] 34.44%
#         31 iterations
#    0.89957 iters/sec. Estimated time to finish: 0:01:05.587079.
# validation [#################.................................] 35.56%
#         32 iterations
#    0.87133 iters/sec. Estimated time to finish: 0:01:06.564939.
# validation [##################................................] 36.67%
#         33 iterations
#    0.89535 iters/sec. Estimated time to finish: 0:01:03.662157.
# validation [##################................................] 37.78%
#         34 iterations
#     0.8771 iters/sec. Estimated time to finish: 0:01:03.846989.
# validation [###################...............................] 38.89%
#         35 iterations
#    0.90032 iters/sec. Estimated time to finish: 0:01:01.089349.
# validation [####################..............................] 40.00%
#         36 iterations
#    0.88156 iters/sec. Estimated time to finish: 0:01:01.254788.
# validation [####################..............................] 41.11%
#         37 iterations
#    0.90334 iters/sec. Estimated time to finish: 0:00:58.671236.
# validation [#####################.............................] 42.22%
#         38 iterations
#    0.87857 iters/sec. Estimated time to finish: 0:00:59.187059.
# validation [#####################.............................] 43.33%
#         39 iterations
#    0.89938 iters/sec. Estimated time to finish: 0:00:56.705480.
# validation [######################............................] 44.44%
#         40 iterations
#    0.88274 iters/sec. Estimated time to finish: 0:00:56.641881.
# validation [######################............................] 45.56%
#         41 iterations
#     0.9026 iters/sec. Estimated time to finish: 0:00:54.287722.
# validation [#######################...........................] 46.67%
#         42 iterations
#     0.8745 iters/sec. Estimated time to finish: 0:00:54.888786.
# validation [#######################...........................] 47.78%
#         43 iterations
#    0.89332 iters/sec. Estimated time to finish: 0:00:52.612618.
# validation [########################..........................] 48.89%
#         44 iterations
#    0.88089 iters/sec. Estimated time to finish: 0:00:52.219787.
# validation [#########################.........................] 50.00%
#         45 iterations
#    0.89909 iters/sec. Estimated time to finish: 0:00:50.050803.
# validation [#########################.........................] 51.11%
#         46 iterations
#    0.88734 iters/sec. Estimated time to finish: 0:00:49.586642.
# validation [##########################........................] 52.22%
#         47 iterations
#    0.90458 iters/sec. Estimated time to finish: 0:00:47.535994.
# validation [##########################........................] 53.33%
#         48 iterations
#    0.89145 iters/sec. Estimated time to finish: 0:00:47.114146.
# validation [###########################.......................] 54.44%
#         49 iterations
#    0.90816 iters/sec. Estimated time to finish: 0:00:45.146207.
# validation [###########################.......................] 55.56%
#         50 iterations
#    0.89381 iters/sec. Estimated time to finish: 0:00:44.752265.
# validation [############################......................] 56.67%
#         51 iterations
#    0.90979 iters/sec. Estimated time to finish: 0:00:42.867218.
# validation [############################......................] 57.78%
#         52 iterations
#    0.88644 iters/sec. Estimated time to finish: 0:00:42.868176.
# validation [#############################.....................] 58.89%
#         53 iterations
#    0.90183 iters/sec. Estimated time to finish: 0:00:41.027642.
# validation [##############################....................] 60.00%
#         54 iterations
#    0.89128 iters/sec. Estimated time to finish: 0:00:40.391420.
# validation [##############################....................] 61.11%
#         55 iterations
#    0.90556 iters/sec. Estimated time to finish: 0:00:38.650207.
# validation [###############################...................] 62.22%
#         56 iterations
#     0.8905 iters/sec. Estimated time to finish: 0:00:38.180705.
# validation [###############################...................] 63.33%
#         57 iterations
#    0.90492 iters/sec. Estimated time to finish: 0:00:36.467336.
# validation [################################..................] 64.44%
#         58 iterations
#    0.89502 iters/sec. Estimated time to finish: 0:00:35.753485.
# validation [################################..................] 65.56%
#         59 iterations
#    0.90892 iters/sec. Estimated time to finish: 0:00:34.106403.
# validation [#################################.................] 66.67%
#         60 iterations
#    0.89998 iters/sec. Estimated time to finish: 0:00:33.334152.
# validation [#################################.................] 67.78%
#         61 iterations
#     0.9135 iters/sec. Estimated time to finish: 0:00:31.745970.
# validation [##################################................] 68.89%
#         62 iterations
#    0.90122 iters/sec. Estimated time to finish: 0:00:31.068875.
# validation [###################################...............] 70.00%
#         63 iterations
#    0.91414 iters/sec. Estimated time to finish: 0:00:29.536041.
# validation [###################################...............] 71.11%
#         64 iterations
#    0.90384 iters/sec. Estimated time to finish: 0:00:28.766102.
# validation [####################################..............] 72.22%
#         65 iterations
#    0.91648 iters/sec. Estimated time to finish: 0:00:27.278344.
# validation [####################################..............] 73.33%
#         66 iterations
#     0.9073 iters/sec. Estimated time to finish: 0:00:26.452008.
# validation [#####################################.............] 74.44%
#         67 iterations
#    0.91967 iters/sec. Estimated time to finish: 0:00:25.008955.
# validation [#####################################.............] 75.56%
#         68 iterations
#    0.91007 iters/sec. Estimated time to finish: 0:00:24.173998.
# validation [######################################............] 76.67%
#         69 iterations
#    0.92219 iters/sec. Estimated time to finish: 0:00:22.771963.
# validation [######################################............] 77.78%
#         70 iterations
#    0.91266 iters/sec. Estimated time to finish: 0:00:21.914065.
# validation [#######################################...........] 78.89%
#         71 iterations
#    0.92435 iters/sec. Estimated time to finish: 0:00:20.554905.
# validation [########################################..........] 80.00%
#         72 iterations
#    0.91307 iters/sec. Estimated time to finish: 0:00:19.713681.
# validation [########################################..........] 81.11%
#         73 iterations
#    0.92438 iters/sec. Estimated time to finish: 0:00:18.390669.
# validation [#########################################.........] 82.22%
#         74 iterations
#    0.91273 iters/sec. Estimated time to finish: 0:00:17.529877.
# validation [#########################################.........] 83.33%
#         75 iterations
#    0.92377 iters/sec. Estimated time to finish: 0:00:16.237831.
# validation [##########################################........] 84.44%
#         76 iterations
#    0.90874 iters/sec. Estimated time to finish: 0:00:15.405961.
# validation [##########################################........] 85.56%
#         77 iterations
#    0.91949 iters/sec. Estimated time to finish: 0:00:14.138327.
# validation [###########################################.......] 86.67%
#         78 iterations
#    0.90224 iters/sec. Estimated time to finish: 0:00:13.300192.
# validation [###########################################.......] 87.78%
#         79 iterations
#    0.91274 iters/sec. Estimated time to finish: 0:00:12.051578.
# validation [############################################......] 88.89%
#         80 iterations
#    0.88176 iters/sec. Estimated time to finish: 0:00:11.340904.
# validation [#############################################.....] 90.00%
#         81 iterations
#     0.8916 iters/sec. Estimated time to finish: 0:00:10.094256.
# validation [#############################################.....] 91.11%
#         82 iterations
#    0.88044 iters/sec. Estimated time to finish: 0:00:09.086396.
# validation [##############################################....] 92.22%
#         83 iterations
#    0.89016 iters/sec. Estimated time to finish: 0:00:07.863719.
# validation [##############################################....] 93.33%
#         84 iterations
#    0.87991 iters/sec. Estimated time to finish: 0:00:06.818907.
# validation [###############################################...] 94.44%
#         85 iterations
#    0.88941 iters/sec. Estimated time to finish: 0:00:05.621675.
# validation [###############################################...] 95.56%
#         86 iterations
#    0.88763 iters/sec. Estimated time to finish: 0:00:04.506369.
# validation [################################################..] 96.67%
#         87 iterations
#    0.89697 iters/sec. Estimated time to finish: 0:00:03.344576.
# validation [################################################..] 97.78%
#         88 iterations
#    0.89432 iters/sec. Estimated time to finish: 0:00:02.236348.
# validation [#################################################.] 98.89%
#         89 iterations
#    0.90424 iters/sec. Estimated time to finish: 0:00:01.105901.
# 1           534         0.000345492  0.036053    0.0253217   539.856
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=534.0), HTML(value='')))
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [..................................................]  1.11%
#          1 iterations
#     8.8394 iters/sec. Estimated time to finish: 0:00:10.068515.
# validation [#.................................................]  2.22%
#          2 iterations
#    0.83369 iters/sec. Estimated time to finish: 0:01:45.554339.
# validation [#.................................................]  3.33%
#          3 iterations
#     1.1982 iters/sec. Estimated time to finish: 0:01:12.607805.
# validation [##................................................]  4.44%
#          4 iterations
#    0.85978 iters/sec. Estimated time to finish: 0:01:40.025811.
# validation [##................................................]  5.56%
#          5 iterations
#     1.0491 iters/sec. Estimated time to finish: 0:01:21.019873.
# validation [###...............................................]  6.67%
#          6 iterations
#    0.89011 iters/sec. Estimated time to finish: 0:01:34.370651.
# validation [###...............................................]  7.78%
#          7 iterations
#     1.0047 iters/sec. Estimated time to finish: 0:01:22.610215.
# validation [####..............................................]  8.89%
#          8 iterations
#    0.91387 iters/sec. Estimated time to finish: 0:01:29.728788.
# validation [#####.............................................] 10.00%
#          9 iterations
#    0.99399 iters/sec. Estimated time to finish: 0:01:21.489799.
# validation [#####.............................................] 11.11%
#         10 iterations
#    0.92644 iters/sec. Estimated time to finish: 0:01:26.351812.
# validation [######............................................] 12.22%
#         11 iterations
#     1.0043 iters/sec. Estimated time to finish: 0:01:18.663188.
# validation [######............................................] 13.33%
#         12 iterations
#    0.91132 iters/sec. Estimated time to finish: 0:01:25.589798.
# validation [#######...........................................] 14.44%
#         13 iterations
#    0.96948 iters/sec. Estimated time to finish: 0:01:19.423942.
# validation [#######...........................................] 15.56%
#         14 iterations
#    0.90748 iters/sec. Estimated time to finish: 0:01:23.747955.
# validation [########..........................................] 16.67%
#         15 iterations
#    0.96555 iters/sec. Estimated time to finish: 0:01:17.675993.
# validation [########..........................................] 17.78%
#         16 iterations
#    0.89148 iters/sec. Estimated time to finish: 0:01:23.008178.
# validation [#########.........................................] 18.89%
#         17 iterations
#    0.94154 iters/sec. Estimated time to finish: 0:01:17.532162.
# validation [##########........................................] 20.00%
#         18 iterations
#    0.91091 iters/sec. Estimated time to finish: 0:01:19.041967.
# validation [##########........................................] 21.11%
#         19 iterations
#    0.95618 iters/sec. Estimated time to finish: 0:01:14.253757.
# validation [###########.......................................] 22.22%
#         20 iterations
#     0.9189 iters/sec. Estimated time to finish: 0:01:16.178428.
# validation [###########.......................................] 23.33%
#         21 iterations
#    0.96018 iters/sec. Estimated time to finish: 0:01:11.861212.
# validation [############......................................] 24.44%
#         22 iterations
#    0.90079 iters/sec. Estimated time to finish: 0:01:15.489366.
# validation [############......................................] 25.56%
#         23 iterations
#    0.93769 iters/sec. Estimated time to finish: 0:01:11.452140.
# validation [#############.....................................] 26.67%
#         24 iterations
#    0.86547 iters/sec. Estimated time to finish: 0:01:16.259135.
# validation [#############.....................................] 27.78%
#         25 iterations
#    0.89723 iters/sec. Estimated time to finish: 0:01:12.445470.
# validation [##############....................................] 28.89%
#         26 iterations
#    0.84278 iters/sec. Estimated time to finish: 0:01:15.939089.
# validation [###############...................................] 30.00%
#         27 iterations
#    0.87176 iters/sec. Estimated time to finish: 0:01:12.267556.
# validation [###############...................................] 31.11%
#         28 iterations
#    0.85251 iters/sec. Estimated time to finish: 0:01:12.726574.
# validation [################..................................] 32.22%
#         29 iterations
#    0.87957 iters/sec. Estimated time to finish: 0:01:09.351864.
# validation [################..................................] 33.33%
#         30 iterations
#    0.84743 iters/sec. Estimated time to finish: 0:01:10.802152.
# validation [#################.................................] 34.44%
#         31 iterations
#    0.87307 iters/sec. Estimated time to finish: 0:01:07.577893.
# validation [#################.................................] 35.56%
#         32 iterations
#     0.8564 iters/sec. Estimated time to finish: 0:01:07.725188.
# validation [##################................................] 36.67%
#         33 iterations
#    0.88054 iters/sec. Estimated time to finish: 0:01:04.732938.
# validation [##################................................] 37.78%
#         34 iterations
#    0.86098 iters/sec. Estimated time to finish: 0:01:05.042285.
# validation [###################...............................] 38.89%
#         35 iterations
#    0.88375 iters/sec. Estimated time to finish: 0:01:02.234600.
# validation [####################..............................] 40.00%
#         36 iterations
#    0.86854 iters/sec. Estimated time to finish: 0:01:02.173189.
# validation [####################..............................] 41.11%
#         37 iterations
#    0.89024 iters/sec. Estimated time to finish: 0:00:59.534464.
# validation [#####################.............................] 42.22%
#         38 iterations
#    0.86744 iters/sec. Estimated time to finish: 0:00:59.946845.
# validation [#####################.............................] 43.33%
#         39 iterations
#    0.88794 iters/sec. Estimated time to finish: 0:00:57.436173.
# validation [######################............................] 44.44%
#         40 iterations
#    0.86367 iters/sec. Estimated time to finish: 0:00:57.892611.
# validation [######################............................] 45.56%
#         41 iterations
#    0.88321 iters/sec. Estimated time to finish: 0:00:55.479728.
# validation [#######################...........................] 46.67%
#         42 iterations
#    0.86504 iters/sec. Estimated time to finish: 0:00:55.488587.
# validation [#######################...........................] 47.78%
#         43 iterations
#    0.88363 iters/sec. Estimated time to finish: 0:00:53.189866.
# validation [########################..........................] 48.89%
#         44 iterations
#    0.87223 iters/sec. Estimated time to finish: 0:00:52.738095.
# validation [#########################.........................] 50.00%
#         45 iterations
#    0.88998 iters/sec. Estimated time to finish: 0:00:50.562926.
# validation [#########################.........................] 51.11%
#         46 iterations
#    0.87971 iters/sec. Estimated time to finish: 0:00:50.016663.
# validation [##########################........................] 52.22%
#         47 iterations
#    0.89707 iters/sec. Estimated time to finish: 0:00:47.933886.
# validation [##########################........................] 53.33%
#         48 iterations
#    0.88526 iters/sec. Estimated time to finish: 0:00:47.443499.
# validation [###########################.......................] 54.44%
#         49 iterations
#    0.90199 iters/sec. Estimated time to finish: 0:00:45.455231.
# validation [###########################.......................] 55.56%
#         50 iterations
#    0.88247 iters/sec. Estimated time to finish: 0:00:45.327198.
# validation [############################......................] 56.67%
#         51 iterations
#     0.8985 iters/sec. Estimated time to finish: 0:00:43.405488.
# validation [############################......................] 57.78%
#         52 iterations
#    0.88357 iters/sec. Estimated time to finish: 0:00:43.007276.
# validation [#############################.....................] 58.89%
#         53 iterations
#    0.89889 iters/sec. Estimated time to finish: 0:00:41.161790.
# validation [##############################....................] 60.00%
#         54 iterations
#    0.88447 iters/sec. Estimated time to finish: 0:00:40.702328.
# validation [##############################....................] 61.11%
#         55 iterations
#    0.89916 iters/sec. Estimated time to finish: 0:00:38.925178.
# validation [###############################...................] 62.22%
#         56 iterations
#    0.88431 iters/sec. Estimated time to finish: 0:00:38.448097.
# validation [###############################...................] 63.33%
#         57 iterations
#    0.89858 iters/sec. Estimated time to finish: 0:00:36.724628.
# validation [################################..................] 64.44%
#         58 iterations
#    0.89009 iters/sec. Estimated time to finish: 0:00:35.951493.
# validation [################################..................] 65.56%
#         59 iterations
#    0.90366 iters/sec. Estimated time to finish: 0:00:34.305009.
# validation [#################################.................] 66.67%
#         60 iterations
#    0.89319 iters/sec. Estimated time to finish: 0:00:33.587654.
# validation [#################################.................] 67.78%
#         61 iterations
#     0.9065 iters/sec. Estimated time to finish: 0:00:31.991161.
# validation [##################################................] 68.89%
#         62 iterations
#    0.89516 iters/sec. Estimated time to finish: 0:00:31.279236.
# validation [###################################...............] 70.00%
#         63 iterations
#    0.90821 iters/sec. Estimated time to finish: 0:00:29.728934.
# validation [###################################...............] 71.11%
#         64 iterations
#    0.89994 iters/sec. Estimated time to finish: 0:00:28.890811.
# validation [####################################..............] 72.22%
#         65 iterations
#    0.91257 iters/sec. Estimated time to finish: 0:00:27.395209.
# validation [####################################..............] 73.33%
#         66 iterations
#    0.90313 iters/sec. Estimated time to finish: 0:00:26.574302.
# validation [#####################################.............] 74.44%
#         67 iterations
#    0.91524 iters/sec. Estimated time to finish: 0:00:25.130068.
# validation [#####################################.............] 75.56%
#         68 iterations
#    0.90717 iters/sec. Estimated time to finish: 0:00:24.251156.
# validation [######################################............] 76.67%
#         69 iterations
#    0.91902 iters/sec. Estimated time to finish: 0:00:22.850457.
# validation [######################################............] 77.78%
#         70 iterations
#    0.91118 iters/sec. Estimated time to finish: 0:00:21.949637.
# validation [#######################################...........] 78.89%
#         71 iterations
#    0.92296 iters/sec. Estimated time to finish: 0:00:20.585829.
# validation [########################################..........] 80.00%
#         72 iterations
#    0.90892 iters/sec. Estimated time to finish: 0:00:19.803701.
# validation [########################################..........] 81.11%
#         73 iterations
#    0.92025 iters/sec. Estimated time to finish: 0:00:18.473341.
# validation [#########################################.........] 82.22%
#         74 iterations
#    0.91309 iters/sec. Estimated time to finish: 0:00:17.522993.
# validation [#########################################.........] 83.33%
#         75 iterations
#    0.92403 iters/sec. Estimated time to finish: 0:00:16.233176.
# validation [##########################################........] 84.44%
#         76 iterations
#    0.91013 iters/sec. Estimated time to finish: 0:00:15.382502.
# validation [##########################################........] 85.56%
#         77 iterations
#    0.92087 iters/sec. Estimated time to finish: 0:00:14.117156.
# validation [###########################################.......] 86.67%
#         78 iterations
#    0.90666 iters/sec. Estimated time to finish: 0:00:13.235360.
# validation [###########################################.......] 87.78%
#         79 iterations
#    0.91702 iters/sec. Estimated time to finish: 0:00:11.995422.
# validation [############################################......] 88.89%
#         80 iterations
#    0.90595 iters/sec. Estimated time to finish: 0:00:11.038149.
# validation [#############################################.....] 90.00%
#         81 iterations
#     0.9161 iters/sec. Estimated time to finish: 0:00:09.824222.
# validation [#############################################.....] 91.11%
#         82 iterations
#    0.90167 iters/sec. Estimated time to finish: 0:00:08.872388.
# validation [##############################################....] 92.22%
#         83 iterations
#    0.91156 iters/sec. Estimated time to finish: 0:00:07.679163.
# validation [##############################################....] 93.33%
#         84 iterations
#    0.90262 iters/sec. Estimated time to finish: 0:00:06.647337.
# validation [###############################################...] 94.44%
#         85 iterations
#    0.91219 iters/sec. Estimated time to finish: 0:00:05.481303.
# validation [###############################################...] 95.56%
#         86 iterations
#    0.90533 iters/sec. Estimated time to finish: 0:00:04.418278.
# validation [################################################..] 96.67%
#         87 iterations
#    0.91485 iters/sec. Estimated time to finish: 0:00:03.279230.
# validation [################################################..] 97.78%
#         88 iterations
#    0.91402 iters/sec. Estimated time to finish: 0:00:02.188145.
# validation [#################################################.] 98.89%
#         89 iterations
#    0.92414 iters/sec. Estimated time to finish: 0:00:01.082082.
# 2           1068        9.54915e-05  0.0241727   0.022113    1078.51
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=534.0), HTML(value='')))
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [..................................................]  1.11%
#          1 iterations
#     9.2614 iters/sec. Estimated time to finish: 0:00:09.609776.
# validation [#.................................................]  2.22%
#          2 iterations
#    0.98676 iters/sec. Estimated time to finish: 0:01:29.180361.
# validation [#.................................................]  3.33%
#          3 iterations
#     1.4036 iters/sec. Estimated time to finish: 0:01:01.983394.
# validation [##................................................]  4.44%
#          4 iterations
#    0.96815 iters/sec. Estimated time to finish: 0:01:28.828993.
# validation [##................................................]  5.56%
#          5 iterations
#     1.1752 iters/sec. Estimated time to finish: 0:01:12.326434.
# validation [###...............................................]  6.67%
#          6 iterations
#    0.93361 iters/sec. Estimated time to finish: 0:01:29.973451.
# validation [###...............................................]  7.78%
#          7 iterations
#     1.0721 iters/sec. Estimated time to finish: 0:01:17.416683.
# validation [####..............................................]  8.89%
#          8 iterations
#    0.97205 iters/sec. Estimated time to finish: 0:01:24.357996.
# validation [#####.............................................] 10.00%
#          9 iterations
#     1.0684 iters/sec. Estimated time to finish: 0:01:15.813919.
# validation [#####.............................................] 11.11%
#         10 iterations
#    0.98835 iters/sec. Estimated time to finish: 0:01:20.942894.
# validation [######............................................] 12.22%
#         11 iterations
#     1.0543 iters/sec. Estimated time to finish: 0:01:14.932067.
# validation [######............................................] 13.33%
#         12 iterations
#    0.99772 iters/sec. Estimated time to finish: 0:01:18.178362.
# validation [#######...........................................] 14.44%
#         13 iterations
#     1.0482 iters/sec. Estimated time to finish: 0:01:13.459303.
# validation [#######...........................................] 15.56%
#         14 iterations
#    0.98118 iters/sec. Estimated time to finish: 0:01:17.457763.
# validation [########..........................................] 16.67%
#         15 iterations
#     1.0432 iters/sec. Estimated time to finish: 0:01:11.891927.
# validation [########..........................................] 17.78%
#         16 iterations
#    0.94004 iters/sec. Estimated time to finish: 0:01:18.720316.
# validation [#########.........................................] 18.89%
#         17 iterations
#    0.99183 iters/sec. Estimated time to finish: 0:01:13.601044.
# validation [##########........................................] 20.00%
#         18 iterations
#      0.957 iters/sec. Estimated time to finish: 0:01:15.235270.
# validation [##########........................................] 21.11%
#         19 iterations
#     1.0047 iters/sec. Estimated time to finish: 0:01:10.667559.
# validation [###########.......................................] 22.22%
#         20 iterations
#    0.96216 iters/sec. Estimated time to finish: 0:01:12.753206.
# validation [###########.......................................] 23.33%
#         21 iterations
#     1.0053 iters/sec. Estimated time to finish: 0:01:08.635937.
# validation [############......................................] 24.44%
#         22 iterations
#    0.96353 iters/sec. Estimated time to finish: 0:01:10.573941.
# validation [############......................................] 25.56%
#         23 iterations
#      1.002 iters/sec. Estimated time to finish: 0:01:06.863238.
# validation [#############.....................................] 26.67%
#         24 iterations
#    0.96035 iters/sec. Estimated time to finish: 0:01:08.725070.
# validation [#############.....................................] 27.78%
#         25 iterations
#    0.99627 iters/sec. Estimated time to finish: 0:01:05.243208.
# validation [##############....................................] 28.89%
#         26 iterations
#    0.92465 iters/sec. Estimated time to finish: 0:01:09.215580.
# validation [###############...................................] 30.00%
#         27 iterations
#    0.95666 iters/sec. Estimated time to finish: 0:01:05.854144.
# validation [###############...................................] 31.11%
#         28 iterations
#    0.93649 iters/sec. Estimated time to finish: 0:01:06.204518.
# validation [################..................................] 32.22%
#         29 iterations
#    0.96619 iters/sec. Estimated time to finish: 0:01:03.134761.
# validation [################..................................] 33.33%
#         30 iterations
#    0.93918 iters/sec. Estimated time to finish: 0:01:03.885288.
# validation [#################.................................] 34.44%
#         31 iterations
#    0.96706 iters/sec. Estimated time to finish: 0:01:01.009504.
# validation [#################.................................] 35.56%
#         32 iterations
#    0.94366 iters/sec. Estimated time to finish: 0:01:01.463029.
# validation [##################................................] 36.67%
#         33 iterations
#    0.96986 iters/sec. Estimated time to finish: 0:00:58.771649.
# validation [##################................................] 37.78%
#         34 iterations
#    0.94944 iters/sec. Estimated time to finish: 0:00:58.982405.
# validation [###################...............................] 38.89%
#         35 iterations
#     0.9745 iters/sec. Estimated time to finish: 0:00:56.439428.
# validation [####################..............................] 40.00%
#         36 iterations
#    0.94425 iters/sec. Estimated time to finish: 0:00:57.188247.
# validation [####################..............................] 41.11%
#         37 iterations
#    0.96748 iters/sec. Estimated time to finish: 0:00:54.781485.
# validation [#####################.............................] 42.22%
#         38 iterations
#    0.93809 iters/sec. Estimated time to finish: 0:00:55.431901.
# validation [#####################.............................] 43.33%
#         39 iterations
#      0.958 iters/sec. Estimated time to finish: 0:00:53.235916.
# validation [######################............................] 44.44%
#         40 iterations
#    0.92936 iters/sec. Estimated time to finish: 0:00:53.800358.
# validation [######################............................] 45.56%
#         41 iterations
#    0.94996 iters/sec. Estimated time to finish: 0:00:51.581080.
# validation [#######################...........................] 46.67%
#         42 iterations
#    0.91757 iters/sec. Estimated time to finish: 0:00:52.312279.
# validation [#######################...........................] 47.78%
#         43 iterations
#    0.93717 iters/sec. Estimated time to finish: 0:00:50.150922.
# validation [########################..........................] 48.89%
#         44 iterations
#    0.92378 iters/sec. Estimated time to finish: 0:00:49.795637.
# validation [#########################.........................] 50.00%
#         45 iterations
#    0.94275 iters/sec. Estimated time to finish: 0:00:47.732898.
# validation [#########################.........................] 51.11%
#         46 iterations
#     0.9231 iters/sec. Estimated time to finish: 0:00:47.665263.
# validation [##########################........................] 52.22%
#         47 iterations
#      0.941 iters/sec. Estimated time to finish: 0:00:45.695942.
# validation [##########################........................] 53.33%
#         48 iterations
#    0.92681 iters/sec. Estimated time to finish: 0:00:45.316827.
# validation [###########################.......................] 54.44%
#         49 iterations
#    0.94419 iters/sec. Estimated time to finish: 0:00:43.423253.
# validation [###########################.......................] 55.56%
#         50 iterations
#    0.92871 iters/sec. Estimated time to finish: 0:00:43.070288.
# validation [############################......................] 56.67%
#         51 iterations
#    0.94548 iters/sec. Estimated time to finish: 0:00:41.248714.
# validation [############################......................] 57.78%
#         52 iterations
#    0.92896 iters/sec. Estimated time to finish: 0:00:40.905763.
# validation [#############################.....................] 58.89%
#         53 iterations
#    0.94483 iters/sec. Estimated time to finish: 0:00:39.160482.
# validation [##############################....................] 60.00%
#         54 iterations
#     0.9323 iters/sec. Estimated time to finish: 0:00:38.613982.
# validation [##############################....................] 61.11%
#         55 iterations
#    0.94784 iters/sec. Estimated time to finish: 0:00:36.925944.
# validation [###############################...................] 62.22%
#         56 iterations
#    0.92344 iters/sec. Estimated time to finish: 0:00:36.818965.
# validation [###############################...................] 63.33%
#         57 iterations
#    0.93798 iters/sec. Estimated time to finish: 0:00:35.182013.
# validation [################################..................] 64.44%
#         58 iterations
#     0.9237 iters/sec. Estimated time to finish: 0:00:34.643132.
# validation [################################..................] 65.56%
#         59 iterations
#    0.93788 iters/sec. Estimated time to finish: 0:00:33.053395.
# validation [#################################.................] 66.67%
#         60 iterations
#    0.92964 iters/sec. Estimated time to finish: 0:00:32.270531.
# validation [#################################.................] 67.78%
#         61 iterations
#    0.94356 iters/sec. Estimated time to finish: 0:00:30.734759.
# validation [##################################................] 68.89%
#         62 iterations
#    0.93321 iters/sec. Estimated time to finish: 0:00:30.003993.
# validation [###################################...............] 70.00%
#         63 iterations
#    0.94671 iters/sec. Estimated time to finish: 0:00:28.519710.
# validation [###################################...............] 71.11%
#         64 iterations
#    0.93733 iters/sec. Estimated time to finish: 0:00:27.738295.
# validation [####################################..............] 72.22%
#         65 iterations
#    0.95043 iters/sec. Estimated time to finish: 0:00:26.303884.
# validation [####################################..............] 73.33%
#         66 iterations
#     0.9406 iters/sec. Estimated time to finish: 0:00:25.515704.
# validation [#####################################.............] 74.44%
#         67 iterations
#    0.95307 iters/sec. Estimated time to finish: 0:00:24.132652.
# validation [#####################################.............] 75.56%
#         68 iterations
#    0.93884 iters/sec. Estimated time to finish: 0:00:23.433162.
# validation [######################################............] 76.67%
#         69 iterations
#    0.95111 iters/sec. Estimated time to finish: 0:00:22.079442.
# validation [######################################............] 77.78%
#         70 iterations
#     0.9411 iters/sec. Estimated time to finish: 0:00:21.251737.
# validation [#######################################...........] 78.89%
#         71 iterations
#    0.95291 iters/sec. Estimated time to finish: 0:00:19.939017.
# validation [########################################..........] 80.00%
#         72 iterations
#    0.94224 iters/sec. Estimated time to finish: 0:00:19.103477.
# validation [########################################..........] 81.11%
#         73 iterations
#      0.954 iters/sec. Estimated time to finish: 0:00:17.819640.
# validation [#########################################.........] 82.22%
#         74 iterations
#    0.94706 iters/sec. Estimated time to finish: 0:00:16.894406.
# validation [#########################################.........] 83.33%
#         75 iterations
#    0.95853 iters/sec. Estimated time to finish: 0:00:15.648965.
# validation [##########################################........] 84.44%
#         76 iterations
#    0.94291 iters/sec. Estimated time to finish: 0:00:14.847667.
# validation [##########################################........] 85.56%
#         77 iterations
#    0.95403 iters/sec. Estimated time to finish: 0:00:13.626459.
# validation [###########################################.......] 86.67%
#         78 iterations
#    0.93711 iters/sec. Estimated time to finish: 0:00:12.805345.
# validation [###########################################.......] 87.78%
#         79 iterations
#    0.94788 iters/sec. Estimated time to finish: 0:00:11.604825.
# validation [############################################......] 88.89%
#         80 iterations
#    0.93688 iters/sec. Estimated time to finish: 0:00:10.673701.
# validation [#############################################.....] 90.00%
#         81 iterations
#    0.94734 iters/sec. Estimated time to finish: 0:00:09.500282.
# validation [#############################################.....] 91.11%
#         82 iterations
#    0.93571 iters/sec. Estimated time to finish: 0:00:08.549672.
# validation [##############################################....] 92.22%
#         83 iterations
#    0.94594 iters/sec. Estimated time to finish: 0:00:07.400008.
# validation [##############################################....] 93.33%
#         84 iterations
#    0.93666 iters/sec. Estimated time to finish: 0:00:06.405713.
# validation [###############################################...] 94.44%
#         85 iterations
#    0.94668 iters/sec. Estimated time to finish: 0:00:05.281631.
# validation [###############################################...] 95.56%
#         86 iterations
#    0.93957 iters/sec. Estimated time to finish: 0:00:04.257250.
# validation [################################################..] 96.67%
#         87 iterations
#    0.94941 iters/sec. Estimated time to finish: 0:00:03.159851.
# validation [################################################..] 97.78%
#         88 iterations
#    0.94538 iters/sec. Estimated time to finish: 0:00:02.115558.
# validation [#################################################.] 98.89%
#         89 iterations
#    0.95585 iters/sec. Estimated time to finish: 0:00:01.046185.
# 3           1602        0.000904508  0.0206139   0.0180304   1599.49
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=534.0), HTML(value='')))
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [..................................................]  1.11%
#          1 iterations
#     9.2622 iters/sec. Estimated time to finish: 0:00:09.608969.
# validation [#.................................................]  2.22%
#          2 iterations
#    0.84827 iters/sec. Estimated time to finish: 0:01:43.740966.
# validation [#.................................................]  3.33%
#          3 iterations
#     1.2165 iters/sec. Estimated time to finish: 0:01:11.515399.
# validation [##................................................]  4.44%
#          4 iterations
#    0.91681 iters/sec. Estimated time to finish: 0:01:33.803519.
# validation [##................................................]  5.56%
#          5 iterations
#     1.1182 iters/sec. Estimated time to finish: 0:01:16.013075.
# validation [###...............................................]  6.67%
#          6 iterations
#     0.9563 iters/sec. Estimated time to finish: 0:01:27.838569.
# validation [###...............................................]  7.78%
#          7 iterations
#     1.0976 iters/sec. Estimated time to finish: 0:01:15.622062.
# validation [####..............................................]  8.89%
#          8 iterations
#    0.98535 iters/sec. Estimated time to finish: 0:01:23.219041.
# validation [#####.............................................] 10.00%
#          9 iterations
#     1.0943 iters/sec. Estimated time to finish: 0:01:14.021090.
# validation [#####.............................................] 11.11%
#         10 iterations
#     1.0017 iters/sec. Estimated time to finish: 0:01:19.860800.
# validation [######............................................] 12.22%
#         11 iterations
#       1.09 iters/sec. Estimated time to finish: 0:01:12.476572.
# validation [######............................................] 13.33%
#         12 iterations
#    0.99621 iters/sec. Estimated time to finish: 0:01:18.296899.
# validation [#######...........................................] 14.44%
#         13 iterations
#     1.0515 iters/sec. Estimated time to finish: 0:01:13.225535.
# validation [#######...........................................] 15.56%
#         14 iterations
#     0.9701 iters/sec. Estimated time to finish: 0:01:18.342554.
# validation [########..........................................] 16.67%
#         15 iterations
#     1.0311 iters/sec. Estimated time to finish: 0:01:12.740545.
# validation [########..........................................] 17.78%
#         16 iterations
#    0.94409 iters/sec. Estimated time to finish: 0:01:18.382480.
# validation [#########.........................................] 18.89%
#         17 iterations
#    0.99678 iters/sec. Estimated time to finish: 0:01:13.235897.
# validation [##########........................................] 20.00%
#         18 iterations
#    0.96053 iters/sec. Estimated time to finish: 0:01:14.958480.
# validation [##########........................................] 21.11%
#         19 iterations
#     1.0084 iters/sec. Estimated time to finish: 0:01:10.411931.
# validation [###########.......................................] 22.22%
#         20 iterations
#    0.96799 iters/sec. Estimated time to finish: 0:01:12.314864.
# validation [###########.......................................] 23.33%
#         21 iterations
#     1.0113 iters/sec. Estimated time to finish: 0:01:08.229493.
# validation [############......................................] 24.44%
#         22 iterations
#    0.96382 iters/sec. Estimated time to finish: 0:01:10.552605.
# validation [############......................................] 25.56%
#         23 iterations
#     1.0022 iters/sec. Estimated time to finish: 0:01:06.856249.
# validation [#############.....................................] 26.67%
#         24 iterations
#    0.94626 iters/sec. Estimated time to finish: 0:01:09.748210.
# validation [#############.....................................] 27.78%
#         25 iterations
#    0.98159 iters/sec. Estimated time to finish: 0:01:06.219252.
# validation [##############....................................] 28.89%
#         26 iterations
#    0.93084 iters/sec. Estimated time to finish: 0:01:08.754796.
# ...
# validation [#############################################.....] 90.00%
#         81 iterations
#     0.9833 iters/sec. Estimated time to finish: 0:00:09.152888.
# validation [#############################################.....] 91.11%
#         82 iterations
#    0.97361 iters/sec. Estimated time to finish: 0:00:08.216875.
# validation [##############################################....] 92.22%
#         83 iterations
#    0.98429 iters/sec. Estimated time to finish: 0:00:07.111731.
# validation [##############################################....] 93.33%
#         84 iterations
#    0.97479 iters/sec. Estimated time to finish: 0:00:06.155197.
# validation [###############################################...] 94.44%
#         85 iterations
#    0.98515 iters/sec. Estimated time to finish: 0:00:05.075357.
# validation [###############################################...] 95.56%
#         86 iterations
#    0.97774 iters/sec. Estimated time to finish: 0:00:04.091058.
# validation [################################################..] 96.67%
#         87 iterations
#    0.98786 iters/sec. Estimated time to finish: 0:00:03.036868.
# validation [################################################..] 97.78%
#         88 iterations
#    0.98623 iters/sec. Estimated time to finish: 0:00:02.027923.
# validation [#################################################.] 98.89%
#         89 iterations
#    0.99717 iters/sec. Estimated time to finish: 0:00:01.002834.
# 39          20826       0.000345492  0.00424143  0.0116477   20322
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=534.0), HTML(value='')))
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [..................................................]  1.11%
#          1 iterations
#     8.2087 iters/sec. Estimated time to finish: 0:00:10.842105.
# validation [#.................................................]  2.22%
#          2 iterations
#    0.99149 iters/sec. Estimated time to finish: 0:01:28.755363.
# validation [#.................................................]  3.33%
#          3 iterations
#     1.4141 iters/sec. Estimated time to finish: 0:01:01.525374.
# validation [##................................................]  4.44%
#          4 iterations
#    0.99369 iters/sec. Estimated time to finish: 0:01:26.546119.
# validation [##................................................]  5.56%
#          5 iterations
#     1.2111 iters/sec. Estimated time to finish: 0:01:10.185740.
# validation [###...............................................]  6.67%
#          6 iterations
#      0.964 iters/sec. Estimated time to finish: 0:01:27.136490.
# validation [###...............................................]  7.78%
#          7 iterations
#     1.0939 iters/sec. Estimated time to finish: 0:01:15.877495.
# validation [####..............................................]  8.89%
#          8 iterations
#     1.0046 iters/sec. Estimated time to finish: 0:01:21.626555.
# validation [#####.............................................] 10.00%
#          9 iterations
#     1.0785 iters/sec. Estimated time to finish: 0:01:15.106288.
# validation [#####.............................................] 11.11%
#         10 iterations
#     1.0263 iters/sec. Estimated time to finish: 0:01:17.951580.
# validation [######............................................] 12.22%
#         11 iterations
#     1.0906 iters/sec. Estimated time to finish: 0:01:12.435356.
# validation [######............................................] 13.33%
#         12 iterations
#     1.0342 iters/sec. Estimated time to finish: 0:01:15.420322.
# validation [#######...........................................] 14.44%
#         13 iterations
#     1.0802 iters/sec. Estimated time to finish: 0:01:11.283313.
# validation [#######...........................................] 15.56%
#         14 iterations
#    0.98761 iters/sec. Estimated time to finish: 0:01:16.953305.
# validation [########..........................................] 16.67%
#         15 iterations
#     1.0501 iters/sec. Estimated time to finish: 0:01:11.422877.
# validation [########..........................................] 17.78%
#         16 iterations
#      0.945 iters/sec. Estimated time to finish: 0:01:18.306856.
# validation [#########.........................................] 18.89%
#         17 iterations
#    0.99674 iters/sec. Estimated time to finish: 0:01:13.238900.
# validation [##########........................................] 20.00%
#         18 iterations
#    0.95211 iters/sec. Estimated time to finish: 0:01:15.621661.
# validation [##########........................................] 21.11%
#         19 iterations
#    0.99264 iters/sec. Estimated time to finish: 0:01:11.526609.
# validation [###########.......................................] 22.22%
#         20 iterations
#    0.96402 iters/sec. Estimated time to finish: 0:01:12.612334.
# validation [###########.......................................] 23.33%
#         21 iterations
#    0.99887 iters/sec. Estimated time to finish: 0:01:09.077767.
# validation [############......................................] 24.44%
#         22 iterations
#     0.9683 iters/sec. Estimated time to finish: 0:01:10.226295.
# validation [############......................................] 25.56%
#         23 iterations
#    0.99324 iters/sec. Estimated time to finish: 0:01:07.456278.
# validation [#############.....................................] 26.67%
#         24 iterations
#    0.96176 iters/sec. Estimated time to finish: 0:01:08.623958.
# validation [#############.....................................] 27.78%
#         25 iterations
#    0.99769 iters/sec. Estimated time to finish: 0:01:05.150691.
# validation [##############....................................] 28.89%
#         26 iterations
#    0.93172 iters/sec. Estimated time to finish: 0:01:08.690340.
# validation [###############...................................] 30.00%
#         27 iterations
#    0.96279 iters/sec. Estimated time to finish: 0:01:05.435091.
# validation [###############...................................] 31.11%
#         28 iterations
#    0.94141 iters/sec. Estimated time to finish: 0:01:05.858755.
# validation [################..................................] 32.22%
#         29 iterations
#    0.97142 iters/sec. Estimated time to finish: 0:01:02.794761.
# validation [################..................................] 33.33%
#         30 iterations
#    0.95022 iters/sec. Estimated time to finish: 0:01:03.142959.
# validation [#################.................................] 34.44%
#         31 iterations
#    0.97849 iters/sec. Estimated time to finish: 0:01:00.296865.
# validation [#################.................................] 35.56%
#         32 iterations
#    0.95207 iters/sec. Estimated time to finish: 0:01:00.920091.
# validation [##################................................] 36.67%
#         33 iterations
#    0.97879 iters/sec. Estimated time to finish: 0:00:58.235196.
# validation [##################................................] 37.78%
#         34 iterations
#    0.96025 iters/sec. Estimated time to finish: 0:00:58.318390.
# validation [###################...............................] 38.89%
#         35 iterations
#    0.98528 iters/sec. Estimated time to finish: 0:00:55.821485.
# validation [####################..............................] 40.00%
#         36 iterations
#    0.96901 iters/sec. Estimated time to finish: 0:00:55.726846.
# validation [####################..............................] 41.11%
#         37 iterations
#    0.99306 iters/sec. Estimated time to finish: 0:00:53.370438.
# validation [#####################.............................] 42.22%
#         38 iterations
#    0.95606 iters/sec. Estimated time to finish: 0:00:54.389928.
# validation [#####################.............................] 43.33%
#         39 iterations
#    0.97849 iters/sec. Estimated time to finish: 0:00:52.121051.
# validation [######################............................] 44.44%
#         40 iterations
#    0.96025 iters/sec. Estimated time to finish: 0:00:52.069885.
# validation [######################............................] 45.56%
#         41 iterations
#    0.98172 iters/sec. Estimated time to finish: 0:00:49.912556.
# validation [#######################...........................] 46.67%
#         42 iterations
#    0.95909 iters/sec. Estimated time to finish: 0:00:50.047612.
# validation [#######################...........................] 47.78%
#         43 iterations
#     0.9795 iters/sec. Estimated time to finish: 0:00:47.983855.
# validation [########################..........................] 48.89%
#         44 iterations
#     0.9666 iters/sec. Estimated time to finish: 0:00:47.589694.
# validation [#########################.........................] 50.00%
#         45 iterations
#    0.98637 iters/sec. Estimated time to finish: 0:00:45.621870.
# validation [#########################.........................] 51.11%
#         46 iterations
#    0.97428 iters/sec. Estimated time to finish: 0:00:45.161619.
# validation [##########################........................] 52.22%
#         47 iterations
#    0.99326 iters/sec. Estimated time to finish: 0:00:43.291981.
# validation [##########################........................] 53.33%
#         48 iterations
#    0.97646 iters/sec. Estimated time to finish: 0:00:43.012674.
# validation [###########################.......................] 54.44%
#         49 iterations
#    0.99471 iters/sec. Estimated time to finish: 0:00:41.218051.
# validation [###########################.......................] 55.56%
#         50 iterations
#    0.97882 iters/sec. Estimated time to finish: 0:00:40.865350.
# validation [############################......................] 56.67%
#         51 iterations
#    0.99612 iters/sec. Estimated time to finish: 0:00:39.151850.
# validation [############################......................] 57.78%
#         52 iterations
#    0.97901 iters/sec. Estimated time to finish: 0:00:38.814566.
# validation [#############################.....................] 58.89%
#         53 iterations
#    0.99581 iters/sec. Estimated time to finish: 0:00:37.155625.
# validation [##############################....................] 60.00%
#         54 iterations
#    0.98137 iters/sec. Estimated time to finish: 0:00:36.683510.
# validation [##############################....................] 61.11%
#         55 iterations
#    0.99735 iters/sec. Estimated time to finish: 0:00:35.093108.
# validation [###############################...................] 62.22%
#         56 iterations
#    0.97616 iters/sec. Estimated time to finish: 0:00:34.830204.
# validation [###############################...................] 63.33%
#         57 iterations
#    0.99171 iters/sec. Estimated time to finish: 0:00:33.275769.
# validation [################################..................] 64.44%
#         58 iterations
#    0.98098 iters/sec. Estimated time to finish: 0:00:32.620305.
# validation [################################..................] 65.56%
#         59 iterations
#    0.99608 iters/sec. Estimated time to finish: 0:00:31.122091.
# validation [#################################.................] 66.67%
#         60 iterations
#    0.98096 iters/sec. Estimated time to finish: 0:00:30.582287.
# validation [#################################.................] 67.78%
#         61 iterations
#    0.99544 iters/sec. Estimated time to finish: 0:00:29.132897.
# validation [##################################................] 68.89%
#         62 iterations
#    0.98526 iters/sec. Estimated time to finish: 0:00:28.418935.
# validation [###################################...............] 70.00%
#         63 iterations
#    0.99897 iters/sec. Estimated time to finish: 0:00:27.027704.
# validation [###################################...............] 71.11%
#         64 iterations
#    0.98502 iters/sec. Estimated time to finish: 0:00:26.395472.
# validation [####################################..............] 72.22%
#         65 iterations
#     0.9988 iters/sec. Estimated time to finish: 0:00:25.030053.
# validation [####################################..............] 73.33%
#         66 iterations
#    0.98812 iters/sec. Estimated time to finish: 0:00:24.288509.
# validation [#####################################.............] 74.44%
#         67 iterations
#     1.0015 iters/sec. Estimated time to finish: 0:00:22.964891.
# validation [#####################################.............] 75.56%
#         68 iterations
#    0.99164 iters/sec. Estimated time to finish: 0:00:22.185401.
# validation [######################################............] 76.67%
#         69 iterations
#     1.0047 iters/sec. Estimated time to finish: 0:00:20.901963.
# validation [######################################............] 77.78%
#         70 iterations
#    0.99494 iters/sec. Estimated time to finish: 0:00:20.101656.
# validation [#######################################...........] 78.89%
#         71 iterations
#     1.0077 iters/sec. Estimated time to finish: 0:00:18.854943.
# validation [########################################..........] 80.00%
#         72 iterations
#    0.99229 iters/sec. Estimated time to finish: 0:00:18.139863.
# validation [########################################..........] 81.11%
#         73 iterations
#     1.0047 iters/sec. Estimated time to finish: 0:00:16.921160.
# validation [#########################################.........] 82.22%
#         74 iterations
#    0.98917 iters/sec. Estimated time to finish: 0:00:16.175121.
# validation [#########################################.........] 83.33%
#         75 iterations
#     1.0012 iters/sec. Estimated time to finish: 0:00:14.982422.
# validation [##########################################........] 84.44%
#         76 iterations
#    0.98134 iters/sec. Estimated time to finish: 0:00:14.266161.
# validation [##########################################........] 85.56%
#         77 iterations
#    0.99288 iters/sec. Estimated time to finish: 0:00:13.093164.
# validation [###########################################.......] 86.67%
#         78 iterations
#    0.98069 iters/sec. Estimated time to finish: 0:00:12.236306.
# validation [###########################################.......] 87.78%
#         79 iterations
#    0.99192 iters/sec. Estimated time to finish: 0:00:11.089556.
# validation [############################################......] 88.89%
#         80 iterations
#    0.97604 iters/sec. Estimated time to finish: 0:00:10.245478.
# validation [#############################################.....] 90.00%
#         81 iterations
#    0.98686 iters/sec. Estimated time to finish: 0:00:09.119848.
# validation [#############################################.....] 91.11%
#         82 iterations
#    0.97406 iters/sec. Estimated time to finish: 0:00:08.213054.
# validation [##############################################....] 92.22%
#         83 iterations
#    0.98459 iters/sec. Estimated time to finish: 0:00:07.109528.
# validation [##############################################....] 93.33%
#         84 iterations
#    0.97417 iters/sec. Estimated time to finish: 0:00:06.159111.
# validation [###############################################...] 94.44%
#         85 iterations
#    0.98423 iters/sec. Estimated time to finish: 0:00:05.080099.
# validation [###############################################...] 95.56%
#         86 iterations
#    0.97742 iters/sec. Estimated time to finish: 0:00:04.092394.
# validation [################################################..] 96.67%
#         87 iterations
#    0.98762 iters/sec. Estimated time to finish: 0:00:03.037599.
# validation [################################################..] 97.78%
#         88 iterations
#    0.98718 iters/sec. Estimated time to finish: 0:00:02.025979.
# validation [#################################################.] 98.89%
#         89 iterations
#    0.99815 iters/sec. Estimated time to finish: 0:00:01.001856.
# 40          21360       0.001       0.00420773  0.0118202   20823.3

# %%
del train_loader
del val_loader
del model
del optimizer
del scheduler
del loss_func
del manager

gc.collect()
# Out:
# 228580

# %% [markdown]
# ## save results

# %%
# %%bash
# ls /kaggle/training_output
# Out:
# log
# loss.png
# lr.png
# snapshot_epoch_1.pth
# snapshot_epoch_10.pth
# snapshot_epoch_13.pth
# snapshot_epoch_14.pth
# snapshot_epoch_2.pth
# snapshot_epoch_3.pth
# snapshot_epoch_4.pth
# snapshot_epoch_5.pth
# snapshot_epoch_6.pth
# snapshot_epoch_7.pth
# snapshot_epoch_9.pth

# %%
for f_name in ["log","loss.png", "lr.png"]:
    shutil.copy(output_dir / f_name, f_name)

# %%
log = pd.read_json("log")
best_epoch = log["val/loss"].idxmin() + 1
log.iloc[[best_epoch - 1],]
# Out:
#     train/loss        lr  val/loss  epoch  iteration  elapsed_time
# 13    0.008426  0.000655  0.010489     14       7476   7485.866482

# %%
shutil.copy(output_dir / "snapshot_epoch_{}.pth".format(best_epoch), "best_model.pth")
# Out:
# 'best_model.pth'

# %%
m = get_model({
    'name': settings["model"]["name"],
    'params': {'pretrained': False, 'n_classes': 264}})
state_dict = torch.load('best_model.pth')
m.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
train_file_list[0]
# Out:
# ['/kaggle/input/birdsong-resampled-train-audio-00/aldfly/XC134874.wav',
#  'aldfly']

# %%
temp = SpectrogramDataset(train_file_list[0:5],**settings["dataset"]["params"])

# %%
img ,lb = temp.__getitem__(0)

# %%
# from PIL import Image
# import numpy as np

# img = Image.fromarray(img.values)

img.shape
# Out:
# (3, 256, 256)

# %%
settings["dataset"]["params"]['img_size']=224

# %%
# from matplotlib import pyplot as plt
# plt.imshow(img, interpolation='nearest')
# plt.show()
