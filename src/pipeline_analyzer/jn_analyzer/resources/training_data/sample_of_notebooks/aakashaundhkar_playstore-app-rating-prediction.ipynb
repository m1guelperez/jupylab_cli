# %% [markdown]
# # Playstore_App_Rating_Prediction

# %% [markdown]
# ## Importing the Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly 
import plotly.offline as pyo
from plotly.offline import iplot,plot,init_notebook_mode
import plotly.express as px
import cufflinks as cf
import plotly.graph_objects as go
import seaborn as sns
plt.rc('figure', figsize=(20.0, 10.0))

# %%
pyo.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import plotly.io as pio
pio.renderers.default = 'colab'

# %% [markdown]
# ## Importing Dataset

# %%
dataset=pd.read_csv("/kaggle/input/playstore-analysis/googleplaystore.csv")

# %%
dataset.head()
# Out:
#    Rating                                                App        Category  \
# 0     4.1     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1     3.9                                Coloring book moana  ART_AND_DESIGN
# 2     4.7  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3     4.5                              Sketch - Draw & Paint  ART_AND_DESIGN
# 4     4.3              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design    07-Jan-18               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play    15-Jan-18               2.0.0  4.0.3 and up
# 2               Art & Design    01-Aug-18               1.2.4  4.0.3 and up
# 3               Art & Design    08-Jun-18  Varies with device    4.2 and up
# 4    Art & Design;Creativity    20-Jun-18                 1.1    4.4 and up

# %% [markdown]
# ## Finding and Handling any Missing Data

# %% [markdown]
# Analysing various columns for any null values

# %%
dataset.isnull().sum()
# Out:
# Rating            1474
# App                  0
# Category             0
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %% [markdown]
# Dropping the rows which have any null records

# %%
dataset=dataset.dropna()
dataset=dataset.reset_index(drop=True)

# %% [markdown]
# Checking for any null records

# %%
dataset.isnull().sum()
# Out:
# Rating            0
# App               0
# Category          0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# Analysing various data types of different rows in dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9360 entries, 0 to 9359
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rating          9360 non-null   float64
#  1   App             9360 non-null   object
#  2   Category        9360 non-null   object
#  3   Reviews         9360 non-null   int64
#  4   Size            9360 non-null   object
#  5   Installs        9360 non-null   object
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   object
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 950.8+ KB

# %% [markdown]
# Converting the Reviews column into integers

# %%
dataset['Reviews']=dataset["Reviews"].astype(int)

# %% [markdown]
# Converting the size variable into a single type by removing 'M', 'k' and the string "varies with device" present in it

# %%
dataset["Size"].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '5.5M', '17M', '39M', '31M',
#        '4.2M', '23M', '6.0M', '6.1M', '4.6M', '9.2M', '5.2M', '11M',
#        '24M', 'Varies with device', '9.4M', '15M', '10M', '1.2M', '26M',
#        '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k', '3.6M', '5.7M',
#        '8.6M', '2.4M', '27M', '2.7M', '2.5M', '7.0M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '22M', '6.4M', '3.2M', '8.2M', '4.9M', '9.5M', '5.0M',
#        '5.9M', '13M', '73M', '6.8M', '3.5M', '4.0M', '2.3M', '2.1M',
#        '42M', '9.1M', '55M', '23k', '7.3M', '6.5M', '1.5M', '7.5M', '51M',
#        '41M', '48M', '8.5M', '46M', '8.3M', '4.3M', '4.7M', '3.3M', '40M',
#        '7.8M', '8.8M', '6.6M', '5.1M', '61M', '66M', '79k', '8.4M',
#        '3.7M', '118k', '44M', '695k', '1.6M', '6.2M', '53M', '1.4M',
#        '3.0M', '7.2M', '5.8M', '3.8M', '9.6M', '45M', '63M', '49M', '77M',
#        '4.4M', '70M', '9.3M', '8.1M', '36M', '6.9M', '7.4M', '84M', '97M',
#        '2.0M', '1.9M', '1.8M', '5.3M', '47M', '556k', '526k', '76M',
#        '7.6M', '59M', '9.7M', '78M', '72M', '43M', '7.7M', '6.3M', '334k',
#        '93M', '65M', '79M', '100M', '58M', '50M', '68M', '64M', '34M',
#        '67M', '60M', '94M', '9.9M', '232k', '99M', '624k', '95M', '8.5k',
#        '41k', '292k', '80M', '1.7M', '10.0M', '74M', '62M', '69M', '75M',
#        '98M', '85M', '82M', '96M', '87M', '71M', '86M', '91M', '81M',
#        '92M', '83M', '88M', '704k', '862k', '899k', '378k', '4.8M',
#        '266k', '375k', '1.3M', '975k', '980k', '4.1M', '89M', '696k',
#        '544k', '525k', '920k', '779k', '853k', '720k', '713k', '772k',
#        '318k', '58k', '241k', '196k', '857k', '51k', '953k', '865k',
#        '251k', '930k', '540k', '313k', '746k', '203k', '26k', '314k',
#        '239k', '371k', '220k', '730k', '756k', '91k', '293k', '17k',
#        '74k', '14k', '317k', '78k', '924k', '818k', '81k', '939k', '169k',
#        '45k', '965k', '90M', '545k', '61k', '283k', '655k', '714k', '93k',
#        '872k', '121k', '322k', '976k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '306k', '175k', '350k', '383k', '454k',
#        '1.0M', '70k', '812k', '442k', '842k', '417k', '412k', '459k',
#        '478k', '335k', '782k', '721k', '430k', '429k', '192k', '460k',
#        '728k', '496k', '816k', '414k', '506k', '887k', '613k', '778k',
#        '683k', '592k', '186k', '840k', '647k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '219k', '55k', '323k', '691k', '511k',
#        '951k', '963k', '25k', '554k', '351k', '27k', '82k', '208k',
#        '551k', '29k', '103k', '116k', '153k', '209k', '499k', '173k',
#        '597k', '809k', '122k', '411k', '400k', '801k', '787k', '50k',
#        '643k', '986k', '516k', '837k', '780k', '20k', '498k', '600k',
#        '656k', '221k', '228k', '176k', '34k', '259k', '164k', '458k',
#        '629k', '28k', '288k', '775k', '785k', '636k', '916k', '994k',
#        '309k', '485k', '914k', '903k', '608k', '500k', '54k', '562k',
#        '847k', '948k', '811k', '270k', '48k', '523k', '784k', '280k',
#        '24k', '892k', '154k', '18k', '33k', '860k', '364k', '387k',
#        '626k', '161k', '879k', '39k', '170k', '141k', '160k', '144k',
#        '143k', '190k', '376k', '193k', '473k', '246k', '73k', '253k',
#        '957k', '420k', '72k', '404k', '470k', '226k', '240k', '89k',
#        '234k', '257k', '861k', '467k', '676k', '552k', '582k', '619k'],
#       dtype=object)

# %% [markdown]
# This function will check whether the value have 'M' or 'k' and according to it will change the value.

# %%
def mb_to_kb(a):
  if a.endswith("M"):
    return float(a[:-1])*1000
  elif a.endswith("k"):
    return float(a[:-1])
  else:
    return a

# %%
dataset["Size"]=dataset["Size"].apply(lambda x:mb_to_kb(x))

# %%
dataset[dataset["Size"]=="Varies with device"]
# Out:
#       Rating                                                App  \
# 35       4.1                                 Floor Plan Creator
# 40       4.4                         Textgram - write on photos
# 50       4.6                      Used Cars and Trucks for Sale
# 65       4.3                                 Ulysse Speedometer
# 66       3.9                                             REPUVE
# ...      ...                                                ...
# 9267     4.4  My Earthquake Alerts - US & Worldwide Earthquakes
# 9279     3.6                                          Posta App
# 9307     3.4                    Chat For Strangers - Video Chat
# 9348     4.0          Frim: get new friends on local chat rooms
# 9358     4.5                      The SCP Foundation DB fr nn5n
#
#                  Category  Reviews                Size     Installs  Type  \
# 35         ART_AND_DESIGN    36639  Varies with device   5,000,000+  Free
# 40         ART_AND_DESIGN   295221  Varies with device  10,000,000+  Free
# 50      AUTO_AND_VEHICLES    17057  Varies with device   1,000,000+  Free
# 65      AUTO_AND_VEHICLES    40211  Varies with device   5,000,000+  Free
# 66      AUTO_AND_VEHICLES      356  Varies with device     100,000+  Free
# ...                   ...      ...                 ...          ...   ...
# 9267              WEATHER     3471  Varies with device     100,000+  Free
# 9279  MAPS_AND_NAVIGATION        8  Varies with device       1,000+  Free
# 9307               SOCIAL      622  Varies with device     100,000+  Free
# 9348               SOCIAL    88486  Varies with device   5,000,000+  Free
# 9358  BOOKS_AND_REFERENCE      114  Varies with device       1,000+  Free
#
#      Price Content Rating             Genres Last Updated         Current Ver  \
# 35       0       Everyone       Art & Design    14-Jul-18  Varies with device
# 40       0       Everyone       Art & Design    30-Jul-18  Varies with device
# 50       0       Everyone    Auto & Vehicles    30-Jul-18  Varies with device
# 65       0       Everyone    Auto & Vehicles    30-Jul-18  Varies with device
# 66       0       Everyone    Auto & Vehicles    25-May-18  Varies with device
# ...    ...            ...                ...          ...                 ...
# 9267     0       Everyone            Weather    24-Jul-18  Varies with device
# 9279     0       Everyone  Maps & Navigation    27-Sep-17  Varies with device
# 9307     0     Mature 17+             Social    23-May-18  Varies with device
# 9348     0     Mature 17+             Social    23-Mar-18  Varies with device
# 9358     0     Mature 17+  Books & Reference    19-Jan-15  Varies with device
#
#              Android Ver
# 35          2.3.3 and up
# 40    Varies with device
# 50    Varies with device
# 65    Varies with device
# 66    Varies with device
# ...                  ...
# 9267  Varies with device
# 9279          4.4 and up
# 9307  Varies with device
# 9348  Varies with device
# 9358  Varies with device
#
# [1637 rows x 13 columns]

# %%
rows=dataset[dataset["Size"]=="Varies with device"].index

# %%
dataset.drop(rows,inplace=True)

# %% [markdown]
# Removing the '+' symbol from each value in Installs column

# %%
dataset["Installs"].value_counts()
# Out:
# 1,000,000+        1301
# 100,000+          1037
# 10,000+            968
# 10,000,000+        825
# 1,000+             689
# 5,000,000+         535
# 500,000+           490
# 50,000+            436
# 5,000+             419
# 100+               303
# 100,000,000+       201
# 500+               197
# 50,000,000+        147
# 10+                 67
# 50+                 56
# 500,000,000+        30
# 1,000,000,000+      10
# 5+                   9
# 1+                   3
# Name: Installs, dtype: int64

# %%
dataset["Installs"]=dataset["Installs"].str[:-1]
dataset["Installs"]=dataset["Installs"].apply(lambda x:x.replace(",",""))

# %%
dataset["Installs"]=dataset["Installs"].astype(int)

# %% [markdown]
# Removing the '$' sign from the Price Column

# %%
dataset["Price"].unique()
# Out:
# array(['0', '$4.99 ', '$6.99 ', '$7.99 ', '$3.99 ', '$5.99 ', '$2.99 ',
#        '$1.99 ', '$9.99 ', '$0.99 ', '$9.00 ', '$5.49 ', '$10.00 ',
#        '$24.99 ', '$11.99 ', '$79.99 ', '$16.99 ', '$14.99 ', '$29.99 ',
#        '$12.99 ', '$3.49 ', '$10.99 ', '$7.49 ', '$1.50 ', '$19.99 ',
#        '$15.99 ', '$33.99 ', '$39.99 ', '$2.49 ', '$4.49 ', '$1.70 ',
#        '$1.49 ', '$3.88 ', '$399.99 ', '$17.99 ', '$400.00 ', '$3.02 ',
#        '$1.76 ', '$4.84 ', '$4.77 ', '$1.61 ', '$1.59 ', '$6.49 ',
#        '$1.29 ', '$299.99 ', '$379.99 ', '$37.99 ', '$18.99 ', '$389.99 ',
#        '$8.49 ', '$1.75 ', '$14.00 ', '$2.00 ', '$3.08 ', '$2.59 ',
#        '$19.40 ', '$15.46 ', '$8.99 ', '$3.04 ', '$13.99 ', '$4.29 ',
#        '$3.28 ', '$4.60 ', '$1.00 ', '$2.90 ', '$1.97 ', '$2.56 ',
#        '$1.20 '], dtype=object)

# %%
dataset["Price"]=dataset["Price"].apply(lambda x:x.replace("$",""))
dataset["Price"]=dataset["Price"].astype(float)

# %% [markdown]
# Removing the rows with more nummber of rating than installs

# %%
dataset["Rating"].between(0,5).sum()
# Out:
# 7723

# %%
rows=dataset[dataset["Installs"]<dataset["Reviews"]].index
dataset.drop(rows,inplace=True)

# %% [markdown]
# ## Univariate Analysis

# %%
dataset.head()
# Out:
#    Rating                                                App        Category  \
# 0     4.1     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1     3.9                                Coloring book moana  ART_AND_DESIGN
# 2     4.7  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3     4.5                              Sketch - Draw & Paint  ART_AND_DESIGN
# 4     4.3              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
#
#    Reviews   Size  Installs  Type  Price Content Rating  \
# 0      159  19000     10000  Free    0.0       Everyone
# 1      967  14000    500000  Free    0.0       Everyone
# 2    87510   8700   5000000  Free    0.0       Everyone
# 3   215644  25000  50000000  Free    0.0           Teen
# 4      967   2800    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design    07-Jan-18               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play    15-Jan-18               2.0.0  4.0.3 and up
# 2               Art & Design    01-Aug-18               1.2.4  4.0.3 and up
# 3               Art & Design    08-Jun-18  Varies with device    4.2 and up
# 4    Art & Design;Creativity    20-Jun-18                 1.1    4.4 and up

# %% [markdown]
# ## Outline Correction

# %%
sns.boxplot(data=dataset,orient="h",palette="Set2")

# %% [markdown]
# It is evident from the box plot that there are some outliners in Reviews, Installs and Price columns

# %%
dataset["Reviews"].value_counts()
# Out:
# 2          80
# 3          77
# 5          74
# 4          71
# 1          66
#            ..
# 3063        1
# 33782       1
# 1010        1
# 77717       1
# 1385093     1
# Name: Reviews, Length: 4669, dtype: int64

# %% [markdown]
# Very few apps have very high number of reviews. These are all star apps that don’t help with the analysis and, in fact, will skew it. Thus Removing the applications having reviews more than 2 million

# %%
rows=dataset[dataset["Reviews"]>2000000].index

# %%
dataset.drop(rows,inplace=True)

# %% [markdown]
# From the box plot, it seems like there are some apps with very high price. A price of 200 for an application on the Play Store is very high and suspicious!. Hence removing the applications with price more than 200$

# %%
rows=dataset[dataset["Price"]>200].index

# %%
dataset.drop(rows,inplace=True)

# %% [markdown]
# There seems to be some outliers in installs field too. Hence setting the threshold at 500000.

# %%
perc=[.10, .25, .50, .70, .90, .95, .99]
dataset["Installs"].describe(percentiles=perc)
# Out:
# count    7.483000e+03
# mean     3.947465e+06
# std      2.781831e+07
# min      5.000000e+00
# 10%      1.000000e+03
# 25%      1.000000e+04
# 50%      1.000000e+05
# 70%      1.000000e+06
# 90%      1.000000e+07
# 95%      1.000000e+07
# 99%      5.000000e+07
# max      1.000000e+09
# Name: Installs, dtype: float64

# %%
sns.distplot(dataset["Installs"],kde=False)

# %%
rows=dataset[dataset["Price"]>500000].index

# %%
dataset.drop(rows,inplace=True)

# %%
sns.distplot(dataset["Rating"],kde=False)

# %%
sns.distplot(dataset["Size"],kde=False)

# %% [markdown]
# From above both histograms it is clear that both of them dont have any significant outliners.

# %% [markdown]
# ## Multivariate Analysis

# %%
dataset
# Out:
#       Rating                                                App  \
# 0        4.1     Photo Editor & Candy Camera & Grid & ScrapBook
# 1        3.9                                Coloring book moana
# 2        4.7  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3        4.5                              Sketch - Draw & Paint
# 4        4.3              Pixel Draw - Number Art Coloring Book
# ...      ...                                                ...
# 9354     4.8                                        Chemin (fr)
# 9355     4.0                                      FR Calculator
# 9356     4.5                                   Sya9a Maroc - FR
# 9357     5.0                   Fr. Mike Schmitz Audio Teachings
# 9359     4.5      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Reviews   Size  Installs  Type  Price  \
# 0          ART_AND_DESIGN      159  19000     10000  Free    0.0
# 1          ART_AND_DESIGN      967  14000    500000  Free    0.0
# 2          ART_AND_DESIGN    87510   8700   5000000  Free    0.0
# 3          ART_AND_DESIGN   215644  25000  50000000  Free    0.0
# 4          ART_AND_DESIGN      967   2800    100000  Free    0.0
# ...                   ...      ...    ...       ...   ...    ...
# 9354  BOOKS_AND_REFERENCE       44    619      1000  Free    0.0
# 9355               FAMILY        7   2600       500  Free    0.0
# 9356               FAMILY       38  53000      5000  Free    0.0
# 9357               FAMILY        4   3600       100  Free    0.0
# 9359            LIFESTYLE   398307  19000  10000000  Free    0.0
#
#      Content Rating                     Genres Last Updated  \
# 0          Everyone               Art & Design    07-Jan-18
# 1          Everyone  Art & Design;Pretend Play    15-Jan-18
# 2          Everyone               Art & Design    01-Aug-18
# 3              Teen               Art & Design    08-Jun-18
# 4          Everyone    Art & Design;Creativity    20-Jun-18
# ...             ...                        ...          ...
# 9354       Everyone          Books & Reference    23-Mar-14
# 9355       Everyone                  Education    18-Jun-17
# 9356       Everyone                  Education    25-Jul-17
# 9357       Everyone                  Education    06-Jul-18
# 9359       Everyone                  Lifestyle    25-Jul-18
#
#              Current Ver         Android Ver
# 0                  1.0.0        4.0.3 and up
# 1                  2.0.0        4.0.3 and up
# 2                  1.2.4        4.0.3 and up
# 3     Varies with device          4.2 and up
# 4                    1.1          4.4 and up
# ...                  ...                 ...
# 9354                 0.8          2.2 and up
# 9355               1.0.0          4.1 and up
# 9356                1.48          4.1 and up
# 9357                   1          4.1 and up
# 9359  Varies with device  Varies with device
#
# [7483 rows x 13 columns]

# %%
plt.figure(figsize=(11,8))
sns.scatterplot(x=dataset["Rating"],y=dataset["Price"],hue=dataset["Rating"])

# %% [markdown]
# Well there is no clear pattern that paid apps get better ratings but apps with minimum price of 9$ gets atleast average rating of 2.5

# %%
px.scatter(dataset,x="Rating",y="Size",color="Size",color_continuous_scale=px.colors.sequential.Viridis)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7b3c0723-acc2-406e-a491-b5debd775248" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7b3c0723-acc2-406e-a491-b5debd775248")) {
#                     Plotly.newPlot(
#                         '7b3c0723-acc2-406e-a491-b5debd775248',
#                         [{"hovertemplate": "Size=%{y}<br>Rating=%{x}<extra></extra>", "legendgroup": "19000.0", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "19000.0", "showlegend": true, "type": "scattergl", "x": [4.1, 3.8, 4.6, 3.3, 4.6, 4.2, 4.2, 4.4, 4.3, 1.9, 2.5, 2.5, 1.9, 4.0, 1.9, 3.8, 4.3, 4.0, 4.0, 4.0, 4.2, 4.0, 3.9, 4.0, 4.0, 4.2, 3.9, 4.0, 4.0, 3.9, 4.2, 3.9, 4.6, 3.8, 4.6, 4.7, 4.6, 4.5, 4.5, 4.6, 4.6, 4.7, 3.3, 3.9, 4.4, 4.3, 4.1, 4.1, 4.1, 4.6, 4.6, 3.7, 4.5, 4.4, 4.6, 4.3, 4.6, 4.5, 4.5, 4.1, 4.5, 4.5, 4.5, 4.4, 4.5, 4.2, 4.5, 3.6, 4.0, 4.6, 3.3, 4.1, 4.4, 3.0, 4.5, 4.0, 4.4, 3.8, 3.6, 3.0, 3.6, 4.6, 4.0, 4.3, 4.5, 4.4, 3.8, 4.0, 4.7, 4.6, 4.5, 3.3, 3.7,
5, 1.8, 4.6, 4.3, 2.8, 4.0, 3.3, 3.6, 3.3, 3.1, 4.8, 4.8, 4.1, 4.1, 4.2, 3.6, 4.0, 3.5, 4.2, 4.5, 4.9, 4.3, 3.9, 4.2, 4.2, 3.4, 3.8, 4.5, 3.8], "xaxis": "x", "y": [967, 450, 1754, 49790, 4369, 6903, 103755, 296, 308, 296, 103755, 83239, 83239, 894, 8, 8, 5, 53, 172640, 55256, 55256, 3874, 21996, 7514, 964, 2473, 41941, 17368, 3346, 9305, 21892, 21892, 974, 1595, 47213, 45, 41, 156410, 87418, 87418, 17, 9701, 9701, 9701, 5123, 635846, 76346, 136626, 32862, 136633, 928, 136626, 136626, 154578, 48979, 7146, 15633, 298321, 66453, 97890, 25037, 1498393, 1413, 169965, 350, 56524, 23292, 1240, 39480, 1311, 1736105, 16257, 96, 777, 41917, 9140, 1955, 1486, 4264, 15097, 34, 23291, 8696, 253, 345, 57400, 45370, 76340, 17, 2, 53, 70, 27, 8, 120, 193, 93, 19, 5644, 9765, 73, 97890, 25035, 55723, 291, 5, 363, 4, 8, 2, 145, 76, 1873, 159, 70, 36557, 15, 77717, 655, 345, 534, 315, 6208, 1231, 3661, 20843, 766, 5, 951435, 6, 6450, 152395, 1387, 16, 12, 93930, 19234, 29, 127, 4114, 496, 279, 1242, 17, 311, 47576, 211, 32812, 12846, 21, 2000, 43191, 91397, 10, 1539, 28429, 4, 70753, 37, 133, 3320, 4], "yaxis": "y"}, {"hovertemplate": "Size=8700.0<br>Rating=%{x}<br>Reviews=%{y}<extra></extra>", "legendgroup": "8700.0", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "8700.0", "showlegend": true, "type": "scattergl", "x": [4.7, 4.6, 4 ...

# %% [markdown]
# There is no particular patter that is followed between reviews and rating but we can see that after some point rating becomes independent of popularity.

# %%
px.box(dataset,y="Rating",x="Content Rating")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4b5e317e-0245-414f-8379-0b7101502ba5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4b5e317e-0245-414f-8379-0b7101502ba5")) {
#                     Plotly.newPlot(
#                         '4b5e317e-0245-414f-8379-0b7101502ba5',
#                         [{"alignmentgroup": "True", "hovertemplate": "Content Rating=%{x}<br>Rating=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["Everyone", "Everyone", "Everyone", "Teen", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Teen", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone 10+", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Teen", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone",
class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("08ae5b84-a571-4ab6-9cd4-23d321075ce9")) {
#                     Plotly.newPlot(
#                         '08ae5b84-a571-4ab6-9cd4-23d321075ce9',
#                         [{"alignmentgroup": "True", "hovertemplate": "Category=%{x}<br>Rating=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "ART_AND_DESIGN", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "AUTO_AND_VEHICLES", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BEAUTY", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BOOKS_AND_REFERENCE", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "BUSINESS", "COMICS", "COMICS", "COMICS", "COMICS", "COMICS", "COMICS", "COMICS", "COMICS", "COMICS", "COMICS", "COMICS", "COMICS", "COMICS", "COMICS", "COMICS", "COMICS", "CO ...

# %% [markdown]
# ## Data Preprocessing

# %%
dataset.columns
# Out:
# Index(['Rating', 'App', 'Category', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# Reseting the rows' index

# %%
dataset=dataset.reset_index(drop=True)

# %% [markdown]
# Droping all teh unnecessary columns from the dataset

# %%
dataset.drop(["App","Installs","Type","Content Rating",'Last Updated', 'Current Ver',
       'Android Ver'],axis=1,inplace=True)

# %%
dataset
# Out:
#       Rating             Category  Reviews   Size  Price  \
# 0        4.1       ART_AND_DESIGN      159  19000    0.0
# 1        3.9       ART_AND_DESIGN      967  14000    0.0
# 2        4.7       ART_AND_DESIGN    87510   8700    0.0
# 3        4.5       ART_AND_DESIGN   215644  25000    0.0
# 4        4.3       ART_AND_DESIGN      967   2800    0.0
# ...      ...                  ...      ...    ...    ...
# 7478     4.8  BOOKS_AND_REFERENCE       44    619    0.0
# 7479     4.0               FAMILY        7   2600    0.0
# 7480     4.5               FAMILY       38  53000    0.0
# 7481     5.0               FAMILY        4   3600    0.0
# 7482     4.5            LIFESTYLE   398307  19000    0.0
#
#                          Genres
# 0                  Art & Design
# 1     Art & Design;Pretend Play
# 2                  Art & Design
# 3                  Art & Design
# 4       Art & Design;Creativity
# ...                         ...
# 7478          Books & Reference
# 7479                  Education
# 7480                  Education
# 7481                  Education
# 7482                  Lifestyle
#
# [7483 rows x 6 columns]

# %% [markdown]
# Seprating the independent and dependent variable

# %%
X=dataset.iloc[:,1:].values
y=dataset.iloc[:,0].values

# %%
X
# Out:
# array([['ART_AND_DESIGN', 159, 19000.0, 0.0, 'Art & Design'],
#        ['ART_AND_DESIGN', 967, 14000.0, 0.0, 'Art & Design;Pretend Play'],
#        ['ART_AND_DESIGN', 87510, 8700.0, 0.0, 'Art & Design'],
#        ...,
#        ['FAMILY', 38, 53000.0, 0.0, 'Education'],
#        ['FAMILY', 4, 3600.0, 0.0, 'Education'],
#        ['LIFESTYLE', 398307, 19000.0, 0.0, 'Lifestyle']], dtype=object)

# %% [markdown]
# One Hot Encoder for converting the categorical data present in both the "Category" and "Genre" column

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(sparse=False), [4])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(sparse=False), [-4])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %% [markdown]
# Spliting the dataset into training and testing dataset

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %% [markdown]
# ## Model Training

# %% [markdown]
# Using the LinearRegression model from sklearn library

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
model=regressor.fit(X_train, y_train)

# %% [markdown]
# Predicting the Test result

# %%
y_pred=model.predict(X_test)

# %% [markdown]
# Finding various metrics for evaluating the regression model from sklearn library

# %%
from sklearn.metrics import r2_score,mean_squared_error
print('R2_Score=',r2_score(y_test,y_pred))
print('Root_Mean_Squared_Error(RMSE)=',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2_Score= 0.05029650677675779
# Root_Mean_Squared_Error(RMSE)= 0.5563453917629464

# %%
a=pd.DataFrame({'Actual':y_test.flatten(),'Predicted':y_pred.flatten()});a.head(10)
# Out:
#    Actual  Predicted
# 0     4.3   4.017616
# 1     4.7   4.330144
# 2     4.5   4.198882
# 3     4.5   4.400106
# 4     3.3   4.009041
# 5     4.7   4.005493
# 6     4.5   4.207755
# 7     4.5   4.082562
# 8     4.5   4.068799
# 9     4.5   4.125397

# %%
fig=a.head(25)
fig.plot(kind='bar',figsize=(10,8))
