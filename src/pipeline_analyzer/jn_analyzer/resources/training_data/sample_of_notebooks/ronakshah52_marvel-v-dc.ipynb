# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# %matplotlib inline

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/fivethirtyeight-comic-characters-dataset/dc-wikia-data.csv
# /kaggle/input/fivethirtyeight-comic-characters-dataset/marvel-wikia-data.csv
# /kaggle/input/fivethirtyeight-comic-characters-dataset/README.md

# %%
dc = pd.read_csv("../input/fivethirtyeight-comic-characters-dataset/dc-wikia-data.csv")
marvel = pd.read_csv("../input/fivethirtyeight-comic-characters-dataset/marvel-wikia-data.csv")

# %%
dc.head()
# Out:
#    page_id                         name                              urlslug  \
# 0     1422         Batman (Bruce Wayne)         \/wiki\/Batman_(Bruce_Wayne)
# 1    23387        Superman (Clark Kent)        \/wiki\/Superman_(Clark_Kent)
# 2     1458   Green Lantern (Hal Jordan)   \/wiki\/Green_Lantern_(Hal_Jordan)
# 3     1659     James Gordon (New Earth)     \/wiki\/James_Gordon_(New_Earth)
# 4     1576  Richard Grayson (New Earth)  \/wiki\/Richard_Grayson_(New_Earth)
#
#                 ID            ALIGN         EYE        HAIR              SEX  \
# 0  Secret Identity  Good Characters   Blue Eyes  Black Hair  Male Characters
# 1  Secret Identity  Good Characters   Blue Eyes  Black Hair  Male Characters
# 2  Secret Identity  Good Characters  Brown Eyes  Brown Hair  Male Characters
# 3  Public Identity  Good Characters  Brown Eyes  White Hair  Male Characters
# 4  Secret Identity  Good Characters   Blue Eyes  Black Hair  Male Characters
#
#    GSM              ALIVE  APPEARANCES FIRST APPEARANCE    YEAR
# 0  NaN  Living Characters       3093.0        1939, May  1939.0
# 1  NaN  Living Characters       2496.0    1986, October  1986.0
# 2  NaN  Living Characters       1565.0    1959, October  1959.0
# 3  NaN  Living Characters       1316.0   1987, February  1987.0
# 4  NaN  Living Characters       1237.0      1940, April  1940.0

# %%
marvel.head()
# Out:
#    page_id                                 name  \
# 0     1678            Spider-Man (Peter Parker)
# 1     7139      Captain America (Steven Rogers)
# 2    64786  Wolverine (James \"Logan\" Howlett)
# 3     1868    Iron Man (Anthony \"Tony\" Stark)
# 4     2460                  Thor (Thor Odinson)
#
#                                    urlslug                ID  \
# 0              \/Spider-Man_(Peter_Parker)   Secret Identity
# 1        \/Captain_America_(Steven_Rogers)   Public Identity
# 2  \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3    \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                    \/Thor_(Thor_Odinson)  No Dual Identity
#
#                 ALIGN         EYE        HAIR              SEX  GSM  \
# 0     Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1     Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2  Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 3     Good Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 4     Good Characters   Blue Eyes  Blond Hair  Male Characters  NaN
#
#                ALIVE  APPEARANCES FIRST APPEARANCE    Year
# 0  Living Characters       4043.0           Aug-62  1962.0
# 1  Living Characters       3360.0           Mar-41  1941.0
# 2  Living Characters       3061.0           Oct-74  1974.0
# 3  Living Characters       2961.0           Mar-63  1963.0
# 4  Living Characters       2258.0           Nov-50  1950.0

# %%
import plotly.express as px

# %%
df = px.data.tips()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %%
marvel_filter = marvel.drop(['GSM'], axis = 1).dropna()
dc_filter = dc.drop(['GSM'], axis = 1).dropna()
q = """select 'marvel' as Universe,SEX, 
count(*) as count from marvel_filter
group by 1,2"""
q = """select 'marvel' as universe, SEX, EYE from marvel_filter"""
marvel_filter = pysqldf(q)
q = """select 'dc' as Universe,SEX, 
count(*) as count from dc_filter
group by 1,2"""
q = """select 'dc' as universe, SEX, EYE from dc_filter"""
dc_filter = pysqldf(q)

# %%
merged_filter = pd.concat([marvel_filter, dc_filter], axis = 0, ignore_index = True)
merged_filter.columns
# Out:
# Index(['universe', 'SEX', 'EYE'], dtype='object')

# %%
merged_filter.head()
# Out:
#   universe              SEX         EYE
# 0   marvel  Male Characters  Hazel Eyes
# 1   marvel  Male Characters   Blue Eyes
# 2   marvel  Male Characters   Blue Eyes
# 3   marvel  Male Characters   Blue Eyes
# 4   marvel  Male Characters   Blue Eyes

# %%
fig = px.parallel_categories(merged_filter, dimensions=['universe', 'SEX'])
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="3c1692e2-4651-41c2-81de-f46c415e27b2" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3c1692e2-4651-41c2-81de-f46c415e27b2")) {
#                     Plotly.newPlot(
#                         '3c1692e2-4651-41c2-81de-f46c415e27b2',
#                         [{"dimensions": [{"label": "universe", "values": ["marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marvel", "marve ...

# %%
marvel_filter = marvel.drop(['GSM'], axis = 1).dropna()
dc_filter = dc.drop(['GSM'], axis = 1).dropna()
q = """select 'marvel' as Universe,SEX, EYE,
count(*) as count from marvel_filter
group by 1,2,3"""
# q = """select 'marvel' as universe, SEX, EYE from marvel_filter"""
marvel_filter = pysqldf(q)
q = """select 'dc' as Universe,SEX, EYE,
count(*) as count from dc_filter
group by 1,2,3"""
# q = """select 'dc' as universe, SEX, EYE from dc_filter"""
dc_filter = pysqldf(q)
merged_filter = pd.concat([marvel_filter, dc_filter], axis = 0, ignore_index = True)
merged_filter.head()
# Out:
#   Universe                 SEX            EYE  count
# 0   marvel  Agender Characters     Black Eyes      2
# 1   marvel  Agender Characters     Brown Eyes      1
# 2   marvel  Agender Characters     Green Eyes      1
# 3   marvel  Agender Characters       Red Eyes      1
# 4   marvel  Agender Characters  Variable Eyes      2

# %%
px.scatter(merged_filter,x = "SEX", y="EYE", size = "count", color = "Universe")
# Out:
# <div>
#
#
#             <div id="bb034118-50c9-4331-b8c1-af0e7fb74243" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bb034118-50c9-4331-b8c1-af0e7fb74243")) {
#                     Plotly.newPlot(
#                         'bb034118-50c9-4331-b8c1-af0e7fb74243',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Universe=marvel<br>SEX=%{x}<br>EYE=%{y}<br>count=%{marker.size}", "legendgroup": "Universe=marvel", "marker": {"color": "#636efa", "size": [2, 1, 1, 1, 2, 5, 2, 2, 75, 500, 374, 2, 188, 18, 10, 2, 1, 1, 4, 3, 10, 45, 4, 5, 6, 47, 2, 38, 1, 1, 4, 1, 240, 948, 959, 8, 234, 55, 42, 1, 2, 12, 15, 8, 10, 220, 2, 17, 2, 159, 2, 108], "sizemode": "area", "sizeref": 2.3975, "symbol": "circle"}, "mode": "markers", "name": "Universe=marvel", "showlegend": true, "type": "scatter", "x": ["Agender Characters", "Agender Characters", "Agender Characters", "Agender Characters", "Agender Characters", "Agender Characters", "Agender Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Genderfluid Characters", "Genderfluid Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters"], "xaxis": "x", "y": ["Black Eyes", "Brown Eyes", "Green Eyes", "Red Eyes", "Variable Eyes", "White Eyes", "Yellow Eyes", "Black Eyeballs", "Black Eyes", "Blue Eyes", "Brown Eyes", "Gold Eyes", "Green Eyes", "Grey Eyes", "Hazel Eyes", "Magenta Eyes", "Multiple Eyes", "No Eyes", "Orange Eyes", "Pink Eyes", "Purple Eyes", "Red Eyes", "Silver Eyes", "Variable Eyes", "Violet Eyes", "White Eyes", "Yellow Eyeballs", "Yellow Eyes", "Brown Eyes", "Green Eyes", "Amber Eyes", "Black Eyeballs", "Black Eyes", "Blue Eyes", "Brown Eyes", "Gold Eyes", "Green Eyes", "Grey Eyes", "Hazel Eyes", "Multiple Eyes", "No Eyes", "One Eye", "Orange Eyes", "Pink Eyes", "Purple Eyes", "Red Eyes", "Silver Eyes", "Variable Eyes", "Violet Eyes", "White Eyes", "Yellow Eyeballs", "Yellow Eyes"], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Universe=dc<br>SEX=%{x}<br>EYE=%{y}<br>count=%{marker.size}", "legendgroup": "Universe=dc", "marker": {"color": "#EF553B", "size": [3, 66, 282, 208, 3, 109, 8, 10, 1, 3, 6, 26, 8, 21, 6, 1, 1, 1, 185, 523, 398, 3, 65, 19, 10, 1, 3, 2, 74, 1, 28, 22], "sizemode": "area", "sizeref": 2.3975, "symbol": "circle"}, "mode": "markers", "name": "Universe=dc", "showlegend": true, "type": "scatter", "x": ["Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Female Characters", "Genderless Characters", "Genderless Characters", "Genderless Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters", "Male Characters"], "xaxis": "x", "y": ["Amber Eyes", "Black Eyes", "Blue Eyes", "Brown Eyes", "Gold Eyes", "Green Eyes", "Grey Eyes", "Hazel Eyes", "Orange Eyes", "Pink Eyes", "Purple Eyes", "Red Eyes", "Violet Eyes", "White Eyes", "Yellow Eyes", "Black Eyes", "Brown Eyes", "Green Eyes", "Black Eyes", "Blue Eyes", "Brown Eyes", "Gold Eyes", "Green Eyes", "Grey Eyes", "Hazel Eyes", "Orange Eyes", "Photocellular Eyes", "Purple Eyes", "Red Eyes", "Violet Eyes", "White Eyes", "Yellow Eyes"], "yaxis": ...
#                         {"height": 600, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"color
