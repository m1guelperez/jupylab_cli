# %% [markdown]
# # CITY VS RESTAURANTS COUNT PLOTING INSIDE INDIAN MAP USING BASEMAP LIBRARY ,I WILL BE USING THE ZOMATO DATA SET ONLY WHICH I USED IN MY LAST KERNAL.
# # THE CODE WILL BE A BIT COMPLEX AS I WILL USE SOME ADDITONAL APIS FROM GOOGLE FOR FINIDING THE LONGITUDE AND LATITUDES OF DIFFERENT CITIES TO SET AND PLOT THE CITY LOCATIONS
# # STAY TUNE FOR MORE UPDATES AND DONT FORGET TO SUBSCRIBE TO OUR YOUTUBE CHANNEL https://www.youtube.com/channel/UCYtH9iBldgQo4ns2xI1PHhw?view_as=subscriber

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from glob import glob as gb

# %%
#list all the directories
dirs=os.listdir("../input/zomato_data/")
dirs
# Out:
# ['Nashik',
#  'Allahabad',
#  'Guntur',
#  'Bhopal',
#  'Udaipur',
#  'Coimbatore',
#  'Mangalore',
#  'Chennai',
#  'Shimla',
#  'Trivandrum',
#  'Vijayawada',
#  'Tirupati',
#  'Goa',
#  'Salem',
#  'Rajkot',
#  'Mumbai',
#  'Gwalior',
#  'Jamnagar',
#  'Mussoorie',
#  'Bengaluru',
#  'Vadodara',
#  'Amritsar',
#  'Dharamshala',
#  'Meerut',
#  'Lucknow',
#  'Thrissur',
#  'Nainital',
#  'Mysore',
#  'Guwahati',
#  'Rishikesh',
#  'Patna',
#  'Manali',
#  'Visakhapatnam',
#  'Ludhiana',
#  'Jamshedpur',
#  'Kota',
#  'Haridwar',
#  'Kochi',
#  'Jalandhar',
#  'Jodhpur',
#  'Puducherry',
#  'Delhi NCR',
#  'Jaipur',
#  'Ahmedabad',
#  'Patiala',
#  'Varanasi',
#  'Siliguri',
#  'Bhubaneswar',
#  'Alappuzha',
#  'Trichy',
#  'Kanpur',
#  'Gangtok',
#  'Manipal',
#  'Jhansi',
#  'Palakkad',
#  'Raipur',
#  'Madurai',
#  'Kolkata',
#  'Kolhapur',
#  'Agra',
#  'Cuttack',
#  'Hyderabad',
#  'Aurangabad',
#  'Jammu',
#  'Gorakhpur',
#  'Indore',
#  'Amravati',
#  'Jabalpur',
#  'Surat',
#  'Ranchi',
#  'Pune',
#  'Ooty',
#  'Chandigarh',
#  'Srinagar',
#  'Ajmer',
#  'Pushkar',
#  'Nagpur',
#  'Neemrana',
#  'Dehradun',
#  'Vellore',
#  'Darjeeling']

# %%
len(dirs)
# Out:
# 81

# %%
#storing all the files from every directory
li=[]
for dir1 in dirs:
    files=os.listdir(r"../input/zomato_data/"+dir1)
    #reading each file from list of files from previous step and creating pandas data fame    
    for file in files:
        
        df_file=pd.read_csv("../input/zomato_data/"+dir1+"/"+file,quotechar='"',delimiter="|")
#appending the dataframe into a list
        li.append(df_file.values)

# %%
len(li)
# Out:
# 7089

# %%
#numpys vstack method to append all the datafames to stack the sequence of input vertically to make a single array
df_np=np.vstack(li)

# %%
#no of rows is represents the total no restaurants ,now of coloumns(12) is columns for the dataframe
df_np.shape
# Out:
# (105623, 12)

# %%
#creating final dataframe from the numpy array
df_final=pd.DataFrame(df_np)

# %%
#adding the header columns
df_final=pd.DataFrame(df_final.values, columns =["NAME","PRICE","CUSINE_CATEGORY","CITY","REGION","URL","PAGE NO","CUSINE TYPE","TIMING","RATING_TYPE","RATING","VOTES"])

# %%
#displaying the dataframe
df_final
# Out:
#                                           NAME PRICE  ...  RATING VOTES
# 0                                    S.P Foods   300  ...     NEW   NEW
# 1                    Mahesh Snacks and Chinese   300  ...     NEW   NEW
# 2               Sachin Foods & Bakery Products   250  ...       -     -
# 3                   Shree Sadguru Juice Center   300  ...     NEW   NEW
# 4                          Sippers Choice Cafe   300  ...       -     -
# 5                               Kondaji Chivda   300  ...       -     -
# 6                                 Bakers Kraft   400  ...       -     -
# 7                       Zaki Dum Biryani House   300  ...       -     -
# 8                            Yash Cake Factory   250  ...       -     -
# 9                                    T20 Foodz   250  ...       -     -
# 10                          Soni Snacks Corner   200  ...       -     -
# 11                        Amritsari By Kalra's   300  ...     NEW   NEW
# 12                    Jay Yogeshwar Fast Foods   200  ...       -     -
# 13                        Quality Parcel Point   300  ...     NEW   NEW
# 14                             Cakes N Cookies   500  ...       -     -
# 15                           The Second Empire   800  ...     4.1    33
# 16                              VM Enterprises   500  ...     3.7    31
# 17                   Tandoor Family Restaurant   650  ...     3.6    56
# 18                              Roadside Wraps   200  ...     3.7    60
# 19                         D S Biryani Express   250  ...     3.6    16
# 20                            Shivsagar's Fern   500  ...     3.9    45
# 21                            Spirits N Spices  1200  ...     3.7    17
# 22                             Hotel Saptarang   500  ...     3.9    63
# 23                        Jagannath Restaurant   500  ...     2.7    35
# 24                                     Bobby's   500  ...     3.7    41
# 25                                Twisty Tasty   400  ...     3.6    22
# 26                                Live Baker's   200  ...       -     -
# 27                                       Utsav   500  ...     4.0    34
# 28                         Shalimar Restaurant   400  ...     3.5    54
# 29                                    Kareem's   600  ...     3.7    38
# ...                                        ...   ...  ...     ...   ...
# 105593                  Hotel Sai Suprabaatham   250  ...     3.3     5
# 105594                               Auro Cafe   250  ...     3.3    10
# 105595         Nalan's Multicuisine Restaurant   300  ...     3.2    10
# 105596                     Bangs Fried Chicken   300  ...     3.2     4
# 105597                     Fresh & Fresh Juice   100  ...     3.2     6
# 105598                           Wangs Kitchen   500  ...     3.2    11
# 105599                      The Vellore Bakers   200  ...     3.3     5
# 105600                              Lassi Shop   250  ...       -     -
# 105601                            Crispy House   250  ...     3.2     6
# 105602                        Royal Restaurant   600  ...       -     -
# 105603                             Kulfi House   300  ...     3.2    12
# 105604                            Bombay Kulfi   150  ...       -     -
# 105605  Sri Amaravathi Fine Dinning Restaurant   250  ...     3.3     4
# 105606                           Harish Banyan   450  ...     3.2     7
# 105607                            Yaseen Dhaba   300  ...     3.4    15
# 105608                           Punjabi Dhaba   300  ...     3.2    24
# 105609                       Andhra Aunty Mess   250  ...     3.3    16
# 105610                         Royal Fast Food   250  ...     3.5    16
# 105611                  Rajshree Punjabi Dhaba   200  ...     3.5     9
# 105612                      Goli Vada Pav No:1   200  ...     3.3    20
# 105613                           Green Kitchen   350  ...     3.3    20
# 105614                          King Fast Food   200  ...     3.3    11
# 105615                 Rajshree Mithai & Chats   200  ...     3.4    10
# 105616                             Hart Lounge   250  ...     NEW   NEW
# 105617                            Madras Spicy   350  ...     3.4    11
# 105618                  Star Beef Sheek  Kabab   300  ...     3.4    14
# 105619                            Paaya Palace   200  ...     3.3     8
# 105620                           Bismi Briyani   200  ...     3.2     9
# 105621                            Lassi Corner   200  ...     3.2     9
# 105622                          Domino's Pizza   400  ...       -     -
#
# [105623 rows x 12 columns]

# %%
#header column "PAGE NO" is not required ,i used it while scraping the data from zomato to do some sort of validation,lets remove the column
df_final.drop(columns=["PAGE NO"],axis=1,inplace=True)

# %%
#display the dataframe again
df_final
# Out:
#                                           NAME PRICE  ...  RATING VOTES
# 0                                    S.P Foods   300  ...     NEW   NEW
# 1                    Mahesh Snacks and Chinese   300  ...     NEW   NEW
# 2               Sachin Foods & Bakery Products   250  ...       -     -
# 3                   Shree Sadguru Juice Center   300  ...     NEW   NEW
# 4                          Sippers Choice Cafe   300  ...       -     -
# 5                               Kondaji Chivda   300  ...       -     -
# 6                                 Bakers Kraft   400  ...       -     -
# 7                       Zaki Dum Biryani House   300  ...       -     -
# 8                            Yash Cake Factory   250  ...       -     -
# 9                                    T20 Foodz   250  ...       -     -
# 10                          Soni Snacks Corner   200  ...       -     -
# 11                        Amritsari By Kalra's   300  ...     NEW   NEW
# 12                    Jay Yogeshwar Fast Foods   200  ...       -     -
# 13                        Quality Parcel Point   300  ...     NEW   NEW
# 14                             Cakes N Cookies   500  ...       -     -
# 15                           The Second Empire   800  ...     4.1    33
# 16                              VM Enterprises   500  ...     3.7    31
# 17                   Tandoor Family Restaurant   650  ...     3.6    56
# 18                              Roadside Wraps   200  ...     3.7    60
# 19                         D S Biryani Express   250  ...     3.6    16
# 20                            Shivsagar's Fern   500  ...     3.9    45
# 21                            Spirits N Spices  1200  ...     3.7    17
# 22                             Hotel Saptarang   500  ...     3.9    63
# 23                        Jagannath Restaurant   500  ...     2.7    35
# 24                                     Bobby's   500  ...     3.7    41
# 25                                Twisty Tasty   400  ...     3.6    22
# 26                                Live Baker's   200  ...       -     -
# 27                                       Utsav   500  ...     4.0    34
# 28                         Shalimar Restaurant   400  ...     3.5    54
# 29                                    Kareem's   600  ...     3.7    38
# ...                                        ...   ...  ...     ...   ...
# 105593                  Hotel Sai Suprabaatham   250  ...     3.3     5
# 105594                               Auro Cafe   250  ...     3.3    10
# 105595         Nalan's Multicuisine Restaurant   300  ...     3.2    10
# 105596                     Bangs Fried Chicken   300  ...     3.2     4
# 105597                     Fresh & Fresh Juice   100  ...     3.2     6
# 105598                           Wangs Kitchen   500  ...     3.2    11
# 105599                      The Vellore Bakers   200  ...     3.3     5
# 105600                              Lassi Shop   250  ...       -     -
# 105601                            Crispy House   250  ...     3.2     6
# 105602                        Royal Restaurant   600  ...       -     -
# 105603                             Kulfi House   300  ...     3.2    12
# 105604                            Bombay Kulfi   150  ...       -     -
# 105605  Sri Amaravathi Fine Dinning Restaurant   250  ...     3.3     4
# 105606                           Harish Banyan   450  ...     3.2     7
# 105607                            Yaseen Dhaba   300  ...     3.4    15
# 105608                           Punjabi Dhaba   300  ...     3.2    24
# 105609                       Andhra Aunty Mess   250  ...     3.3    16
# 105610                         Royal Fast Food   250  ...     3.5    16
# 105611                  Rajshree Punjabi Dhaba   200  ...     3.5     9
# 105612                      Goli Vada Pav No:1   200  ...     3.3    20
# 105613                           Green Kitchen   350  ...     3.3    20
# 105614                          King Fast Food   200  ...     3.3    11
# 105615                 Rajshree Mithai & Chats   200  ...     3.4    10
# 105616                             Hart Lounge   250  ...     NEW   NEW
# 105617                            Madras Spicy   350  ...     3.4    11
# 105618                  Star Beef Sheek  Kabab   300  ...     3.4    14
# 105619                            Paaya Palace   200  ...     3.3     8
# 105620                           Bismi Briyani   200  ...     3.2     9
# 105621                            Lassi Corner   200  ...     3.2     9
# 105622                          Domino's Pizza   400  ...       -     -
#
# [105623 rows x 11 columns]

# %%
#lets count how many unique cities are there 

df_final["CITY"].unique()
# Out:
# array(['Nashik', 'Allahabad', 'Guntur', 'Bhopal', 'Udaipur', 'Coimbatore',
#        'Mangalore', 'Chennai', 'Shimla', 'Trivandrum', 'Vijayawada',
#        'Tirupati', 'Goa', 'Salem', 'Rajkot', 'Mumbai', 'Gwalior',
#        'Jamnagar', 'Mussoorie', 'Bengaluru', 'Vadodara', 'Amritsar',
#        'Dharamshala', 'Meerut', 'Lucknow', 'Thrissur', 'Nainital',
#        'Mysore', 'Guwahati', 'Rishikesh', 'Patna', 'Manali',
#        'Visakhapatnam', 'Ludhiana', 'Jamshedpur', 'Kota', 'Haridwar',
#        'Kochi', 'Jalandhar', 'Jodhpur', 'Puducherry', 'Delhi NCR',
#        'Jaipur', 'Ahmedabad', 'Patiala', 'Varanasi', 'Siliguri',
#        'Bhubaneswar', 'Alappuzha', 'Trichy', 'Kanpur', 'Gangtok',
#        'Manipal', 'Jhansi', 'Palakkad', 'Raipur', 'Madurai', 'Kolkata',
#        'Kolhapur', 'Agra', 'Cuttack', 'Hyderabad', 'Aurangabad', 'Jammu',
#        'Gorakhpur', 'Indore', 'Amravati', 'Jabalpur', 'Surat', 'Ranchi',
#        'Pune', 'Ooty', 'Chandigarh', 'Srinagar', 'Ajmer', 'Pushkar',
#        'Nagpur', 'Neemrana', 'Dehradun', 'Vellore', 'Darjeeling'],
#       dtype=object)

# %%
# import json and requests library to use googl apis to get the longitude ant latituide values
import requests
import json

#creating a separate array with all city names as elements of array
city_name=df_final["CITY"].unique()
li1=[]

#googlemap api calling url 
geo_s ='https://maps.googleapis.com/maps/api/geocode/json'
#iterating through a for loop for each city names 
for i in range(len(city_name)):

#i have used my own google map api, please use ypur own api     
 param = {'address': city_name[i], 'key': 'AIzaSyD-kYTK-8FQGueJqA2028t2YHbUX96V0vk'}
 
 response = requests.get(geo_s, params=param)
 
 response=response.text

 data=json.loads(response)

#setting up the variable with corresponding city longitude and latitude
 lat=data["results"][0]["geometry"]["location"]["lat"]
 lng=data["results"][0]["geometry"]["location"]["lng"]

#creating a new data frame with city , latitude and longitude as columns
 df2=pd.DataFrame([[city_name[i],lat,lng]])
 li1.append(df2.values)

# %%
#numpys vstack method to append all the datafames to stack the sequence of input vertically to make a single array
df_np=np.vstack(li1)

# %%
#creating a second dataframe with city name, latitude and longitude
df_sec=pd.DataFrame(df_np,columns=["CITY","lat","lng"])

# %%
#display the second dataframe contents
df_sec
# Out:
#            CITY      lat      lng
# 0        Nashik  19.9975  73.7898
# 1     Allahabad  25.4358  81.8463
# 2        Guntur  16.3067  80.4365
# 3        Bhopal  23.2599  77.4126
# 4       Udaipur  24.5854  73.7125
# 5    Coimbatore  11.0168  76.9558
# 6     Mangalore  12.9141   74.856
# 7       Chennai  13.0827  80.2707
# 8        Shimla  31.1048  77.1734
# 9    Trivandrum  8.52414  76.9366
# 10   Vijayawada  16.5062   80.648
# 11     Tirupati  13.6288  79.4192
# 12          Goa  15.2993   74.124
# 13        Salem  42.5195 -70.8967
# 14       Rajkot  22.3039  70.8022
# 15       Mumbai   19.076  72.8777
# 16      Gwalior  26.2183  78.1828
# 17     Jamnagar  22.4707  70.0577
# 18    Mussoorie  30.4599  78.0664
# 19    Bengaluru  12.9716  77.5946
# 20     Vadodara  22.3072  73.1812
# 21     Amritsar   31.634  74.8723
# 22  Dharamshala   32.219  76.3234
# 23       Meerut  28.9845  77.7064
# 24      Lucknow  26.8467  80.9462
# 25     Thrissur  10.5276  76.2144
# 26     Nainital  29.3803  79.4636
# 27       Mysore  12.2958  76.6394
# 28     Guwahati  26.1445  91.7362
# 29    Rishikesh  30.0869  78.2676
# ..          ...      ...      ...
# 51      Gangtok  27.3389  88.6065
# 52      Manipal  13.3605  74.7864
# 53       Jhansi  25.4484  78.5685
# 54     Palakkad  10.7867  76.6548
# 55       Raipur  21.2514  81.6296
# 56      Madurai   9.9252  78.1198
# 57      Kolkata  22.5726  88.3639
# 58     Kolhapur   16.705  74.2433
# 59         Agra  27.1767  78.0081
# 60      Cuttack  20.4625   85.883
# 61    Hyderabad   17.385  78.4867
# 62   Aurangabad  19.8762  75.3433
# 63        Jammu  33.7782  76.5762
# 64    Gorakhpur  29.4438  75.6703
# 65       Indore  22.7196  75.8577
# 66     Amravati   20.932  77.7523
# 67     Jabalpur  23.1815  79.9864
# 68        Surat  21.1702  72.8311
# 69       Ranchi  23.3441  85.3096
# 70         Pune  18.5204  73.8567
# 71         Ooty  11.4064  76.6932
# 72   Chandigarh  30.7333  76.7794
# 73     Srinagar  34.0837  74.7973
# 74        Ajmer  26.4499  74.6399
# 75      Pushkar  26.4897  74.5511
# 76       Nagpur  21.1458  79.0882
# 77     Neemrana  27.9854  76.3827
# 78     Dehradun  30.3165  78.0322
# 79      Vellore  12.9165  79.1325
# 80   Darjeeling   27.036  88.2627
#
# [81 rows x 3 columns]

# %%
#merge this data frame to the existing df_final data frame using merge and join features from pandas,and creating a new data frame
df_final2=df_final.merge(df_sec,on="CITY",how="left")

# %%
#display the contents , it will have longitude and latitude now
df_final2
# Out:
#                                           NAME PRICE   ...         lat      lng
# 0                                    S.P Foods   300   ...     19.9975  73.7898
# 1                    Mahesh Snacks and Chinese   300   ...     19.9975  73.7898
# 2               Sachin Foods & Bakery Products   250   ...     19.9975  73.7898
# 3                   Shree Sadguru Juice Center   300   ...     19.9975  73.7898
# 4                          Sippers Choice Cafe   300   ...     19.9975  73.7898
# 5                               Kondaji Chivda   300   ...     19.9975  73.7898
# 6                                 Bakers Kraft   400   ...     19.9975  73.7898
# 7                       Zaki Dum Biryani House   300   ...     19.9975  73.7898
# 8                            Yash Cake Factory   250   ...     19.9975  73.7898
# 9                                    T20 Foodz   250   ...     19.9975  73.7898
# 10                          Soni Snacks Corner   200   ...     19.9975  73.7898
# 11                        Amritsari By Kalra's   300   ...     19.9975  73.7898
# 12                    Jay Yogeshwar Fast Foods   200   ...     19.9975  73.7898
# 13                        Quality Parcel Point   300   ...     19.9975  73.7898
# 14                             Cakes N Cookies   500   ...     19.9975  73.7898
# 15                           The Second Empire   800   ...     19.9975  73.7898
# 16                              VM Enterprises   500   ...     19.9975  73.7898
# 17                   Tandoor Family Restaurant   650   ...     19.9975  73.7898
# 18                              Roadside Wraps   200   ...     19.9975  73.7898
# 19                         D S Biryani Express   250   ...     19.9975  73.7898
# 20                            Shivsagar's Fern   500   ...     19.9975  73.7898
# 21                            Spirits N Spices  1200   ...     19.9975  73.7898
# 22                             Hotel Saptarang   500   ...     19.9975  73.7898
# 23                        Jagannath Restaurant   500   ...     19.9975  73.7898
# 24                                     Bobby's   500   ...     19.9975  73.7898
# 25                                Twisty Tasty   400   ...     19.9975  73.7898
# 26                                Live Baker's   200   ...     19.9975  73.7898
# 27                                       Utsav   500   ...     19.9975  73.7898
# 28                         Shalimar Restaurant   400   ...     19.9975  73.7898
# 29                                    Kareem's   600   ...     19.9975  73.7898
# ...                                        ...   ...   ...         ...      ...
# 105593                  Hotel Sai Suprabaatham   250   ...     12.9165  79.1325
# 105594                               Auro Cafe   250   ...     12.9165  79.1325
# 105595         Nalan's Multicuisine Restaurant   300   ...     12.9165  79.1325
# 105596                     Bangs Fried Chicken   300   ...     12.9165  79.1325
# 105597                     Fresh & Fresh Juice   100   ...     12.9165  79.1325
# 105598                           Wangs Kitchen   500   ...     12.9165  79.1325
# 105599                      The Vellore Bakers   200   ...     12.9165  79.1325
# 105600                              Lassi Shop   250   ...     12.9165  79.1325
# 105601                            Crispy House   250   ...     12.9165  79.1325
# 105602                        Royal Restaurant   600   ...     12.9165  79.1325
# 105603                             Kulfi House   300   ...     12.9165  79.1325
# 105604                            Bombay Kulfi   150   ...     12.9165  79.1325
# 105605  Sri Amaravathi Fine Dinning Restaurant   250   ...     12.9165  79.1325
# 105606                           Harish Banyan   450   ...     12.9165  79.1325
# 105607                            Yaseen Dhaba   300   ...     12.9165  79.1325
# 105608                           Punjabi Dhaba   300   ...     12.9165  79.1325
# 105609                       Andhra Aunty Mess   250   ...     12.9165  79.1325
# 105610                         Royal Fast Food   250   ...     12.9165  79.1325
# 105611                  Rajshree Punjabi Dhaba   200   ...     12.9165  79.1325
# 105612                      Goli Vada Pav No:1   200   ...     12.9165  79.1325
# 105613                           Green Kitchen   350   ...     12.9165  79.1325
# 105614                          King Fast Food   200   ...     12.9165  79.1325
# 105615                 Rajshree Mithai & Chats   200   ...     12.9165  79.1325
# 105616                             Hart Lounge   250   ...     12.9165  79.1325
# 105617                            Madras Spicy   350   ...     12.9165  79.1325
# 105618                  Star Beef Sheek  Kabab   300   ...     12.9165  79.1325
# 105619                            Paaya Palace   200   ...     12.9165  79.1325
# 105620                           Bismi Briyani   200   ...     12.9165  79.1325
# 105621                            Lassi Corner   200   ...     12.9165  79.1325
# 105622                          Domino's Pizza   400   ...      27.036  88.2627
#
# [105623 rows x 13 columns]

# %%
#creating pandas series to hold the citynames and corresponding count of restuarnats in ascending order
li2=df_final["CITY"].value_counts().sort_values(ascending=True)

# %%
li2
# Out:
# Darjeeling         1
# Neemrana           3
# Pushkar            4
# Gangtok            5
# Mussoorie         11
# Rishikesh         15
# Alappuzha         17
# Manali            17
# Palakkad          18
# Srinagar          19
# Shimla            29
# Nainital          43
# Dharamshala       50
# Ooty              67
# Vellore          141
# Salem            146
# Tirupati         161
# Jamnagar         164
# Siliguri         176
# Thrissur         182
# Amravati         182
# Cuttack          187
# Haridwar         207
# Guntur           207
# Trichy           221
# Gorakhpur        240
# Ajmer            260
# Manipal          261
# Kolhapur         277
# Jamshedpur       290
#                ...
# Patna            678
# Guwahati         706
# Udaipur          742
# Nashik           783
# Dehradun         802
# Aurangabad       803
# Raipur           817
# Kanpur           835
# Agra             893
# Goa              901
# Kochi           1031
# Surat           1039
# Coimbatore      1056
# Bhubaneswar     1073
# Ludhiana        1272
# Bhopal          1280
# Vadodara        1288
# Indore          1622
# Nagpur          1683
# Lucknow         1838
# Chandigarh      2145
# Ahmedabad       2598
# Jaipur          2603
# Kolkata         4310
# Chennai         4845
# Hyderabad       5255
# Pune            7549
# Bengaluru       8506
# Mumbai         14138
# Delhi NCR      19610
# Name: CITY, Length: 81, dtype: int64

# %%
#creating a empty dictionary
dc={}

#setting dictionary values as city name , count of restuarnat and key will city names as well
for i,j in li2.items():
    x=i + "," +str(j)
    dc.update({i:[i,j]})

# %%
#displaying the dictionary
dc
# Out:
# {'Darjeeling': ['Darjeeling', 1],
#  'Neemrana': ['Neemrana', 3],
#  'Pushkar': ['Pushkar', 4],
#  'Gangtok': ['Gangtok', 5],
#  'Mussoorie': ['Mussoorie', 11],
#  'Rishikesh': ['Rishikesh', 15],
#  'Alappuzha': ['Alappuzha', 17],
#  'Manali': ['Manali', 17],
#  'Palakkad': ['Palakkad', 18],
#  'Srinagar': ['Srinagar', 19],
#  'Shimla': ['Shimla', 29],
#  'Nainital': ['Nainital', 43],
#  'Dharamshala': ['Dharamshala', 50],
#  'Ooty': ['Ooty', 67],
#  'Vellore': ['Vellore', 141],
#  'Salem': ['Salem', 146],
#  'Tirupati': ['Tirupati', 161],
#  'Jamnagar': ['Jamnagar', 164],
#  'Siliguri': ['Siliguri', 176],
#  'Thrissur': ['Thrissur', 182],
#  'Amravati': ['Amravati', 182],
#  'Cuttack': ['Cuttack', 187],
#  'Haridwar': ['Haridwar', 207],
#  'Guntur': ['Guntur', 207],
#  'Trichy': ['Trichy', 221],
#  'Gorakhpur': ['Gorakhpur', 240],
#  'Ajmer': ['Ajmer', 260],
#  'Manipal': ['Manipal', 261],
#  'Kolhapur': ['Kolhapur', 277],
#  'Jamshedpur': ['Jamshedpur', 290],
#  'Jammu': ['Jammu', 293],
#  'Jhansi': ['Jhansi', 303],
#  'Trivandrum': ['Trivandrum', 309],
#  'Puducherry': ['Puducherry', 335],
#  'Vijayawada': ['Vijayawada', 347],
#  'Meerut': ['Meerut', 364],
#  'Allahabad': ['Allahabad', 370],
#  'Madurai': ['Madurai', 375],
#  'Patiala': ['Patiala', 392],
#  'Rajkot': ['Rajkot', 406],
#  'Jabalpur': ['Jabalpur', 409],
#  'Mysore': ['Mysore', 422],
#  'Mangalore': ['Mangalore', 480],
#  'Jalandhar': ['Jalandhar', 485],
#  'Gwalior': ['Gwalior', 526],
#  'Amritsar': ['Amritsar', 537],
#  'Jodhpur': ['Jodhpur', 537],
#  'Varanasi': ['Varanasi', 552],
#  'Kota': ['Kota', 584],
#  'Ranchi': ['Ranchi', 647],
#  'Visakhapatnam': ['Visakhapatnam', 648],
#  'Patna': ['Patna', 678],
#  'Guwahati': ['Guwahati', 706],
#  'Udaipur': ['Udaipur', 742],
#  'Nashik': ['Nashik', 783],
#  'Dehradun': ['Dehradun', 802],
#  'Aurangabad': ['Aurangabad', 803],
#  'Raipur': ['Raipur', 817],
#  'Kanpur': ['Kanpur', 835],
#  'Agra': ['Agra', 893],
#  'Goa': ['Goa', 901],
#  'Kochi': ['Kochi', 1031],
#  'Surat': ['Surat', 1039],
#  'Coimbatore': ['Coimbatore', 1056],
#  'Bhubaneswar': ['Bhubaneswar', 1073],
#  'Ludhiana': ['Ludhiana', 1272],
#  'Bhopal': ['Bhopal', 1280],
#  'Vadodara': ['Vadodara', 1288],
#  'Indore': ['Indore', 1622],
#  'Nagpur': ['Nagpur', 1683],
#  'Lucknow': ['Lucknow', 1838],
#  'Chandigarh': ['Chandigarh', 2145],
#  'Ahmedabad': ['Ahmedabad', 2598],
#  'Jaipur': ['Jaipur', 2603],
#  'Kolkata': ['Kolkata', 4310],
#  'Chennai': ['Chennai', 4845],
#  'Hyderabad': ['Hyderabad', 5255],
#  'Pune': ['Pune', 7549],
#  'Bengaluru': ['Bengaluru', 8506],
#  'Mumbai': ['Mumbai', 14138],
#  'Delhi NCR': ['Delhi NCR', 19610]}

# %%
#creating another data frame from the above dictionary
df_map=pd.DataFrame.from_dict(dc,orient="index",columns=["CITY","COUNT"])

# %%
#displaying the data frame
df_map
# Out:
#                     CITY  COUNT
# Darjeeling    Darjeeling      1
# Neemrana        Neemrana      3
# Pushkar          Pushkar      4
# Gangtok          Gangtok      5
# Mussoorie      Mussoorie     11
# Rishikesh      Rishikesh     15
# Alappuzha      Alappuzha     17
# Manali            Manali     17
# Palakkad        Palakkad     18
# Srinagar        Srinagar     19
# Shimla            Shimla     29
# Nainital        Nainital     43
# Dharamshala  Dharamshala     50
# Ooty                Ooty     67
# Vellore          Vellore    141
# Salem              Salem    146
# Tirupati        Tirupati    161
# Jamnagar        Jamnagar    164
# Siliguri        Siliguri    176
# Thrissur        Thrissur    182
# Amravati        Amravati    182
# Cuttack          Cuttack    187
# Haridwar        Haridwar    207
# Guntur            Guntur    207
# Trichy            Trichy    221
# Gorakhpur      Gorakhpur    240
# Ajmer              Ajmer    260
# Manipal          Manipal    261
# Kolhapur        Kolhapur    277
# Jamshedpur    Jamshedpur    290
# ...                  ...    ...
# Patna              Patna    678
# Guwahati        Guwahati    706
# Udaipur          Udaipur    742
# Nashik            Nashik    783
# Dehradun        Dehradun    802
# Aurangabad    Aurangabad    803
# Raipur            Raipur    817
# Kanpur            Kanpur    835
# Agra                Agra    893
# Goa                  Goa    901
# Kochi              Kochi   1031
# Surat              Surat   1039
# Coimbatore    Coimbatore   1056
# Bhubaneswar  Bhubaneswar   1073
# Ludhiana        Ludhiana   1272
# Bhopal            Bhopal   1280
# Vadodara        Vadodara   1288
# Indore            Indore   1622
# Nagpur            Nagpur   1683
# Lucknow          Lucknow   1838
# Chandigarh    Chandigarh   2145
# Ahmedabad      Ahmedabad   2598
# Jaipur            Jaipur   2603
# Kolkata          Kolkata   4310
# Chennai          Chennai   4845
# Hyderabad      Hyderabad   5255
# Pune                Pune   7549
# Bengaluru      Bengaluru   8506
# Mumbai            Mumbai  14138
# Delhi NCR      Delhi NCR  19610
#
# [81 rows x 2 columns]

# %%
#merging this data frame with df_sec data frame(which we created using city names,longitude and latitude)
df_map_final=df_map.merge(df_sec,on="CITY",how="left")

# %%
#displaying the new data frame this frame will be used for map ploting
df_map_final
# Out:
#            CITY  COUNT      lat      lng
# 0    Darjeeling      1   27.036  88.2627
# 1      Neemrana      3  27.9854  76.3827
# 2       Pushkar      4  26.4897  74.5511
# 3       Gangtok      5  27.3389  88.6065
# 4     Mussoorie     11  30.4599  78.0664
# 5     Rishikesh     15  30.0869  78.2676
# 6     Alappuzha     17  9.49807  76.3388
# 7        Manali     17  32.2396  77.1887
# 8      Palakkad     18  10.7867  76.6548
# 9      Srinagar     19  34.0837  74.7973
# 10       Shimla     29  31.1048  77.1734
# 11     Nainital     43  29.3803  79.4636
# 12  Dharamshala     50   32.219  76.3234
# 13         Ooty     67  11.4064  76.6932
# 14      Vellore    141  12.9165  79.1325
# 15        Salem    146  42.5195 -70.8967
# 16     Tirupati    161  13.6288  79.4192
# 17     Jamnagar    164  22.4707  70.0577
# 18     Siliguri    176  26.7271  88.3953
# 19     Thrissur    182  10.5276  76.2144
# 20     Amravati    182   20.932  77.7523
# 21      Cuttack    187  20.4625   85.883
# 22     Haridwar    207  29.9457  78.1642
# 23       Guntur    207  16.3067  80.4365
# 24       Trichy    221  10.7905  78.7047
# 25    Gorakhpur    240  29.4438  75.6703
# 26        Ajmer    260  26.4499  74.6399
# 27      Manipal    261  13.3605  74.7864
# 28     Kolhapur    277   16.705  74.2433
# 29   Jamshedpur    290  22.8046  86.2029
# ..          ...    ...      ...      ...
# 51        Patna    678  25.5941  85.1376
# 52     Guwahati    706  26.1445  91.7362
# 53      Udaipur    742  24.5854  73.7125
# 54       Nashik    783  19.9975  73.7898
# 55     Dehradun    802  30.3165  78.0322
# 56   Aurangabad    803  19.8762  75.3433
# 57       Raipur    817  21.2514  81.6296
# 58       Kanpur    835  26.4499  80.3319
# 59         Agra    893  27.1767  78.0081
# 60          Goa    901  15.2993   74.124
# 61        Kochi   1031  9.93123  76.2673
# 62        Surat   1039  21.1702  72.8311
# 63   Coimbatore   1056  11.0168  76.9558
# 64  Bhubaneswar   1073  20.2961  85.8245
# 65     Ludhiana   1272   30.901  75.8573
# 66       Bhopal   1280  23.2599  77.4126
# 67     Vadodara   1288  22.3072  73.1812
# 68       Indore   1622  22.7196  75.8577
# 69       Nagpur   1683  21.1458  79.0882
# 70      Lucknow   1838  26.8467  80.9462
# 71   Chandigarh   2145  30.7333  76.7794
# 72    Ahmedabad   2598  23.0225  72.5714
# 73       Jaipur   2603  26.9124  75.7873
# 74      Kolkata   4310  22.5726  88.3639
# 75      Chennai   4845  13.0827  80.2707
# 76    Hyderabad   5255   17.385  78.4867
# 77         Pune   7549  18.5204  73.8567
# 78    Bengaluru   8506  12.9716  77.5946
# 79       Mumbai  14138   19.076  72.8777
# 80    Delhi NCR  19610   28.402   76.826
#
# [81 rows x 4 columns]

# %%
#importing the libraries for map ploting
from matplotlib import cm
from matplotlib.dates import date2num
from mpl_toolkits.basemap import Basemap

# for date and time processing
import datetime

# %%
#lets take one data frame for top 20 cities with most retaurants counts 
df_plot_top=df_map_final.tail(20)

# %%
#displaying the data frame
df_plot_top
# Out:
#            CITY  COUNT      lat      lng
# 61        Kochi   1031  9.93123  76.2673
# 62        Surat   1039  21.1702  72.8311
# 63   Coimbatore   1056  11.0168  76.9558
# 64  Bhubaneswar   1073  20.2961  85.8245
# 65     Ludhiana   1272   30.901  75.8573
# 66       Bhopal   1280  23.2599  77.4126
# 67     Vadodara   1288  22.3072  73.1812
# 68       Indore   1622  22.7196  75.8577
# 69       Nagpur   1683  21.1458  79.0882
# 70      Lucknow   1838  26.8467  80.9462
# 71   Chandigarh   2145  30.7333  76.7794
# 72    Ahmedabad   2598  23.0225  72.5714
# 73       Jaipur   2603  26.9124  75.7873
# 74      Kolkata   4310  22.5726  88.3639
# 75      Chennai   4845  13.0827  80.2707
# 76    Hyderabad   5255   17.385  78.4867
# 77         Pune   7549  18.5204  73.8567
# 78    Bengaluru   8506  12.9716  77.5946
# 79       Mumbai  14138   19.076  72.8777
# 80    Delhi NCR  19610   28.402   76.826

# %%
#lets plot this inside the map corresponding to the cities exact co-ordinates which we received from google api 
#plt.subplots(figsize=(20,50))
plt.figure(figsize=(50,60))
map=Basemap(width=120000,height=900000,projection="lcc",resolution="l",llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=28,lon_0=77)
map.drawcountries()
map.drawmapboundary(color='#f2f2f2')

map.drawcoastlines()



lg=np.array(df_plot_top["lng"])
lat=np.array(df_plot_top["lat"])
pt=np.array(df_plot_top["COUNT"])
city_name=np.array(df_plot_top["CITY"])

x,y=map(lg,lat)

#using lambda function to create different sizes of marker as per thecount 

p_s=df_plot_top["COUNT"].apply(lambda x: int(x)/2)

#plt.scatter takes logitude ,latitude, marker size,shape,and color as parameter in the below , in this plot marker color is always blue.
plt.scatter(x,y,s=p_s,marker="o",c='BLUE')
plt.title("TOP 20 INDIAN CITIES RESTAURANT COUNTS PLOT AS PER ZOMATO",fontsize=30,color='RED')
# Out:
# Text(0.5, 1.0, 'TOP 20 INDIAN CITIES RESTAURANT COUNTS PLOT AS PER ZOMATO')

# %%
#lets plot this inside the map corresponding to the cities exact co-ordinates which we received from google api ,here marker color will be different as per marker size
#plt.subplots(figsize=(20,50))
plt.figure(figsize=(50,60))
map=Basemap(width=120000,height=900000,projection="lcc",resolution="l",llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=28,lon_0=77)
map.drawcountries()
map.drawmapboundary(color='#f2f2f2')

map.drawcoastlines()



lg=np.array(df_plot_top["lng"])
lat=np.array(df_plot_top["lat"])
pt=np.array(df_plot_top["COUNT"])
city_name=np.array(df_plot_top["CITY"])

x,y=map(lg,lat)

#using lambda function to create different sizes of marker as per thecount 

p_s=df_plot_top["COUNT"].apply(lambda x: int(x)/2)

#plt.scatter takes logitude ,latitude, marker size,shape,and color as parameter in the below , in this plot marker color is different.
plt.scatter(x,y,s=p_s,marker="o",c=p_s)
plt.title("TOP 20 INDIAN CITIES RESTAURANT COUNTS PLOT AS PER ZOMATO",fontsize=30,color='RED')
# Out:
# Text(0.5, 1.0, 'TOP 20 INDIAN CITIES RESTAURANT COUNTS PLOT AS PER ZOMATO')

# %%
#lets plot with the city names inside the map corresponding to the cities exact co-ordinates which we received from google api ,here marker color will be different as per marker size
#plt.subplots(figsize=(20,50))
plt.figure(figsize=(50,60))
map=Basemap(width=120000,height=900000,projection="lcc",resolution="l",llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=28,lon_0=77)
map.drawcountries()
map.drawmapboundary(color='#f2f2f2')

map.drawcoastlines()



lg=np.array(df_plot_top["lng"])
lat=np.array(df_plot_top["lat"])
pt=np.array(df_plot_top["COUNT"])
city_name=np.array(df_plot_top["CITY"])

x,y=map(lg,lat)

#using lambda function to create different sizes of marker as per thecount 

p_s=df_plot_top["COUNT"].apply(lambda x: int(x)/2)

#plt.scatter takes logitude ,latitude, marker size,shape,and color as parameter in the below , in this plot marker color is different.
plt.scatter(x,y,s=p_s,marker="o",c=p_s)

for a,b ,c,d in zip(x,y,city_name,pt):
    #plt.text takes x position , y position ,text ,font size and color as arguments
    plt.text(a,b,c,fontsize=30,color="r")
   
    
    
plt.title("TOP 20 INDIAN CITIES RESTAURANT COUNTS PLOT AS PER ZOMATO",fontsize=30,color='RED')
# Out:
# Text(0.5, 1.0, 'TOP 20 INDIAN CITIES RESTAURANT COUNTS PLOT AS PER ZOMATO')

# %%
#lets plot with the city names and restaurants count inside the map corresponding to the cities exact co-ordinates which we received from google api ,here marker color will be different as per marker size
#plt.subplots(figsize=(20,50))
plt.figure(figsize=(50,60))
map=Basemap(width=120000,height=900000,projection="lcc",resolution="l",llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=28,lon_0=77)
map.drawcountries()
map.drawmapboundary(color='#f2f2f2')

map.drawcoastlines()



lg=np.array(df_plot_top["lng"])
lat=np.array(df_plot_top["lat"])
pt=np.array(df_plot_top["COUNT"])
city_name=np.array(df_plot_top["CITY"])

x,y=map(lg,lat)

#using lambda function to create different sizes of marker as per thecount 

p_s=df_plot_top["COUNT"].apply(lambda x: int(x)/2)

#plt.scatter takes logitude ,latitude, marker size,shape,and color as parameter in the below , in this plot marker color is different.
plt.scatter(x,y,s=p_s,marker="o",c=p_s)

for a,b ,c,d in zip(x,y,city_name,pt):
    #plt.text takes x position , y position ,text(city name) ,font size and color as arguments
    plt.text(a,b,c,fontsize=30,color="r")
    #plt.text takes x position , y position ,text(restaurant counts) ,font size and color as arguments, like above . but only i have changed the x and y position to make it more clean and easier to read
    plt.text(a+60000,b+30000,d,fontsize=30)
   
    
    
plt.title("TOP 20 INDIAN CITIES RESTAURANT COUNTS PLOT AS PER ZOMATO",fontsize=30,color='RED')
# Out:
# Text(0.5, 1.0, 'TOP 20 INDIAN CITIES RESTAURANT COUNTS PLOT AS PER ZOMATO')

# %%
#lets take one data frame for bottom 15 cities with minimum retaurants counts 
df_plot_bottom=df_map_final.head(15)

# %%
#displaying the data frame
df_plot_bottom
# Out:
#            CITY  COUNT      lat      lng
# 0    Darjeeling      1   27.036  88.2627
# 1      Neemrana      3  27.9854  76.3827
# 2       Pushkar      4  26.4897  74.5511
# 3       Gangtok      5  27.3389  88.6065
# 4     Mussoorie     11  30.4599  78.0664
# 5     Rishikesh     15  30.0869  78.2676
# 6     Alappuzha     17  9.49807  76.3388
# 7        Manali     17  32.2396  77.1887
# 8      Palakkad     18  10.7867  76.6548
# 9      Srinagar     19  34.0837  74.7973
# 10       Shimla     29  31.1048  77.1734
# 11     Nainital     43  29.3803  79.4636
# 12  Dharamshala     50   32.219  76.3234
# 13         Ooty     67  11.4064  76.6932
# 14      Vellore    141  12.9165  79.1325

# %%
#lets plot with the city names and restaurants count inside the map corresponding to the cities exact co-ordinates which we received from google api ,here marker color will be different as per marker size
#plt.subplots(figsize=(20,50))
plt.figure(figsize=(50,50))
map=Basemap(width=120000,height=900000,projection="tmerc",resolution="l",llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=20,lon_0=88)
map.drawcountries()
map.drawmapboundary(color='#f2f2f2')

map.drawcoastlines()



lg=np.array(df_plot_bottom["lng"])
lat=np.array(df_plot_bottom["lat"])
pt=np.array(df_plot_bottom["COUNT"])
city_name=np.array(df_plot_bottom["CITY"])

x,y=map(lg,lat)

#using lambda function to create different sizes of marker as per thecount 

p_s=df_plot_bottom["COUNT"].apply(lambda x: int(x)*50)

#plt.scatter takes logitude ,latitude, marker size,shape,and color as parameter in the below , in this plot marker color is different.
plt.scatter(x,y,s=p_s,marker="o",c=p_s)

for a,b ,c,d in zip(x,y,city_name,pt):
    #plt.text takes x position , y position ,text(city name) ,font size and color as arguments
    plt.text(a-3000,b,c,fontsize=30,color="r")
    #plt.text takes x position , y position ,text(restaurant counts) ,font size and color as arguments, like above . but only i have changed the x and y position to make it more clean and easier to read
    plt.text(a+60000,b+30000,d,fontsize=30)
   
    
    
plt.title("BOTTOM 15 INDIAN CITIES MINIMUM RESTAURANT COUNTS PLOT AS PER ZOMATO",fontsize=30,color='RED')
# Out:
# Text(0.5, 1.0, 'BOTTOM 15 INDIAN CITIES MINIMUM RESTAURANT COUNTS PLOT AS PER ZOMATO')

# %% [markdown]
# #thats all guys , please let me know , if you like my work , will be coming up with more kernels from this dataset
# #dont forget to subscribe to my youtube channel https://www.youtube.com/channel/UCYtH9iBldgQo4ns2xI1PHhw?view_as=subscriber
