# %% [markdown]
# ### What types of questions from a leadership team would I get in this situation?
#
# I tried to make this about a work type of dataset because that is what I know.  So I am pretending I work at the company that owns the titanic.
# I was trying to think of potential questions from leaders (that related to the data at hand):
# * How many people died?
# * What are the traits of passengers that lived and died?
# * If they had a family member on the ship, what questions would be most important to ask to know whether that family member survived?

# %% [markdown]
# ## Import Data into BigQuery
# Because I know BigQuery and am most familiar with it, I imported the data into bigquery using my kaggle account and imported the data from CSVs into BigQuery tables.  I was at first surprised it was not already one of their public datasets, but figured that those are reserved practical datasets.
#
# Once imported, I unioned the data together
#
# *(ignore the project name, in hindsight, I should have made a new project.  I leveraged a project I created for a personal project I did with my son to scrape local aerial photos of parking lots and try to find parking lots for him to skateboard in -- fastai making me feel like a rockstar!)*
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Leverage Tableau to get to know the data
# I use Tableau a lot at work for data discovery.  It makes you feel like you work for the New York Times in how beautiful it can make your data look.  I tell folks on my teams though to be careful because your data looks so good, you often will not double check your numbers, so I usually suggest you double check totals and high level numbers in a query as well.

# %% [markdown]
# ***********

# %% [markdown]
# You'll notice below that 38% of the passengers (in the train) survived while 63% (136 passengers) survived while in 1st class.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > >

# %% [markdown]
# ************

# %% [markdown]
# If your family member was a female in 1st or 2nd class, she was very likely to survive.
# Unfortunately, only 14% of males from 3rd class survived.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Now I'd like to dig into the groups that **DID NOT** have a high survival rate

# %% [markdown]
# **************

# %% [markdown]
# Focusing in on the **FEMALES** in the **3rd CLASS**
# We didn't know the age of 42 of the 144.  Survival rate seems pretty flat for females in the 3rd class.
#
# ![image.png](attachment:image.png)
# Let's dig more.

# %% [markdown]
# Cutting the FEMALES in 3rd CLASS by Embarked From... females in 3rd class from Southhampton didn't seem to fare well.
#
# ![image.png](attachment:image.png)
