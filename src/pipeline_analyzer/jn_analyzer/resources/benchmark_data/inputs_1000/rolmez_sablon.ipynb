# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
import seaborn as sns

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/international-football-results-from-1872-to-2017/results.csv

# %%
data = pd.read_csv('../input/international-football-results-from-1872-to-2017/results.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41540 entries, 0 to 41539
# Data columns (total 9 columns):
# date          41540 non-null object
# home_team     41540 non-null object
# away_team     41540 non-null object
# home_score    41540 non-null int64
# away_score    41540 non-null int64
# tournament    41540 non-null object
# city          41540 non-null object
# country       41540 non-null object
# neutral       41540 non-null bool
# dtypes: bool(1), int64(2), object(6)
# memory usage: 2.6+ MB

# %%
data.corr()
# Out:
#             home_score  away_score   neutral
# home_score    1.000000   -0.135921 -0.032086
# away_score   -0.135921    1.000000  0.084924
# neutral      -0.032086    0.084924  1.000000

# %%
f,ax = plt.subplots(figsize=(13, 13))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
data.head(10)
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
# 5  1876-03-25  Scotland     Wales           4           0   Friendly  Glasgow
# 6  1877-03-03   England  Scotland           1           3   Friendly   London
# 7  1877-03-05     Wales  Scotland           0           2   Friendly  Wrexham
# 8  1878-03-02  Scotland   England           7           2   Friendly  Glasgow
# 9  1878-03-23  Scotland     Wales           9           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False
# 5  Scotland    False
# 6   England    False
# 7     Wales    False
# 8  Scotland    False
# 9  Scotland    False

# %%
data.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'home_score', 'away_score',
#        'tournament', 'city', 'country', 'neutral'],
#       dtype='object')

# %%
# Line Plot
data.home_score.plot(kind = 'line', color = 'g',label = 'Home Score',linewidth=1,alpha = 0.5,grid = True,linestyle = ':')
data.away_score.plot(color = 'r',label = 'Away Score',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right')    
plt.xlabel('x axis')              # label = name of label
plt.ylabel('y axis')
plt.title('Line Plot')            # title = title of plot
plt.show()

# %%
# Scatter Plot 
data.plot(kind='scatter', x='home_score', y='away_score',alpha = 0.5,color = 'red')
plt.xlabel('home_score')              # label = name of label
plt.ylabel('away_score')
plt.title('Home Score - Away Score ')
# Out:
# Text(0.5, 1.0, 'Home Score - Away Score ')

# %%
# Histogram
data.home_score.plot(kind = 'hist',bins = 50,figsize = (12,12))
plt.show()

# %%
x = data['home_score'] > 5
data[x]
# Out:
#              date   home_team                 away_team  home_score  \
# 8      1878-03-02    Scotland                   England           7
# 9      1878-03-23    Scotland                     Wales           9
# 20     1882-02-25       Wales          Northern Ireland           7
# 25     1883-02-24     England          Northern Ireland           7
# 30     1884-02-09       Wales          Northern Ireland           6
# ...           ...         ...                       ...         ...
# 41421  2019-11-15       Spain                     Malta           7
# 41474  2019-11-17  Guadeloupe  Turks and Caicos Islands          10
# 41488  2019-11-18       Italy                   Armenia           9
# 41502  2019-11-19     Germany          Northern Ireland           6
# 41510  2019-11-19     Belgium                    Cyprus           6
#
#        away_score               tournament        city     country  neutral
# 8               2                 Friendly     Glasgow    Scotland    False
# 9               0                 Friendly     Glasgow    Scotland    False
# 20              1                 Friendly     Wrexham       Wales    False
# 25              0                 Friendly   Liverpool     England    False
# 30              0     British Championship     Wrexham       Wales    False
# ...           ...                      ...         ...         ...      ...
# 41421           0  UEFA Euro qualification       Cadiz       Spain    False
# 41474           0  CONCACAF Nations League  Les Abymes  Guadeloupe    False
# 41488           1  UEFA Euro qualification     Palermo       Italy    False
# 41502           1  UEFA Euro qualification   Frankfurt     Germany    False
# 41510           1  UEFA Euro qualification    Brussels     Belgium    False
#
# [1500 rows x 9 columns]

# %%
y = data['away_score'] > 5
data[y]
# Out:
#              date         home_team    away_team  home_score  away_score  \
# 17     1881-03-12           England     Scotland           1           6
# 19     1882-02-18  Northern Ireland      England           0          13
# 31     1884-02-23  Northern Ireland      England           1           8
# 39     1885-03-23             Wales     Scotland           1           8
# 40     1885-04-11  Northern Ireland        Wales           2           8
# ...           ...               ...          ...         ...         ...
# 41283  2019-10-14          Bulgaria      England           0           6
# 41319  2019-10-15             Aruba      Jamaica           0           6
# 41326  2019-10-15    Chinese Taipei    Australia           1           7
# 41482  2019-11-18             Niger   Madagascar           2           6
# 41484  2019-11-18         Gibraltar  Switzerland           1           6
#
#                                  tournament        city              country  \
# 17                                 Friendly      London              England
# 19                                 Friendly     Belfast  Republic of Ireland
# 31                     British Championship     Belfast  Republic of Ireland
# 39                     British Championship     Wrexham                Wales
# 40                     British Championship     Belfast  Republic of Ireland
# ...                                     ...         ...                  ...
# 41283               UEFA Euro qualification       Sofia             Bulgaria
# 41319               CONCACAF Nations League  Willemstad              Curaçao
# 41326          FIFA World Cup qualification   Kaohsiung       Chinese Taipei
# 41482  African Cup of Nations qualification      Niamey                Niger
# 41484               UEFA Euro qualification   Gibraltar            Gibraltar
#
#        neutral
# 17       False
# 19       False
# 31       False
# 39       False
# 40       False
# ...        ...
# 41283    False
# 41319     True
# 41326    False
# 41482    False
# 41484    False
#
# [582 rows x 9 columns]

# %%
data[(data['home_score']>3) & (data['away_score']>3)]
# Out:
#              date            home_team         away_team  home_score  \
# 11     1879-04-05              England          Scotland           5
# 13     1880-03-13             Scotland           England           5
# 181    1906-04-02                Wales  Northern Ireland           4
# 187    1906-10-07       Czechoslovakia           Hungary           4
# 318    1912-03-24          Netherlands           Germany           5
# ...           ...                  ...               ...         ...
# 35448  2013-09-06          Switzerland           Iceland           4
# 37125  2015-07-15  Trinidad and Tobago            Mexico           4
# 38948  2017-06-25         Saare County          Shetland           4
# 40320  2018-11-18            Yorkshire            Panjab           5
# 40933  2019-07-18                 Fiji   Solomon Islands           4
#
#        away_score                    tournament       city        country  \
# 11              4                      Friendly     London        England
# 13              4                      Friendly    Glasgow       Scotland
# 181             4          British Championship    Wrexham          Wales
# 187             4                      Friendly     Prague        Bohemia
# 318             5                      Friendly     Zwolle    Netherlands
# ...           ...                           ...        ...            ...
# 35448           4  FIFA World Cup qualification      Berne    Switzerland
# 37125           4                      Gold Cup  Charlotte  United States
# 38948           5                  Island Games      Hemse         Sweden
# 40320           4                      Friendly     Ossett        England
# 40933           4                 Pacific Games       Apia          Samoa
#
#        neutral
# 11       False
# 13       False
# 181      False
# 187      False
# 318      False
# ...        ...
# 35448    False
# 37125     True
# 38948     True
# 40320    False
# 40933     True
#
# [136 rows x 9 columns]

# %%
data.head() # head shows first 5 rows
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
data.tail() # tail shows last 5 rows
# Out:
#              date     home_team    away_team  home_score  away_score  \
# 41535  2019-11-19    Kyrgyzstan   Tajikistan           1           1
# 41536  2019-11-19       Vietnam     Thailand           0           0
# 41537  2019-11-19      Malaysia    Indonesia           2           0
# 41538  2019-11-19  Turkmenistan    Sri Lanka           2           0
# 41539  2019-11-19       Lebanon  North Korea           0           0
#
#                          tournament          city       country  neutral
# 41535  FIFA World Cup qualification       Bishkek    Kyrgyzstan    False
# 41536  FIFA World Cup qualification         Hanoi       Vietnam    False
# 41537  FIFA World Cup qualification  Kuala Lumpur      Malaysia    False
# 41538  FIFA World Cup qualification      Ashgabat  Turkmenistan    False
# 41539  FIFA World Cup qualification        Beirut       Lebanon    False

# %%
# columns gives column names of features
data.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'home_score', 'away_score',
#        'tournament', 'city', 'country', 'neutral'],
#       dtype='object')

# %%
# shape gives number of rows and columns in a tuble 
data.shape
# Out:
# (41540, 9)

# %%
# info gives data type like dataframe, number of sample or row, number of feature or column
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41540 entries, 0 to 41539
# Data columns (total 9 columns):
# date          41540 non-null object
# home_team     41540 non-null object
# away_team     41540 non-null object
# home_score    41540 non-null int64
# away_score    41540 non-null int64
# tournament    41540 non-null object
# city          41540 non-null object
# country       41540 non-null object
# neutral       41540 non-null bool
# dtypes: bool(1), int64(2), object(6)
# memory usage: 2.6+ MB

# %%
# value_counts() : Frequency counts 
print(data['home_team'].value_counts(dropna="False")) # if there are nan values that also be counted.
# Out:
# Brazil                           568
# Argentina                        548
# Mexico                           513
# Germany                          506
# England                          498
#                                 ...
# St Vincent and the Grenadines      1
# Central Spain                      1
# Kabylia                            1
# St. Pierre & Miquelon              1
# Chameria                           1
# Name: home_team, Length: 309, dtype: int64

# %%
print(data['away_team'].value_counts(dropna="False"))
# Out:
# Uruguay          541
# Sweden           530
# England          511
# Hungary          475
# Paraguay         453
#                 ...
# Central Spain      1
# Barawa             1
# Asturias           1
# Surrey             1
# Andalusia          1
# Name: away_team, Length: 306, dtype: int64

# %%
print(data['city'].value_counts(dropna="False"))
# Out:
# Kuala Lumpur    589
# Doha            442
# Bangkok         427
# London          395
# Budapest        386
#                ...
# Mufalira          1
# Vlorë             1
# Orange Walk       1
# Villemomble       1
# Hunedoara         1
# Name: city, Length: 2012, dtype: int64

# %%
# outliers: The value is considerably higher or lower from rest of the data
# count: Number of entries
# mean: Average of entries
# std: Standart deviation
# min: Minimum entry
# 25%: First quantile
# 50%: Median or Second quantile
# 75%: Third quantile
data.describe()
# Out:
#          home_score    away_score
# count  41540.000000  41540.000000
# mean       1.745643      1.187819
# std        1.753444      1.405511
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      2.000000
# max       31.000000     21.000000

# %%
# Box Plots: Visualize basic statistics like outliers, min/max or quantiles
data.boxplot(column='home_score', by='neutral')
plt.show()

# %%
#Tidy Data - melt()
data_new = data.head()
data_new
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
# Melt etmek : Datayı farklı bir yapıya büründürmek
melted = pd.melt(frame = data_new, id_vars = 'home_team', value_vars = ['away_team', 'home_score'])
print(melted)
# Out:
#   home_team    variable     value
# 0  Scotland   away_team   England
# 1   England   away_team  Scotland
# 2  Scotland   away_team   England
# 3   England   away_team  Scotland
# 4  Scotland   away_team   England
# 5  Scotland  home_score         0
# 6   England  home_score         4
# 7  Scotland  home_score         2
# 8   England  home_score         2
# 9  Scotland  home_score         3

# %%
# Concatenating Data - We can concatenate two DATAFRAME
data1 = data.head()
data2 = data.tail()
conc_data_row = pd.concat([data1, data2], axis = 0, ignore_index = True)
conc_data_row
# Out:
#          date     home_team    away_team  home_score  away_score  \
# 0  1872-11-30      Scotland      England           0           0
# 1  1873-03-08       England     Scotland           4           2
# 2  1874-03-07      Scotland      England           2           1
# 3  1875-03-06       England     Scotland           2           2
# 4  1876-03-04      Scotland      England           3           0
# 5  2019-11-19    Kyrgyzstan   Tajikistan           1           1
# 6  2019-11-19       Vietnam     Thailand           0           0
# 7  2019-11-19      Malaysia    Indonesia           2           0
# 8  2019-11-19  Turkmenistan    Sri Lanka           2           0
# 9  2019-11-19       Lebanon  North Korea           0           0
#
#                      tournament          city       country  neutral
# 0                      Friendly       Glasgow      Scotland    False
# 1                      Friendly        London       England    False
# 2                      Friendly       Glasgow      Scotland    False
# 3                      Friendly        London       England    False
# 4                      Friendly       Glasgow      Scotland    False
# 5  FIFA World Cup qualification       Bishkek    Kyrgyzstan    False
# 6  FIFA World Cup qualification         Hanoi       Vietnam    False
# 7  FIFA World Cup qualification  Kuala Lumpur      Malaysia    False
# 8  FIFA World Cup qualification      Ashgabat  Turkmenistan    False
# 9  FIFA World Cup qualification        Beirut       Lebanon    False

# %%
data1 = data['home_score'].head()
data2 = data['away_score'].head()
conc_data_col = pd.concat([data1, data2], axis = 1)
conc_data_col
# Out:
#    home_score  away_score
# 0           0           0
# 1           4           2
# 2           2           1
# 3           2           2
# 4           3           0

# %%
# Data Types
data.dtypes
# Out:
# date          object
# home_team     object
# away_team     object
# home_score     int64
# away_score     int64
# tournament    object
# city          object
# country       object
# neutral         bool
# dtype: object

# %%
data['home_team'] = data['home_team'].astype('category')
data['away_score'] = data['away_score'].astype('float')
data.dtypes
# Out:
# date            object
# home_team     category
# away_team       object
# home_score       int64
# away_score     float64
# tournament      object
# city            object
# country         object
# neutral           bool
# dtype: object

# %%
# Building Data Frame From Scratch
 # Data Frames From Dictionary
country = ["Spain", "France"]
population = ["11", "12"]
list_label = ["country", "population"]
list_col = [country, population]
zipped = list(zip(list_label, list_col))
data_dict = dict(zipped)
df = pd.DataFrame(data_dict)
df
# Out:
#   country population
# 0   Spain         11
# 1  France         12

# %%
# Add new columns
df["capital"] = ["madrid", "paris"]
df
# Out:
#   country population capital
# 0   Spain         11  madrid
# 1  France         12   paris

# %%
# Broadcasting
df["income"] = 0 #Broadcasting entire column
df
# Out:
#   country population capital  income
# 0   Spain         11  madrid       0
# 1  France         12   paris       0

# %%
# Visual Exploratory Data Analysis
 # Plotting all data
data1 = data.loc[:, ["home_score", "away_score"]]
data1.plot()
# it is confusing

# %%
data1.plot(subplots = True)
plt.show()

# %%
# Scatter plot
data1.plot(kind = "scatter", x = "home_score", y = "away_score")
plt.show()

# %%
# Hist plot
data1.plot(kind = "hist", y="home_score", bins = 50, range=(0,5), normed = False)
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
# Indexing Pandas Time Series
time_list = ["1992-03-08", "1992-04-12"]
print(type(time_list[1])) # date is string
datetime_object = pd.to_datetime(time_list)
print(type(datetime_object))
# Out:
# <class 'str'>
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
import warnings
warnings.filterwarnings("ignore")
data2 = data.head()
date_list = ["1992-01-10", "1992-02-10", "1992-03-10", "1993-03-15", "1993-03-16"]
datetime_object = pd.to_datetime(date_list)
data2["date"] = datetime_object
data2 = data2.set_index("date")
data2
# Out:
#            home_team away_team  home_score  away_score tournament     city  \
# date
# 1992-01-10  Scotland   England           0         0.0   Friendly  Glasgow
# 1992-02-10   England  Scotland           4         2.0   Friendly   London
# 1992-03-10  Scotland   England           2         1.0   Friendly  Glasgow
# 1993-03-15   England  Scotland           2         2.0   Friendly   London
# 1993-03-16  Scotland   England           3         0.0   Friendly  Glasgow
#
#              country  neutral
# date
# 1992-01-10  Scotland    False
# 1992-02-10   England    False
# 1992-03-10  Scotland    False
# 1993-03-15   England    False
# 1993-03-16  Scotland    False

# %%
print(data2.loc["1993-03-16"])
print(data2.loc["1992-03-10":"1993-03-16"])
# Out:
# home_team     Scotland
# away_team      England
# home_score           3
# away_score           0
# tournament    Friendly
# city           Glasgow
# country       Scotland
# neutral          False
# Name: 1993-03-16 00:00:00, dtype: object
#            home_team away_team  home_score  away_score tournament     city  \
# date
# 1992-03-10  Scotland   England           2         1.0   Friendly  Glasgow
# 1993-03-15   England  Scotland           2         2.0   Friendly   London
# 1993-03-16  Scotland   England           3         0.0   Friendly  Glasgow
#
#              country  neutral
# date
# 1992-03-10  Scotland    False
# 1993-03-15   England    False
# 1993-03-16  Scotland    False

# %%
# Resampling Pandas Time Series
data2.resample("A").mean()
# Out:
#             home_score  away_score  neutral
# date
# 1992-12-31         2.0         1.0    False
# 1993-12-31         2.5         1.0    False

# %%
data2.resample("M").mean()
# Out:
#             home_score  away_score  neutral
# date
# 1992-01-31         0.0         0.0      0.0
# 1992-02-29         4.0         2.0      0.0
# 1992-03-31         2.0         1.0      0.0
# 1992-04-30         NaN         NaN      NaN
# 1992-05-31         NaN         NaN      NaN
# 1992-06-30         NaN         NaN      NaN
# 1992-07-31         NaN         NaN      NaN
# 1992-08-31         NaN         NaN      NaN
# 1992-09-30         NaN         NaN      NaN
# 1992-10-31         NaN         NaN      NaN
# 1992-11-30         NaN         NaN      NaN
# 1992-12-31         NaN         NaN      NaN
# 1993-01-31         NaN         NaN      NaN
# 1993-02-28         NaN         NaN      NaN
# 1993-03-31         2.5         1.0      0.0

# %%
# INDEXING DATA FRAMES
data = pd.read_csv('../input/international-football-results-from-1872-to-2017/results.csv')
data.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
# indexing using square brackets
data["home_score"][1]
# Out:
# 4

# %%
# using column attribute and row label
data.home_score[1]
# Out:
# 4

# %%
# using loc accessor
data.loc[1,"home_score"]
# Out:
# 4

# %%
# selecting only some columns
data[["home_score","away_score"]]
# Out:
#        home_score  away_score
# 0               0           0
# 1               4           2
# 2               2           1
# 3               2           2
# 4               3           0
# ...           ...         ...
# 41535           1           1
# 41536           0           0
# 41537           2           0
# 41538           2           0
# 41539           0           0
#
# [41540 rows x 2 columns]

# %%
# SLICING DATA FRAME
 # Difference between selecting columns: series and dataframe
print(type(data['home_score'])) # series
print(type(data[['home_score']])) # data frames
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# sciling and indexing series
data.loc[1:10,"home_score":"away_score"]
# Out:
#     home_score  away_score
# 1            4           2
# 2            2           1
# 3            2           2
# 4            3           0
# 5            4           0
# 6            1           3
# 7            0           2
# 8            7           2
# 9            9           0
# 10           2           1

# %%
# reverse slicing
data.loc[10:1:-1,"home_score":"away_score"]
# Out:
#     home_score  away_score
# 10           2           1
# 9            9           0
# 8            7           2
# 7            0           2
# 6            1           3
# 5            4           0
# 4            3           0
# 3            2           2
# 2            2           1
# 1            4           2

# %%
# from something to end
data.loc[1:10,"tournament":]
# Out:
#    tournament     city   country  neutral
# 1    Friendly   London   England    False
# 2    Friendly  Glasgow  Scotland    False
# 3    Friendly   London   England    False
# 4    Friendly  Glasgow  Scotland    False
# 5    Friendly  Glasgow  Scotland    False
# 6    Friendly   London   England    False
# 7    Friendly  Wrexham     Wales    False
# 8    Friendly  Glasgow  Scotland    False
# 9    Friendly  Glasgow  Scotland    False
# 10   Friendly   London   England    False

# %%
# FILTERING DATA FRAMES
 # creating boolean series
boolean = data.home_score > 20
data[boolean]
# Out:
#              date  home_team       away_team  home_score  away_score  \
# 7902   1971-09-13     Tahiti    Cook Islands          30           0
# 10937  1979-08-30       Fiji        Kiribati          24           0
# 23785  2001-04-09  Australia           Tonga          22           0
# 23788  2001-04-11  Australia  American Samoa          31           0
# 28822  2006-11-24      Sápmi          Monaco          21           1
#
#                          tournament           city           country  neutral
# 7902            South Pacific Games        Papeete  French Polynesia    False
# 10937           South Pacific Games        Nausori              Fiji    False
# 23785  FIFA World Cup qualification  Coffs Harbour         Australia    False
# 23788  FIFA World Cup qualification  Coffs Harbour         Australia    False
# 28822                Viva World Cup         Hyères            France     True

# %%
# combining filters
first_filter = data.home_score > 5
second_filter = data.away_score > 3
data[first_filter & second_filter]
# Out:
#              date            home_team       away_team  home_score  \
# 527    1920-01-18                Italy          France           9
# 1581   1933-06-17            Australia     New Zealand           6
# 1614   1933-10-23  Trinidad and Tobago        Barbados           8
# 1693   1934-06-03           Yugoslavia          Brazil           8
# 1926   1937-01-03               Brazil           Chile           6
# 1972   1937-05-17               Uganda           Kenya           9
# 2091   1938-06-05               Brazil          Poland           6
# 2162   1938-10-16               Mexico  Basque Country           8
# 2820   1948-04-21              Hungary     Switzerland           7
# 3164   1950-10-15          Switzerland     Netherlands           7
# 3281   1951-11-25          Netherlands         Belgium           6
# 3500   1953-07-13            Mauritius         Réunion           9
# 3501   1953-07-16           Madagascar         Réunion           6
# 4054   1956-11-16            Indonesia   United States           7
# 4392   1958-08-13               Norway       German DR           6
# 5664   1964-09-08                India  Chinese Taipei           6
# 5689   1964-10-09               Uganda         Burundi           7
# 6183   1966-06-28             China PR        Tanzania          10
# 8617   1973-06-10             China PR        Pakistan           7
# 8626   1973-06-17             China PR         Somalia           7
# 9057   1974-07-10             China PR       Yemen DPR           6
# 10034  1977-03-01             Malaysia        Thailand           6
# 20755  1997-08-20               Turkey           Wales           6
# 22118  1999-07-02             Guernsey        Shetland           6
#
#        away_score                    tournament           city  \
# 527             4                      Friendly          Milan
# 1581            4                      Friendly         Sydney
# 1614            4                      Friendly  Port of Spain
# 1693            4                      Friendly       Belgrade
# 1926            4                  Copa América   Buenos Aires
# 1972            5                      Friendly        Kampala
# 2091            5                FIFA World Cup     Strasbourg
# 2162            4                      Friendly    Mexico City
# 2820            4             International Cup       Budapest
# 3164            5                      Friendly          Basel
# 3281            7                      Friendly      Rotterdam
# 3500            4                      Friendly   Antananarivo
# 3501            4                      Friendly   Antananarivo
# 4054            5                      Friendly        Jakarta
# 4392            5                      Friendly           Oslo
# 5664            4                      Friendly   Kuala Lumpur
# 5689            5                      Friendly        Kampala
# 6183            4                      Friendly        Beijing
# 8617            4                      Friendly        Beijing
# 8626            4                      Friendly        Beijing
# 9057            5                      Friendly        Beijing
# 10034           4  FIFA World Cup qualification        Kallang
# 20755           4  FIFA World Cup qualification       Istanbul
# 22118           5                  Island Games          Visby
#
#                    country  neutral
# 527                  Italy    False
# 1581             Australia    False
# 1614   Trinidad and Tobago    False
# 1693            Yugoslavia    False
# 1926             Argentina     True
# 1972                Uganda    False
# 2091                France     True
# 2162                Mexico    False
# 2820               Hungary    False
# 3164           Switzerland    False
# 3281           Netherlands    False
# 3500            Madagascar     True
# 3501            Madagascar    False
# 4054             Indonesia    False
# 4392                Norway    False
# 5664              Malaysia     True
# 5689                Uganda    False
# 6183              China PR    False
# 8617              China PR    False
# 8626              China PR    False
# 9057              China PR    False
# 10034            Singapore     True
# 20755               Turkey    False
# 22118               Sweden     True

# %%
# filtering column based others
data.home_score[data.away_score>15]
# Out:
# 5455     0
# 7898     1
# 12703    0
# 14711    0
# 16660    0
# 19102    0
# 20502    0
# 25678    0
# 25681    0
# 25739    0
# 27357    0
# 33367    1
# 33392    1
# 34101    0
# 34473    1
# 36004    0
# 36009    0
# Name: home_score, dtype: int64

# %%
# TRANSFORMING DATA
def div(n):
    return n/2
data.home_score.apply(div)
# Out:
# 0        0.0
# 1        2.0
# 2        1.0
# 3        1.0
# 4        1.5
#         ...
# 41535    0.5
# 41536    0.0
# 41537    1.0
# 41538    1.0
# 41539    0.0
# Name: home_score, Length: 41540, dtype: float64

# %%
# or we can use lambda function
data.home_score.apply(lambda n : n/2)
# Out:
# 0        0.0
# 1        2.0
# 2        1.0
# 3        1.0
# 4        1.5
#         ...
# 41535    0.5
# 41536    0.0
# 41537    1.0
# 41538    1.0
# 41539    0.0
# Name: home_score, Length: 41540, dtype: float64

# %%
# defining column using other columns
data["total_score"] = data.home_score + data.away_score
data.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral  total_score
# 0  Scotland    False            0
# 1   England    False            6
# 2  Scotland    False            3
# 3   England    False            4
# 4  Scotland    False            3

# %%
# INDEX OBJECTS AND LABELED DATA
print(data.index.name)
data.index.name = "index_name"
data.head()
# Out:
# None
#                   date home_team away_team  home_score  away_score tournament  \
# index_name
# 0           1872-11-30  Scotland   England           0           0   Friendly
# 1           1873-03-08   England  Scotland           4           2   Friendly
# 2           1874-03-07  Scotland   England           2           1   Friendly
# 3           1875-03-06   England  Scotland           2           2   Friendly
# 4           1876-03-04  Scotland   England           3           0   Friendly
#
#                city   country  neutral  total_score
# index_name
# 0           Glasgow  Scotland    False            0
# 1            London   England    False            6
# 2           Glasgow  Scotland    False            3
# 3            London   England    False            4
# 4           Glasgow  Scotland    False            3

# %%
# overwrite index
 # first copy of our data to data3 then change index
data3 = data.copy()
 # lets make index start from 100. It is not remarkable change but it is just example
data3.index = range(100,41640,1)
data3.head()
# Out:
#            date home_team away_team  home_score  away_score tournament  \
# 100  1872-11-30  Scotland   England           0           0   Friendly
# 101  1873-03-08   England  Scotland           4           2   Friendly
# 102  1874-03-07  Scotland   England           2           1   Friendly
# 103  1875-03-06   England  Scotland           2           2   Friendly
# 104  1876-03-04  Scotland   England           3           0   Friendly
#
#         city   country  neutral  total_score
# 100  Glasgow  Scotland    False            0
# 101   London   England    False            6
# 102  Glasgow  Scotland    False            3
# 103   London   England    False            4
# 104  Glasgow  Scotland    False            3

# %%
### HIERARCHICAL INDEXING
data = pd.read_csv('../input/international-football-results-from-1872-to-2017/results.csv')
data.head()
data1 = data.set_index(["country","city"])
data1.tail(20)
# Out:
#                                          date     home_team       away_team  \
# country              city
# Croatia              Pula          2019-11-19       Croatia         Georgia
# United States        Harrison      2019-11-19       Ecuador        Colombia
# Montenegro           Podgorica     2019-11-19    Montenegro         Belarus
# Saudi Arabia         Riyadh        2019-11-19  Saudi Arabia        Paraguay
# Maldives             Malé          2019-11-19      Maldives            Guam
# United Arab Emirates Dubai         2019-11-19         Syria     Philippines
# Bhutan               Thimphu       2019-11-19         Nepal          Kuwait
# Jordan               Amman         2019-11-19        Jordan  Chinese Taipei
#                      Amman         2019-11-19          Iraq         Bahrain
# Hong Kong            Hong Kong     2019-11-19     Hong Kong        Cambodia
# Uzbekistan           Tashkent      2019-11-19    Uzbekistan       Palestine
# Bahrain              Muharraq      2019-11-19         Yemen       Singapore
# Tajikistan           Dushanbe      2019-11-19   Afghanistan           Qatar
# Oman                 Muscat        2019-11-19          Oman           India
# Myanmar              Mandalay      2019-11-19       Myanmar        Mongolia
# Kyrgyzstan           Bishkek       2019-11-19    Kyrgyzstan      Tajikistan
# Vietnam              Hanoi         2019-11-19       Vietnam        Thailand
# Malaysia             Kuala Lumpur  2019-11-19      Malaysia       Indonesia
# Turkmenistan         Ashgabat      2019-11-19  Turkmenistan       Sri Lanka
# Lebanon              Beirut        2019-11-19       Lebanon     North Korea
#
#                                    home_score  away_score  \
# country              city
# Croatia              Pula                   2           1
# United States        Harrison               0           1
# Montenegro           Podgorica              2           0
# Saudi Arabia         Riyadh                 0           0
# Maldives             Malé                   3           1
# United Arab Emirates Dubai                  1           0
# Bhutan               Thimphu                0           1
# Jordan               Amman                  5           0
#                      Amman                  0           0
# Hong Kong            Hong Kong              2           0
# Uzbekistan           Tashkent               2           0
# Bahrain              Muharraq               1           2
# Tajikistan           Dushanbe               0           1
# Oman                 Muscat                 1           0
# Myanmar              Mandalay               1           0
# Kyrgyzstan           Bishkek                1           1
# Vietnam              Hanoi                  0           0
# Malaysia             Kuala Lumpur           2           0
# Turkmenistan         Ashgabat               2           0
# Lebanon              Beirut                 0           0
#
#                                                      tournament  neutral
# country              city
# Croatia              Pula                              Friendly    False
# United States        Harrison                          Friendly     True
# Montenegro           Podgorica                         Friendly    False
# Saudi Arabia         Riyadh                            Friendly    False
# Maldives             Malé          FIFA World Cup qualification    False
# United Arab Emirates Dubai         FIFA World Cup qualification     True
# Bhutan               Thimphu       FIFA World Cup qualification     True
# Jordan               Amman         FIFA World Cup qualification    False
#                      Amman         FIFA World Cup qualification     True
# Hong Kong            Hong Kong     FIFA World Cup qualification    False
# Uzbekistan           Tashkent      FIFA World Cup qualification    False
# Bahrain              Muharraq      FIFA World Cup qualification     True
# Tajikistan           Dushanbe      FIFA World Cup qualification     True
# Oman                 Muscat        FIFA World Cup qualification    False
# Myanmar              Mandalay      FIFA World Cup qualification    False
# Kyrgyzstan           Bishkek       FIFA World Cup qualification    False
# Vietnam              Hanoi         FIFA World Cup qualification    False
# Malaysia             Kuala Lumpur  FIFA World Cup qualification    False
# Turkmenistan         Ashgabat      FIFA World Cup qualification    False
# Lebanon              Beirut        FIFA World Cup qualification    False

# %%
# PIVOTING DATA FRAMES
dic = {"treatment":["A","A","B","B"], "gender":["F","M","F","M"],"response":[10,45,5,9],"age":[15,4,72,65]}
df = pd.DataFrame(dic)
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
 # pivoting
df.pivot(index="treatment", columns="gender",values="response")
# Out:
# gender      F   M
# treatment
# A          10  45
# B           5   9

# %%
# STACKING AND UNSTACKING DATAFRAME
df1 = df.set_index(["treatment","gender"])
df1
# Out:
#                   response  age
# treatment gender
# A         F             10   15
#           M             45    4
# B         F              5   72
#           M              9   65

# %%
df1.unstack(level=0)
# Out:
#           response    age
# treatment        A  B   A   B
# gender
# F               10  5  15  72
# M               45  9   4  65

# %%
df.unstack(level=1)
# Out:
# treatment  0     A
#            1     A
#            2     B
#            3     B
# gender     0     F
#            1     M
#            2     F
#            3     M
# response   0    10
#            1    45
#            2     5
#            3     9
# age        0    15
#            1     4
#            2    72
#            3    65
# dtype: object

# %%
df2 = df1.swaplevel(0,1)
df2
# Out:
#                   response  age
# gender treatment
# F      A                10   15
# M      A                45    4
# F      B                 5   72
# M      B                 9   65

# %%
# MELTING DATA FRAMES
 # reverse of pivoting
df
pd.melt(df,id_vars="treatment",value_vars=["age","response"])
# Out:
#   treatment  variable  value
# 0         A       age     15
# 1         A       age      4
# 2         B       age     72
# 3         B       age     65
# 4         A  response     10
# 5         A  response     45
# 6         B  response      5
# 7         B  response      9

# %%
# CATEGORICALS AND GROUPBY
df.groupby("treatment").mean()
# Out:
#            response   age
# treatment
# A              27.5   9.5
# B               7.0  68.5

# %%
df.groupby("treatment").age.mean()
# Out:
# treatment
# A     9.5
# B    68.5
# Name: age, dtype: float64

# %%
df.groupby("treatment")[["age","response"]].min()
# Out:
#            age  response
# treatment
# A            4        10
# B           65         5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
# treatment    4 non-null object
# gender       4 non-null object
# response     4 non-null int64
# age          4 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes
