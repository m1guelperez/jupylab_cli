# %% [markdown]
# #History of Tsunamis

# %% [markdown]
# A tsunami (from Japanese: 津波, "harbour wave"; English pronunciation: /tsuːˈnɑːmi/) or tidal wave, also known as a seismic sea wave, is a series of waves in a water body caused by the displacement of a large volume of water, generally in an ocean or a large lake. Earthquakes, volcanic eruptions and other underwater explosions (including detonations of underwater nuclear devices), landslides, glacier calvings, meteorite impacts and other disturbances above or below water all have the potential to generate a tsunami. Unlike normal ocean waves which are generated by wind, or tides which are generated by the gravitational pull of the Moon and Sun, a tsunami is generated by the displacement of water.
# [more....][1]
#
#
#   [1]: https://en.wikipedia.org/wiki/Tsunami

# %% [markdown]
# ###Source
# The objetive of the notebook is to made a short study about tsunamis thanks some variables (year, country, damage, etc).
#
# Whole of the info was download from **National Centers for Enviromental Information - National Oceanic and Atmospheric Administration (NOAA)**.
# [Source][1]
#
#   [1]: https://www.ngdc.noaa.gov/hazard/tsu_db.shtml

# %% [markdown]
# ###Variables Definitions
# There are 45 diferents variable in the file, I only will work with some of them in the first version. Otherwise, you can check the rest of them [here][1].
#
#  - **Year** (2000 to Present) The Date and Time are given in Universal Coordinated Time (also known as Greenwich Mean Time). The local date may be one day different.
#  - **Country** The Country where the tsunami source occurred.
#  - **Region Code** Regional boundaries are based on frequency of occurrence of tsunamigenic events, geophysical relations, risk in distant areas and political justification. [more...][2]
#  - **Cause Code** (0 to 11) [more...][3]
#  - **Intensity Soloviev** (-5 to 10) **I = log2(21/2 * h)**, where "h" is the maximum runup height of the wave.
#  - **Deaths and Deaths Description** (0 to 4) [more...][4]
#  - **Missing and Missing Description** (0 to 4) [more..][5]
#
#
#   [1]: https://www.ngdc.noaa.gov/nndc/struts/results?&t=102564&s=230&d=230
#   [2]: https://www.ngdc.noaa.gov/nndc/DescribeField.jsp?dataset=101650&search_look=77&field_name=tsevent_vsqp.REGION_CODE
#   [3]: https://www.ngdc.noaa.gov/nndc/DescribeField.jsp?dataset=101650&search_look=77&field_name=tsevent_vsqp.CAUSE_CODE
#   [4]: https://www.ngdc.noaa.gov/nndc/DescribeField.jsp?dataset=101650&search_look=77&field_name=tsevent_vsqp.DEATHS_AMOUNT_ORDER
#   [5]: https://www.ngdc.noaa.gov/nndc/DescribeField.jsp?dataset=101650&search_look=77&field_name=tsevent_vsqp.MISSING_AMOUNT_ORDER

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

#Read the file
tsunami_data = pd.read_csv('../input/sources.csv', sep=",", header=0, index_col=0)
tsunami_data.head()
# Out:
#            YEAR  MONTH  DAY  HOUR  MINUTE  CAUSE  VALIDITY  FOCAL_DEPTH  \
# SOURCE_ID
# 1         -2000    NaN  NaN   NaN     NaN    1.0       1.0          NaN
# 3         -1610    NaN  NaN   NaN     NaN    6.0       4.0          NaN
# 4         -1365    NaN  NaN   NaN     NaN    1.0       1.0          NaN
# 5         -1300    NaN  NaN   NaN     NaN    0.0       2.0          NaN
# 6          -760    NaN  NaN   NaN     NaN    0.0       2.0          NaN
#
#            PRIMARY_MAGNITUDE  REGION_CODE           ...             \
# SOURCE_ID                                           ...
# 1                        NaN         50.0           ...
# 3                        NaN         50.0           ...
# 4                        NaN         50.0           ...
# 5                        6.0         50.0           ...
# 6                        NaN         50.0           ...
#
#           ALL_INJURIES INJURY_TOTAL ALL_FATALITIES  FATALITY_TOTAL  \
# SOURCE_ID
# 1                  NaN          NaN            NaN             3.0
# 3                  NaN          NaN            NaN             3.0
# 4                  NaN          NaN            NaN             NaN
# 5                  NaN          NaN            NaN             NaN
# 6                  NaN          NaN            NaN             NaN
#
#            ALL_DAMAGE_MILLIONS  DAMAGE_TOTAL  ALL_HOUSES_DAMAGED  \
# SOURCE_ID
# 1                          NaN           4.0                 NaN
# 3                          NaN           3.0                 NaN
# 4                          NaN           3.0                 NaN
# 5                          NaN           NaN                 NaN
# 6                          NaN           NaN                 NaN
#
#            HOUSE_DAMAGE_TOTAL  ALL_HOUSES_DESTROYED  HOUSE_DESTRUCTION_TOTAL
# SOURCE_ID
# 1                         NaN                   NaN                      NaN
# 3                         NaN                   NaN                      NaN
# 4                         NaN                   NaN                      NaN
# 5                         NaN                   NaN                      NaN
# 6                         NaN                   NaN                      NaN
#
# [5 rows x 44 columns]

# %%
# you can check de ID's, there aren't correlatives. 
# I'm going to make a reset_index

tsunami_data.reset_index(drop=True, inplace=True)
tsunami_data.head()
# Out:
#    YEAR  MONTH  DAY  HOUR  MINUTE  CAUSE  VALIDITY  FOCAL_DEPTH  \
# 0 -2000    NaN  NaN   NaN     NaN    1.0       1.0          NaN
# 1 -1610    NaN  NaN   NaN     NaN    6.0       4.0          NaN
# 2 -1365    NaN  NaN   NaN     NaN    1.0       1.0          NaN
# 3 -1300    NaN  NaN   NaN     NaN    0.0       2.0          NaN
# 4  -760    NaN  NaN   NaN     NaN    0.0       2.0          NaN
#
#    PRIMARY_MAGNITUDE  REGION_CODE           ...            ALL_INJURIES  \
# 0                NaN         50.0           ...                     NaN
# 1                NaN         50.0           ...                     NaN
# 2                NaN         50.0           ...                     NaN
# 3                6.0         50.0           ...                     NaN
# 4                NaN         50.0           ...                     NaN
#
#   INJURY_TOTAL ALL_FATALITIES  FATALITY_TOTAL  ALL_DAMAGE_MILLIONS  \
# 0          NaN            NaN             3.0                  NaN
# 1          NaN            NaN             3.0                  NaN
# 2          NaN            NaN             NaN                  NaN
# 3          NaN            NaN             NaN                  NaN
# 4          NaN            NaN             NaN                  NaN
#
#    DAMAGE_TOTAL  ALL_HOUSES_DAMAGED  HOUSE_DAMAGE_TOTAL  ALL_HOUSES_DESTROYED  \
# 0           4.0                 NaN                 NaN                   NaN
# 1           3.0                 NaN                 NaN                   NaN
# 2           3.0                 NaN                 NaN                   NaN
# 3           NaN                 NaN                 NaN                   NaN
# 4           NaN                 NaN                 NaN                   NaN
#
#    HOUSE_DESTRUCTION_TOTAL
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
#
# [5 rows x 44 columns]

# %%
#Duplicates and NaN values
#Check first the numbers of row
print("Before cleaning: ",tsunami_data.index)

#Drop and clean row to duplicates
tsunami_data.dropna()
tsunami_data.drop_duplicates()

print("After cleaning: ",tsunami_data.index)

#There weren't rows duplicated.
# Out:
# Before cleaning:  RangeIndex(start=0, stop=2582, step=1)
# After cleaning:  RangeIndex(start=0, stop=2582, step=1)

# %% [markdown]
# ### Group by Countries
#
# **Japan** is known for the amount of tsunamis during its history, Nowadays is sadly famous due to 2011 tsunami.

# %%
#Group by Countries
tsunami_data['COUNTRY_FRECUENCY'] = tsunami_data.groupby(tsunami_data.COUNTRY)['COUNTRY'].transform('count')

# %%
#Frecuency tsunamis by countries
tsunami_data.COUNTRY[tsunami_data.COUNTRY_FRECUENCY > 50].value_counts().plot(kind='bar',
                                             legend=False,
                                             figsize=(12,5),
                                             title="Tsunamis frecuency by countries > 50",
                                             fontsize=12,
                                             alpha=0.5
                                            );

# %%
#Tsunamis frecuency (year > 1950)
tsunami_data.COUNTRY[(tsunami_data.YEAR >= 1950) & (tsunami_data.COUNTRY_FRECUENCY > 50)].value_counts().plot(kind='bar',
                                             legend=False,
                                             figsize=(12,5),
                                             title="Tsunamis frecuency by countries (Year >= 1950)",
                                             fontsize=12,
                                             alpha=0.5
                                            );

# %% [markdown]
# ### Group by Regions
#
# This *dataSet* divide tsunamis by regions. We are going to find something curious, there is a region that has have more recorded tsunamis than Japan along the history.

# %%
#Mapping different regions
regions = {77:'West Coast of Africa',
            78:'Central Africa',
            73:'Northeast Atlantic Ocean',
            72:'Northwest Atlantic Ocean',
            70:'Southeast Atlantic Ocean',
            71:'Southwest Atlantic Ocean',
            75:'E. Coast USA and Canada, St Pierre and Miquelon',
            76:'Gulf of Mexico',
            74:'Caribbean Sea',
            40:'Black Sea and Caspian Sea',
            50:'Mediterranean Sea',
            30:'Red Sea and Persian Gulf',
            60:'Indian Ocean (including west coast of Australia)',
            87:'Alaska (including Aleutian Islands)',
            84:'China, North and South Korea, Philippines, Taiwan',
            81:'E. Coast Australia, New Zealand, South Pacific Is.',
            80:'Hawaii, Johnston Atoll, Midway I',
            83:'E. Indonesia (Pacific Ocean) and Malaysia',
            82:'New Caledonia, New Guinea, Solomon Is., Vanuatu',
            86:'Kamchatka and Kuril Islands',
            85:'Japan',
            88:'West Coast of North and Central America',
            89:'West Coast of South America'}


tsunami_data['REGIONS'] = tsunami_data['REGION_CODE'].map(regions)

#Group by Regions
tsunami_data['REGIONS_FRECUENCY'] = tsunami_data.groupby(tsunami_data.REGIONS)['REGIONS'].transform('count')

# %%
#Frecuency by Regions
tsunami_data.REGIONS[tsunami_data.REGIONS_FRECUENCY > 100].value_counts().plot(kind='barh',
                                              legend=False,
                                              figsize=(8,7),
                                              title="Tsunamis by Regions",
                                              alpha=0.5);

# %% [markdown]
# Due to advanced civilitations like Greeck or Romans, in the Mediterranean region exists more recorded data about tsunamis, that was the reason about high level of tsunamis.
# With a year filter you can fix the anomaly.

# %%
tsunami_data.REGIONS[(tsunami_data.YEAR >= 1916) & (tsunami_data.REGIONS_FRECUENCY > 100)].value_counts().plot(kind='barh',
                                              legend=False,
                                              figsize=(8,7),                                                                                                               
                                              title="Tsunamis by Regions (Year >= 1916)",
                                              alpha=0.5);

# %% [markdown]
# ###Case Study Spain
# Spain has coast in 2 different regions, the next pie show the percentaje of recorded tsunamis in each one.

# %%
#Case Study (Spain)
tsunami_data.REGIONS[(tsunami_data.COUNTRY == 'SPAIN')].value_counts().plot(kind='pie',
                                            legend=False,
                                            figsize=(8,7),
                                            title="Tsunamis by Regions (Spain)",
                                            autopct='%.1f%%');

# %% [markdown]
# ### Group by Causes
#
# This *dataSet* divide tsunamis by causes.

# %%
#Mapping different causes
causes = {0:'Unknown',
          1:'Earthquake',
          2:'Questionable Earthquake',
          3:'Earthquake and Landslide',
          4:'Volcano and Earthquake',
          5:'Volcano, Earthquake, and Landslide',
          6:'Volcano',
          7:'Volcano and Landslide',
          8:'Landslide',
          9:'Meteorological',
          10:'Explosion',
          11:'Astronomical Tide'}

tsunami_data['CAUSES'] = tsunami_data['CAUSE'].map(causes)

#Group by Causes
tsunami_data['CAUSES_FRECUENCY'] = tsunami_data.groupby(tsunami_data.CAUSES)['CAUSES'].transform('count')

# %%
#Causes of tsunamis
tsunami_data.CAUSES[tsunami_data.CAUSES_FRECUENCY >= 50].value_counts().plot(kind='pie',
                                            legend=False,
                                            figsize=(8,7),
                                            title="Causes of tsunamis",
                                            autopct='%.1f%%');

# %%
#Tsunamis frecuency (year > 1950)
tsunami_data.COUNTRY[(tsunami_data.YEAR >= 1950) & (tsunami_data.COUNTRY_FRECUENCY > 50)].value_counts().plot(kind='bar',
                                            legend=False,
                                            figsize=(12,5),
                                            title="Tsunamis frecuency by countries (Year >= 1950)",
                                            fontsize=12,
                                            alpha=0.5
                                            );

# %%
tsunami_region_mediterranean = tsunami_data[tsunami_data['REGION_CODE'] == 50]
tsunami_region_mediterranean_no_unknown = tsunami_region_mediterranean[(tsunami_region_mediterranean['CAUSES'] != 'Unknown')
                                                                       & (tsunami_region_mediterranean['VALIDITY'] >= 3.0)]
tsunami_mediterranean_cause_group = tsunami_region_mediterranean_no_unknown.groupby(['COUNTRY','CAUSES'])

add_counts = tsunami_mediterranean_cause_group.size().unstack().fillna(0)
normed_subnet = add_counts.div(add_counts.sum(1), axis=0)
add_counts.plot(kind='barh', legend=True, figsize=(11,7), stacked=True);

# %%
tsunami_region_mediterranean_no_unknown_1800 = tsunami_region_mediterranean_no_unknown[(tsunami_region_mediterranean_no_unknown['YEAR'] >= 1800)
                                                                                      & (tsunami_region_mediterranean_no_unknown['VALIDITY'] >= 3.0)]
tsunami_region_mediterranean_no_unknown_1800_group = tsunami_region_mediterranean_no_unknown_1800.groupby(['COUNTRY','CAUSES'])

add_counts = tsunami_region_mediterranean_no_unknown_1800_group.size().unstack().fillna(0)
normed_subnet = add_counts.div(add_counts.sum(1), axis=0)
add_counts.plot(kind='barh', legend=True, figsize=(11,7), stacked=True);

# %%
tsunami_region_japan_1700 = tsunami_data[(tsunami_data['YEAR'] >= 1700) 
                                         & (tsunami_data['REGION_CODE'] == 85) 
                                         & (tsunami_data['CAUSES'] != 'Unknown')
                                         & (tsunami_data['VALIDITY'] >= 3.0)]
tsunami_region_japan_1700.count()
tsunami_region_japan_1700_group = tsunami_region_japan_1700.groupby(['DAMAGE_TOTAL','CAUSES'])

add_counts = tsunami_region_japan_1700_group.size().unstack().fillna(0)
normed_subnet = add_counts.div(add_counts.sum(1), axis=0)
add_counts.plot(kind='bar', legend=True, figsize=(11,7), stacked=True);

# %% [markdown]
# ##Conclusion
# In next steps I'll study about the veracity of the recorded tsunamis, the intensity and differents effects about them.

# %%
#tsunami_data.EVENT_VALIDITY.value_counts()
