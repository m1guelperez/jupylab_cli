# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import xgboost as xgb
from xgboost import XGBClassifier, XGBRegressor
from xgboost import plot_importance
from catboost import CatBoostRegressor,CatBoostClassifier
from matplotlib import pyplot
import shap
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
from time import time
from tqdm import tqdm
from collections import Counter
from scipy import stats
import lightgbm as lgb
from sklearn.metrics import cohen_kappa_score, mean_squared_error
from sklearn.model_selection import KFold, StratifiedKFold
import gc
import json
pd.set_option('display.max_columns', 1000)
# Out:
# /kaggle/input/data-science-bowl-2019/sample_submission.csv
# /kaggle/input/data-science-bowl-2019/specs.csv
# /kaggle/input/data-science-bowl-2019/train_labels.csv
# /kaggle/input/data-science-bowl-2019/test.csv
# /kaggle/input/data-science-bowl-2019/train.csv

# %%
def eval_qwk_lgb_regr(y_true, y_pred):
    """
    Fast cappa eval function for lgb.
    """
    dist = Counter(reduce_train['accuracy_group'])
    for k in dist:
        dist[k] /= len(reduce_train)
    reduce_train['accuracy_group'].hist()
    
    acum = 0
    bound = {}
    for i in range(3):
        acum += dist[i]
        bound[i] = np.percentile(y_pred, acum * 100)

    def classify(x):
        if x <= bound[0]:
            return 0
        elif x <= bound[1]:
            return 1
        elif x <= bound[2]:
            return 2
        else:
            return 3

    y_pred = np.array(list(map(classify, y_pred))).reshape(y_true.shape)

    return 'cappa', cohen_kappa_score(y_true, y_pred, weights='quadratic'), True

# %%
def cohenkappa(ypred, y):
    y = y.get_label().astype("int")
    ypred = ypred.reshape((4, -1)).argmax(axis = 0)
    loss = cohenkappascore(y, y_pred, weights = 'quadratic')
    return "cappa", loss, True

# %%
def read_data():
    print('Reading train.csv file....')
    #train = pd.read_csv('/kaggle/input/data-science-bowl-2019/train.csv')
    train = pd.read_csv('/kaggle/input/data-science-bowl-2019/train.csv')
    print('Training.csv file have {} rows and {} columns'.format(train.shape[0], train.shape[1]))

    print('Reading test.csv file....')
    test = pd.read_csv('/kaggle/input/data-science-bowl-2019/test.csv')
    print('Test.csv file have {} rows and {} columns'.format(test.shape[0], test.shape[1]))

    print('Reading train_labels.csv file....')
    train_labels = pd.read_csv('/kaggle/input/data-science-bowl-2019/train_labels.csv')
    print('Train_labels.csv file have {} rows and {} columns'.format(train_labels.shape[0], train_labels.shape[1]))

    print('Reading specs.csv file....')
    specs = pd.read_csv('/kaggle/input/data-science-bowl-2019/specs.csv')
    print('Specs.csv file have {} rows and {} columns'.format(specs.shape[0], specs.shape[1]))

    print('Reading sample_submission.csv file....')
    sample_submission = pd.read_csv('/kaggle/input/data-science-bowl-2019/sample_submission.csv')
    print('Sample_submission.csv file have {} rows and {} columns'.format(sample_submission.shape[0], sample_submission.shape[1]))
    return train, test, train_labels, specs, sample_submission

# %%
def encode_title(train, test, train_labels):
    # encode title
    train['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), train['title'], train['event_code']))
    test['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), test['title'], test['event_code']))
    all_title_event_code = list(set(train["title_event_code"].unique()).union(test["title_event_code"].unique()))
    # make a list with all the unique 'titles' from the train and test set
    list_of_user_activities = list(set(train['title'].unique()).union(set(test['title'].unique())))
    # make a list with all the unique 'event_code' from the train and test set
    list_of_event_code = list(set(train['event_code'].unique()).union(set(test['event_code'].unique())))
    list_of_event_id = list(set(train['event_id'].unique()).union(set(test['event_id'].unique())))
    # make a list with all the unique worlds from the train and test set
    list_of_worlds = list(set(train['world'].unique()).union(set(test['world'].unique())))
    # create a dictionary numerating the titles
    activities_map = dict(zip(list_of_user_activities, np.arange(len(list_of_user_activities))))
    activities_labels = dict(zip(np.arange(len(list_of_user_activities)), list_of_user_activities))
    activities_world = dict(zip(list_of_worlds, np.arange(len(list_of_worlds))))
    assess_titles = list(set(train[train['type'] == 'Assessment']['title'].value_counts().index).union(set(test[test['type'] == 'Assessment']['title'].value_counts().index)))
    # replace the text titles with the number titles from the dict
    train['title'] = train['title'].map(activities_map)
    test['title'] = test['title'].map(activities_map)
    train['world'] = train['world'].map(activities_world)
    test['world'] = test['world'].map(activities_world)
    train_labels['title'] = train_labels['title'].map(activities_map)
    win_code = dict(zip(activities_map.values(), (4100*np.ones(len(activities_map))).astype('int')))
    # then, it set one element, the 'Bird Measurer (Assessment)' as 4110, 10 more than the rest
    win_code[activities_map['Bird Measurer (Assessment)']] = 4110
    # convert text into datetime
    train['timestamp'] = pd.to_datetime(train['timestamp'])
    test['timestamp'] = pd.to_datetime(test['timestamp'])
    
    
    return train, test, train_labels, win_code, list_of_user_activities, list_of_event_code, activities_labels, assess_titles, list_of_event_id, all_title_event_code

# %%
# this is the function that convert the raw data into processed features
def get_data(user_sample, test_set=False):
    '''
    The user_sample is a DataFrame from train or test where the only one 
    installation_id is filtered
    And the test_set parameter is related with the labels processing, that is only requered
    if test_set=False
    '''
    # Constants and parameters declaration
    last_activity = 0
    
    user_activities_count = {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
    
    # new features: time spent in each activity
    last_session_time_sec = 0
    accuracy_groups = {0:0, 1:0, 2:0, 3:0}
    all_assessments = []
    accumulated_accuracy_group = 0
    accumulated_accuracy = 0
    accumulated_correct_attempts = 0 
    accumulated_uncorrect_attempts = 0
    accumulated_actions = 0
    counter = 0
    time_first_activity = float(user_sample['timestamp'].values[0])
    durations = []
    last_accuracy_title = {'acc_' + title: -1 for title in assess_titles}
    event_code_count: Dict[str, int] = {ev: 0 for ev in list_of_event_code}
    event_id_count: Dict[str, int] = {eve: 0 for eve in list_of_event_id}
    title_count: Dict[str, int] = {eve: 0 for eve in activities_labels.values()} 
    title_event_code_count: Dict[str, int] = {t_eve: 0 for t_eve in all_title_event_code}
        
    # last features
    sessions_count = 0
    
    # itarates through each session of one instalation_id
    for i, session in user_sample.groupby('game_session', sort=False):
        # i = game_session_id
        # session is a DataFrame that contain only one game_session
        
        # get some sessions information
        session_type = session['type'].iloc[0]
        session_title = session['title'].iloc[0]
        session_title_text = activities_labels[session_title]
                    
            
        # for each assessment, and only this kind off session, the features below are processed
        # and a register are generated
        if (session_type == 'Assessment') & (test_set or len(session)>1):
            # search for event_code 4100, that represents the assessments trial
            all_attempts = session.query(f'event_code == {win_code[session_title]}')
            # then, check the numbers of wins and the number of losses
            true_attempts = all_attempts['event_data'].str.contains('true').sum()
            false_attempts = all_attempts['event_data'].str.contains('false').sum()
            # copy a dict to use as feature template, it's initialized with some itens: 
            # {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
            features = user_activities_count.copy()
            features.update(last_accuracy_title.copy())
            features.update(event_code_count.copy())
            features.update(event_id_count.copy())
            features.update(title_count.copy())
            features.update(title_event_code_count.copy())
            features.update(last_accuracy_title.copy())
            features['installation_session_count'] = sessions_count
            
            variety_features = [('var_event_code', event_code_count),
                              ('var_event_id', event_id_count),
                               ('var_title', title_count),
                               ('var_title_event_code', title_event_code_count)]
            
            for name, dict_counts in variety_features:
                arr = np.array(list(dict_counts.values()))
                features[name] = np.count_nonzero(arr)
                 
            # get installation_id for aggregated features
            features['installation_id'] = session['installation_id'].iloc[-1]
            # add title as feature, remembering that title represents the name of the game
            features['session_title'] = session['title'].iloc[0]
            # the 4 lines below add the feature of the history of the trials of this player
            # this is based on the all time attempts so far, at the moment of this assessment
            features['accumulated_correct_attempts'] = accumulated_correct_attempts
            features['accumulated_uncorrect_attempts'] = accumulated_uncorrect_attempts
            accumulated_correct_attempts += true_attempts 
            accumulated_uncorrect_attempts += false_attempts
            # the time spent in the app so far
            if durations == []:
                features['duration_mean'] = 0
                features['duration_std'] = 0
            else:
                features['duration_mean'] = np.mean(durations)
                features['duration_std'] = np.std(durations)
            durations.append((session.iloc[-1, 2] - session.iloc[0, 2] ).seconds)
            # the accurace is the all time wins divided by the all time attempts
            features['accumulated_accuracy'] = accumulated_accuracy/counter if counter > 0 else 0
            accuracy = true_attempts/(true_attempts+false_attempts) if (true_attempts+false_attempts) != 0 else 0
            accumulated_accuracy += accuracy
            last_accuracy_title['acc_' + session_title_text] = accuracy
            # a feature of the current accuracy categorized
            # it is a counter of how many times this player was in each accuracy group
            if accuracy == 0:
                features['accuracy_group'] = 0
            elif accuracy == 1:
                features['accuracy_group'] = 3
            elif accuracy == 0.5:
                features['accuracy_group'] = 2
            else:
                features['accuracy_group'] = 1
            features.update(accuracy_groups)
            accuracy_groups[features['accuracy_group']] += 1
            # mean of the all accuracy groups of this player
            features['accumulated_accuracy_group'] = accumulated_accuracy_group/counter if counter > 0 else 0
            accumulated_accuracy_group += features['accuracy_group']
            # how many actions the player has done so far, it is initialized as 0 and updated some lines below
            features['accumulated_actions'] = accumulated_actions
            
            # there are some conditions to allow this features to be inserted in the datasets
            # if it's a test set, all sessions belong to the final dataset
            # it it's a train, needs to be passed throught this clausule: session.query(f'event_code == {win_code[session_title]}')
            # that means, must exist an event_code 4100 or 4110
            if test_set:
                all_assessments.append(features)
            elif true_attempts+false_attempts > 0:
                all_assessments.append(features)
                
            counter += 1
        
        sessions_count += 1
        # this piece counts how many actions was made in each event_code so far
        def update_counters(counter: dict, col: str):
                num_of_session_count = Counter(session[col])
                for k in num_of_session_count.keys():
                    x = k
                    if col == 'title':
                        x = activities_labels[k]
                    counter[x] += num_of_session_count[k]
                return counter
            
        event_code_count = update_counters(event_code_count, "event_code")
        event_id_count = update_counters(event_id_count, "event_id")
        title_count = update_counters(title_count, 'title')
        title_event_code_count = update_counters(title_event_code_count, 'title_event_code')

        # counts how many actions the player has done so far, used in the feature of the same name
        accumulated_actions += len(session)
        if last_activity != session_type:
            user_activities_count[session_type] += 1
            last_activitiy = session_type 
                        
    # if it't the test_set, only the last assessment must be predicted, the previous are scraped
    if test_set:
        return all_assessments[-1]
    # in the train_set, all assessments goes to the dataset
    return all_assessments

# %%
def get_train_and_test(train, test):
    compiled_train = []
    compiled_test = []
    for i, (ins_id, user_sample) in tqdm(enumerate(train.groupby('installation_id', sort = False)), total = 17000):
        compiled_train += get_data(user_sample)
    for ins_id, user_sample in tqdm(test.groupby('installation_id', sort = False), total = 1000):
        test_data = get_data(user_sample, test_set = True)
        compiled_test.append(test_data)
    reduce_train = pd.DataFrame(compiled_train)
    reduce_test = pd.DataFrame(compiled_test)
    categoricals = ['session_title']
    return reduce_train, reduce_test, categoricals

# %%
# read data
train, test, train_labels, specs, sample_submission = read_data()
# Out:
# Reading train.csv file....
# Training.csv file have 11341042 rows and 11 columns
# Reading test.csv file....
# Test.csv file have 1156414 rows and 11 columns
# Reading train_labels.csv file....
# Train_labels.csv file have 17690 rows and 7 columns
# Reading specs.csv file....
# Specs.csv file have 386 rows and 3 columns
# Reading sample_submission.csv file....
# Sample_submission.csv file have 1000 rows and 2 columns

# %%
# get usefull dict with maping encode
train, test, train_labels, win_code, list_of_user_activities, list_of_event_code, activities_labels, assess_titles, list_of_event_id, all_title_event_code = encode_title(train, test, train_labels)

# %%
# tranform function to get the train and test set
reduce_train, reduce_test, categoricals = get_train_and_test(train, test)
# Out:
# 100%|██████████| 17000/17000 [07:32<00:00, 37.57it/s]
# 100%|██████████| 1000/1000 [00:49<00:00, 20.20it/s]

# %%
# call feature engineering function
features = reduce_train.loc[(reduce_train.sum(axis=1) != 0), (reduce_train.sum(axis=0) != 0)].columns # delete useless columns
features = [x for x in features if x not in ['accuracy_group', 'installation_id']]

# %%
counter = 0
to_remove = []
for feat_a in features:
    for feat_b in features:
        if feat_a != feat_b and feat_a not in to_remove and feat_b not in to_remove:
            c = np.corrcoef(reduce_train[feat_a], reduce_train[feat_b])[0][1]
            if c > 0.995:
                counter += 1
                to_remove.append(feat_b)
                print('{}: FEAT_A: {} FEAT_B: {} - Correlation: {}'.format(counter, feat_a, feat_b, c))
# Out:
# 1: FEAT_A: Clip FEAT_B: 27253bdc - Correlation: 0.9999999999999999
# 2: FEAT_A: 2050 FEAT_B: 2040 - Correlation: 0.9965259434878118
# 3: FEAT_A: 2050 FEAT_B: 73757a5e - Correlation: 0.9998050146713992
# 4: FEAT_A: 2050 FEAT_B: 37c53127 - Correlation: 1.0
# 5: FEAT_A: 2050 FEAT_B: dcaede90 - Correlation: 0.9965259434878118
# 6: FEAT_A: 2050 FEAT_B: 2b9272f4 - Correlation: 0.9999839030068793
# 7: FEAT_A: 2050 FEAT_B: 26fd2d99 - Correlation: 0.9965084543995759
# 8: FEAT_A: 2050 FEAT_B: 08fd73f3 - Correlation: 0.9966123918733654
# 9: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_3021 - Correlation: 0.9998050146713992
# 10: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_3121 - Correlation: 0.9999839030068793
# 11: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_2030 - Correlation: 0.9966123918733654
# 12: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_2050 - Correlation: 1.0
# 13: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_2020 - Correlation: 0.9965084543995759
# 14: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_2040 - Correlation: 0.9965259434878118
# 15: FEAT_A: 4230 FEAT_B: 4235 - Correlation: 0.9999995197498746
# 16: FEAT_A: 4230 FEAT_B: 85de926c - Correlation: 0.9999995197498746
# 17: FEAT_A: 4230 FEAT_B: ad148f58 - Correlation: 0.9999999999999998
# 18: FEAT_A: 4230 FEAT_B: Bubble Bath_4230 - Correlation: 0.9999999999999998
# 19: FEAT_A: 4230 FEAT_B: Bubble Bath_4235 - Correlation: 0.9999995197498746
# 20: FEAT_A: 5000 FEAT_B: 5010 - Correlation: 0.9991849213605333
# 21: FEAT_A: 5000 FEAT_B: a6d66e51 - Correlation: 1.0
# 22: FEAT_A: 5000 FEAT_B: 71e712d8 - Correlation: 0.9991849213605333
# 23: FEAT_A: 5000 FEAT_B: Watering Hole (Activity)_5000 - Correlation: 1.0
# 24: FEAT_A: 5000 FEAT_B: Watering Hole (Activity)_5010 - Correlation: 0.9991849213605333
# 25: FEAT_A: 3110 FEAT_B: 3010 - Correlation: 0.9999293402893735
# 26: FEAT_A: 3120 FEAT_B: 3020 - Correlation: 0.9998761417908972
# 27: FEAT_A: 3121 FEAT_B: 3021 - Correlation: 0.9999098200487934
# 28: FEAT_A: 4031 FEAT_B: 1996c610 - Correlation: 1.0
# 29: FEAT_A: 4031 FEAT_B: Dino Drink_4031 - Correlation: 1.0
# 30: FEAT_A: 2000 FEAT_B: installation_session_count - Correlation: 1.0
# 31: FEAT_A: 4050 FEAT_B: a1192f43 - Correlation: 0.9999999999999999
# 32: FEAT_A: 4050 FEAT_B: Crystals Rule_4050 - Correlation: 0.9999999999999999
# 33: FEAT_A: 2020 FEAT_B: 2030 - Correlation: 0.9959933262816534
# 34: FEAT_A: 4220 FEAT_B: 1340b8d7 - Correlation: 1.0
# 35: FEAT_A: 4220 FEAT_B: Bubble Bath_4220 - Correlation: 1.0
# 36: FEAT_A: 6f8106d9 FEAT_B: Dino Drink_4090 - Correlation: 1.0
# 37: FEAT_A: a1e4395d FEAT_B: a52b92d5 - Correlation: 0.9991003891313368
# 38: FEAT_A: a1e4395d FEAT_B: Mushroom Sorter (Assessment)_3110 - Correlation: 0.9991003891313368
# 39: FEAT_A: a1e4395d FEAT_B: Mushroom Sorter (Assessment)_3010 - Correlation: 1.0
# 40: FEAT_A: 9ed8f6da FEAT_B: Dino Drink_2075 - Correlation: 0.9999999999999999
# 41: FEAT_A: 3393b68b FEAT_B: Bird Measurer (Assessment)_2010 - Correlation: 1.0
# 42: FEAT_A: 0db6d71d FEAT_B: Chest Sorter (Assessment)_4020 - Correlation: 1.0
# 43: FEAT_A: c277e121 FEAT_B: d45ed6a1 - Correlation: 0.9979692879543319
# 44: FEAT_A: c277e121 FEAT_B: b120f2ac - Correlation: 0.9999983835744551
# 45: FEAT_A: c277e121 FEAT_B: All Star Sorting_2025 - Correlation: 0.9999983835744551
# 46: FEAT_A: c277e121 FEAT_B: All Star Sorting_3120 - Correlation: 0.9979692879543319
# 47: FEAT_A: c277e121 FEAT_B: All Star Sorting_3020 - Correlation: 1.0
# 48: FEAT_A: 3babcb9b FEAT_B: 5154fc30 - Correlation: 0.999986924640935
# 49: FEAT_A: 3babcb9b FEAT_B: 86c924c4 - Correlation: 0.9988970478897697
# 50: FEAT_A: 3babcb9b FEAT_B: 3323d7e9 - Correlation: 0.9952332162875015
# 51: FEAT_A: 3babcb9b FEAT_B: 7cf1bc53 - Correlation: 0.9961136759226749
# 52: FEAT_A: 3babcb9b FEAT_B: Crystals Rule_2020 - Correlation: 0.9961136759226749
# 53: FEAT_A: 3babcb9b FEAT_B: Crystals Rule_3010 - Correlation: 0.999986924640935
# 54: FEAT_A: 3babcb9b FEAT_B: Crystals Rule_4020 - Correlation: 0.9988970478897697
# 55: FEAT_A: 3babcb9b FEAT_B: Crystals Rule_2030 - Correlation: 0.9952332162875015
# 56: FEAT_A: 3babcb9b FEAT_B: Crystals Rule_3110 - Correlation: 1.0
# 57: FEAT_A: f54238ee FEAT_B: Fireworks (Activity)_4090 - Correlation: 1.0
# 58: FEAT_A: 4a4c3d21 FEAT_B: Bird Measurer (Assessment)_4025 - Correlation: 1.0
# 59: FEAT_A: e4d32835 FEAT_B: Pan Balance_4080 - Correlation: 0.9999999999999998
# 60: FEAT_A: 7372e1a5 FEAT_B: Chow Time_4070 - Correlation: 1.0
# 61: FEAT_A: cb6010f8 FEAT_B: 56817e2b - Correlation: 0.999047573942978
# 62: FEAT_A: cb6010f8 FEAT_B: 47026d5f - Correlation: 0.9996901555713447
# 63: FEAT_A: cb6010f8 FEAT_B: Chow Time_2030 - Correlation: 0.999047573942978
# 64: FEAT_A: cb6010f8 FEAT_B: Chow Time_3021 - Correlation: 0.9996901555713447
# 65: FEAT_A: cb6010f8 FEAT_B: Chow Time_3121 - Correlation: 0.9999999999999999
# 66: FEAT_A: 0330ab6a FEAT_B: 2230fab4 - Correlation: 0.9998673365188063
# 67: FEAT_A: 0330ab6a FEAT_B: Chow Time_3020 - Correlation: 1.0
# 68: FEAT_A: 0330ab6a FEAT_B: Chow Time_3120 - Correlation: 0.9998673365188063
# 69: FEAT_A: fd20ea40 FEAT_B: Leaf Leader_4010 - Correlation: 0.9999999999999998
# 70: FEAT_A: a8876db3 FEAT_B: Cart Balancer (Assessment)_3021 - Correlation: 1.0
# 71: FEAT_A: 7d5c30a2 FEAT_B: Dino Dive_2060 - Correlation: 1.0
# 72: FEAT_A: 4ef8cdd3 FEAT_B: Chow Time_4020 - Correlation: 1.0
# 73: FEAT_A: 67aa2ada FEAT_B: Leaf Leader_4090 - Correlation: 1.0
# 74: FEAT_A: f806dc10 FEAT_B: Dino Drink_2020 - Correlation: 1.0
# 75: FEAT_A: 58a0de5c FEAT_B: f5b8c21a - Correlation: 0.9977888184537715
# 76: FEAT_A: 58a0de5c FEAT_B: 9b4001e4 - Correlation: 0.9999159362216189
# 77: FEAT_A: 58a0de5c FEAT_B: Air Show_3021 - Correlation: 0.9999159362216189
# 78: FEAT_A: 58a0de5c FEAT_B: Air Show_3121 - Correlation: 1.0
# 79: FEAT_A: 58a0de5c FEAT_B: Air Show_2030 - Correlation: 0.9977888184537715
# 80: FEAT_A: 28a4eb9a FEAT_B: 9de5e594 - Correlation: 0.9995923561196808
# 81: FEAT_A: 28a4eb9a FEAT_B: Dino Dive_3120 - Correlation: 0.9999999999999998
# 82: FEAT_A: 28a4eb9a FEAT_B: Dino Dive_3020 - Correlation: 0.9995923561196808
# 83: FEAT_A: e080a381 FEAT_B: Pan Balance_4090 - Correlation: 1.0
# 84: FEAT_A: 19967db1 FEAT_B: Chow Time_4090 - Correlation: 1.0
# 85: FEAT_A: c189aaf2 FEAT_B: Happy Camel_2083 - Correlation: 0.9999999999999999
# 86: FEAT_A: 7da34a02 FEAT_B: Mushroom Sorter (Assessment)_4070 - Correlation: 0.9999999999999998
# 87: FEAT_A: a5e9da97 FEAT_B: Pan Balance_4100 - Correlation: 1.0
# 88: FEAT_A: 53c6e11a FEAT_B: Leaf Leader_2075 - Correlation: 0.9999999999999999
# 89: FEAT_A: cfbd47c8 FEAT_B: Chow Time_4030 - Correlation: 1.0
# 90: FEAT_A: 71fe8f75 FEAT_B: 0a08139c - Correlation: 0.9999850342981554
# 91: FEAT_A: 71fe8f75 FEAT_B: Bug Measurer (Activity)_3110 - Correlation: 1.0
# 92: FEAT_A: 71fe8f75 FEAT_B: Bug Measurer (Activity)_3010 - Correlation: 0.9999850342981554
# 93: FEAT_A: b2e5b0f1 FEAT_B: ecaab346 - Correlation: 0.999849464604504
# 94: FEAT_A: b2e5b0f1 FEAT_B: b74258a0 - Correlation: 0.999849464604504
# 95: FEAT_A: b2e5b0f1 FEAT_B: Cart Balancer (Assessment)_2030 - Correlation: 0.999849464604504
# 96: FEAT_A: b2e5b0f1 FEAT_B: Cart Balancer (Assessment)_2010 - Correlation: 1.0
# 97: FEAT_A: b2e5b0f1 FEAT_B: Cart Balancer (Assessment)_3121 - Correlation: 0.999849464604504
# 98: FEAT_A: 598f4598 FEAT_B: Flower Waterer (Activity)_4025 - Correlation: 0.9999999999999998
# 99: FEAT_A: 05ad839b FEAT_B: Happy Camel_4090 - Correlation: 1.0
# 100: FEAT_A: e9c52111 FEAT_B: b7530680 - Correlation: 0.998817689964623
# 101: FEAT_A: e9c52111 FEAT_B: Bottle Filler (Activity)_2030 - Correlation: 1.0
# 102: FEAT_A: e9c52111 FEAT_B: Bottle Filler (Activity)_2020 - Correlation: 0.998817689964623
# 103: FEAT_A: 7ad3efc6 FEAT_B: 65a38bf7 - Correlation: 0.999978626569043
# 104: FEAT_A: 7ad3efc6 FEAT_B: Cart Balancer (Assessment)_2000 - Correlation: 1.0
# 195: FEAT_A: 31973d56 FEAT_B: 5de79a6a - Correlation: 0.9973945339840646
# 196: FEAT_A: 31973d56 FEAT_B: Cart Balancer (Assessment)_3020 - Correlation: 0.9973945339840646
# 197: FEAT_A: 31973d56 FEAT_B: Cart Balancer (Assessment)_3120 - Correlation: 1.0
# 198: FEAT_A: 6c930e6e FEAT_B: a5be6304 - Correlation: 0.9962760616821671
# 199: FEAT_A: 6c930e6e FEAT_B: Mushroom Sorter (Assessment)_2030 - Correlation: 0.9999999999999999
# 200: FEAT_A: 6c930e6e FEAT_B: Mushroom Sorter (Assessment)_2010 - Correlation: 0.9962760616821671
# 201: FEAT_A: f93fc684 FEAT_B: Chow Time_4010 - Correlation: 0.9999999999999999
# 202: FEAT_A: 9b01374f FEAT_B: Flower Waterer (Activity)_2000 - Correlation: 1.0
# 203: FEAT_A: 7dfe6d8a FEAT_B: Leaf Leader_4070 - Correlation: 0.9999999999999998
# 204: FEAT_A: 51311d7a FEAT_B: Dino Drink_2000 - Correlation: 1.0
# 205: FEAT_A: 756e5507 FEAT_B: Chicken Balancer (Activity)_2000 - Correlation: 1.0
# 206: FEAT_A: 1bb5fbdb FEAT_B: b2dba42b - Correlation: 0.9999521729413294
# 207: FEAT_A: 1bb5fbdb FEAT_B: Sandcastle Builder (Activity)_3010 - Correlation: 0.9999521729413294
# 208: FEAT_A: 1bb5fbdb FEAT_B: Sandcastle Builder (Activity)_3110 - Correlation: 1.0
# 209: FEAT_A: 89aace00 FEAT_B: e5734469 - Correlation: 0.9998406115110345
# 210: FEAT_A: 89aace00 FEAT_B: Dino Drink_3120 - Correlation: 1.0
# 211: FEAT_A: 89aace00 FEAT_B: Dino Drink_3020 - Correlation: 0.9998406115110345
# 212: FEAT_A: 857f21c0 FEAT_B: Bubble Bath_4040 - Correlation: 1.0
# 213: FEAT_A: 5c2f29ca FEAT_B: Cart Balancer (Assessment)_4020 - Correlation: 1.0
# 214: FEAT_A: a1bbe385 FEAT_B: f28c589a - Correlation: 0.999953679734225
# 215: FEAT_A: a1bbe385 FEAT_B: Air Show_3110 - Correlation: 1.0
# 216: FEAT_A: a1bbe385 FEAT_B: Air Show_3010 - Correlation: 0.999953679734225
# 217: FEAT_A: fbaf3456 FEAT_B: Mushroom Sorter (Assessment)_4030 - Correlation: 0.9999999999999999
# 218: FEAT_A: 90ea0bac FEAT_B: 5859dfb6 - Correlation: 0.9981052472610569
# 219: FEAT_A: 90ea0bac FEAT_B: Bubble Bath_3120 - Correlation: 0.9981052472610569
# 220: FEAT_A: 90ea0bac FEAT_B: Bubble Bath_3020 - Correlation: 1.0
# 221: FEAT_A: 3bf1cf26 FEAT_B: 1af8be29 - Correlation: 0.9998900847287077
# 222: FEAT_A: 3bf1cf26 FEAT_B: Happy Camel_3020 - Correlation: 0.9998900847287077
# 223: FEAT_A: 3bf1cf26 FEAT_B: Happy Camel_3120 - Correlation: 0.9999999999999999
# 224: FEAT_A: bc8f2793 FEAT_B: Pan Balance_4035 - Correlation: 0.9999999999999999
# 225: FEAT_A: b1d5101d FEAT_B: All Star Sorting_4095 - Correlation: 1.0
# 226: FEAT_A: 76babcde FEAT_B: Dino Dive_4070 - Correlation: 1.0
# 227: FEAT_A: 3d0b9317 FEAT_B: Chest Sorter (Assessment)_4040 - Correlation: 1.0
# 228: FEAT_A: 8b757ab8 FEAT_B: 44cb4907 - Correlation: 0.999835058794711
# 229: FEAT_A: 8b757ab8 FEAT_B: Crystals Rule_3020 - Correlation: 0.999835058794711
# 230: FEAT_A: 8b757ab8 FEAT_B: Crystals Rule_3120 - Correlation: 1.0
# 231: FEAT_A: 9e34ea74 FEAT_B: Egg Dropper (Activity)_4070 - Correlation: 1.0
# 232: FEAT_A: 92687c59 FEAT_B: Scrub-A-Dub_4090 - Correlation: 1.0
# 233: FEAT_A: 731c0cbe FEAT_B: Bird Measurer (Assessment)_4090 - Correlation: 1.0
# 234: FEAT_A: c7128948 FEAT_B: Mushroom Sorter (Assessment)_4040 - Correlation: 1.0
# 235: FEAT_A: 90d848e0 FEAT_B: Cauldron Filler (Assessment)_2000 - Correlation: 1.0
# 236: FEAT_A: 923afab1 FEAT_B: 2dcad279 - Correlation: 0.9998567985670082
# 237: FEAT_A: 923afab1 FEAT_B: Cauldron Filler (Assessment)_3110 - Correlation: 0.9998567985670082
# 238: FEAT_A: 923afab1 FEAT_B: Cauldron Filler (Assessment)_3010 - Correlation: 1.0
# 239: FEAT_A: e4f1efe6 FEAT_B: 3afb49e6 - Correlation: 0.9985179906980773
# 240: FEAT_A: e4f1efe6 FEAT_B: 38074c54 - Correlation: 0.9984044689083383
# 241: FEAT_A: e4f1efe6 FEAT_B: 222660ff - Correlation: 0.9984044689083383
# 242: FEAT_A: e4f1efe6 FEAT_B: Chest Sorter (Assessment)_3121 - Correlation: 1.0
# 243: FEAT_A: e4f1efe6 FEAT_B: Chest Sorter (Assessment)_3021 - Correlation: 0.9985179906980773
# 244: FEAT_A: e4f1efe6 FEAT_B: Chest Sorter (Assessment)_2010 - Correlation: 0.9984044689083383
# 245: FEAT_A: e4f1efe6 FEAT_B: Chest Sorter (Assessment)_2030 - Correlation: 0.9984044689083383
# 246: FEAT_A: e7e44842 FEAT_B: Watering Hole (Activity)_4090 - Correlation: 0.9999999999999999
# 247: FEAT_A: 392e14df FEAT_B: Cauldron Filler (Assessment)_4100 - Correlation: 1.0
# 248: FEAT_A: 3a4be871 FEAT_B: Flower Waterer (Activity)_4080 - Correlation: 1.0
# 249: FEAT_A: 6d90d394 FEAT_B: Scrub-A-Dub_2000 - Correlation: 0.9999999999999999
# 250: FEAT_A: 6cf7d25c FEAT_B: 15f99afc - Correlation: 0.9994848234397947
# 251: FEAT_A: 6cf7d25c FEAT_B: Pan Balance_3010 - Correlation: 1.0
# 252: FEAT_A: 6cf7d25c FEAT_B: Pan Balance_3110 - Correlation: 0.9994848234397947
# 253: FEAT_A: 87d743c1 FEAT_B: Dino Dive_4010 - Correlation: 1.0
# 254: FEAT_A: 828e68f9 FEAT_B: Cart Balancer (Assessment)_3110 - Correlation: 1.0
# 255: FEAT_A: 56cd3b43 FEAT_B: bbfe0445 - Correlation: 0.9996926215355526
# 256: FEAT_A: 56cd3b43 FEAT_B: Flower Waterer (Activity)_3010 - Correlation: 1.0
# 257: FEAT_A: 56cd3b43 FEAT_B: Flower Waterer (Activity)_3110 - Correlation: 0.9996926215355526
# 258: FEAT_A: 15a43e5b FEAT_B: Bottle Filler (Activity)_4070 - Correlation: 1.0
# 259: FEAT_A: f71c4741 FEAT_B: f7e47413 - Correlation: 0.9999426890770878
# 260: FEAT_A: f71c4741 FEAT_B: Scrub-A-Dub_3010 - Correlation: 1.0
# 261: FEAT_A: f71c4741 FEAT_B: Scrub-A-Dub_3110 - Correlation: 0.9999426890770878
# 262: FEAT_A: 29f54413 FEAT_B: Leaf Leader_2060 - Correlation: 0.9999999999999998
# 263: FEAT_A: 155f62a4 FEAT_B: 5b49460a - Correlation: 0.9999999999999999
# 264: FEAT_A: 155f62a4 FEAT_B: Chest Sorter (Assessment)_2020 - Correlation: 0.9999999999999999
# 265: FEAT_A: 155f62a4 FEAT_B: Chest Sorter (Assessment)_2000 - Correlation: 0.9999999999999999
# 266: FEAT_A: 91561152 FEAT_B: Cauldron Filler (Assessment)_4025 - Correlation: 1.0
# 267: FEAT_A: 51102b85 FEAT_B: Bird Measurer (Assessment)_4030 - Correlation: 1.0
# 268: FEAT_A: bd701df8 FEAT_B: 49ed92e9 - Correlation: 0.9993109138888533
# 269: FEAT_A: bd701df8 FEAT_B: Watering Hole (Activity)_3110 - Correlation: 1.0
# 270: FEAT_A: bd701df8 FEAT_B: Watering Hole (Activity)_3010 - Correlation: 0.9993109138888533
# 271: FEAT_A: 9c5ef70c FEAT_B: Pan Balance_2000 - Correlation: 1.0
# 272: FEAT_A: e720d930 FEAT_B: 3ddc79c3 - Correlation: 0.9998920962508024
# 273: FEAT_A: e720d930 FEAT_B: Crystals Rule_3121 - Correlation: 1.0
# 274: FEAT_A: e720d930 FEAT_B: Crystals Rule_3021 - Correlation: 0.9998920962508024
# 275: FEAT_A: 93edfe2e FEAT_B: Crystals Rule_4090 - Correlation: 1.0
# 276: FEAT_A: f6947f54 FEAT_B: Bird Measurer (Assessment)_2030 - Correlation: 1.0
# 277: FEAT_A: 0ce40006 FEAT_B: Happy Camel_4080 - Correlation: 1.0
# 278: FEAT_A: 3b2048ee FEAT_B: Leaf Leader_4095 - Correlation: 1.0
# 279: FEAT_A: d3f1e122 FEAT_B: Bottle Filler (Activity)_4035 - Correlation: 1.0
# 280: FEAT_A: 46b50ba8 FEAT_B: Happy Camel_4095 - Correlation: 0.9999999999999998
# 281: FEAT_A: 29bdd9ba FEAT_B: Dino Dive_2000 - Correlation: 1.0
# 282: FEAT_A: 7d093bf9 FEAT_B: Chow Time_2000 - Correlation: 0.9999999999999999
# 283: FEAT_A: db02c830 FEAT_B: 3bfd1a65 - Correlation: 0.9999982205265873
# 284: FEAT_A: db02c830 FEAT_B: Mushroom Sorter (Assessment)_2000 - Correlation: 0.9999982205265873
# 285: FEAT_A: db02c830 FEAT_B: Mushroom Sorter (Assessment)_2025 - Correlation: 0.9999999999999999
# 286: FEAT_A: df4940d3 FEAT_B: 67439901 - Correlation: 0.999935162643595
# 287: FEAT_A: df4940d3 FEAT_B: Bottle Filler (Activity)_3010 - Correlation: 0.999935162643595
# 288: FEAT_A: df4940d3 FEAT_B: Bottle Filler (Activity)_3110 - Correlation: 0.9999999999999999
# 289: FEAT_A: 0d1da71f FEAT_B: Chow Time_3110 - Correlation: 1.0
# 290: FEAT_A: 8af75982 FEAT_B: Happy Camel_4020 - Correlation: 1.0
# 291: FEAT_A: de26c3a6 FEAT_B: Flower Waterer (Activity)_4020 - Correlation: 0.9999999999999999
# 292: FEAT_A: 14de4c5d FEAT_B: Air Show_4100 - Correlation: 1.0
# 293: FEAT_A: cb1178ad FEAT_B: Chest Sorter (Assessment)_4090 - Correlation: 1.0
# 294: FEAT_A: d02b7a8e FEAT_B: All Star Sorting_4035 - Correlation: 1.0
# 295: FEAT_A: 5e812b27 FEAT_B: Sandcastle Builder (Activity)_4030 - Correlation: 1.0
# 296: FEAT_A: 77ead60d FEAT_B: 4d911100 - Correlation: 0.9998475927724766
# 297: FEAT_A: 77ead60d FEAT_B: 16dffff1 - Correlation: 0.9984674845132689
# 298: FEAT_A: 77ead60d FEAT_B: Dino Drink_3021 - Correlation: 0.9999999999999999
# 299: FEAT_A: 77ead60d FEAT_B: Dino Drink_3121 - Correlation: 0.9998475927724766
# 300: FEAT_A: 77ead60d FEAT_B: Dino Drink_2030 - Correlation: 0.9984674845132689
# 301: FEAT_A: 7f0836bf FEAT_B: a29c5338 - Correlation: 0.9986531654717627
# 302: FEAT_A: 7f0836bf FEAT_B: Dino Drink_3010 - Correlation: 0.9986531654717627
# 303: FEAT_A: 7f0836bf FEAT_B: Dino Drink_3110 - Correlation: 1.0
# 304: FEAT_A: 7ec0c298 FEAT_B: Chow Time_3010 - Correlation: 0.9999999999999999
# 305: FEAT_A: 28f975ea FEAT_B: Air Show_4020 - Correlation: 1.0
# 306: FEAT_A: e37a2b78 FEAT_B: ad2fc29c - Correlation: 0.9992191329664104
# 307: FEAT_A: e37a2b78 FEAT_B: 17113b36 - Correlation: 0.9982548122198927
# 308: FEAT_A: e37a2b78 FEAT_B: Bird Measurer (Assessment)_4110 - Correlation: 0.9982548122198927
# 309: FEAT_A: e37a2b78 FEAT_B: Bird Measurer (Assessment)_3120 - Correlation: 1.0
# 310: FEAT_A: e37a2b78 FEAT_B: Bird Measurer (Assessment)_3020 - Correlation: 0.9992191329664104
# 311: FEAT_A: d122731b FEAT_B: Cart Balancer (Assessment)_4100 - Correlation: 0.9999999999999998
# 312: FEAT_A: 562cec5f FEAT_B: Chest Sorter (Assessment)_4025 - Correlation: 1.0
# 313: FEAT_A: c51d8688 FEAT_B: 907a054b - Correlation: 0.9999667370361688
# 314: FEAT_A: c51d8688 FEAT_B: Pan Balance_3020 - Correlation: 0.9999667370361688
# 376: FEAT_A: ec138c1c FEAT_B: Bird Measurer (Assessment)_2020 - Correlation: 0.9999999999999999
# 377: FEAT_A: 6f445b57 FEAT_B: Chow Time_4080 - Correlation: 1.0
# 378: FEAT_A: c7f7f0e1 FEAT_B: Bug Measurer (Activity)_2000 - Correlation: 1.0
# 379: FEAT_A: 5d042115 FEAT_B: Flower Waterer (Activity)_4030 - Correlation: 1.0
# 380: FEAT_A: 77c76bc5 FEAT_B: Cauldron Filler (Assessment)_4090 - Correlation: 1.0
# 381: FEAT_A: 3edf6747 FEAT_B: Cauldron Filler (Assessment)_4035 - Correlation: 0.9999999999999999
# 382: FEAT_A: 4901243f FEAT_B: Fireworks (Activity)_2000 - Correlation: 1.0
# 383: FEAT_A: 9554a50b FEAT_B: Cauldron Filler (Assessment)_4080 - Correlation: 0.9999999999999999
# 384: FEAT_A: 48349b14 FEAT_B: Crystals Rule_2000 - Correlation: 1.0
# 385: FEAT_A: 9b23e8ee FEAT_B: 736f9581 - Correlation: 0.9999999999999999
# 386: FEAT_A: 9b23e8ee FEAT_B: Egg Dropper (Activity)_2020 - Correlation: 0.9999999999999999
# 387: FEAT_A: 9b23e8ee FEAT_B: Egg Dropper (Activity)_2000 - Correlation: 0.9999999999999999
# 388: FEAT_A: 77261ab5 FEAT_B: Sandcastle Builder (Activity)_2000 - Correlation: 0.9999999999999999
# 389: FEAT_A: d88ca108 FEAT_B: Air Show_2070 - Correlation: 1.0
# 390: FEAT_A: a7640a16 FEAT_B: Happy Camel_4070 - Correlation: 1.0
# 391: FEAT_A: 2c4e6db0 FEAT_B: All Star Sorting_2020 - Correlation: 1.0
# 392: FEAT_A: ab4ec3a4 FEAT_B: Dino Drink_4080 - Correlation: 1.0
# 393: FEAT_A: 1cc7cfca FEAT_B: All Star Sorting_4030 - Correlation: 1.0
# 394: FEAT_A: bfc77bd6 FEAT_B: Chest Sorter (Assessment)_4080 - Correlation: 0.9999999999999998
# 395: FEAT_A: 792530f8 FEAT_B: Dino Drink_4030 - Correlation: 1.0
# 396: FEAT_A: e79f3763 FEAT_B: Bug Measurer (Activity)_4030 - Correlation: 1.0
# 397: FEAT_A: e3ff61fb FEAT_B: Dino Dive_3021 - Correlation: 1.0
# 398: FEAT_A: bdf49a58 FEAT_B: 1375ccb7 - Correlation: 0.9993801763820347
# 399: FEAT_A: bdf49a58 FEAT_B: Bird Measurer (Assessment)_3110 - Correlation: 1.0
# 400: FEAT_A: bdf49a58 FEAT_B: Bird Measurer (Assessment)_3010 - Correlation: 0.9993801763820347
# 401: FEAT_A: c1cac9a2 FEAT_B: Scrub-A-Dub_2081 - Correlation: 0.9999999999999998
# 402: FEAT_A: ea296733 FEAT_B: df4fe8b6 - Correlation: 0.9972489515829078
# 403: FEAT_A: ea296733 FEAT_B: Chest Sorter (Assessment)_3020 - Correlation: 1.0
# 404: FEAT_A: ea296733 FEAT_B: Chest Sorter (Assessment)_3120 - Correlation: 0.9972489515829078
# 405: FEAT_A: c0415e5c FEAT_B: Dino Dive_4020 - Correlation: 1.0
# 406: FEAT_A: e694a35b FEAT_B: Fireworks (Activity)_4020 - Correlation: 1.0
# 407: FEAT_A: 01ca3a3c FEAT_B: Leaf Leader_4080 - Correlation: 0.9999999999999999
# 408: FEAT_A: 6077cc36 FEAT_B: Bird Measurer (Assessment)_4080 - Correlation: 0.9999999999999998
# 409: FEAT_A: f50fc6c1 FEAT_B: Watering Hole (Activity)_4021 - Correlation: 1.0
# 410: FEAT_A: cc5087a3 FEAT_B: Crystals Rule_4010 - Correlation: 1.0
# 411: FEAT_A: 9d4e7b25 FEAT_B: Cart Balancer (Assessment)_4040 - Correlation: 1.0
# 412: FEAT_A: a0faea5d FEAT_B: Bubble Bath_4070 - Correlation: 1.0
# 413: FEAT_A: 3ee399c3 FEAT_B: Cauldron Filler (Assessment)_4070 - Correlation: 1.0
# 414: FEAT_A: 8d748b58 FEAT_B: Bug Measurer (Activity)_4090 - Correlation: 0.9999999999999998
# 415: FEAT_A: 1b54d27f FEAT_B: Watering Hole (Activity)_2010 - Correlation: 1.0
# 416: FEAT_A: 25fa8af4 FEAT_B: Mushroom Sorter (Assessment)_4100 - Correlation: 1.0
# 417: FEAT_A: 5e109ec3 FEAT_B: Cart Balancer (Assessment)_4030 - Correlation: 1.0
# 418: FEAT_A: abc5811c FEAT_B: Happy Camel_4010 - Correlation: 1.0
# 419: FEAT_A: 46cd75b4 FEAT_B: Chicken Balancer (Activity)_4022 - Correlation: 0.9999999999999998
# 420: FEAT_A: 99abe2bb FEAT_B: Bubble Bath_2080 - Correlation: 1.0
# 421: FEAT_A: 532a2afb FEAT_B: Cauldron Filler (Assessment)_2020 - Correlation: 1.0
# 422: FEAT_A: f3cd5473 FEAT_B: Pan Balance_4070 - Correlation: 1.0
# 423: FEAT_A: d51b1749 FEAT_B: Happy Camel_2080 - Correlation: 1.0
# 424: FEAT_A: 84538528 FEAT_B: Sandcastle Builder (Activity)_4020 - Correlation: 1.0
# 425: FEAT_A: 5f5b2617 FEAT_B: Bottle Filler (Activity)_4080 - Correlation: 1.0
# 426: FEAT_A: ac92046e FEAT_B: d88e8f25 - Correlation: 0.9999763070332107
# 427: FEAT_A: ac92046e FEAT_B: Scrub-A-Dub_3020 - Correlation: 0.9999763070332107
# 428: FEAT_A: ac92046e FEAT_B: Scrub-A-Dub_3120 - Correlation: 1.0
# 429: FEAT_A: 93b353f2 FEAT_B: Chest Sorter (Assessment)_4100 - Correlation: 0.9999999999999998
# 430: FEAT_A: 7040c096 FEAT_B: Scrub-A-Dub_4010 - Correlation: 1.0
# 431: FEAT_A: 795e4a37 FEAT_B: Cart Balancer (Assessment)_3010 - Correlation: 1.0
# 432: FEAT_A: 99ea62f3 FEAT_B: Bubble Bath_2083 - Correlation: 1.0
# 433: FEAT_A: 06372577 FEAT_B: Air Show_2060 - Correlation: 1.0
# 434: FEAT_A: d185d3ea FEAT_B: Chow Time_4035 - Correlation: 1.0
# 435: FEAT_A: ecc6157f FEAT_B: Cart Balancer (Assessment)_4080 - Correlation: 0.9999999999999999
# 436: FEAT_A: e7561dd2 FEAT_B: Pan Balance_4025 - Correlation: 0.9999999999999998
# 437: FEAT_A: c58186bf FEAT_B: Sandcastle Builder (Activity)_4035 - Correlation: 1.0
# 438: FEAT_A: 5c3d2b2f FEAT_B: Scrub-A-Dub_4020 - Correlation: 1.0
# 439: FEAT_A: 37937459 FEAT_B: Sandcastle Builder (Activity)_4090 - Correlation: 0.9999999999999998
# 440: FEAT_A: 461eace6 FEAT_B: Egg Dropper (Activity)_4020 - Correlation: 1.0
# 441: FEAT_A: 4e5fc6f5 FEAT_B: Cart Balancer (Assessment)_4090 - Correlation: 1.0
# 442: FEAT_A: 3d63345e FEAT_B: Cart Balancer (Assessment)_4035 - Correlation: 1.0
# 443: FEAT_A: 6f4adc4b FEAT_B: 55115cbd - Correlation: 0.9997831892615398
# 444: FEAT_A: 6f4adc4b FEAT_B: Bubble Bath_3021 - Correlation: 1.0
# 445: FEAT_A: 6f4adc4b FEAT_B: Bubble Bath_3121 - Correlation: 0.9997831892615398
# 446: FEAT_A: bcceccc6 FEAT_B: Air Show_4070 - Correlation: 1.0
# 447: FEAT_A: 6c517a88 FEAT_B: Dino Drink_4070 - Correlation: 1.0
# 448: FEAT_A: 6bf9e3e1 FEAT_B: Happy Camel_4040 - Correlation: 0.9999999999999999
# 449: FEAT_A: a8efe47b FEAT_B: Chest Sorter (Assessment)_4030 - Correlation: 1.0
# 450: FEAT_A: 804ee27f FEAT_B: Pan Balance_4020 - Correlation: 1.0
# 451: FEAT_A: 69fdac0a FEAT_B: 8d7e386c - Correlation: 0.9996590210382708
# 452: FEAT_A: 69fdac0a FEAT_B: Happy Camel_3010 - Correlation: 0.9996590210382708
# 453: FEAT_A: 69fdac0a FEAT_B: Happy Camel_3110 - Correlation: 0.9999999999999999
# 454: FEAT_A: acf5c23f FEAT_B: Cart Balancer (Assessment)_4070 - Correlation: 1.0
# 455: FEAT_A: d2659ab4 FEAT_B: Air Show_2075 - Correlation: 1.0
# 456: FEAT_A: 9ce586dd FEAT_B: Chest Sorter (Assessment)_4035 - Correlation: 1.0
# 457: FEAT_A: a76029ee FEAT_B: Bird Measurer (Assessment)_4040 - Correlation: 0.9999999999999999
# 458: FEAT_A: 1beb320a FEAT_B: Bubble Bath_2020 - Correlation: 1.0
# 459: FEAT_A: b5053438 FEAT_B: d3268efa - Correlation: 0.999576326704631
# 460: FEAT_A: b5053438 FEAT_B: 28520915 - Correlation: 0.9990905166101879
# 461: FEAT_A: b5053438 FEAT_B: Cauldron Filler (Assessment)_2030 - Correlation: 0.9990905166101879
# 462: FEAT_A: b5053438 FEAT_B: Cauldron Filler (Assessment)_3121 - Correlation: 1.0
# 463: FEAT_A: b5053438 FEAT_B: Cauldron Filler (Assessment)_3021 - Correlation: 0.999576326704631
# 464: FEAT_A: a16a373e FEAT_B: Bird Measurer (Assessment)_4070 - Correlation: 1.0
# 465: FEAT_A: 611485c5 FEAT_B: Fireworks (Activity)_4080 - Correlation: 1.0
# 466: FEAT_A: 0086365d FEAT_B: Pan Balance_4010 - Correlation: 0.9999999999999999
# 467: FEAT_A: 4bb2f698 FEAT_B: Chicken Balancer (Activity)_4070 - Correlation: 0.9999999999999998
# 468: FEAT_A: 5e3ea25a FEAT_B: Crystals Rule_4070 - Correlation: 1.0
# 469: FEAT_A: f56e0afc FEAT_B: Bird Measurer (Assessment)_2000 - Correlation: 1.0
# 470: FEAT_A: cdd22e43 FEAT_B: Chicken Balancer (Activity)_4035 - Correlation: 1.0
# 471: FEAT_A: 119b5b02 FEAT_B: Dino Dive_4080 - Correlation: 1.0
# 472: FEAT_A: 262136f4 FEAT_B: Leaf Leader_4020 - Correlation: 1.0
# 473: FEAT_A: 74e5f8a7 FEAT_B: Dino Drink_4020 - Correlation: 1.0
# 474: FEAT_A: d38c2fd7 FEAT_B: Bird Measurer (Assessment)_4035 - Correlation: 0.9999999999999999
# 475: FEAT_A: d2278a3b FEAT_B: Bottle Filler (Activity)_2000 - Correlation: 1.0
# 476: FEAT_A: 4d6737eb FEAT_B: Dino Drink_2070 - Correlation: 1.0
# 477: FEAT_A: 2b058fe3 FEAT_B: Cauldron Filler (Assessment)_2010 - Correlation: 1.0
# 478: FEAT_A: 5be391b5 FEAT_B: Dino Drink_4010 - Correlation: 1.0
# 479: FEAT_A: 16667cc5 FEAT_B: Chicken Balancer (Activity)_4080 - Correlation: 0.9999999999999999
# 480: FEAT_A: beb0a7b9 FEAT_B: b88f38da - Correlation: 0.9999125179829754
# 481: FEAT_A: beb0a7b9 FEAT_B: Fireworks (Activity)_3110 - Correlation: 0.9999125179829754
# 482: FEAT_A: beb0a7b9 FEAT_B: Fireworks (Activity)_3010 - Correlation: 1.0
# 483: FEAT_A: 8fee50e2 FEAT_B: Bird Measurer (Assessment)_4020 - Correlation: 1.0
# 484: FEAT_A: 2a444e03 FEAT_B: Pan Balance_4030 - Correlation: 1.0
# 485: FEAT_A: 884228c8 FEAT_B: Fireworks (Activity)_4070 - Correlation: 1.0
# 486: FEAT_A: fcfdffb6 FEAT_B: Flower Waterer (Activity)_4022 - Correlation: 1.0
# 487: FEAT_A: Crystal Caves - Level 1 FEAT_B: Crystal Caves - Level 1_2000 - Correlation: 1.0
# 488: FEAT_A: Honey Cake FEAT_B: Honey Cake_2000 - Correlation: 1.0
# 489: FEAT_A: Tree Top City - Level 1 FEAT_B: Tree Top City - Level 1_2000 - Correlation: 0.9999999999999999
# 490: FEAT_A: Costume Box FEAT_B: Costume Box_2000 - Correlation: 1.0
# 491: FEAT_A: Tree Top City - Level 2 FEAT_B: Tree Top City - Level 2_2000 - Correlation: 1.0
# 492: FEAT_A: Crystal Caves - Level 3 FEAT_B: Crystal Caves - Level 3_2000 - Correlation: 1.0
# 493: FEAT_A: Magma Peak - Level 2 FEAT_B: Magma Peak - Level 2_2000 - Correlation: 1.0
# 494: FEAT_A: Crystal Caves - Level 2 FEAT_B: Crystal Caves - Level 2_2000 - Correlation: 1.0
# 495: FEAT_A: Treasure Map FEAT_B: Treasure Map_2000 - Correlation: 1.0
# 496: FEAT_A: Slop Problem FEAT_B: Slop Problem_2000 - Correlation: 1.0
# 497: FEAT_A: Magma Peak - Level 1 FEAT_B: Magma Peak - Level 1_2000 - Correlation: 1.0
# 498: FEAT_A: Pirate's Tale FEAT_B: Pirate's Tale_2000 - Correlation: 0.9999999999999999
# 499: FEAT_A: Heavy, Heavier, Heaviest FEAT_B: Heavy, Heavier, Heaviest_2000 - Correlation: 1.0
# 500: FEAT_A: Tree Top City - Level 3 FEAT_B: Tree Top City - Level 3_2000 - Correlation: 1.0
# 501: FEAT_A: Ordering Spheres FEAT_B: Ordering Spheres_2000 - Correlation: 1.0
# 502: FEAT_A: Welcome to Lost Lagoon! FEAT_B: Welcome to Lost Lagoon!_2000 - Correlation: 1.0
# 503: FEAT_A: Balancing Act FEAT_B: Balancing Act_2000 - Correlation: 1.0
# 504: FEAT_A: Lifting Heavy Things FEAT_B: Lifting Heavy Things_2000 - Correlation: 0.9999999999999999
# 505: FEAT_A: 12 Monkeys FEAT_B: 12 Monkeys_2000 - Correlation: 1.0
# 506: FEAT_A: Rulers FEAT_B: Rulers_2000 - Correlation: 1.0
# 507: FEAT_A: var_event_id FEAT_B: var_title_event_code - Correlation: 0.9995254184300616

# %%
to_exclude = [] 
ajusted_test = reduce_test.copy()
for feature in ajusted_test.columns:
    if feature not in ['accuracy_group', 'installation_id', 'accuracy_group', 'session_title']:
        data = reduce_train[feature]
        train_mean = data.mean()
        data = ajusted_test[feature] 
        test_mean = data.mean()
        try:
            error = stract_hists(feature, adjust=True)
            ajust_factor = train_mean / test_mean
            if ajust_factor > 10 or ajust_factor < 0.1:# or error > 0.01:
                to_exclude.append(feature)
                print(feature, train_mean, test_mean, error)
            else:
                ajusted_test[feature] *= ajust_factor
        except:
            to_exclude.append(feature)
            print(feature, train_mean, test_mean)
# Out:
# Clip 34.06529112492934 15.253
# Activity 10.746410401356698 4.726
# Assessment 7.8468626342566425 2.347
# Game 12.502939513849633 5.119
# acc_Mushroom Sorter (Assessment) -0.1132083557733651 -0.517832142857143
# acc_Chest Sorter (Assessment) -0.4492879287736696 -0.7507142857142856
# acc_Bird Measurer (Assessment) -0.43114150123580497 -0.721518874181374
# acc_Cauldron Filler (Assessment) -0.08582722503299132 -0.48076626984127
# acc_Cart Balancer (Assessment) -0.04020325710970116 -0.47065833333333346
# 2050 7.501356698699831 2.862
# 4100 26.189881288863766 7.284
# 4230 8.124816280384398 3.4
# 5000 4.9399660825325045 2.273
# 4235 8.123685698134539 3.4
# 2060 3.9443188241944602 1.614
# 4110 6.011588468061052 1.32
# 5010 4.828547201808932 2.215
# 2070 2.0806105144149236 0.843
# 2075 1.622215941209723 0.682
# 2080 8.874053137365744 3.467
# 2081 2.1376483889202937 0.876
# 2083 6.166817410966648 2.412
# 3110 346.88004522329 140.268
# 4010 12.74120972300735 5.193
# 3120 70.54013566986998 26.494
# Scrub-A-Dub_2030 22.714697569248163 8.243
# Mushroom Sorter (Assessment)_4030 8.763143018654608 2.304
# Mushroom Sorter (Assessment)_4090 0.17382702091577162 0.008
# Flower Waterer (Activity)_2000 1.2569248162803843 0.527
# Sandcastle Builder (Activity)_4030 37.48575466365178 15.981
# Bug Measurer (Activity)_4035 7.218089315997739 4.184
# Sandcastle Builder (Activity)_2010 0.0 0.0
# Cart Balancer (Assessment)_3110 2.5602600339174675 0.879
# Chow Time_4010 1.9292820802713397 0.87
# Chow Time_4030 33.139570378745056 16.422
# Pan Balance_4080 0.0013001695873374789 0.0
# Crystals Rule_3010 35.79564725833804 11.004
# Sandcastle Builder (Activity)_3010 29.667552289429057 13.016
# Chow Time_3021 7.057207461842849 3.662
# Bubble Bath_3010 15.292142453363482 7.641
# Dino Drink_4080 0.0009044657998869418 0.0
# Cart Balancer (Assessment)_4100 2.391124929338609 0.832
# Happy Camel_4040 11.347484454494065 4.836
# Air Show_4020 8.676653476540418 2.267
# Mushroom Sorter (Assessment)_2035 1.6977388355002827 0.455
# Air Show_3110 20.908027133973995 5.744
# All Star Sorting_4080 0.004861503674392312 0.002
# Pan Balance_3121 4.471848501978519 1.491
# Dino Dive_2030 3.065856416054268 1.292
# Bottle Filler (Activity)_4035 14.1152063312606 7.254
# Scrub-A-Dub_3020 9.371905031091012 3.481
# Dino Drink_4030 14.781062747314866 7.126
# Dino Dive_3110 14.848501978518938 6.359
# Happy Camel_2081 0.5529677784058791 0.207
# Flower Waterer (Activity)_4070 12.667213114754098 6.298
# Dino Drink_2060 1.0397399660825326 0.483
# Chow Time_4020 22.577614471452797 11.176
# Tree Top City - Level 1_2000 1.6021481062747316 0.901
# Bubble Bath_2035 1.9019219898247597 0.934
# Scrub-A-Dub_2050 7.501356698699831 2.862
# All Star Sorting_3010 7.715262860373092 3.341
# Bug Measurer (Activity)_4090 0.10056529112492933 0.079
# Pan Balance_2000 0.8132278123233465 0.331
# All Star Sorting_4035 3.4456755228942906 1.659
# Sandcastle Builder (Activity)_4020 9.03408705483324 3.941
# Chicken Balancer (Activity)_4035 12.540361786319954 6.106
# Bug Measurer (Activity)_2000 1.042622950819672 0.431
# Bird Measurer (Assessment)_4070 13.307744488411531 3.969
# Air Show_3010 21.107461842849066 5.81
# All Star Sorting_4030 21.927077444884116 9.652
# Cauldron Filler (Assessment)_4025 3.4277557942340304 0.703
# Happy Camel_4095 0.36687394007914076 0.145
# Mushroom Sorter (Assessment)_3020 1.9105144149236857 0.271
# Bubble Bath_4230 8.124816280384398 3.4
# Pan Balance_4030 19.72622950819672 7.254
# Mushroom Sorter (Assessment)_4025 5.142849067269644 1.383
# Bird Measurer (Assessment)_4020 2.396325607687959 0.96
# Crystals Rule_2010 0.0 0.0
# Crystals Rule_3121 6.2569813453928775 1.893
# Leaf Leader_4090 0.040079140757490105 0.013
# Bug Measurer (Activity)_3110 42.538835500282644 19.119
# Magma Peak - Level 1_2000 1.6795929903900508 0.903
# Treasure Map_2000 0.9309214245336348 0.223
# Cauldron Filler (Assessment)_4030 11.815093273035613 3.345
# Chest Sorter (Assessment)_4040 1.7508196721311475 0.479
# Egg Dropper (Activity)_2000 0.9527981910684002 0.363
# Mushroom Sorter (Assessment)_2010 1.187337478801583 0.36
# Flower Waterer (Activity)_4022 14.577162238552855 6.834
# Bird Measurer (Assessment)_3121 0.5040135669869983 0.208
# Magma Peak - Level 2_2000 3.0242509892594684 1.434
# Dino Dive_3020 3.5071791972866024 1.518
# Scrub-A-Dub_3010 28.76376483889203 10.4
# Cart Balancer (Assessment)_2020 1.6141888072357264 0.565
# Heavy, Heavier, Heaviest_2000 0.8858677218767665 0.281
# Dino Drink_3110 5.851158846806105 2.708
# Chow Time_3121 6.973092142453363 3.61
# Air Show_4110 0.8690785754663651 0.217
# Cauldron Filler (Assessment)_3010 8.575466365178066 2.368
# Mushroom Sorter (Assessment)_4040 1.657263990955342 0.416
# Leaf Leader_2075 0.5787450537026568 0.24
# Bug Measurer (Activity)_4030 14.515488976823065 7.309
# Crystals Rule_2000 0.9024307518371961 0.318
# Flower Waterer (Activity)_3110 11.57976257772753 4.852
# Dino Dive_4020 10.553646127755794 4.42
# Pan Balance_3120 4.582306387789711 1.322
# Chicken Balancer (Activity)_3010 7.663425664217072 3.431
# Pan Balance_4070 22.56591294516676 7.4
# Cauldron Filler (Assessment)_4020 8.531543244771058 2.361
# Bug Measurer (Activity)_4070 11.115545505935557 6.454
# Bird Measurer (Assessment)_4090 0.10864895421141887 0.021
# Chow Time_4035 10.552176370830978 5.245
# Mushroom Sorter (Assessment)_4070 15.866704352741662 4.818
# Happy Camel_4070 7.420746184284907 2.869
# Crystals Rule_4090 0.054267947993216506 0.028
# Chicken Balancer (Activity)_2000 1.021311475409836 0.487
# Happy Camel_3021 3.2550028264556246 1.351
# Sandcastle Builder (Activity)_3110 29.44527981910684 12.905
# Leaf Leader_2000 0.8383267382702092 0.323
# Scrub-A-Dub_2040 8.366365178066705 3.221
# Happy Camel_3120 2.3774448841153193 0.876
# Balancing Act_2000 1.144544940644432 0.528
# All Star Sorting_3020 1.539400791407575 0.69
# Chow Time_4080 0.05161107970604861 0.015
# Honey Cake_2000 0.9101187111362352 0.442
# Watering Hole (Activity)_4090 0.17851893725268514 0.084
# Costume Box_2000 1.0873940079140758 0.422
# Flower Waterer (Activity)_4090 0.18892029395138496 0.05
# All Star Sorting_3021 3.4200678349349913 1.44
# Cauldron Filler (Assessment)_4100 4.282419446014697 0.944
# Chow Time_2000 1.7391181458451102 0.786
# Chest Sorter (Assessment)_2000 1.3233465234595816 0.359
# Rulers_2000 0.901752402487281 0.32
# Cart Balancer (Assessment)_3120 0.9540983606557377 0.336
# Happy Camel_2080 2.016280384397965 0.8
# Crystals Rule_3110 35.59723007348784 10.918
# Pan Balance_4010 0.8116449971735443 0.326
# Ordering Spheres_2000 2.2379875635952517 0.783
# Mushroom Sorter (Assessment)_3021 6.396156020350481 1.777
# Bubble Bath_2000 1.302600339174675 0.464
# Chicken Balancer (Activity)_4090 0.18501978518937254 0.107
# Air Show_2030 1.8753533069530808 0.53
# Air Show_2020 2.20192198982476 0.654
# Air Show_4070 23.975805539853024 8.551
# Cauldron Filler (Assessment)_3021 4.086941775014132 1.304
# Bottle Filler (Activity)_2020 18.042453363482192 8.93
# Scrub-A-Dub_3110 28.35048049745619 10.211
# All Star Sorting_2030 3.483776144714528 1.47
# Happy Camel_3110 10.666139061616732 4.561
# Sandcastle Builder (Activity)_4080 0.012266817410966647 0.048
# Cart Balancer (Assessment)_3121 1.1250423968343697 0.396
# All Star Sorting_4020 18.473092142453364 7.989
# Bubble Bath_2080 1.0609383832673827 0.426
# Scrub-A-Dub_2000 1.3738835500282645 0.588
# Bubble Bath_4040 8.653193894855852 4.007
# All Star Sorting_2020 4.099095534200113 1.765
# installation_session_count 65.1615036743923 27.445
# var_event_code 27.782758620689656 22.151
# var_event_id 144.04262295081966 86.324
# var_title 22.355963821368004 14.862
# var_title_event_code 153.5320520067835 92.871
# accumulated_correct_attempts 4.836178631995478 1.598
# accumulated_uncorrect_attempts 13.639739966082532 2.894
# duration_mean 174.58295457150786 78.53250750997883
# duration_std 324.2980849842511 131.94236117299278
# accumulated_accuracy 0.4512559791681549 0.3353760806657431
# 0 3.0106840022611645 0.749
# 1 0.9547767100056529 0.265
# 2 0.743640474844545 0.242
# 3 3.1377614471452797 1.091
# accumulated_accuracy_group 1.4232457612417453 1.0525390284699299
# accumulated_actions 2752.3266252119843 1155.414

# %%
features = [x for x in features if x not in (to_exclude + to_remove)]
reduce_train[features].shape
# Out:
# (17690, 1)

# %%
#Cat Model creation
from catboost import CatBoostRegressor,CatBoostClassifier
cat_clf=CatBoostClassifier(loss_function= 'MultiClass',task_type= "CPU",iterations= 200,
                   od_type= "Iter",depth= 10,colsample_bylevel= 0.5,early_stopping_rounds= 100,
                   l2_leaf_reg= 18,random_seed= 42,use_best_model= True)

cv = StratifiedKFold(n_splits=2, shuffle=True, random_state=42)
X=reduce_train[to_exclude]
Y=reduce_train['accuracy_group']
for train_idx, val_idx in cv.split(X,Y):
    x_train, y_train = X.iloc[train_idx], Y.iloc[train_idx] 
    x_test, y_test = X.iloc[val_idx], Y.iloc[val_idx]     
    cat_clf.fit(x_train,y_train,eval_set=(x_test, y_test),verbose=100)
# Out:
# 0:	learn: 1.3762286	test: 1.3765460	best: 1.3765460 (0)	total: 1.62s	remaining: 5m 23s
# 100:	learn: 1.1232935	test: 1.1614426	best: 1.1614426 (100)	total: 1m 55s	remaining: 1m 52s
# 199:	learn: 1.0703886	test: 1.1415364	best: 1.1415364 (199)	total: 3m 48s	remaining: 0us
#
# bestTest = 1.141536424
# bestIteration = 199
#
# 0:	learn: 1.3753570	test: 1.3753485	best: 1.3753485 (0)	total: 1.28s	remaining: 4m 14s
# 100:	learn: 1.1271896	test: 1.1586566	best: 1.1586566 (100)	total: 1m 54s	remaining: 1m 52s
# 199:	learn: 1.0742400	test: 1.1392939	best: 1.1392939 (199)	total: 3m 47s	remaining: 0us
#
# bestTest = 1.139293863
# bestIteration = 199

# %%
#save models
import pickle
#cat_model
pickle.dump(cat_clf, open('cat.sav', 'wb'))

# %%
#xg model
xgb_clf=xgb.XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=1, gamma=0,
              learning_rate=0.05, max_delta_step=0, max_depth=10,
              min_child_weight=6, missing=None, n_estimators=200, n_jobs=1,
              nthread=None, objective='multi:softprob', random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
              silent=None, subsample=1, verbosity=1)
cv = StratifiedKFold(n_splits=2, shuffle=True, random_state=42)
X=reduce_train[to_exclude]
Y=reduce_train['accuracy_group']
for train_idx, val_idx in cv.split(X,Y):
    x_train, y_train = X.iloc[train_idx], Y.iloc[train_idx] 
    x_test, y_test = X.iloc[val_idx], Y.iloc[val_idx]     
    xgb_clf.fit(x_train,y_train)

# %%
#randomforest
from sklearn.ensemble import RandomForestClassifier
rf_clf=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
                       max_depth=10, max_features='auto', max_leaf_nodes=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=4, min_samples_split=5,
                       min_weight_fraction_leaf=0.0, n_estimators=200,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
cv = StratifiedKFold(n_splits=2, shuffle=True, random_state=42)
X=reduce_train[to_exclude]
Y=reduce_train['accuracy_group']
for train_idx, val_idx in cv.split(X,Y):
    x_train, y_train = X.iloc[train_idx], Y.iloc[train_idx] 
    x_test, y_test = X.iloc[val_idx], Y.iloc[val_idx]     
    rf_clf.fit(x_train,y_train)

# %%
#nn model
#cnn model

# %%
#meta data prepration
X=reduce_train[to_exclude]
X1=reduce_test[to_exclude]
Y=reduce_train['accuracy_group']
Y=Y.to_numpy()

#train data
tr1=cat_clf.predict_proba(X)
tr2=xgb_clf.predict_proba(X)
tr3=rf_clf.predict_proba(X)

#test data
ts1=cat_clf.predict_proba(X1)
ts2=xgb_clf.predict_proba(X1)
ts3=rf_clf.predict_proba(X1)

#merge the data
meta_data=np.column_stack((tr1,tr2,tr3))
meta_test_data=np.column_stack((ts1,ts2,ts3))

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
tf.keras.backend.clear_session() ## For easy reset of notebook state
inputs = keras.Input(shape=(12,), name='ip')
x = layers.Dense(36, activation='sigmoid', name='dense_1')(inputs)
x = layers.Dense(24, activation='tanh', name='dense_4')(x)
x = layers.Dense(12, activation='relu', name='dense_7')(x)
x = layers.Dropout(.25)(inputs)
x = layers.Dense(8, activation='relu', name='dense_9')(x)
outputs = layers.Dense(4, activation='softmax', name='predictions')(x)
meta_clf = keras.Model(inputs=inputs, outputs=outputs)
meta_clf.compile(optimizer=keras.optimizers.RMSprop(),  # Optimizer
              loss=keras.losses.SparseCategoricalCrossentropy(), # Loss function to minimize
              metrics=[keras.metrics.SparseCategoricalAccuracy()]) # List of metrics to monitor

# %%
#data split up
from sklearn.model_selection import train_test_split
x1_train, x1_test, y1_train, y1_test = train_test_split(meta_data,Y, test_size=0.3)
cv = StratifiedKFold(n_splits=2, shuffle=True, random_state=42)
for train_idx, val_idx in cv.split(x1_train,y1_train):
    x_train, y_train = x1_train[train_idx], y1_train[train_idx] 
    x_test, y_test = x1_train[val_idx], y1_train[val_idx] 
    history = meta_clf.fit(x_train, y_train,validation_data=(x_test, y_test),batch_size=24,epochs=50)
    #print('\nhistory dict:', history.history)
# Out:
# Train on 6191 samples, validate on 6192 samples
# Epoch 1/50
# 6191/6191 [==============================] - 1s 228us/sample - loss: 1.2078 - sparse_categorical_accuracy: 0.5049 - val_loss: 1.1024 - val_sparse_categorical_accuracy: 0.5027
# Epoch 2/50
# 6191/6191 [==============================] - 1s 120us/sample - loss: 1.0785 - sparse_categorical_accuracy: 0.5577 - val_loss: 1.0031 - val_sparse_categorical_accuracy: 0.6370
# Epoch 3/50
# 6191/6191 [==============================] - 1s 121us/sample - loss: 1.0132 - sparse_categorical_accuracy: 0.6109 - val_loss: 0.9406 - val_sparse_categorical_accuracy: 0.6717
# Epoch 4/50
# 6191/6191 [==============================] - 1s 121us/sample - loss: 0.9821 - sparse_categorical_accuracy: 0.6185 - val_loss: 0.9047 - val_sparse_categorical_accuracy: 0.6775
# Epoch 5/50
# 6191/6191 [==============================] - 1s 122us/sample - loss: 0.9595 - sparse_categorical_accuracy: 0.6316 - val_loss: 0.8836 - val_sparse_categorical_accuracy: 0.6860
# Epoch 6/50
# 6191/6191 [==============================] - 1s 121us/sample - loss: 0.9527 - sparse_categorical_accuracy: 0.6446 - val_loss: 0.8720 - val_sparse_categorical_accuracy: 0.6883
# Epoch 7/50
# 6191/6191 [==============================] - 1s 123us/sample - loss: 0.9418 - sparse_categorical_accuracy: 0.6487 - val_loss: 0.8611 - val_sparse_categorical_accuracy: 0.6996
# Epoch 8/50
# 6191/6191 [==============================] - 1s 119us/sample - loss: 0.9400 - sparse_categorical_accuracy: 0.6543 - val_loss: 0.8533 - val_sparse_categorical_accuracy: 0.7038
# Epoch 9/50
# 6191/6191 [==============================] - 1s 120us/sample - loss: 0.9383 - sparse_categorical_accuracy: 0.6566 - val_loss: 0.8485 - val_sparse_categorical_accuracy: 0.7096
# Epoch 10/50
# 6191/6191 [==============================] - 1s 119us/sample - loss: 0.9296 - sparse_categorical_accuracy: 0.6610 - val_loss: 0.8432 - val_sparse_categorical_accuracy: 0.7145
# Epoch 11/50
# 6191/6191 [==============================] - 1s 118us/sample - loss: 0.9149 - sparse_categorical_accuracy: 0.6695 - val_loss: 0.8436 - val_sparse_categorical_accuracy: 0.7209
# Epoch 12/50
# 6191/6191 [==============================] - 1s 120us/sample - loss: 0.9171 - sparse_categorical_accuracy: 0.6674 - val_loss: 0.8437 - val_sparse_categorical_accuracy: 0.7227
# Epoch 13/50
# 6191/6191 [==============================] - 1s 121us/sample - loss: 0.9099 - sparse_categorical_accuracy: 0.6713 - val_loss: 0.8370 - val_sparse_categorical_accuracy: 0.7221
# Epoch 14/50
# 6191/6191 [==============================] - 1s 118us/sample - loss: 0.9144 - sparse_categorical_accuracy: 0.6674 - val_loss: 0.8393 - val_sparse_categorical_accuracy: 0.7234
# Epoch 15/50
# 6191/6191 [==============================] - 1s 118us/sample - loss: 0.9175 - sparse_categorical_accuracy: 0.6632 - val_loss: 0.8362 - val_sparse_categorical_accuracy: 0.7243
# Epoch 16/50
# 6191/6191 [==============================] - 1s 117us/sample - loss: 0.9204 - sparse_categorical_accuracy: 0.6606 - val_loss: 0.8373 - val_sparse_categorical_accuracy: 0.7248
# Epoch 17/50
# 6191/6191 [==============================] - 1s 118us/sample - loss: 0.9137 - sparse_categorical_accuracy: 0.6689 - val_loss: 0.8382 - val_sparse_categorical_accuracy: 0.7243
# Epoch 18/50
# 6191/6191 [==============================] - 1s 118us/sample - loss: 0.9123 - sparse_categorical_accuracy: 0.6698 - val_loss: 0.8344 - val_sparse_categorical_accuracy: 0.7272
# Epoch 19/50
# 6191/6191 [==============================] - 1s 122us/sample - loss: 0.9009 - sparse_categorical_accuracy: 0.6739 - val_loss: 0.8381 - val_sparse_categorical_accuracy: 0.7271
# Epoch 20/50
# 6191/6191 [==============================] - 1s 124us/sample - loss: 0.9005 - sparse_categorical_accuracy: 0.6744 - val_loss: 0.8329 - val_sparse_categorical_accuracy: 0.7277
# Epoch 21/50
# 6191/6191 [==============================] - 1s 119us/sample - loss: 0.9082 - sparse_categorical_accuracy: 0.6684 - val_loss: 0.8313 - val_sparse_categorical_accuracy: 0.7267
# Epoch 22/50
# 6191/6191 [==============================] - 1s 118us/sample - loss: 0.9144 - sparse_categorical_accuracy: 0.6645 - val_loss: 0.8320 - val_sparse_categorical_accuracy: 0.7279
# Epoch 23/50
# 6191/6191 [==============================] - 1s 119us/sample - loss: 0.8985 - sparse_categorical_accuracy: 0.6728 - val_loss: 0.8368 - val_sparse_categorical_accuracy: 0.7253
# Epoch 24/50
# 6191/6191 [==============================] - 1s 119us/sample - loss: 0.9091 - sparse_categorical_accuracy: 0.6658 - val_loss: 0.8383 - val_sparse_categorical_accuracy: 0.7251
# Epoch 25/50
# 6191/6191 [==============================] - 1s 121us/sample - loss: 0.9073 - sparse_categorical_accuracy: 0.6694 - val_loss: 0.8302 - val_sparse_categorical_accuracy: 0.7285
# Epoch 26/50
# 6191/6191 [==============================] - 1s 117us/sample - loss: 0.8990 - sparse_categorical_accuracy: 0.6708 - val_loss: 0.8254 - val_sparse_categorical_accuracy: 0.7272
# Epoch 27/50
# 6191/6191 [==============================] - 1s 119us/sample - loss: 0.9179 - sparse_categorical_accuracy: 0.6689 - val_loss: 0.8401 - val_sparse_categorical_accuracy: 0.7276
# Epoch 28/50
# 6191/6191 [==============================] - 1s 121us/sample - loss: 0.9058 - sparse_categorical_accuracy: 0.6690 - val_loss: 0.8408 - val_sparse_categorical_accuracy: 0.7255
# Epoch 29/50
# 6191/6191 [==============================] - 1s 121us/sample - loss: 0.8954 - sparse_categorical_accuracy: 0.6682 - val_loss: 0.8313 - val_sparse_categorical_accuracy: 0.7274
# Epoch 30/50
# 6191/6191 [==============================] - 1s 118us/sample - loss: 0.8919 - sparse_categorical_accuracy: 0.6757 - val_loss: 0.8353 - val_sparse_categorical_accuracy: 0.7269
# Epoch 31/50
# 6191/6191 [==============================] - 1s 119us/sample - loss: 0.9026 - sparse_categorical_accuracy: 0.6715 - val_loss: 0.8344 - val_sparse_categorical_accuracy: 0.7274
# Epoch 32/50
# 6191/6191 [==============================] - 1s 121us/sample - loss: 0.8977 - sparse_categorical_accuracy: 0.6698 - val_loss: 0.8261 - val_sparse_categorical_accuracy: 0.7285
# Epoch 33/50
# 6191/6191 [==============================] - 1s 119us/sample - loss: 0.8941 - sparse_categorical_accuracy: 0.6760 - val_loss: 0.8319 - val_sparse_categorical_accuracy: 0.7288
# Epoch 34/50
# 6191/6191 [==============================] - 1s 123us/sample - loss: 0.9002 - sparse_categorical_accuracy: 0.6718 - val_loss: 0.8328 - val_sparse_categorical_accuracy: 0.7266
# Epoch 35/50
# 6191/6191 [==============================] - 1s 119us/sample - loss: 0.8925 - sparse_categorical_accuracy: 0.6739 - val_loss: 0.8298 - val_sparse_categorical_accuracy: 0.7279
# Epoch 36/50
# 6191/6191 [==============================] - 1s 119us/sample - loss: 0.8966 - sparse_categorical_accuracy: 0.6697 - val_loss: 0.8442 - val_sparse_categorical_accuracy: 0.7259
# Epoch 37/50
# 6191/6191 [==============================] - 1s 120us/sample - loss: 0.8984 - sparse_categorical_accuracy: 0.6719 - val_loss: 0.8471 - val_sparse_categorical_accuracy: 0.7266
# Epoch 38/50
# 6191/6191 [==============================] - 1s 123us/sample - loss: 0.9009 - sparse_categorical_accuracy: 0.6681 - val_loss: 0.8354 - val_sparse_categorical_accuracy: 0.7271
# Epoch 39/50
# 6191/6191 [==============================] - 1s 119us/sample - loss: 0.8905 - sparse_categorical_accuracy: 0.6778 - val_loss: 0.8368 - val_sparse_categorical_accuracy: 0.7272
# Epoch 40/50
# 6191/6191 [==============================] - 1s 120us/sample - loss: 0.8992 - sparse_categorical_accuracy: 0.6702 - val_loss: 0.8491 - val_sparse_categorical_accuracy: 0.7219
# Epoch 41/50
# 6191/6191 [==============================] - 1s 140us/sample - loss: 0.8968 - sparse_categorical_accuracy: 0.6697 - val_loss: 0.8395 - val_sparse_categorical_accuracy: 0.7246
# Epoch 42/50
# 6191/6191 [==============================] - 1s 119us/sample - loss: 0.8900 - sparse_categorical_accuracy: 0.6716 - val_loss: 0.8424 - val_sparse_categorical_accuracy: 0.7243
# Epoch 43/50
# 6191/6191 [==============================] - 1s 121us/sample - loss: 0.8969 - sparse_categorical_accuracy: 0.6724 - val_loss: 0.8520 - val_sparse_categorical_accuracy: 0.7204
# Epoch 44/50
# 6191/6191 [==============================] - 1s 119us/sample - loss: 0.8888 - sparse_categorical_accuracy: 0.6737 - val_loss: 0.8395 - val_sparse_categorical_accuracy: 0.7242
# Epoch 45/50
# 6191/6191 [==============================] - 1s 122us/sample - loss: 0.8858 - sparse_categorical_accuracy: 0.6760 - val_loss: 0.8428 - val_sparse_categorical_accuracy: 0.7245
# Epoch 46/50
# 6191/6191 [==============================] - 1s 121us/sample - loss: 0.8930 - sparse_categorical_accuracy: 0.6742 - val_loss: 0.8496 - val_sparse_categorical_accuracy: 0.7211
# Epoch 47/50
# 6191/6191 [==============================] - 1s 123us/sample - loss: 0.8893 - sparse_categorical_accuracy: 0.6737 - val_loss: 0.8491 - val_sparse_categorical_accuracy: 0.7235
# Epoch 48/50
# 6191/6191 [==============================] - 1s 129us/sample - loss: 0.8898 - sparse_categorical_accuracy: 0.6737 - val_loss: 0.8430 - val_sparse_categorical_accuracy: 0.7250
# Epoch 49/50
# 6191/6191 [==============================] - 1s 123us/sample - loss: 0.8874 - sparse_categorical_accuracy: 0.6791 - val_loss: 0.8432 - val_sparse_categorical_accuracy: 0.7245
# Epoch 50/50
# 6191/6191 [==============================] - 1s 120us/sample - loss: 0.8950 - sparse_categorical_accuracy: 0.6737 - val_loss: 0.8357 - val_sparse_categorical_accuracy: 0.7256
# Train on 6192 samples, validate on 6191 samples
# Epoch 1/50
# 6192/6192 [==============================] - 1s 170us/sample - loss: 0.8799 - sparse_categorical_accuracy: 0.6812 - val_loss: 0.8363 - val_sparse_categorical_accuracy: 0.7204
# Epoch 2/50
# 6192/6192 [==============================] - 1s 117us/sample - loss: 0.8893 - sparse_categorical_accuracy: 0.6751 - val_loss: 0.8422 - val_sparse_categorical_accuracy: 0.7222
# Epoch 3/50
# 6192/6192 [==============================] - 1s 122us/sample - loss: 0.8784 - sparse_categorical_accuracy: 0.6801 - val_loss: 0.8460 - val_sparse_categorical_accuracy: 0.7206
# Epoch 4/50
# 6192/6192 [==============================] - 1s 118us/sample - loss: 0.8829 - sparse_categorical_accuracy: 0.6770 - val_loss: 0.8483 - val_sparse_categorical_accuracy: 0.7193
# Epoch 5/50
# 6192/6192 [==============================] - 1s 121us/sample - loss: 0.8864 - sparse_categorical_accuracy: 0.6820 - val_loss: 0.8449 - val_sparse_categorical_accuracy: 0.7196
# Epoch 6/50
# 6192/6192 [==============================] - 1s 118us/sample - loss: 0.8767 - sparse_categorical_accuracy: 0.6878 - val_loss: 0.8404 - val_sparse_categorical_accuracy: 0.7204
# Epoch 7/50
# 6192/6192 [==============================] - 1s 117us/sample - loss: 0.8812 - sparse_categorical_accuracy: 0.6802 - val_loss: 0.8577 - val_sparse_categorical_accuracy: 0.7144
# Epoch 8/50
# 6192/6192 [==============================] - 1s 120us/sample - loss: 0.8866 - sparse_categorical_accuracy: 0.6801 - val_loss: 0.8595 - val_sparse_categorical_accuracy: 0.7146
# Epoch 9/50
# 6192/6192 [==============================] - 1s 119us/sample - loss: 0.8702 - sparse_categorical_accuracy: 0.6886 - val_loss: 0.8453 - val_sparse_categorical_accuracy: 0.7186
# Epoch 10/50
# 6192/6192 [==============================] - 1s 122us/sample - loss: 0.8679 - sparse_categorical_accuracy: 0.6867 - val_loss: 0.8532 - val_sparse_categorical_accuracy: 0.7146
# Epoch 11/50
# 6192/6192 [==============================] - 1s 121us/sample - loss: 0.8790 - sparse_categorical_accuracy: 0.6786 - val_loss: 0.8428 - val_sparse_categorical_accuracy: 0.7199
# Epoch 12/50
# 6192/6192 [==============================] - 1s 117us/sample - loss: 0.8815 - sparse_categorical_accuracy: 0.6844 - val_loss: 0.8351 - val_sparse_categorical_accuracy: 0.7210
# Epoch 13/50
# 6192/6192 [==============================] - 1s 117us/sample - loss: 0.8681 - sparse_categorical_accuracy: 0.6846 - val_loss: 0.8582 - val_sparse_categorical_accuracy: 0.7135
# Epoch 14/50
# 6192/6192 [==============================] - 1s 117us/sample - loss: 0.8731 - sparse_categorical_accuracy: 0.6878 - val_loss: 0.8372 - val_sparse_categorical_accuracy: 0.7185
# Epoch 15/50
# 6192/6192 [==============================] - 1s 118us/sample - loss: 0.8803 - sparse_categorical_accuracy: 0.6815 - val_loss: 0.8427 - val_sparse_categorical_accuracy: 0.7164
# Epoch 16/50
# 6192/6192 [==============================] - 1s 118us/sample - loss: 0.8823 - sparse_categorical_accuracy: 0.6825 - val_loss: 0.8523 - val_sparse_categorical_accuracy: 0.7173
# Epoch 17/50
# 6192/6192 [==============================] - 1s 175us/sample - loss: 0.8705 - sparse_categorical_accuracy: 0.6880 - val_loss: 0.8385 - val_sparse_categorical_accuracy: 0.7204
# Epoch 18/50
# 6192/6192 [==============================] - 1s 209us/sample - loss: 0.8827 - sparse_categorical_accuracy: 0.6778 - val_loss: 0.8546 - val_sparse_categorical_accuracy: 0.7128
# Epoch 19/50
# 6192/6192 [==============================] - 1s 118us/sample - loss: 0.8716 - sparse_categorical_accuracy: 0.6899 - val_loss: 0.8409 - val_sparse_categorical_accuracy: 0.7177
# Epoch 20/50
# 6192/6192 [==============================] - 1s 117us/sample - loss: 0.8726 - sparse_categorical_accuracy: 0.6896 - val_loss: 0.8419 - val_sparse_categorical_accuracy: 0.7178
# Epoch 21/50
# 6192/6192 [==============================] - 1s 120us/sample - loss: 0.8721 - sparse_categorical_accuracy: 0.6848 - val_loss: 0.8489 - val_sparse_categorical_accuracy: 0.7172
# Epoch 22/50
# 6192/6192 [==============================] - 1s 121us/sample - loss: 0.8671 - sparse_categorical_accuracy: 0.6881 - val_loss: 0.8618 - val_sparse_categorical_accuracy: 0.7133
# Epoch 23/50
# 6192/6192 [==============================] - 1s 119us/sample - loss: 0.8695 - sparse_categorical_accuracy: 0.6864 - val_loss: 0.8416 - val_sparse_categorical_accuracy: 0.7164
# Epoch 24/50
# 6192/6192 [==============================] - 1s 117us/sample - loss: 0.8735 - sparse_categorical_accuracy: 0.6873 - val_loss: 0.8479 - val_sparse_categorical_accuracy: 0.7181
# Epoch 25/50
# 6192/6192 [==============================] - 1s 117us/sample - loss: 0.8822 - sparse_categorical_accuracy: 0.6809 - val_loss: 0.8659 - val_sparse_categorical_accuracy: 0.7135
# Epoch 26/50
# 6192/6192 [==============================] - 1s 118us/sample - loss: 0.8686 - sparse_categorical_accuracy: 0.6914 - val_loss: 0.8616 - val_sparse_categorical_accuracy: 0.7138
# Epoch 27/50
# 6192/6192 [==============================] - 1s 124us/sample - loss: 0.8688 - sparse_categorical_accuracy: 0.6852 - val_loss: 0.8411 - val_sparse_categorical_accuracy: 0.7170
# Epoch 28/50
# 6192/6192 [==============================] - 1s 117us/sample - loss: 0.8647 - sparse_categorical_accuracy: 0.6922 - val_loss: 0.8596 - val_sparse_categorical_accuracy: 0.7123
# Epoch 29/50
# 6192/6192 [==============================] - 1s 118us/sample - loss: 0.8719 - sparse_categorical_accuracy: 0.6828 - val_loss: 0.8615 - val_sparse_categorical_accuracy: 0.7146
# Epoch 30/50
# 6192/6192 [==============================] - 1s 119us/sample - loss: 0.8625 - sparse_categorical_accuracy: 0.6922 - val_loss: 0.8494 - val_sparse_categorical_accuracy: 0.7154
# Epoch 31/50
# 6192/6192 [==============================] - 1s 118us/sample - loss: 0.8610 - sparse_categorical_accuracy: 0.6920 - val_loss: 0.8471 - val_sparse_categorical_accuracy: 0.7167
# Epoch 32/50
# 6192/6192 [==============================] - 1s 119us/sample - loss: 0.8619 - sparse_categorical_accuracy: 0.6914 - val_loss: 0.8563 - val_sparse_categorical_accuracy: 0.7130
# Epoch 33/50
# 6192/6192 [==============================] - 1s 118us/sample - loss: 0.8806 - sparse_categorical_accuracy: 0.6810 - val_loss: 0.8435 - val_sparse_categorical_accuracy: 0.7167
# Epoch 34/50
# 6192/6192 [==============================] - 1s 119us/sample - loss: 0.8652 - sparse_categorical_accuracy: 0.6907 - val_loss: 0.8464 - val_sparse_categorical_accuracy: 0.7156
# Epoch 35/50
# 6192/6192 [==============================] - 1s 121us/sample - loss: 0.8709 - sparse_categorical_accuracy: 0.6898 - val_loss: 0.8514 - val_sparse_categorical_accuracy: 0.7123
# Epoch 36/50
# 6192/6192 [==============================] - 1s 133us/sample - loss: 0.8660 - sparse_categorical_accuracy: 0.6899 - val_loss: 0.8705 - val_sparse_categorical_accuracy: 0.7120
# Epoch 37/50
# 6192/6192 [==============================] - 1s 130us/sample - loss: 0.8630 - sparse_categorical_accuracy: 0.6919 - val_loss: 0.8511 - val_sparse_categorical_accuracy: 0.7125
# Epoch 38/50
# 6192/6192 [==============================] - 1s 130us/sample - loss: 0.8701 - sparse_categorical_accuracy: 0.6873 - val_loss: 0.8614 - val_sparse_categorical_accuracy: 0.7120
# Epoch 39/50
# 6192/6192 [==============================] - 1s 130us/sample - loss: 0.8627 - sparse_categorical_accuracy: 0.6933 - val_loss: 0.8459 - val_sparse_categorical_accuracy: 0.7175
# Epoch 40/50
# 6192/6192 [==============================] - 1s 130us/sample - loss: 0.8729 - sparse_categorical_accuracy: 0.6846 - val_loss: 0.8619 - val_sparse_categorical_accuracy: 0.7128
# Epoch 41/50
# 6192/6192 [==============================] - 1s 131us/sample - loss: 0.8702 - sparse_categorical_accuracy: 0.6880 - val_loss: 0.8633 - val_sparse_categorical_accuracy: 0.7117
# Epoch 42/50
# 6192/6192 [==============================] - 1s 133us/sample - loss: 0.8689 - sparse_categorical_accuracy: 0.6886 - val_loss: 0.8734 - val_sparse_categorical_accuracy: 0.7094
691376, 0.685239, 0.69218343, 0.68281657, 0.69218343, 0.69202197, 0.691376, 0.68104005, 0.69073, 0.689761, 0.68992245, 0.69186044, 0.68733853, 0.69331396, 0.684593, 0.68798447, 0.68863046, 0.68895346, 0.6934754, 0.689115, 0.69024545, 0.69282943, 0.689761, 0.687177, 0.6963824], 'val_loss': [0.8363046855037691, 0.8421674842519457, 0.845960726059806, 0.8482914803448256, 0.8448772283791148, 0.8403823491714821, 0.8576543828316948, 0.8595224510697205, 0.8453136441915953, 0.8531800580417527, 0.8428069425214572, 0.8351029555067032, 0.8582225526559528, 0.8371828688190357, 0.8427221082154547, 0.8522714593071214, 0.8384694840233732, 0.8545948023981702, 0.8409333450019003, 0.8419360915113778, 0.8489068654622925, 0.8617974093803352, 0.8416300580432623, 0.8478557474681353, 0.865927766654126, 0.8616063537437453, 0.841106214877227, 0.8596363301482036, 0.8615414689804506, 0.8494412989324485, 0.8471493531729135, 0.8563228845211208, 0.8434779125660962, 0.8463964301210057, 0.8514195128858927, 0.8705059820414552, 0.8510918463013935, 0.8613987389914035, 0.8459368058811423, 0.8618774969769186, 0.8632617971947574, 0.8733960656487408, 0.8609806856360426, 0.8596921848511392, 0.8659478586087067, 0.8654973133279249, 0.8649137494753143, 0.8688642500271379, 0.8747278417452647, 0.8555904459806968], 'val_sparse_categorical_accuracy': [0.7204006, 0.7221773, 0.7205621, 0.71926993, 0.7195929, 0.7204006, 0.7144242, 0.71458566, 0.7186238, 0.71458566, 0.719916, 0.7210467, 0.713455, 0.7184623, 0.7163625, 0.7173316, 0.7204006, 0.7128089, 0.71765465, 0.7178162, 0.71717006, 0.7132935, 0.7163625, 0.71813923, 0.713455, 0.7137781, 0.71700853, 0.7123243, 0.71458566, 0.7153933, 0.71668553, 0.71297044, 0.71668553, 0.71555483, 0.7123243, 0.71200126, 0.71248585, 0.71200126, 0.7174931, 0.7128089, 0.71167827, 0.70941687, 0.71248585, 0.7126474, 0.7123243, 0.7118398, 0.7123243, 0.7118398, 0.7095784, 0.71361655]}

# %%
results = meta_clf.evaluate(x_test, y_test, batch_size=32)
pred=meta_clf.predict(x_test)
f_pred=[]
for i in pred:
    indices = np.where(i == i.max())
    f_pred.append(int(indices[0]))
# Out:
# 6191/6191 [==============================] - 0s 34us/sample - loss: 0.8556 - sparse_categorical_accuracy: 0.7136

# %%
from sklearn.metrics import cohen_kappa_score
kappa = cohen_kappa_score(f_pred,y_test,weights='quadratic')
print('test loss, test acc:', results)
print('Kappa Score:', kappa)
# Out:
# test loss, test acc: [0.8555904385963061, 0.71361655]
# Kappa Score: 0.5979548084378716

# %%
#predict for the test data
pred1=meta_clf.predict(meta_test_data)
final_pred=[]
for i in pred1:
    indices = np.where(i == i.max())
    final_pred.append(int(indices[0]))

# %%
sample_submission['accuracy_group'] = final_pred
sample_submission.to_csv('submission.csv', index=False)

# %%
sample_submission.groupby(['accuracy_group']).count()
# Out:
#                 installation_id
# accuracy_group
# 0                           380
# 1                            26
# 2                            13
# 3                           581
