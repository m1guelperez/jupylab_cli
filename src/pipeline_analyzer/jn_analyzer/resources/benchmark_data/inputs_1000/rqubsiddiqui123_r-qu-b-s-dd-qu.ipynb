# %%
import pandas as pd
import numpy as np

# %%
data_set=pd.read_csv('../input/ecommerce-behavior-data-from-multi-category-store/2019-Nov.csv',nrows=100000)

# %%
from sklearn.model_selection import train_test_split

# %%
x=data_set.iloc[:,0:8]
y=data_set.iloc[:,8]


x_train,x_test,y_train,y_test=train_test_split(x,y,test_size =0.90,random_state=0)

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90000 entries, 3582 to 71863
# Data columns (total 8 columns):
# event_time       90000 non-null object
# event_type       90000 non-null object
# product_id       90000 non-null int64
# category_id      90000 non-null int64
# category_code    59541 non-null object
# brand            75830 non-null object
# price            90000 non-null float64
# user_id          90000 non-null int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 6.2+ MB

# %%
df1=pd.DataFrame(x_train)

# %%
df2=pd.DataFrame(y_train)

# %%
df= df1.join(df2)

# %%
df.head(10)
# Out:
#                     event_time event_type  product_id          category_id  \
# 32779  2019-11-01 02:17:16 UTC   purchase    12703014  2053013553559896355
# 50591  2019-11-01 02:49:28 UTC       view     1005115  2053013555631882655
# 87578  2019-11-01 03:38:40 UTC       view     5100799  2053013553341792533
# 79365  2019-11-01 03:29:00 UTC       view    41600044  2090971680783466556
# 42092  2019-11-01 02:35:00 UTC       view    17800342  2053013559868129947
# 55314  2019-11-01 02:56:58 UTC       view     1005144  2053013555631882655
# 97401  2019-11-01 03:49:57 UTC       view     8800865  2053013555573162395
# 50658  2019-11-01 02:49:35 UTC       view     1004876  2053013555631882655
# 52143  2019-11-01 02:51:56 UTC       view    26403631  2053013563651392361
# 26484  2019-11-01 02:03:41 UTC       view     4700478  2053013560899928785
#
#                         category_code       brand    price    user_id  \
# 32779                             NaN    cordiant    39.38  561405398
# 50591          electronics.smartphone       apple   949.47  561488510
# 87578              electronics.clocks      garmin  1878.15  513166462
# 79365                             NaN  noktamakro   161.65  521759060
# 42092               computers.desktop        zeta    65.36  512455606
# 55314          electronics.smartphone       apple  1661.09  512847357
# 97401           electronics.telephone       texet     6.67  546265086
# 50658          electronics.smartphone      xiaomi    82.11  513286641
# 52143                             NaN         NaN   579.53  566300880
# 26484  auto.accessories.videoregister      sho-me   141.86  536279197
#
#                                user_session
# 32779  9796b53d-f858-4174-abfa-e0dd201667d3
# 50591  9ce1e158-d044-4e67-8f5d-cce97d3412a7
# 87578  8e9098a5-807f-4d86-9d08-f7eedb1a6b80
# 79365  8a745dbc-ed71-42d9-a52b-16449679666c
# 42092  5595a360-3bbf-4b31-b7c5-ee05e906017b
# 55314  3064a95e-5d77-4dec-ad3c-c6f78c1e397c
# 97401  d811d6d2-c677-41b2-9175-5ac74afd782a
# 50658  c4801256-5669-45b0-b985-3b844c52e094
# 52143  698d4143-e499-4423-aba6-45a061c71c2e
# 26484  e4f28036-6ce2-49d8-9153-05d7bc6e7b6d

# %%
df['event_type'].value_counts()
# Out:
# view        9731
# purchase     145
# cart         124
# Name: event_type, dtype: int64

# %%
df.loc[df['category_id']==2090971680783466556].sort_values(by=['event_time'])
# Out:
#                     event_time event_type  product_id          category_id  \
# 3202   2019-11-01 00:21:13 UTC       view    41600018  2090971680783466556
# 40651  2019-11-01 02:32:20 UTC       view    41600035  2090971680783466556
# 41333  2019-11-01 02:33:38 UTC       view    41600018  2090971680783466556
# 47895  2019-11-01 02:44:59 UTC       view    41600033  2090971680783466556
# 60533  2019-11-01 03:04:38 UTC       view    41600044  2090971680783466556
# 76948  2019-11-01 03:26:06 UTC       view    41600015  2090971680783466556
# 79365  2019-11-01 03:29:00 UTC       view    41600044  2090971680783466556
# 88852  2019-11-01 03:40:05 UTC       view    41600014  2090971680783466556
#
#       category_code       brand    price    user_id  \
# 3202            NaN     garrett   266.98  553270458
# 40651           NaN  noktamakro   463.33  553448873
# 41333           NaN     garrett   266.98  553448873
# 47895           NaN     minelab  1158.33  561713177
# 60533           NaN  noktamakro   161.65  549862429
# 76948           NaN     garrett   350.86  547076349
# 79365           NaN  noktamakro   161.65  521759060
# 88852           NaN     garrett   178.17  539455998
#
#                                user_session
# 3202   27399ae1-fc02-1b48-47af-02c7569d76af
# 40651  4d0e879c-db28-4fa9-88ea-e6cf359a209e
# 41333  4d0e879c-db28-4fa9-88ea-e6cf359a209e
# 47895  bd1524cf-75b0-4fdd-8a8f-3272e5bdc464
# 60533  cfdaccd2-f7e5-40be-a525-ba12042963a8
# 76948  9c6f0e55-f8a8-4d57-9761-051fa3fa7bd0
# 79365  8a745dbc-ed71-42d9-a52b-16449679666c
# 88852  1ed7b0af-a098-420e-926b-200ee0895e8c

# %%
df= df.reset_index()

# %%
df.drop(['index'],axis=1)
# Out:
#                    event_time event_type  product_id          category_id  \
# 0     2019-11-01 02:17:16 UTC   purchase    12703014  2053013553559896355
# 1     2019-11-01 02:49:28 UTC       view     1005115  2053013555631882655
# 2     2019-11-01 03:38:40 UTC       view     5100799  2053013553341792533
# 3     2019-11-01 03:29:00 UTC       view    41600044  2090971680783466556
# 4     2019-11-01 02:35:00 UTC       view    17800342  2053013559868129947
# ...                       ...        ...         ...                  ...
# 9995  2019-11-01 01:51:02 UTC       view    30901098  2053013554004492609
# 9996  2019-11-01 02:41:33 UTC       view     1005266  2053013555631882655
# 9997  2019-11-01 02:35:54 UTC       view    26403500  2053013563651392361
# 9998  2019-11-01 02:37:37 UTC       view    12703493  2053013553559896355
# 9999  2019-11-01 03:15:01 UTC       view    15700262  2053013559733912211
#
#                     category_code       brand    price    user_id  \
# 0                             NaN    cordiant    39.38  561405398
# 1          electronics.smartphone       apple   949.47  561488510
# 2              electronics.clocks      garmin  1878.15  513166462
# 3                             NaN  noktamakro   161.65  521759060
# 4               computers.desktop        zeta    65.36  512455606
# ...                           ...         ...      ...        ...
# 9995  computers.components.cooler    aerocool     3.32  512976134
# 9996       electronics.smartphone      xiaomi   137.18  529223398
# 9997                          NaN         NaN   211.07  548648298
# 9998                          NaN    cordiant    41.19  550333039
# 9999                          NaN      olmeko   275.66  543079251
#
#                               user_session
# 0     9796b53d-f858-4174-abfa-e0dd201667d3
# 1     9ce1e158-d044-4e67-8f5d-cce97d3412a7
# 2     8e9098a5-807f-4d86-9d08-f7eedb1a6b80
# 3     8a745dbc-ed71-42d9-a52b-16449679666c
# 4     5595a360-3bbf-4b31-b7c5-ee05e906017b
# ...                                    ...
# 9995  5848d8fc-d2ca-4378-9236-b1b68b90698d
# 9996  d9094fff-7681-41c1-b7de-eb7bea628fcf
# 9997  3d3177bb-d548-4130-99aa-8522d1708d65
# 9998  13e4198a-c23c-404c-b33e-af0746b5b03f
# 9999  27eb756f-5ada-4740-9441-f790dcaf85d9
#
# [10000 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
# index            10000 non-null int64
# event_time       10000 non-null object
# event_type       10000 non-null object
# product_id       10000 non-null int64
# category_id      10000 non-null int64
# category_code    6619 non-null object
# brand            8394 non-null object
# price            10000 non-null float64
# user_id          10000 non-null int64
# user_session     10000 non-null object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 781.4+ KB

# %%
df.event_time = pd.to_datetime(df.event_time, utc=True)

df['day']=df['event_time'].dt.day
df['hour']=df['event_time'].dt.hour
df['minute']=df['event_time'].dt.minute
df['seconds']=df['event_time'].dt.second

# %%
df.drop(['index'],axis=1,inplace=True)

# %%
df.drop(['event_time'],axis=1,inplace=True)

# %%
df['event_type'].value_counts()
# Out:
# view        9731
# purchase     145
# cart         124
# Name: event_type, dtype: int64

# %%
import matplotlib.pyplot as plt
labels = ['view', 'purchase','cart']
size = df['event_type'].value_counts()
colors = ['lightgreen', 'orange','blue']
explode = [0, 0.1,0.1]

plt.rcParams['figure.figsize'] = (8, 8)
plt.pie(size, colors = colors, explode = explode, labels = labels, shadow = True, autopct = '%.2f%%')
plt.title('Event_Type', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %%
df.drop(['category_code'],axis=1,inplace=True)

# %%
df.drop(['day'],axis=1,inplace=True)

# %%
df.loc[df.category_id==2053013553559896355].sort_values(by='hour')
# Out:
#      event_type  product_id          category_id       brand   price  \
# 8732       view    12710321  2053013553559896355    yokohama   70.53
# 9036       view    12704476  2053013553559896355      nokian   42.73
# 3441       view    12718921  2053013553559896355       nitto   74.26
# 8921       view    12716859  2053013553559896355  bfgoodrich  348.14
# 3292       view    12705003  2053013553559896355    cordiant   40.93
# ...         ...         ...                  ...         ...     ...
# 6305       view    12719016  2053013553559896355    triangle   39.38
# 6266       view    12714586  2053013553559896355      viatti   65.64
# 2951       view    12709266  2053013553559896355       nexen   63.59
# 6421       view    12702958  2053013553559896355    cordiant   42.47
# 5465       view    12709938  2053013553559896355    yokohama   65.64
#
#         user_id                          user_session  hour  minute  seconds
# 8732  530447253  1d5afdd2-e6c3-4532-b9be-f1ebd13def75     0      11        5
# 9036  520538288  c6ecf52b-b3b4-4eaa-93df-921bc3c15557     0      41       40
# 3441  513696396  7efeda5f-9a23-40d3-bfbc-e88e8d792612     0      18        1
# 8921  512840594  a6b3c24f-03b1-4a57-bc4b-56b1d980098c     0      17        0
# 3292  559817681  b8711ab7-5ff4-41b3-833a-628afb88611e     0      50        8
# ...         ...                                   ...   ...     ...      ...
# 6305  530515355  e754c5f6-8eee-45a1-b16d-ed894f1b9480     3      17       38
# 6266  555477249  ef875850-5de8-4274-996a-37604278d9c0     3      50       16
# 2951  520069004  05f3aa75-6b20-40c5-aa22-2cf560d961a6     3      22        2
# 6421  558588393  6e43f3df-21ca-49bf-b2db-b15cc9d95bd1     3      50        1
# 5465  512853858  1e75d424-4ee6-4590-863e-9ac85390e10c     3       6       23
#
# [597 rows x 10 columns]

# %%
df
# Out:
#      event_type  product_id          category_id       brand    price  \
# 0      purchase    12703014  2053013553559896355    cordiant    39.38
# 1          view     1005115  2053013555631882655       apple   949.47
# 2          view     5100799  2053013553341792533      garmin  1878.15
# 3          view    41600044  2090971680783466556  noktamakro   161.65
# 4          view    17800342  2053013559868129947        zeta    65.36
# ...         ...         ...                  ...         ...      ...
# 9995       view    30901098  2053013554004492609    aerocool     3.32
# 9996       view     1005266  2053013555631882655      xiaomi   137.18
# 9997       view    26403500  2053013563651392361         NaN   211.07
# 9998       view    12703493  2053013553559896355    cordiant    41.19
# 9999       view    15700262  2053013559733912211      olmeko   275.66
#
#         user_id                          user_session  hour  minute  seconds
# 0     561405398  9796b53d-f858-4174-abfa-e0dd201667d3     2      17       16
# 1     561488510  9ce1e158-d044-4e67-8f5d-cce97d3412a7     2      49       28
# 2     513166462  8e9098a5-807f-4d86-9d08-f7eedb1a6b80     3      38       40
# 3     521759060  8a745dbc-ed71-42d9-a52b-16449679666c     3      29        0
# 4     512455606  5595a360-3bbf-4b31-b7c5-ee05e906017b     2      35        0
# ...         ...                                   ...   ...     ...      ...
# 9995  512976134  5848d8fc-d2ca-4378-9236-b1b68b90698d     1      51        2
# 9996  529223398  d9094fff-7681-41c1-b7de-eb7bea628fcf     2      41       33
# 9997  548648298  3d3177bb-d548-4130-99aa-8522d1708d65     2      35       54
# 9998  550333039  13e4198a-c23c-404c-b33e-af0746b5b03f     2      37       37
# 9999  543079251  27eb756f-5ada-4740-9441-f790dcaf85d9     3      15        1
#
# [10000 rows x 10 columns]

# %%
df['event_type'] = df['event_type'].astype('category').cat.codes
#purchase=1 View=2 Cart=0

# %%
df['event_type'] = df['event_type'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
# event_type      10000 non-null int64
# product_id      10000 non-null int64
# category_id     10000 non-null int64
# brand           8394 non-null object
# price           10000 non-null float64
# user_id         10000 non-null int64
# user_session    10000 non-null object
# hour            10000 non-null int64
# minute          10000 non-null int64
# seconds         10000 non-null int64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 781.4+ KB

# %%
df['brand'].value_counts().head(50).plot.bar(figsize = (18, 7))
plt.title('Top Brand', fontsize = 20)
plt.xlabel('Names of Brand')
plt.ylabel('Count')
plt.show()

# %%
df['event_type'].groupby(df['brand']).agg('sum').sort_values(ascending = False).head(20).plot.bar(figsize = (15, 7), color = 'lightblue')
plt.title('Top 20 Countries Sales wise', fontsize = 20)
plt.xlabel('Names of Countries')
plt.ylabel('Sales')
plt.show()

# %%
df.head(5)
# Out:
#    event_type  product_id          category_id       brand    price  \
# 0           1    12703014  2053013553559896355    cordiant    39.38
# 1           2     1005115  2053013555631882655       apple   949.47
# 2           2     5100799  2053013553341792533      garmin  1878.15
# 3           2    41600044  2090971680783466556  noktamakro   161.65
# 4           2    17800342  2053013559868129947        zeta    65.36
#
#      user_id                          user_session  hour  minute  seconds
# 0  561405398  9796b53d-f858-4174-abfa-e0dd201667d3     2      17       16
# 1  561488510  9ce1e158-d044-4e67-8f5d-cce97d3412a7     2      49       28
# 2  513166462  8e9098a5-807f-4d86-9d08-f7eedb1a6b80     3      38       40
# 3  521759060  8a745dbc-ed71-42d9-a52b-16449679666c     3      29        0
# 4  512455606  5595a360-3bbf-4b31-b7c5-ee05e906017b     2      35        0

# %%
df['user_session'] = df['user_session'].astype('category').cat.codes.astype(
    'category')
df['user_id'] = df['user_id'].astype('category').cat.codes.astype('category')
df['category_id'] = df['category_id'].astype('category').cat.codes.astype('category')
df['product_id'] = df['product_id'].astype('category').cat.codes.astype('category')

# %%
df
# Out:
#       event_type product_id category_id       brand    price user_id  \
# 0              1       2586          36    cordiant    39.38    5368
# 1              2        339          80       apple   949.47    5382
# 2              2       1736          31      garmin  1878.15     524
# 3              2       5084         322  noktamakro   161.65    2512
# 4              2       3680         152        zeta    65.36      93
# ...          ...        ...         ...         ...      ...     ...
# 9995           2       4879          42    aerocool     3.32     432
# 9996           2        429          80      xiaomi   137.18    3016
# 9997           2       4381         224         NaN   211.07    4338
# 9998           2       2599          36    cordiant    41.19    4475
# 9999           2       3350         148      olmeko   275.66    3892
#
#      user_session  hour  minute  seconds
# 0            4112     2      17       16
# 1            4258     2      49       28
# 2            3852     3      38       40
# 3            3734     3      29        0
# 4            2275     2      35        0
# ...           ...   ...     ...      ...
# 9995         2354     1      51        2
# 9996         5928     2      41       33
# 9997         1601     2      35       54
# 9998          524     2      37       37
# 9999         1022     3      15        1
#
# [10000 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
# event_type      10000 non-null int64
# product_id      10000 non-null category
# category_id     10000 non-null category
# brand           8394 non-null object
# price           10000 non-null float64
# user_id         10000 non-null category
# user_session    10000 non-null category
# hour            10000 non-null int64
# minute          10000 non-null int64
# seconds         10000 non-null int64
# dtypes: category(4), float64(1), int64(4), object(1)
# memory usage: 1.5+ MB
