# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 


import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation
plt.style.use('seaborn-pastel')
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/imdbdata/data.tsv
# /kaggle/input/imdb-dataset/title.ratings.tsv.gz
# /kaggle/input/imdb-dataset/name.basics.tsv.gz
# /kaggle/input/imdb-dataset/title.basics.tsv.gz
# /kaggle/input/imdb-dataset/title.akas.tsv.gz
# /kaggle/input/imdb-dataset/title.principals.tsv.gz
# /kaggle/input/imdb-dataset/name.basics.tsv/name.basics.tsv
# /kaggle/input/imdb-dataset/title.basics.tsv/title.basics.tsv
# /kaggle/input/imdb-dataset/title.principals.tsv/title.principals.tsv
# /kaggle/input/imdb-dataset/title.ratings.tsv/title.ratings.tsv
# /kaggle/input/imdb-dataset/title.akas.tsv/title.akas.tsv

# %%
akas = pd.read_csv("../input/imdb-dataset/title.akas.tsv/title.akas.tsv", sep = "\t")
akas.head()
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      titleId  ordering                      title region language  \
# 0  tt0000001         1  Carmencita - spanyol tánc     HU       \N
# 1  tt0000001         2                 Καρμενσίτα     GR       \N
# 2  tt0000001         3                 Карменсита     RU       \N
# 3  tt0000001         4                 Carmencita     US       \N
# 4  tt0000001         5                 Carmencita     \N       \N
#
#          types attributes isOriginalTitle
# 0  imdbDisplay         \N               0
# 1           \N         \N               0
# 2           \N         \N               0
# 3           \N         \N               0
# 4     original         \N               1

# %%
akas.query("title == 'My Hero Academia'")
# Out:
#             titleId  ordering             title region language        types  \
# 13047178  tt5626028        10  My Hero Academia     CA       en  imdbDisplay
# 13047179  tt5626028        11  My Hero Academia     PT       \N  imdbDisplay
# 13047181  tt5626028        13  My Hero Academia     ES       \N  imdbDisplay
# 13047182  tt5626028        14  My Hero Academia     IT       \N  imdbDisplay
# 13047183  tt5626028        15  My Hero Academia     MX       \N  imdbDisplay
# 13047186  tt5626028         3  My Hero Academia     AU       \N  imdbDisplay
# 13047190  tt5626028         7  My Hero Academia     US       \N  imdbDisplay
# 13047192  tt5626028         9  My Hero Academia    XWW       en  imdbDisplay
#
#          attributes isOriginalTitle
# 13047178         \N               0
# 13047179         \N               0
# 13047181         \N               0
# 13047182         \N               0
# 13047183         \N               0
# 13047186         \N               0
# 13047190         \N               0
# 13047192         \N               0

# %% [markdown]
# tt5626028

# %%
del akas

# %%
ratings = pd.read_csv("../input/imdb-dataset/title.ratings.tsv/title.ratings.tsv", sep = "\t")

# %%
episodes = pd.read_csv("../input/imdbdata/data.tsv", sep = "\t")

# %%
data_filter = episodes.query("parentTconst == 'tt5626028'")

# %%
episodes.head()
# Out:
#       tconst parentTconst seasonNumber episodeNumber
# 0  tt0041951    tt0041038            1             9
# 1  tt0042816    tt0989125            1            17
# 2  tt0042889    tt0989125           \N            \N
# 3  tt0043426    tt0040051            3            42
# 4  tt0043631    tt0989125            2            16

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.6      1550
# 1  tt0000002            6.1       186
# 2  tt0000003            6.5      1207
# 3  tt0000004            6.2       113
# 4  tt0000005            6.1      1934

# %%
q = """select * from data_filter a
inner join
ratings b
on a.tconst = b.tconst order by seasonNumber, episodeNumber"""
data_filter_1 = pysqldf(q)

# %%
data_filter_1 = data_filter_1.drop(69, axis = 0)

# %%
data_filter_1['episode_number'] = data_filter_1.reset_index()['index']+1

data_filter_1['episode_number_1'] = 's0'+data_filter_1['seasonNumber']+'e0'+data_filter_1['episodeNumber']

# %%
Writer = animation.writers['imagemagick']
writer = Writer(fps=20, metadata=dict(artist='u/bloodlessAcranist'), bitrate=1800)

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(10,6))
ax = plt.axes(xlim=(0, 70), ylim=(0, 10))
line, = ax.plot([], [], lw=3, color = 'r')

# fig = plt.figure(figsize=(10,6))
# plt.xlim(0,70)
# plt.ylim(np.min(data_filter_2)[0], np.max(data_filter_2)[0])
plt.xlabel('episode', fontsize = 20)
plt.ylabel('Average Ratings', fontsize = 20)
plt.title('My Hero Academia Ratings', fontsize = 20)
# x = data_filter_1.episode_number
# y = data_filter_1.averageRating
# line.set_data(x,y)
def animate(i):
    data = data_filter_1.iloc[:int(i+1),:]
    x = data.episode_number
    y = data.averageRating
    line.set_data(x, y)
    return line,
ani = FuncAnimation(fig, animate, frames=69, repeat = True)
ani.save('MyHeroAcademiaRatings.gif', writer=writer)
# Out:
# <div id='22197356-17db-4c70-9447-3bd0fe9e73b7'></div>
