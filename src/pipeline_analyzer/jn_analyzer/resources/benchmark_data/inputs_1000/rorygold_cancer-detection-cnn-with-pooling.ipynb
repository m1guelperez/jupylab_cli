# %%
# Cancer Detection project, WIP - Rory Gold
# Aim is to gain familiarity with the use of CNNs with tensorflow for image classification

# CNN structure is based off advice from online Data Science posts and Kaggle Deep Learning microcourse

# %%
# Import libraries
import os

import numpy as np
import pandas as pd
import random
import math 
import time
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, AveragePooling2D
from sklearn.model_selection import train_test_split
from tensorflow.python import keras

from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping

from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.python.keras.constraints import maxnorm
from tensorflow.keras.optimizers import Adam

from os.path import join
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.resnet50 import preprocess_input
# print('Stage complete')
# Out:
# Using TensorFlow backend.

# %%
# Define Functions
def get_filepaths(dirname):
    img_paths = []
    for _,_,filenames in os.walk(dirname):
        for filename in filenames:
            img_paths.append(os.path.join(dirname, filename))
    return img_paths, filenames

def get_file_ids(filenames):
    file_ids = []
    splt_fstop = '.'
    for filename in filenames:
        file_ids.append(filename.partition(splt_fstop)[0])
    return file_ids

def pandas_to_array(data):
    data_array = data.to_numpy()
    return data_array

def OHE_encode_target(target):
    OHE_target = pd.get_dummies(target)
    OHE_target.columns = ['No_Cancer', 'Cancer']
    return OHE_target

def balance_sample_classes(train_labels, img_paths, img_range):
    train_labels = train_labels.iloc[img_range]
    number_samples = len(train_labels)
    number_cancer = sum(train_labels.label)
    class_balance = number_cancer/number_samples
    half_samples = number_samples/2

    noncancer_index = train_labels.index[train_labels.label==0]
    cancer_index = train_labels.index[train_labels.label==1]

    balance_difference = abs(number_cancer-half_samples)
    # If less cancer labels, need to reduce non cancer labels, drop difference number of non cancer
    if number_cancer < half_samples:
        noncancer_index = noncancer_index#[0:(len(noncancer_index)-int(2*balance_difference))]
    if number_cancer > half_samples:
        cancer_index = cancer_index#[0:(len(cancer_index)-int(2*balance_difference))]
    
    # Above code commented out as experimenting with 0 class balancing in the hope that randomized dataset will give representation
    # of spread of data
        
    balanced_index = np.concatenate([noncancer_index, cancer_index])
    balanced_index_sorted = np.sort(balanced_index)

    train_labels_balanced = train_labels.loc[balanced_index_sorted]
    train_labels = train_labels_balanced.reset_index(drop=True)

    img_paths_balanced = []
    for index in balanced_index_sorted:
        img_paths_balanced.append(img_paths[index])
    img_paths = img_paths_balanced
    return train_labels, img_paths

image_size=96
def read_and_prep_images_ver3(img_paths, img_height=image_size, img_width=image_size):
    img_arrays = []
    for img_path in img_paths:
        img = load_img(img_path, target_size=(img_height, img_width))
        img_arrays.append(img_to_array(img))
        img.close
    img_array = np.array(img_arrays)
    
    # Scale images between 0 and 1
    output = img_array/255
    return output

def make_range_listing(list_range):
    index_list = []
    for index in list_range:
        index_list.append(index)
    return index_list

def shuffle_listing(listing):
    shuffled_listing = []
    for index in index_list:
        shuffled_listing.append(listing[index])
    return shuffled_listing

# Create function to generate train batch data for a specific image range
def generate_train_data(img_range, img_paths_train, train_file_ids): 
    # Insert labels for each file
    train_file = '/kaggle/input/histopathologic-cancer-detection/train_labels.csv'
    train_labels = pd.read_csv(train_file)

    # Sort train_labels by train image listing order
    train_labels['id_cat'] = pd.Categorical(train_labels.id, categories = train_file_ids, ordered= True)
    train_labels = train_labels.sort_values('id_cat')
    train_labels = train_labels.reset_index(drop=True)
    del train_labels['id_cat']

    train_labels, img_paths_train = balance_sample_classes(train_labels, img_paths_train, img_range)
    train_data = read_and_prep_images_ver3(img_paths_train)

    train_Y = OHE_encode_target(train_labels.label)
    train_Y = pandas_to_array(train_Y)
    return train_data, train_Y

#print('Stage complete')

# %%
# Set random seed
np.random.seed(1)

# %%
# Choose images to work with
dirname_train = '/kaggle/input/histopathologic-cancer-detection/train/'
dirname_test = '/kaggle/input/histopathologic-cancer-detection/test/'

img_paths_train, filenames_train = get_filepaths(dirname_train)
train_file_ids = get_file_ids(filenames_train)
#print('Stage complete')

# %%
# Insert code to randomize listing - simply randomized listing entries
list_range = range(0,len(img_paths_train))
index_list = make_range_listing(list_range)
random.shuffle(index_list)

# Shuffle path listings
img_paths_train = shuffle_listing(img_paths_train)
filenames_train = shuffle_listing(filenames_train)
train_file_ids = shuffle_listing(train_file_ids)

# %%
def Create_Model(image_size, num_classes):
    img_width = image_size
    img_height = image_size
    model = Sequential()
    model.add(Conv2D(200, kernel_size=(3,3), strides=2, activation='relu', input_shape=(img_height, img_width, 3)))
    model.add(AveragePooling2D())
    model.add(Dropout(0.3))
    model.add(Conv2D(200, kernel_size=(3,3), strides=2, activation='relu'))
    model.add(AveragePooling2D())
    model.add(Dropout(0.3))
    model.add(Conv2D(200, kernel_size=(3,3), strides=2, activation='relu'))
    model.add(AveragePooling2D())
    model.add(Dropout(0.3))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    return model

def train_model(model, train_data, train_Y, callbacks_list):
    model.fit(train_data, train_Y, batch_size=128, epochs=150, validation_split=0.1, callbacks = callbacks_list)
    return model

# %%
# Create model
image_size = 96
num_classes = 2

# Define early stopping parameters
filepath="weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
es = EarlyStopping(monitor = 'val_accuracy', mode = 'max', verbose = 1, patience=10)
callbacks_list = [checkpoint, es]
model = Create_Model(image_size, num_classes)

# Compile model
model.compile(loss=keras.losses.categorical_crossentropy,optimizer='adam',metrics=['accuracy'])

# %%
# Fit model with early stopping
# Define img_range
img_range = range(0,35000)

# Generate training data
train_data, train_Y = generate_train_data(img_range, img_paths_train, train_file_ids)
#print('Stage Complete')
model = train_model(model, train_data, train_Y, callbacks_list)
# Out:
# Train on 31500 samples, validate on 3500 samples
# Epoch 1/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.5480 - accuracy: 0.7219
# Epoch 00001: val_accuracy improved from -inf to 0.77286, saving model to weights.best.hdf5
# 31500/31500 [==============================] - 12s 374us/sample - loss: 0.5481 - accuracy: 0.7219 - val_loss: 0.4712 - val_accuracy: 0.7729
# Epoch 2/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.4793 - accuracy: 0.7783
# Epoch 00002: val_accuracy improved from 0.77286 to 0.77629, saving model to weights.best.hdf5
# 31500/31500 [==============================] - 8s 243us/sample - loss: 0.4792 - accuracy: 0.7784 - val_loss: 0.4715 - val_accuracy: 0.7763
# Epoch 3/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.4621 - accuracy: 0.7882
# Epoch 00003: val_accuracy improved from 0.77629 to 0.78743, saving model to weights.best.hdf5
# 31500/31500 [==============================] - 8s 243us/sample - loss: 0.4618 - accuracy: 0.7883 - val_loss: 0.4606 - val_accuracy: 0.7874
# Epoch 4/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.4478 - accuracy: 0.7961
# Epoch 00004: val_accuracy did not improve from 0.78743
# 31500/31500 [==============================] - 8s 240us/sample - loss: 0.4475 - accuracy: 0.7963 - val_loss: 0.5883 - val_accuracy: 0.6869
# Epoch 5/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.4437 - accuracy: 0.7987
# Epoch 00005: val_accuracy improved from 0.78743 to 0.79886, saving model to weights.best.hdf5
# 31500/31500 [==============================] - 8s 244us/sample - loss: 0.4434 - accuracy: 0.7989 - val_loss: 0.4337 - val_accuracy: 0.7989
# Epoch 6/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.4341 - accuracy: 0.8053
# Epoch 00006: val_accuracy improved from 0.79886 to 0.80286, saving model to weights.best.hdf5
# 31500/31500 [==============================] - 8s 248us/sample - loss: 0.4340 - accuracy: 0.8052 - val_loss: 0.4341 - val_accuracy: 0.8029
# Epoch 7/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.4254 - accuracy: 0.8109
# Epoch 00007: val_accuracy improved from 0.80286 to 0.81371, saving model to weights.best.hdf5
# 31500/31500 [==============================] - 8s 246us/sample - loss: 0.4256 - accuracy: 0.8108 - val_loss: 0.4233 - val_accuracy: 0.8137
# Epoch 8/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.4113 - accuracy: 0.8183
# Epoch 00008: val_accuracy improved from 0.81371 to 0.82343, saving model to weights.best.hdf5
# 31500/31500 [==============================] - 8s 241us/sample - loss: 0.4113 - accuracy: 0.8183 - val_loss: 0.4069 - val_accuracy: 0.8234
# Epoch 9/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.4118 - accuracy: 0.8151
# Epoch 00009: val_accuracy did not improve from 0.82343
# 31500/31500 [==============================] - 7s 237us/sample - loss: 0.4122 - accuracy: 0.8150 - val_loss: 0.4387 - val_accuracy: 0.8006
# Epoch 10/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.4065 - accuracy: 0.8204
# Epoch 00010: val_accuracy did not improve from 0.82343
# 31500/31500 [==============================] - 8s 240us/sample - loss: 0.4071 - accuracy: 0.8203 - val_loss: 0.4164 - val_accuracy: 0.8134
# Epoch 11/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.4029 - accuracy: 0.8218
# Epoch 00011: val_accuracy did not improve from 0.82343
# 31500/31500 [==============================] - 7s 237us/sample - loss: 0.4031 - accuracy: 0.8217 - val_loss: 0.4081 - val_accuracy: 0.8151
# Epoch 12/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.4001 - accuracy: 0.8226
# Epoch 00012: val_accuracy did not improve from 0.82343
# 31500/31500 [==============================] - 7s 236us/sample - loss: 0.3999 - accuracy: 0.8227 - val_loss: 0.4267 - val_accuracy: 0.8109
# Epoch 13/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3927 - accuracy: 0.8257
# Epoch 00013: val_accuracy did not improve from 0.82343
# 31500/31500 [==============================] - 8s 239us/sample - loss: 0.3927 - accuracy: 0.8257 - val_loss: 0.4205 - val_accuracy: 0.8031
# Epoch 14/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3962 - accuracy: 0.8244
# Epoch 00014: val_accuracy improved from 0.82343 to 0.83029, saving model to weights.best.hdf5
# 31500/31500 [==============================] - 8s 249us/sample - loss: 0.3961 - accuracy: 0.8245 - val_loss: 0.4125 - val_accuracy: 0.8303
# Epoch 15/150
# 31488/31500 [============================>.] - ETA: 0s - loss: 0.3885 - accuracy: 0.8284
# Epoch 00015: val_accuracy improved from 0.83029 to 0.83371, saving model to weights.best.hdf5
# 31500/31500 [==============================] - 8s 246us/sample - loss: 0.3884 - accuracy: 0.8285 - val_loss: 0.3957 - val_accuracy: 0.8337
# Epoch 16/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3794 - accuracy: 0.8325
# Epoch 00016: val_accuracy did not improve from 0.83371
# 31500/31500 [==============================] - 7s 237us/sample - loss: 0.3793 - accuracy: 0.8325 - val_loss: 0.3766 - val_accuracy: 0.8317
# Epoch 17/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3829 - accuracy: 0.8328
# Epoch 00017: val_accuracy did not improve from 0.83371
# 31500/31500 [==============================] - 7s 236us/sample - loss: 0.3833 - accuracy: 0.8328 - val_loss: 0.3927 - val_accuracy: 0.8237
# Epoch 18/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3776 - accuracy: 0.8339
# Epoch 00018: val_accuracy did not improve from 0.83371
# 31500/31500 [==============================] - 8s 238us/sample - loss: 0.3775 - accuracy: 0.8340 - val_loss: 0.3988 - val_accuracy: 0.8234
# Epoch 19/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3740 - accuracy: 0.8365
# Epoch 00019: val_accuracy did not improve from 0.83371
# 31500/31500 [==============================] - 8s 241us/sample - loss: 0.3738 - accuracy: 0.8364 - val_loss: 0.4316 - val_accuracy: 0.8014
# Epoch 20/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3746 - accuracy: 0.8359
# Epoch 00020: val_accuracy improved from 0.83371 to 0.83829, saving model to weights.best.hdf5
# 31500/31500 [==============================] - 8s 240us/sample - loss: 0.3744 - accuracy: 0.8359 - val_loss: 0.3766 - val_accuracy: 0.8383
# Epoch 21/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3634 - accuracy: 0.8432
# Epoch 00021: val_accuracy improved from 0.83829 to 0.84057, saving model to weights.best.hdf5
# 31500/31500 [==============================] - 8s 239us/sample - loss: 0.3635 - accuracy: 0.8431 - val_loss: 0.3786 - val_accuracy: 0.8406
# Epoch 22/150
# 31488/31500 [============================>.] - ETA: 0s - loss: 0.3654 - accuracy: 0.8395
# Epoch 00022: val_accuracy did not improve from 0.84057
# 31500/31500 [==============================] - 8s 250us/sample - loss: 0.3653 - accuracy: 0.8395 - val_loss: 0.4006 - val_accuracy: 0.8171
# Epoch 23/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3614 - accuracy: 0.8430
# Epoch 00023: val_accuracy did not improve from 0.84057
# 31500/31500 [==============================] - 8s 239us/sample - loss: 0.3612 - accuracy: 0.8430 - val_loss: 0.3974 - val_accuracy: 0.8254
# Epoch 24/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3598 - accuracy: 0.8434
# Epoch 00024: val_accuracy improved from 0.84057 to 0.84257, saving model to weights.best.hdf5
# 31500/31500 [==============================] - 8s 239us/sample - loss: 0.3595 - accuracy: 0.8435 - val_loss: 0.3752 - val_accuracy: 0.8426
# Epoch 25/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3520 - accuracy: 0.8467
# Epoch 00025: val_accuracy did not improve from 0.84257
# 31500/31500 [==============================] - 7s 235us/sample - loss: 0.3517 - accuracy: 0.8468 - val_loss: 0.4064 - val_accuracy: 0.8251
# Epoch 26/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3459 - accuracy: 0.8493
# Epoch 00026: val_accuracy did not improve from 0.84257
# 31500/31500 [==============================] - 8s 239us/sample - loss: 0.3461 - accuracy: 0.8492 - val_loss: 0.3896 - val_accuracy: 0.8280
# Epoch 27/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3538 - accuracy: 0.8467
# Epoch 00027: val_accuracy did not improve from 0.84257
# 31500/31500 [==============================] - 8s 239us/sample - loss: 0.3539 - accuracy: 0.8466 - val_loss: 0.3802 - val_accuracy: 0.8343
# Epoch 28/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3436 - accuracy: 0.8506
# Epoch 00028: val_accuracy did not improve from 0.84257
# 31500/31500 [==============================] - 7s 237us/sample - loss: 0.3434 - accuracy: 0.8506 - val_loss: 0.4424 - val_accuracy: 0.8123
# Epoch 29/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3396 - accuracy: 0.8536
# Epoch 00029: val_accuracy improved from 0.84257 to 0.85029, saving model to weights.best.hdf5
# 31500/31500 [==============================] - 8s 240us/sample - loss: 0.3394 - accuracy: 0.8537 - val_loss: 0.3578 - val_accuracy: 0.8503
# Epoch 30/150
# 31488/31500 [============================>.] - ETA: 0s - loss: 0.3335 - accuracy: 0.8558
# Epoch 00030: val_accuracy did not improve from 0.85029
# 31500/31500 [==============================] - 8s 247us/sample - loss: 0.3335 - accuracy: 0.8557 - val_loss: 0.3574 - val_accuracy: 0.8457
# Epoch 31/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3271 - accuracy: 0.8581
# Epoch 00031: val_accuracy did not improve from 0.85029
# 31500/31500 [==============================] - 8s 240us/sample - loss: 0.3271 - accuracy: 0.8580 - val_loss: 0.3634 - val_accuracy: 0.8483
# Epoch 32/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3273 - accuracy: 0.8596
# Epoch 00032: val_accuracy did not improve from 0.85029
# 31500/31500 [==============================] - 8s 241us/sample - loss: 0.3272 - accuracy: 0.8597 - val_loss: 0.3644 - val_accuracy: 0.8429
# Epoch 33/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3267 - accuracy: 0.8596
# Epoch 00033: val_accuracy did not improve from 0.85029
# 31500/31500 [==============================] - 7s 237us/sample - loss: 0.3267 - accuracy: 0.8597 - val_loss: 0.3553 - val_accuracy: 0.8483
# Epoch 34/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3169 - accuracy: 0.8631
# Epoch 00034: val_accuracy did not improve from 0.85029
# 31500/31500 [==============================] - 8s 242us/sample - loss: 0.3167 - accuracy: 0.8632 - val_loss: 0.3756 - val_accuracy: 0.8449
# Epoch 35/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3262 - accuracy: 0.8574
# Epoch 00035: val_accuracy did not improve from 0.85029
# 31500/31500 [==============================] - 7s 238us/sample - loss: 0.3263 - accuracy: 0.8576 - val_loss: 0.3584 - val_accuracy: 0.8449
# Epoch 36/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3133 - accuracy: 0.8652
# Epoch 00036: val_accuracy improved from 0.85029 to 0.85286, saving model to weights.best.hdf5
# 31500/31500 [==============================] - 7s 238us/sample - loss: 0.3132 - accuracy: 0.8652 - val_loss: 0.3542 - val_accuracy: 0.8529
# Epoch 37/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.3199 - accuracy: 0.8645
# Epoch 00037: val_accuracy did not improve from 0.85286
# 31500/31500 [==============================] - 7s 236us/sample - loss: 0.3200 - accuracy: 0.8645 - val_loss: 0.3623 - val_accuracy: 0.8437
# Epoch 38/150
# 31488/31500 [============================>.] - ETA: 0s - loss: 0.3071 - accuracy: 0.8704
# Epoch 00038: val_accuracy did not improve from 0.85286
# 31500/31500 [==============================] - 8s 249us/sample - loss: 0.3071 - accuracy: 0.8704 - val_loss: 0.3994 - val_accuracy: 0.8340
# Epoch 39/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2995 - accuracy: 0.8725
# Epoch 00039: val_accuracy did not improve from 0.85286
# 31500/31500 [==============================] - 8s 239us/sample - loss: 0.2993 - accuracy: 0.8726 - val_loss: 0.3843 - val_accuracy: 0.8414
# Epoch 40/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2994 - accuracy: 0.8727
# Epoch 00040: val_accuracy did not improve from 0.85286
# 31500/31500 [==============================] - 7s 238us/sample - loss: 0.2996 - accuracy: 0.8725 - val_loss: 0.3796 - val_accuracy: 0.8406
# Epoch 41/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2974 - accuracy: 0.8728
# Epoch 00041: val_accuracy did not improve from 0.85286
# 31500/31500 [==============================] - 8s 238us/sample - loss: 0.2976 - accuracy: 0.8727 - val_loss: 0.3834 - val_accuracy: 0.8406
# Epoch 42/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2949 - accuracy: 0.8734
# Epoch 00042: val_accuracy improved from 0.85286 to 0.85771, saving model to weights.best.hdf5
# 31500/31500 [==============================] - 8s 239us/sample - loss: 0.2948 - accuracy: 0.8735 - val_loss: 0.3634 - val_accuracy: 0.8577
# Epoch 43/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2851 - accuracy: 0.8793
# Epoch 00043: val_accuracy did not improve from 0.85771
# 31500/31500 [==============================] - 7s 238us/sample - loss: 0.2853 - accuracy: 0.8792 - val_loss: 0.4009 - val_accuracy: 0.8349
# Epoch 44/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2868 - accuracy: 0.8783
# Epoch 00044: val_accuracy improved from 0.85771 to 0.85886, saving model to weights.best.hdf5
# 31500/31500 [==============================] - 8s 238us/sample - loss: 0.2867 - accuracy: 0.8784 - val_loss: 0.3607 - val_accuracy: 0.8589
# Epoch 45/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2864 - accuracy: 0.8798
# Epoch 00045: val_accuracy did not improve from 0.85886
# 31500/31500 [==============================] - 8s 242us/sample - loss: 0.2863 - accuracy: 0.8798 - val_loss: 0.3440 - val_accuracy: 0.8551
# Epoch 46/150
# 31488/31500 [============================>.] - ETA: 0s - loss: 0.2839 - accuracy: 0.8800
# Epoch 00046: val_accuracy did not improve from 0.85886
# 31500/31500 [==============================] - 8s 250us/sample - loss: 0.2839 - accuracy: 0.8800 - val_loss: 0.3559 - val_accuracy: 0.8529
# Epoch 47/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2775 - accuracy: 0.8829
# Epoch 00047: val_accuracy improved from 0.85886 to 0.85914, saving model to weights.best.hdf5
# 31500/31500 [==============================] - 8s 243us/sample - loss: 0.2779 - accuracy: 0.8828 - val_loss: 0.3493 - val_accuracy: 0.8591
# Epoch 48/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2738 - accuracy: 0.8846
# Epoch 00048: val_accuracy did not improve from 0.85914
# 31500/31500 [==============================] - 8s 239us/sample - loss: 0.2740 - accuracy: 0.8844 - val_loss: 0.4045 - val_accuracy: 0.8380
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2384 - accuracy: 0.9025
# Epoch 00062: val_accuracy did not improve from 0.86486
# 31500/31500 [==============================] - 8s 241us/sample - loss: 0.2380 - accuracy: 0.9027 - val_loss: 0.3594 - val_accuracy: 0.8646
# Epoch 63/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2352 - accuracy: 0.9049
# Epoch 00063: val_accuracy did not improve from 0.86486
# 31500/31500 [==============================] - 8s 241us/sample - loss: 0.2353 - accuracy: 0.9048 - val_loss: 0.3465 - val_accuracy: 0.8611
# Epoch 64/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2313 - accuracy: 0.9046
# Epoch 00064: val_accuracy improved from 0.86486 to 0.86543, saving model to weights.best.hdf5
# 31500/31500 [==============================] - 8s 240us/sample - loss: 0.2315 - accuracy: 0.9045 - val_loss: 0.3474 - val_accuracy: 0.8654
# Epoch 65/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2267 - accuracy: 0.9059
# Epoch 00065: val_accuracy did not improve from 0.86543
# 31500/31500 [==============================] - 8s 238us/sample - loss: 0.2266 - accuracy: 0.9059 - val_loss: 0.3834 - val_accuracy: 0.8580
# Epoch 66/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2248 - accuracy: 0.9071
# Epoch 00066: val_accuracy did not improve from 0.86543
# 31500/31500 [==============================] - 8s 241us/sample - loss: 0.2247 - accuracy: 0.9072 - val_loss: 0.3627 - val_accuracy: 0.8617
# Epoch 67/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2287 - accuracy: 0.9043
# Epoch 00067: val_accuracy improved from 0.86543 to 0.86571, saving model to weights.best.hdf5
# 31500/31500 [==============================] - 8s 244us/sample - loss: 0.2290 - accuracy: 0.9043 - val_loss: 0.3524 - val_accuracy: 0.8657
# Epoch 68/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2277 - accuracy: 0.9063
# Epoch 00068: val_accuracy did not improve from 0.86571
# 31500/31500 [==============================] - 7s 238us/sample - loss: 0.2277 - accuracy: 0.9063 - val_loss: 0.4074 - val_accuracy: 0.8566
# Epoch 69/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2214 - accuracy: 0.9100
# Epoch 00069: val_accuracy did not improve from 0.86571
# 31500/31500 [==============================] - 8s 245us/sample - loss: 0.2214 - accuracy: 0.9099 - val_loss: 0.3555 - val_accuracy: 0.8637
# Epoch 70/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2164 - accuracy: 0.9121
# Epoch 00070: val_accuracy did not improve from 0.86571
# 31500/31500 [==============================] - 8s 247us/sample - loss: 0.2166 - accuracy: 0.9121 - val_loss: 0.3737 - val_accuracy: 0.8571
# Epoch 71/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2228 - accuracy: 0.9101
# Epoch 00071: val_accuracy did not improve from 0.86571
# 31500/31500 [==============================] - 7s 236us/sample - loss: 0.2230 - accuracy: 0.9101 - val_loss: 0.3588 - val_accuracy: 0.8617
# Epoch 72/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2148 - accuracy: 0.9139
# Epoch 00072: val_accuracy did not improve from 0.86571
# 31500/31500 [==============================] - 7s 236us/sample - loss: 0.2148 - accuracy: 0.9139 - val_loss: 0.3637 - val_accuracy: 0.8597
# Epoch 73/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2119 - accuracy: 0.9145
# Epoch 00073: val_accuracy did not improve from 0.86571
# 31500/31500 [==============================] - 7s 237us/sample - loss: 0.2120 - accuracy: 0.9145 - val_loss: 0.3668 - val_accuracy: 0.8637
# Epoch 74/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2079 - accuracy: 0.9149
# Epoch 00074: val_accuracy did not improve from 0.86571
# 31500/31500 [==============================] - 8s 239us/sample - loss: 0.2082 - accuracy: 0.9148 - val_loss: 0.3850 - val_accuracy: 0.8586
# Epoch 75/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2147 - accuracy: 0.9135
# Epoch 00075: val_accuracy did not improve from 0.86571
# 31500/31500 [==============================] - 7s 237us/sample - loss: 0.2145 - accuracy: 0.9137 - val_loss: 0.3776 - val_accuracy: 0.8609
# Epoch 76/150
# 31360/31500 [============================>.] - ETA: 0s - loss: 0.2011 - accuracy: 0.9195
# Epoch 00076: val_accuracy did not improve from 0.86571
# 31500/31500 [==============================] - 7s 236us/sample - loss: 0.2012 - accuracy: 0.9194 - val_loss: 0.3699 - val_accuracy: 0.8594
# Epoch 77/150
# 31488/31500 [============================>.] - ETA: 0s - loss: 0.2163 - accuracy: 0.9118
# Epoch 00077: val_accuracy did not improve from 0.86571
# 31500/31500 [==============================] - 8s 247us/sample - loss: 0.2162 - accuracy: 0.9118 - val_loss: 0.3621 - val_accuracy: 0.8614
# Epoch 00077: early stopping

# %%
# Clear training data to clear RAM for next stage
del train_data, train_Y

# %%
# Generate validation data
img_range_val = range(210000, 220025)
validation_data, validation_Y = generate_train_data(img_range_val, img_paths_train, train_file_ids)

# Evaluate model so far
model.load_weights("weights.best.hdf5")
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
scores = model.evaluate(validation_data, validation_Y)

# Delete validation data and show scores
del validation_data, validation_Y
print('My model scored', scores)
# Out:
# 10025/10025 [==============================] - 2s 187us/sample - loss: 0.3237 - accuracy: 0.8695
# My model scored [0.3237222186823438, 0.8695262]
