# %%
import os

import numpy as np
import pandas as pd

# %%
df_train = pd.read_csv("../input/train_users_2.csv")
df_train.sample(n=5)
# Out:
#                 id date_account_created  timestamp_first_active  \
# 25568   d79xp1z34z           2012-05-27          20120527202400
# 212885  qxwjqgtidn           2014-06-30          20140630010505
# 81702   kltelv7gda           2013-06-05          20130605000939
# 206282  n1iw7vc7zg           2014-06-18          20140618001007
# 116386  jm697h5frj           2013-10-12          20131012230430
#
#        date_first_booking  gender   age signup_method  signup_flow language  \
# 25568          2012-05-28  FEMALE  38.0         basic            0       en
# 212885         2014-06-30  FEMALE  24.0         basic           25       en
# 81702          2013-10-23  FEMALE  27.0         basic            0       en
# 206282                NaN    MALE  27.0         basic            0       en
# 116386         2013-10-15  FEMALE  57.0         basic            0       en
#
#        affiliate_channel affiliate_provider first_affiliate_tracked  \
# 25568          sem-brand             google                     omg
# 212885            direct             direct               untracked
# 81702             direct             direct               untracked
# 206282         sem-brand             google               untracked
# 116386            direct             direct               untracked
#
#        signup_app first_device_type  first_browser country_destination
# 25568         Web              iPad  Mobile Safari                  US
# 212885        iOS            iPhone  Mobile Safari                  US
# 81702         Web   Windows Desktop         Chrome                  US
# 206282        Web            iPhone      -unknown-                 NDF
# 116386        Web       Mac Desktop         Safari                  US

# %%
df_test = pd.read_csv("../input/test_users.csv")
df_test.sample(n=5)
# Out:
#                id date_account_created  timestamp_first_active  \
# 40587  08vyotwiq2           2014-08-27          20140827222901
# 11453  qe15adc1hu           2014-07-19          20140719163413
# 50319  9egoc7rhot           2014-09-11          20140911205752
# 5937   h59ary4722           2014-07-11          20140711072319
# 25124  mn1v8i0dw7           2014-08-06          20140806003120
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 40587                 NaN  -unknown-   NaN         basic            0
# 11453                 NaN  -unknown-   NaN         basic            0
# 50319                 NaN  -unknown-   NaN         basic           25
# 5937                  NaN  -unknown-  24.0         basic            0
# 25124                 NaN     FEMALE  43.0      facebook           25
#
#       language affiliate_channel affiliate_provider first_affiliate_tracked  \
# 40587       en         sem-brand             google                     omg
# 11453       en            direct             direct               untracked
# 50319       es            direct             direct               untracked
# 5937        en            direct             direct               untracked
# 25124       en            direct             direct               untracked
#
#       signup_app first_device_type first_browser
# 40587        Web       Mac Desktop        Safari
# 11453        Web   Windows Desktop            IE
# 50319        iOS            iPhone     -unknown-
# 5937         Web   Windows Desktop        Chrome
# 25124        iOS            iPhone     -unknown-

# %%
df_all = pd.concat((df_train, df_test), axis=0, ignore_index=True)
df_all.head(n=5)
# Out:
#   affiliate_channel affiliate_provider   age country_destination  \
# 0            direct             direct   NaN                 NDF
# 1               seo             google  38.0                 NDF
# 2            direct             direct  56.0                  US
# 3            direct             direct  42.0               other
# 4            direct             direct  41.0                  US
#
#   date_account_created date_first_booking first_affiliate_tracked  \
# 0           2010-06-28                NaN               untracked
# 1           2011-05-25                NaN               untracked
# 2           2010-09-28         2010-08-02               untracked
# 3           2011-12-05         2012-09-08               untracked
# 4           2010-09-14         2010-02-18               untracked
#
#   first_browser first_device_type     gender          id language signup_app  \
# 0        Chrome       Mac Desktop  -unknown-  gxn3p5htnn       en        Web
# 1        Chrome       Mac Desktop       MALE  820tgsjxq7       en        Web
# 2            IE   Windows Desktop     FEMALE  4ft3gnwmtx       en        Web
# 3       Firefox       Mac Desktop     FEMALE  bjjt8pjhuk       en        Web
# 4        Chrome       Mac Desktop  -unknown-  87mebub9p4       en        Web
#
#    signup_flow signup_method  timestamp_first_active
# 0            0      facebook          20090319043255
# 1            0      facebook          20090523174809
# 2            3         basic          20090609231247
# 3            0      facebook          20091031060129
# 4            0         basic          20091208061105

# %%
df_all.drop('date_first_booking', axis=1, inplace=True)

# %%
df_all.sample(n=5)
# Out:
#        affiliate_channel affiliate_provider   age country_destination  \
# 194084            direct             direct   NaN                 NDF
# 177660            direct             direct  31.0                 NDF
# 110580            direct             direct   NaN                 NDF
# 158926            direct             direct  56.0               other
# 20164                seo              other  33.0                  US
#
#        date_account_created first_affiliate_tracked  first_browser  \
# 194084           2014-05-23                  linked  Mobile Safari
# 177660           2014-04-19           tracked-other         Chrome
# 110580           2013-09-24               untracked      -unknown-
# 158926           2014-03-03               untracked         Chrome
# 20164            2012-03-31           tracked-other        Firefox
#
#        first_device_type     gender          id language signup_app  \
# 194084            iPhone  -unknown-  fob3bvafko       en      Moweb
# 177660       Mac Desktop  -unknown-  rf6bhc30x1       en        Web
# 110580     Other/Unknown  -unknown-  z7pst0tnct       en    Android
# 158926   Windows Desktop     FEMALE  p1y498l63l       en        Web
# 20164    Windows Desktop     FEMALE  dekjjxrv39       en        Web
#
#         signup_flow signup_method  timestamp_first_active
# 194084           24         basic          20140523213741
# 177660            0         basic          20140419163223
# 110580           23         basic          20130924041729
# 158926            0         basic          20140303183401
# 20164             0         basic          20120331222219

# %%
df_all['date_account_created'] = pd.to_datetime(df_all['date_account_created'],format='%Y-%m-%d')

# %%
df_all.sample(n=5)
# Out:
#        affiliate_channel affiliate_provider   age country_destination  \
# 141059     sem-non-brand             google   NaN                 NDF
# 41369             direct             direct   NaN                  US
# 74671             direct             direct  41.0                 NDF
# 243072            direct             direct   NaN                 NaN
# 193838         sem-brand             google  30.0               other
#
#        date_account_created first_affiliate_tracked first_browser  \
# 141059           2014-01-13                     omg        Safari
# 41369            2012-09-18               untracked        Safari
# 74671            2013-05-03               untracked        Chrome
# 243072           2014-08-12               untracked     -unknown-
# 193838           2014-05-23                     omg        Chrome
#
#        first_device_type     gender          id language signup_app  \
# 141059       Mac Desktop  -unknown-  p3i0mw6ji2       en        Web
# 41369        Mac Desktop  -unknown-  cf6vxl2g7g       en        Web
# 74671    Windows Desktop       MALE  76arj1ki8a       en        Web
# 243072            iPhone  -unknown-  1r1jc03n5m       en        iOS
# 193838   Windows Desktop     FEMALE  ac7djkmd0a       en        Web
#
#         signup_flow signup_method  timestamp_first_active
# 141059            0         basic          20140113032906
# 41369             0         basic          20120918034311
# 74671             0      facebook          20130503162201
# 243072           25         basic          20140812043819
# 193838            0         basic          20140523071245

# %%
df_all['timestamp_first_active']=pd.to_datetime(df_all['timestamp_first_active'], format='%Y%m%d%H%M%S')
df_all.sample(n=5)
# Out:
#        affiliate_channel affiliate_provider   age country_destination  \
# 200692             other          padmapper   NaN                 NDF
# 119447         sem-brand             google   NaN                 NDF
# 141117            direct             direct  29.0                  US
# 155164         sem-brand             google   NaN                 NDF
# 53830                seo             google  29.0                  FR
#
#        date_account_created first_affiliate_tracked first_browser  \
# 200692           2014-06-06           tracked-other        Safari
# 119447           2013-10-25                     omg        Safari
# 141117           2014-01-13                  linked       Firefox
# 155164           2014-02-20                  linked        Safari
# 53830            2012-12-29                  linked        Chrome
#
#        first_device_type     gender          id language signup_app  \
# 200692       Mac Desktop  -unknown-  y1cpnjnzge       en        Web
# 119447       Mac Desktop  -unknown-  0chnfstbkr       en        Web
# 141117   Windows Desktop  -unknown-  l9ha3nveqn       en        Web
# 155164       Mac Desktop  -unknown-  c0adr31t9t       en        Web
# 53830    Windows Desktop     FEMALE  kyvzgw2xw5       en        Web
#
#         signup_flow signup_method timestamp_first_active
# 200692            0         basic    2014-06-06 20:05:24
# 119447            0         basic    2013-10-25 17:36:13
# 141117            0         basic    2014-01-13 06:08:11
# 155164            0         basic    2014-02-20 23:39:36
# 53830             0         basic    2012-12-29 08:44:11

# %%
def remove_age_outliers(x, min_value=15, max_value=90):
    if np.logical_or(x<=min_value, x>=max_value):
        return np.nan
    else:
        return x

# %%
df_all['age'] = df_all['age'].apply(lambda x: remove_age_outliers(x) if(not np.isnan(x)) else x)

# %%
df_all['age'].fillna(-1, inplace=True)

# %%
df_all.sample(n=5)
# Out:
#        affiliate_channel affiliate_provider   age country_destination  \
# 254335            direct             direct  -1.0                 NaN
# 132436            direct             direct  -1.0                 NDF
# 34990                api              other  34.0                 NDF
# 229129            direct             direct  21.0                 NaN
# 139755            direct             direct  31.0                  US
#
#        date_account_created first_affiliate_tracked  first_browser  \
# 254335           2014-08-28               untracked      -unknown-
# 132436           2013-12-14               untracked  Mobile Safari
# 34990            2012-08-04                     omg         Safari
# 229129           2014-07-24               untracked      -unknown-
# 139755           2014-01-09                  linked         Safari
#
#        first_device_type     gender          id language signup_app  \
# 254335     Android Phone  -unknown-  eky33e3pa5       en    Android
# 132436            iPhone  -unknown-  lx2un85t04       en        iOS
# 34990        Mac Desktop       MALE  rqugnmiar2       en        Web
# 229129              iPad     FEMALE  grdczhsnwg       en        iOS
# 139755       Mac Desktop       MALE  nic99ku0l2       en        Web
#
#         signup_flow signup_method timestamp_first_active
# 254335           12        google    2014-08-28 04:26:29
# 132436           25         basic    2013-12-14 16:28:52
# 34990            12      facebook    2012-08-04 07:26:10
# 229129           25      facebook    2014-07-24 03:11:46
# 139755            0      facebook    2014-01-09 17:04:30

# %%
df_all.age = df_all.age.astype(int)
df_all.sample(n=5)
# Out:
#        affiliate_channel affiliate_provider  age country_destination  \
# 83683             direct             direct   38                 NDF
# 169351            direct             direct   -1                  US
# 242439         sem-brand             google   -1                 NaN
# 171642            direct             direct   -1                 NDF
# 42483              other              other   26                  US
#
#        date_account_created first_affiliate_tracked  first_browser  \
# 83683            2013-06-13               untracked        Firefox
# 169351           2014-03-30               untracked        Firefox
# 242439           2014-08-11                     omg         Chrome
# 171642           2014-04-04               untracked  Mobile Safari
# 42483            2012-09-26           tracked-other             IE
#
#        first_device_type     gender          id language signup_app  \
# 83683    Windows Desktop       MALE  g7kk6zlqdn       en        Web
# 169351   Windows Desktop  -unknown-  uk2frwjip4       en        Web
# 242439   Windows Desktop  -unknown-  aiqon6ryyj       en        Web
# 171642            iPhone  -unknown-  bc6bumxcso       en      Moweb
# 42483    Windows Desktop     FEMALE  gqn3kxkhu5       en        Web
#
#         signup_flow signup_method timestamp_first_active
# 83683             0      facebook    2013-06-13 15:12:25
# 169351            0         basic    2014-03-30 01:02:35
# 242439            0         basic    2014-08-11 08:45:40
# 171642           24         basic    2014-04-04 14:40:47
# 42483             0      facebook    2012-09-26 07:02:01

# %%
def check_NaN_Values_in_df(df):
    for col in df:
        nan_count = df[col].isnull().sum()
        
        if nan_count != 0:
            print (col + " => " + str(nan_count) + " NaN Values")

# %%
check_NaN_Values_in_df(df_all)
# Out:
# country_destination => 62096 NaN Values
# first_affiliate_tracked => 6085 NaN Values

# %%
df_all['first_affiliate_tracked'].fillna(-1, inplace=True)

# %%
check_NaN_Values_in_df(df_all)
df_all.sample(n=5)
# Out:
# country_destination => 62096 NaN Values
#        affiliate_channel affiliate_provider  age country_destination  \
# 147852               api              other   33                 NDF
# 223650            direct             direct   -1                 NaN
# 45762             direct             direct   27                  US
# 128932            direct             direct   64                  FR
# 210262            direct             direct   -1                 NDF
#
#        date_account_created first_affiliate_tracked  first_browser  \
# 147852           2014-01-31               untracked      -unknown-
# 223650           2014-07-18               untracked             IE
# 45762            2012-10-22               untracked         Chrome
# 128932           2013-12-02                  linked  Mobile Safari
# 210262           2014-06-25               untracked      -unknown-
#
#        first_device_type     gender          id language signup_app  \
# 147852            iPhone       MALE  hugnmaczqu       en        iOS
# 223650    Android Tablet  -unknown-  q0t1o7npnl       en        Web
# 45762        Mac Desktop     FEMALE  tkkzjf7rhi       en        Web
# 128932              iPad       MALE  sik8dlipxk       en        Web
# 210262            iPhone  -unknown-  y7182xpk4p       en        iOS
#
#         signup_flow signup_method timestamp_first_active
# 147852           12      facebook    2014-01-31 03:27:31
# 223650            0         basic    2014-07-18 01:22:06
# 45762             0         basic    2012-10-22 07:32:44
# 128932            0         basic    2013-12-02 01:29:25
# 210262           25         basic    2014-06-25 04:04:22

# %%
df_all.drop('timestamp_first_active', axis=1, inplace=True)
df_all.drop('language', axis=1, inplace=True)

# %%
df_all.sample(n=5)
# Out:
#        affiliate_channel affiliate_provider  age country_destination  \
# 10260             direct             direct   34                  FR
# 250674            direct             direct   25                 NaN
# 120808               seo             google   24                 NDF
# 62272             direct             direct   -1                 NDF
# 47629          sem-brand             google   -1                 NDF
#
#        date_account_created first_affiliate_tracked  first_browser  \
# 10260            2011-09-27                  linked  Mobile Safari
# 250674           2014-08-23                  linked  Chrome Mobile
# 120808           2013-10-31                  linked         Chrome
# 62272            2013-02-26               untracked         Chrome
# 47629            2012-11-07                  linked        Firefox
#
#        first_device_type     gender          id signup_app  signup_flow  \
# 10260               iPad       MALE  37exsbg02i        Web            0
# 250674     Android Phone       MALE  88i7kukng6      Moweb            0
# 120808   Windows Desktop     FEMALE  6ph21uq56f        Web            0
# 62272    Windows Desktop  -unknown-  turqxffgu4        Web            0
# 47629        Mac Desktop     FEMALE  x3s9nlzvwn        Web            0
#
#        signup_method
# 10260          basic
# 250674      facebook
# 120808         basic
# 62272          basic
# 47629          basic

# %%
df_all = df_all[df_all['date_account_created'] > '2013-02-01']

# %%
df_all.sample(n=5)
# Out:
#        affiliate_channel affiliate_provider  age country_destination  \
# 219133         sem-brand             google   30                 NaN
# 241619         sem-brand             google   -1                 NaN
# 269057            direct             direct   -1                 NaN
# 261378            direct             direct   -1                 NaN
# 75499             direct             direct   -1                 NDF
#
#        date_account_created first_affiliate_tracked  first_browser  \
# 219133           2014-07-10                     omg         Chrome
# 241619           2014-08-10                     omg         Chrome
# 269057           2014-09-20                  linked  Mobile Safari
# 261378           2014-09-08               untracked      -unknown-
# 75499            2013-05-07                      -1      -unknown-
#
#        first_device_type     gender          id signup_app  signup_flow  \
# 219133   Windows Desktop       MALE  0q56us3zwu        Web            0
# 241619   Windows Desktop  -unknown-  ulwkcemghg        Web            0
# 269057            iPhone  -unknown-  7loe995or1      Moweb            0
# 261378     Android Phone  -unknown-  a7bt8s4ibk    Android           12
# 75499      Other/Unknown  -unknown-  3vnr9757y9      Moweb           24
#
#        signup_method
# 219133         basic
# 241619         basic
# 269057         basic
# 261378        google
# 75499          basic

# %%
if not os.path.exists("output"):
    os.makedirs("output")
    
df_all.to_csv("output/cleaned.csv", sep=',', index=False)
