# %% [markdown]
# # Pandas Python

# %% [markdown]
# ## Pandas Series

# %%
import numpy as np
import pandas as pd

# %%
# Passing ndarray to Pandas series
d1 = np.arange(100,110)
pd.Series(d1)
# Out:
# 0    100
# 1    101
# 2    102
# 3    103
# 4    104
# 5    105
# 6    106
# 7    107
# 8    108
# 9    109
# dtype: int64

# %%
#Customized Index values
d2 = np.array(['a','b','c','d','e'])
pd.Series(d2,index=[1,2,3,4,5])
# Out:
# 1    a
# 2    b
# 3    c
# 4    d
# 5    e
# dtype: object

# %%
#with Dictionary
d3 = {"a":1,"b":2,"c":3,"d":4,"e":5}
pd.Series(d3)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
#Retrive elements
data = np.array(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
s = pd.Series(data)

# %%
s[:3]
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
s[-3:]
# Out:
# 5    f
# 6    g
# 7    h
# dtype: object

# %%
s[[0,2,4]]
# Out:
# 0    a
# 2    c
# 4    e
# dtype: object

# %% [markdown]
# ## Pandas Dataframe

# %%
#creating a Dataframe
df = pd.DataFrame(
                  {"Name":["a","b","c","d"],
                  "Age" : [25,24,19,24]},
                   index =[1,2,3,4])
df
# Out:
#   Name  Age
# 1    a   25
# 2    b   24
# 3    c   19
# 4    d   24

# %%
df = pd.DataFrame([['Ab', 25], ['Bb', 24], ['Cd', 19], ['Dd', 24]], columns=['Name','Age'])

# %%
df
# Out:
#   Name  Age
# 0   Ab   25
# 1   Bb   24
# 2   Cd   19
# 3   Dd   24

# %% [markdown]
# ## Data wrangling with pandas

# %%
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings', 'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
            'Rank': [1, 2, 2, 3, 3, 4, 1, 1, 2, 4, 1, 2],
            'Year': [2014, 2015, 2014, 2015, 2014, 2015, 2016, 2017, 2016, 2014, 2015, 2017],
            'Points':[876, 789, 863, 673, 741, 812, 756, 788, 694, 701, 804, 690]}
df = pd.DataFrame(ipl_data)

# %%
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
df.dtypes
# Out:
# Team      object
# Rank       int64
# Year       int64
# Points     int64
# dtype: object

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (12, 4)

# %%
len(df)
# Out:
# 12

# %%
df.size
# Out:
# 48

# %%
df.values
# Out:
# array([['Riders', 1, 2014, 876],
#        ['Riders', 2, 2015, 789],
#        ['Devils', 2, 2014, 863],
#        ['Devils', 3, 2015, 673],
#        ['Kings', 3, 2014, 741],
#        ['kings', 4, 2015, 812],
#        ['Kings', 1, 2016, 756],
#        ['Kings', 1, 2017, 788],
#        ['Riders', 2, 2016, 694],
#        ['Royals', 4, 2014, 701],
#        ['Royals', 1, 2015, 804],
#        ['Riders', 2, 2017, 690]], dtype=object)

# %%
df.head()
# Out:
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 1  Riders     2  2015     789
# 2  Devils     2  2014     863
# 3  Devils     3  2015     673
# 4   Kings     3  2014     741

# %%
df.tail(2)
# Out:
#       Team  Rank  Year  Points
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
#summerize data
grades = [48, 99, 75, 80, 42, 80, 72, 68, 36, 78]

df = pd.DataFrame({'ID': ["x%d" % r for r in range(10)],
                   'Gender': ['F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'M', 'M'],
                   'ExamYear': ['2007', '2007', '2007', '2008', '2008', '2008', '2008', '2009', '2009', '2009'],
                   'Class': ['algebra', 'stats', 'bio', 'algebra', 'algebra', 'stats', 'stats', 'algebra', 'bio', 'bio'],
                   'Participated': ['yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes'],
                   'Passed': ['yes' if x > 50 else 'no' for x in grades],
                   'Employed': [True, True, True, False, False, False, False, True, True, False],
                   'Grade': grades})

# %%
df
# Out:
#    ID Gender ExamYear    Class Participated Passed  Employed  Grade
# 0  x0      F     2007  algebra          yes     no      True     48
# 1  x1      M     2007    stats          yes    yes      True     99
# 2  x2      F     2007      bio          yes    yes      True     75
# 3  x3      M     2008  algebra          yes    yes     False     80
# 4  x4      F     2008  algebra           no     no     False     42
# 5  x5      M     2008    stats          yes    yes     False     80
# 6  x6      F     2008    stats          yes    yes     False     72
# 7  x7      M     2009  algebra          yes    yes      True     68
# 8  x8      M     2009      bio          yes     no      True     36
# 9  x9      M     2009      bio          yes    yes     False     78

# %%
df['Grade'].value_counts()
# Out:
# 80    2
# 78    1
# 75    1
# 42    1
# 36    1
# 72    1
# 68    1
# 99    1
# 48    1
# Name: Grade, dtype: int64

# %%
df['ExamYear'].nunique()
# Out:
# 3

# %%
df.describe()
# Out:
#            Grade
# count  10.000000
# mean   67.800000
# std    19.758542
# min    36.000000
# 25%    53.000000
# 50%    73.500000
# 75%    79.500000
# max    99.000000

# %%
#selectin the Data
df['Class']
# Out:
# 0    algebra
# 1      stats
# 2        bio
# 3    algebra
# 4    algebra
# 5      stats
# 6      stats
# 7    algebra
# 8        bio
# 9        bio
# Name: Class, dtype: object

# %%
df[['ID','Class','Grade']]
# Out:
#    ID    Class  Grade
# 0  x0  algebra     48
# 1  x1    stats     99
# 2  x2      bio     75
# 3  x3  algebra     80
# 4  x4  algebra     42
# 5  x5    stats     80
# 6  x6    stats     72
# 7  x7  algebra     68
# 8  x8      bio     36
# 9  x9      bio     78

# %%
df.Grade
# Out:
# 0    48
# 1    99
# 2    75
# 3    80
# 4    42
# 5    80
# 6    72
# 7    68
# 8    36
# 9    78
# Name: Grade, dtype: int64

# %%
#subset observation
df[df.Gender == 'M']
# Out:
#    ID Gender ExamYear    Class Participated Passed  Employed  Grade
# 1  x1      M     2007    stats          yes    yes      True     99
# 3  x3      M     2008  algebra          yes    yes     False     80
# 5  x5      M     2008    stats          yes    yes     False     80
# 7  x7      M     2009  algebra          yes    yes      True     68
# 8  x8      M     2009      bio          yes     no      True     36
# 9  x9      M     2009      bio          yes    yes     False     78

# %%
df[(df.Grade> 20) & (df.ExamYear == '2008') & (df.Participated == 'yes')]
# Out:
#    ID Gender ExamYear    Class Participated Passed  Employed  Grade
# 3  x3      M     2008  algebra          yes    yes     False     80
# 5  x5      M     2008    stats          yes    yes     False     80
# 6  x6      F     2008    stats          yes    yes     False     72

# %%
#index based slicing

# %%
grades = [48, 99, 75, 80, 42, 80, 72, 68]

df = pd.DataFrame({'ID': ["x%d" % r for r in range(8)],
                   'Gender': ['F', 'M', 'F', 'M', 'F', 'M', 'F', 'M'],
                   'ExamYear': ['2007', '2007', '2007', '2008', '2008', '2008', '2008', '2009'],
                   'Class': ['algebra', 'stats', 'bio', 'algebra', 'algebra', 'stats', 'stats', 'algebra'],
                   'Participated': ['yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes'],
                   'Passed': ['yes' if x > 50 else 'no' for x in grades],
                   'Employed': [True, True, True, False, False, False, False, True],
                   'Grade': grades},
                 index = ["x%d" % r for r in range(8)])

# %%
df
# Out:
#     ID Gender ExamYear    Class Participated Passed  Employed  Grade
# x0  x0      F     2007  algebra          yes     no      True     48
# x1  x1      M     2007    stats          yes    yes      True     99
# x2  x2      F     2007      bio          yes    yes      True     75
# x3  x3      M     2008  algebra          yes    yes     False     80
# x4  x4      F     2008  algebra           no     no     False     42
# x5  x5      M     2008    stats          yes    yes     False     80
# x6  x6      F     2008    stats          yes    yes     False     72
# x7  x7      M     2009  algebra          yes    yes      True     68

# %%
df.loc[:,'Grade']
# Out:
# x0    48
# x1    99
# x2    75
# x3    80
# x4    42
# x5    80
# x6    72
# x7    68
# Name: Grade, dtype: int64

# %%
df.loc[:,['ID', 'Grade']]
# Out:
#     ID  Grade
# x0  x0     48
# x1  x1     99
# x2  x2     75
# x3  x3     80
# x4  x4     42
# x5  x5     80
# x6  x6     72
# x7  x7     68

# %%
df.loc['x2']
# Out:
# ID                x2
# Gender             F
# ExamYear        2007
# Class            bio
# Participated     yes
# Passed           yes
# Employed        True
# Grade             75
# Name: x2, dtype: object

# %%
df.loc[['x1', 'x3', 'x5'],['ID', 'Grade','ExamYear']]
# Out:
#     ID  Grade ExamYear
# x1  x1     99     2007
# x3  x3     80     2008
# x5  x5     80     2008

# %%
#integer based iloc
df.iloc[:4]
# Out:
#     ID Gender ExamYear    Class Participated Passed  Employed  Grade
# x0  x0      F     2007  algebra          yes     no      True     48
# x1  x1      M     2007    stats          yes    yes      True     99
# x2  x2      F     2007      bio          yes    yes      True     75
# x3  x3      M     2008  algebra          yes    yes     False     80

# %%
df
# Out:
#     ID Gender ExamYear    Class Participated Passed  Employed  Grade
# x0  x0      F     2007  algebra          yes     no      True     48
# x1  x1      M     2007    stats          yes    yes      True     99
# x2  x2      F     2007      bio          yes    yes      True     75
# x3  x3      M     2008  algebra          yes    yes     False     80
# x4  x4      F     2008  algebra           no     no     False     42
# x5  x5      M     2008    stats          yes    yes     False     80
# x6  x6      F     2008    stats          yes    yes     False     72
# x7  x7      M     2009  algebra          yes    yes      True     68

# %%
df.iloc[1:5, 2:7]
# Out:
#    ExamYear    Class Participated Passed  Employed
# x1     2007    stats          yes    yes      True
# x2     2007      bio          yes    yes      True
# x3     2008  algebra          yes    yes     False
# x4     2008  algebra           no     no     False

# %% [markdown]
# ### Handling missing data

# %%
df = pd.DataFrame(
    {
        "Name": ['Ab', 'Bb', 'Cd', 'Dd', 'Ed', 'Fc'],
        "Age" : [25, 24, 19, 24, np.nan, 28],
        "Score" : [78, 84, 89, 74, 69, np.nan]},
    index = [1, 2, 3, 4, 5, 6])

# %%
df
# Out:
#   Name   Age  Score
# 1   Ab  25.0   78.0
# 2   Bb  24.0   84.0
# 3   Cd  19.0   89.0
# 4   Dd  24.0   74.0
# 5   Ed   NaN   69.0
# 6   Fc  28.0    NaN

# %%
df.dropna() #drop row cloumn with row data
# Out:
#   Name   Age  Score
# 1   Ab  25.0   78.0
# 2   Bb  24.0   84.0
# 3   Cd  19.0   89.0
# 4   Dd  24.0   74.0

# %%
df['Age'].fillna(value = 15)
# Out:
# 1    25.0
# 2    24.0
# 3    19.0
# 4    24.0
# 5    15.0
# 6    28.0
# Name: Age, dtype: float64

# %%
df
# Out:
#   Name   Age  Score
# 1   Ab  25.0   78.0
# 2   Bb  24.0   84.0
# 3   Cd  19.0   89.0
# 4   Dd  24.0   74.0
# 5   Ed   NaN   69.0
# 6   Fc  28.0    NaN

# %%
df.Age.mean()
# Out:
# 24.0

# %%
df2 = df['Age'].fillna(value = df.Age.mean())

# %%
df2
# Out:
# 1    25.0
# 2    24.0
# 3    19.0
# 4    24.0
# 5    24.0
# 6    28.0
# Name: Age, dtype: float64

# %%
df['Age'] = df['Age'].fillna(value = df.Age.mean())

# %%
df
# Out:
#   Name   Age  Score
# 1   Ab  25.0   78.0
# 2   Bb  24.0   84.0
# 3   Cd  19.0   89.0
# 4   Dd  24.0   74.0
# 5   Ed  24.0   69.0
# 6   Fc  28.0    NaN

# %%
df['Score'] = df['Age'].fillna(value=df.Age.mean())

# %%
df
# Out:
#   Name   Age  Score
# 1   Ab  25.0   25.0
# 2   Bb  24.0   24.0
# 3   Cd  19.0   19.0
# 4   Dd  24.0   24.0
# 5   Ed  24.0   24.0
# 6   Fc  28.0   28.0

# %%
pd.isnull(df)
# Out:
#     Name    Age  Score
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
# 4  False  False  False
# 5  False  False  False
# 6  False  False  False

# %%
#wide long form
data = {'Name': ['John', 'Smith', 'Liz'], 
        'Weight': [150, 170, 110], 
        'BP': [120, 130, 100]}

w_df = pd.DataFrame(data)

# %%
w_df
# Out:
#     Name  Weight   BP
# 0   John     150  120
# 1  Smith     170  130
# 2    Liz     110  100

# %%
w_df.melt(id_vars='Name',var_name='key',value_name='value')
# Out:
#     Name     key  value
# 0   John  Weight    150
# 1  Smith  Weight    170
# 2    Liz  Weight    110
# 3   John      BP    120
# 4  Smith      BP    130
# 5    Liz      BP    100

# %%
data = {'patient': [1, 1, 1, 2, 2],
        'obs': [1, 2, 3, 1, 2], 
        'treatment': [0, 1, 0, 1, 0],
        'score': [6252, 24243, 2345, 2342, 23525]}

Long_df = pd.DataFrame(data, columns = ['patient', 'obs', 'treatment', 'score'])

# %%
Long_df
# Out:
#    patient  obs  treatment  score
# 0        1    1          0   6252
# 1        1    2          1  24243
# 2        1    3          0   2345
# 3        2    1          1   2342
# 4        2    2          0  23525

# %%
Long_df.pivot(index='patient', columns='obs', values='score')
# Out:
# obs           1        2       3
# patient
# 1        6252.0  24243.0  2345.0
# 2        2342.0  23525.0     NaN

# %%
#making a new column

# %%
data = {'Name': ['John', 'Smith', 'Liz', 'Andy', 'Dri'], 
        'Weight': [150, 170, 110, 56, 75], 
        'BP': [120, 130, 100, 110, 125]}

df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Weight   BP
# 0   John     150  120
# 1  Smith     170  130
# 2    Liz     110  100
# 3   Andy      56  110
# 4    Dri      75  125

# %%
df = df.assign(BPw = lambda df: df.Weight / df.BP)

# %%
df
# Out:
#     Name  Weight   BP       BPw
# 0   John     150  120  1.250000
# 1  Smith     170  130  1.307692
# 2    Liz     110  100  1.100000
# 3   Andy      56  110  0.509091
# 4    Dri      75  125  0.600000

# %%
df['BP2'] = df['Weight'] / df['BP']

# %%
df
# Out:
#     Name  Weight   BP       BPw       BP2
# 0   John     150  120  1.250000  1.250000
# 1  Smith     170  130  1.307692  1.307692
# 2    Liz     110  100  1.100000  1.100000
# 3   Andy      56  110  0.509091  0.509091
# 4    Dri      75  125  0.600000  0.600000

# %%
df['BP_hl'] = np.where(df['BP'] > 100 , 'high' , 'low')

# %%
df
# Out:
#     Name  Weight   BP       BPw       BP2 BP_hl
# 0   John     150  120  1.250000  1.250000  high
# 1  Smith     170  130  1.307692  1.307692  high
# 2    Liz     110  100  1.100000  1.100000   low
# 3   Andy      56  110  0.509091  0.509091  high
# 4    Dri      75  125  0.600000  0.600000  high

# %%
df.assign(st_weight = lambda df:df.Weight /df.Weight.sum())
# Out:
#     Name  Weight   BP       BPw       BP2 BP_hl  st_weight
# 0   John     150  120  1.250000  1.250000  high   0.267380
# 1  Smith     170  130  1.307692  1.307692  high   0.303030
# 2    Liz     110  100  1.100000  1.100000   low   0.196078
# 3   Andy      56  110  0.509091  0.509091  high   0.099822
# 4    Dri      75  125  0.600000  0.600000  high   0.133690

# %%
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings', 'Kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
            'Year': [2014, 2015, 2014, 2015, 2014, 2015, 2016, 2017, 2016, 2014, 2015, 2017],
            'Points':[876, 789, 863, 673, 741, 812, 756, 788, 694, 701, 804, 690]}
df = pd.DataFrame(ipl_data)

# %%
df
# Out:
#       Team  Year  Points
# 0   Riders  2014     876
# 1   Riders  2015     789
# 2   Devils  2014     863
# 3   Devils  2015     673
# 4    Kings  2014     741
# 5    Kings  2015     812
# 6    Kings  2016     756
# 7    Kings  2017     788
# 8   Riders  2016     694
# 9   Royals  2014     701
# 10  Royals  2015     804
# 11  Riders  2017     690

# %%
df.groupby(['Team']).sum()
# Out:
#         Year  Points
# Team
# Devils  4029    1536
# Kings   8062    3097
# Riders  8062    3049
# Royals  4029    1505

# %%
df['ratio'] = df.groupby(['Team'], group_keys=False).apply(lambda g: g.Points/(g.Points).sum())

# %%
df
# Out:
#       Team  Year  Points     ratio
# 0   Riders  2014     876  0.287307
# 1   Riders  2015     789  0.258773
# 2   Devils  2014     863  0.561849
# 3   Devils  2015     673  0.438151
# 4    Kings  2014     741  0.239264
# 5    Kings  2015     812  0.262189
# 6    Kings  2016     756  0.244107
# 7    Kings  2017     788  0.254440
# 8   Riders  2016     694  0.227616
# 9   Royals  2014     701  0.465781
# 10  Royals  2015     804  0.534219
# 11  Riders  2017     690  0.226304

# %%
#concatenation
df_one = pd.DataFrame(
    {'Name': ['A1', 'A2', 'A3', 'A4', 'A5'],
     'subject_id':['S01','S02','S03','S04','S05'],
     'Marks_scored':[78, 50, 77, 69, 78]},
    index=[1, 2, 3, 4, 5])

# %%
df_two = pd.DataFrame(
    {'Name': ['B1', 'B2', 'B3', 'B4', 'B5'],
     'subject_id':['S01','S02','S03','S04','S05'],
     'Marks_scored':[89, 85, 78, 87, 88]},
    index=[1, 2, 3, 4, 5])

# %%
pd.concat([df_one,df_two])
# Out:
#   Name subject_id  Marks_scored
# 1   A1        S01            78
# 2   A2        S02            50
# 3   A3        S03            77
# 4   A4        S04            69
# 5   A5        S05            78
# 1   B1        S01            89
# 2   B2        S02            85
# 3   B3        S03            78
# 4   B4        S04            87
# 5   B5        S05            88

# %%
pd.concat([df_one, df_two], keys=['x','y'])
# Out:
#     Name subject_id  Marks_scored
# x 1   A1        S01            78
#   2   A2        S02            50
#   3   A3        S03            77
#   4   A4        S04            69
#   5   A5        S05            78
# y 1   B1        S01            89
#   2   B2        S02            85
#   3   B3        S03            78
#   4   B4        S04            87
#   5   B5        S05            88

# %%
pd.concat([df_one, df_two], keys=['x','y'], ignore_index=True)
# Out:
#   Name subject_id  Marks_scored
# 0   A1        S01            78
# 1   A2        S02            50
# 2   A3        S03            77
# 3   A4        S04            69
# 4   A5        S05            78
# 5   B1        S01            89
# 6   B2        S02            85
# 7   B3        S03            78
# 8   B4        S04            87
# 9   B5        S05            88

# %%
#append columns of Dataframe
pd.concat([df_one, df_two], axis = 1)
# Out:
#   Name subject_id  Marks_scored Name subject_id  Marks_scored
# 1   A1        S01            78   B1        S01            89
# 2   A2        S02            50   B2        S02            85
# 3   A3        S03            77   B3        S03            78
# 4   A4        S04            69   B4        S04            87
# 5   A5        S05            78   B5        S05            88

# %%
#Merging Dataframe

# %%
df_left = pd.DataFrame(
    {'Student': ['St01', 'St02', 'St03', 'St01'],
     'Subject': ['Mat', 'Phy', 'Phy', 'Phy'],
     'Assign1': [54, 63, 56, 78],
     'Assign2': [66, 65, 75, 85]})

df_right = pd.DataFrame(
    {'Student': ['St01', 'St02', 'St01', 'St02'],
     'Subject': ['Mat', 'Mat', 'Phy', 'Phy'],
     'Assign3': [72, 56, 85, 96],
     'Assign4': [78, 89, 56, 88]})

# %%
df_left
# Out:
#   Student Subject  Assign1  Assign2
# 0    St01     Mat       54       66
# 1    St02     Phy       63       65
# 2    St03     Phy       56       75
# 3    St01     Phy       78       85

# %%
df_right
# Out:
#   Student Subject  Assign3  Assign4
# 0    St01     Mat       72       78
# 1    St02     Mat       56       89
# 2    St01     Phy       85       56
# 3    St02     Phy       96       88

# %%
pd.merge(df_left,df_right , on=['Student','Subject'])
# Out:
#   Student Subject  Assign1  Assign2  Assign3  Assign4
# 0    St01     Mat       54       66       72       78
# 1    St02     Phy       63       65       96       88
# 2    St01     Phy       78       85       85       56

# %%
df_right
# Out:
#   Student Subject  Assign3  Assign4
# 0    St01     Mat       72       78
# 1    St02     Mat       56       89
# 2    St01     Phy       85       56
# 3    St02     Phy       96       88

# %%
#left join
pd.merge(df_left,df_right,on=['Student','Subject'] , how = 'left')
# Out:
#   Student Subject  Assign1  Assign2  Assign3  Assign4
# 0    St01     Mat       54       66     72.0     78.0
# 1    St02     Phy       63       65     96.0     88.0
# 2    St03     Phy       56       75      NaN      NaN
# 3    St01     Phy       78       85     85.0     56.0

# %%
#right join
pd.merge(df_left, df_right, on=['Student', 'Subject'], how = 'right')
# Out:
#   Student Subject  Assign1  Assign2  Assign3  Assign4
# 0    St01     Mat     54.0     66.0       72       78
# 1    St02     Phy     63.0     65.0       96       88
# 2    St01     Phy     78.0     85.0       85       56
# 3    St02     Mat      NaN      NaN       56       89

# %%
#inner join
pd.merge(df_left, df_right, on=['Student', 'Subject'], how = 'inner')
# Out:
#   Student Subject  Assign1  Assign2  Assign3  Assign4
# 0    St01     Mat       54       66       72       78
# 1    St02     Phy       63       65       96       88
# 2    St01     Phy       78       85       85       56

# %%
#outer join
pd.merge(df_left, df_right, on=['Student', 'Subject'], how = 'outer')
# Out:
#   Student Subject  Assign1  Assign2  Assign3  Assign4
# 0    St01     Mat     54.0     66.0     72.0     78.0
# 1    St02     Phy     63.0     65.0     96.0     88.0
# 2    St03     Phy     56.0     75.0      NaN      NaN
# 3    St01     Phy     78.0     85.0     85.0     56.0
# 4    St02     Mat      NaN      NaN     56.0     89.0
