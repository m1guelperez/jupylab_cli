# %%
# Titanic Project WIP - Rory Gold

# Classification of Titanic dataset using a Neural Network with an attempt to optimize NN with randomized CV search.
# Preliminary feature selection and engineering performed.

# Randomized search CV code for a NN based on the work of Jason Brownlee 
# https://machinelearningmastery.com/grid-search-hyperparameters-deep-learning-models-python-keras/

# %%
# Import Libraries for use
import numpy as np
import pandas as pd
import math 
import time

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.python.keras.constraints import maxnorm
from tensorflow.keras.optimizers import Adam

from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
# Define functions
def numtostring(data, column):
    values = data[column].values
    value_str = []
    for i in range(0,len(values)):
        value_str.append(str(values[i]))
    data[column] = value_str
    return data

def other_nan(data, column):
    #Replace nan with 'O' for other
    values = data[column].values
    for i in range(0,len(data)):
       if pd.isnull(values[i]) == True:
           values[i] = 'O'
    data[column] = values
    return data

def get_target(data, column):
    data.dropna(axis=0, subset=[column], inplace=True)
    data_Y = data[column]
    data.drop([column], axis=1, inplace=True)
    return data, data_Y

def name_to_title(data):
    splt_fstop = '.'
    splt_comma = ', '
    title = []
    names = data.Name.values
    for name in names:
        partition_1 = name.partition(splt_fstop)[0]
        title.append(partition_1.partition(splt_comma)[2])
    data['Title'] = title
    del data['Name']
    return data

def Cabin_group(data):
    for i in range(0,len(data.Cabin)):
        if pd.isnull(data.Cabin.values[i]) == False:
            data.Cabin.values[i] = data.Cabin.values[i][0]
        if pd.isnull(data.Cabin.values[i]) == True:
            data.Cabin.values[i] = 'NA' 
    return data

def impute_num_columns(train_X, test_X):
    num_columns = [col for col in train_X.columns if train_X[col].dtype in ['float64', 'int'] ]
    imputer = SimpleImputer()
    imputed_train_X = pd.DataFrame(imputer.fit_transform(train_X[num_columns]))
    imputed_test_X = pd.DataFrame(imputer.transform(test_X[num_columns]))
    # Replace imputed column names
    imputed_train_X.columns = num_columns
    imputed_test_X.columns = num_columns
    # Reintroduce index
    imputed_train_X.index = train_X.index
    imputed_test_X.index = test_X.index
    # Replace columns in train_X with new sorted columns so can then do more feateng on them
    train_X[num_columns] = imputed_train_X[num_columns]
    test_X[num_columns] = imputed_test_X[num_columns]
    return train_X, test_X

def age_labelling(data):
    data_under16 = []
    data_under5 = []
    data_over50 = []
    for age in data.Age.values:
        if age < 16:
            data_under16.append('1')
        if age >= 16:
            data_under16.append('0')
        if age > 55:
            data_over50.append('1')
        if age <= 55:
            data_over50.append('0')
        if age < 5:
            data_under5.append('1')
        if age >= 5:
            data_under5.append('0')  
    data['AgeUnder_16'] = data_under16
    data['AgeOver_55'] = data_over50
    data['AgeUnder_5'] = data_under5
    return data

def OHE_encode(train_X, test_X, cat_columns):
    OHE_train_X = pd.get_dummies(train_X[cat_columns])   
    OHE_test_X = pd.get_dummies(test_X[cat_columns])
    # reindex OHE test values to add columns where a value is missing
    OHE_test_X = OHE_test_X.reindex(columns = OHE_train_X.columns, fill_value = 0)
    return OHE_train_X, OHE_test_X

def reset_index(data):
    data = data.reset_index()
    del data['index']
    return data

def scaling(train_X, test_X, num_columns):
    scaler = StandardScaler()
    train_num = train_X[num_columns]
    test_num = test_X[num_columns]
    train_scale = pd.DataFrame(scaler.fit_transform(train_num))
    test_scale = pd.DataFrame(scaler.transform(test_num))
    train_scale.columns = num_columns
    test_scale.columns = num_columns
    # reindex using original index
    train_scale.index = train_X.index
    test_scale.index = test_X.index
    return train_scale, test_scale

def get_important_features(train_X, test_X, train_Y, threshold):
    model = RandomForestClassifier(random_state=1, n_estimators=100)
    model.fit(train_X, train_Y)
    imp = model.feature_importances_
    df = pd.DataFrame()
    df['imp'] = imp
    df['cols'] = train_X.columns
    # Remove features with importance less than 0.01
    rem_cols = []
    for i in range(0, len(df)):
        if df.imp[i] < threshold:
            rem_cols.append(df.cols[i])
    for col in rem_cols:
        del train_X[col]
        del test_X[col]
    n_features = train_X.shape[1]
    important_features = train_X.columns
    return train_X, test_X, n_features, important_features

def OHE_encode_target(target):
    OHE_target = pd.get_dummies(target)
    OHE_target.columns = ['Perished', 'Survived']
    return OHE_target

def pandas_to_array(data):
    data_array = data.to_numpy()
    return data_array

def engineer_features(train_X, test_X, train_Y, test_Y):
    # Breakdown Name into Title
    train_X = name_to_title(train_X)
    test_X = name_to_title(test_X)
    
    # Group size feature
    train_X['GroupSize'] = train_X.SibSp + train_X.Parch
    test_X['GroupSize'] = test_X.SibSp + test_X.Parch
    
    # Cabin group
    train_X = Cabin_group(train_X)
    test_X = Cabin_group(test_X)
            
    # Select features of interest
    features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'GroupSize', 'Fare', 'Embarked', 'Cabin', 'Title']
    train_X = train_X[features]
    test_X = test_X[features]
    
    ''' Preprocess all data '''
    Pclass_train = train_X.Pclass
    Pclass_test = test_X.Pclass
    train_X = numtostring(train_X, 'Pclass')
    test_X = numtostring(test_X, 'Pclass')
    
    # Take care of missing numerical values using imputation, taking mean
    train_X, test_X = impute_num_columns(train_X, test_X)
    
    # Add under age or above age (binary columns)
    train_X = age_labelling(train_X)
    test_X = age_labelling(test_X)
    
    # Add Age + fare for Age_Fare
    train_X['Age_Fare'] = train_X.Age + train_X.Fare
    test_X['Age_Fare'] = test_X.Age + test_X.Fare
    
    # Multiply age by pclass
    train_X['Age_Pclass'] = train_X.Age * Pclass_train
    test_X['Age_Pclass'] = test_X.Age * Pclass_test
    
    ''' Encode Categorical columns '''
    # Replace nan values in categorical column Embarked
    train_X = other_nan(train_X, column = 'Embarked')
    test_X = other_nan(test_X, column = 'Embarked')
    return train_X, test_X, train_Y, test_Y

def encode_scale_features(train_X, test_X, train_Y, test_Y, cat_columns, num_columns):
    OHE_train_X, OHE_test_X = OHE_encode(train_X, test_X, cat_columns)
    
    # Scale numerical values
    train_scale, test_scale = scaling(train_X, test_X, num_columns)
    
    # Rejoin imputed and encoded values together
    train_X = pd.concat([train_scale, OHE_train_X], axis=1)
    test_X = pd.concat([test_scale, OHE_test_X], axis=1)
    
     # OHE train_Y so matches output format  
    train_Y = OHE_encode_target(train_Y)  
    test_Y = OHE_encode_target(test_Y)
    return train_X, test_X, train_Y, test_Y

def get_cat_num_columns_train(train_X):
    cat_columns = [col for col in train_X.columns if train_X[col].dtype == object]
    num_columns = [col for col in train_X.columns if train_X[col].dtype in ['float64', 'int', 'int64']]
    return cat_columns, num_columns

def keep_only_important_features(train_X, test_X, important_features):
    train_X = train_X[important_features]
    test_X = test_X[important_features]
    return train_X, test_X

def transfer_data_to_arrays(train_X, train_Y, test_X, test_Y):
    train_X = pandas_to_array(train_X)
    train_Y = pandas_to_array(train_Y)
    test_X = pandas_to_array(test_X)
    test_Y = pandas_to_array(test_Y)
    return train_X, train_Y, test_X, test_Y

# %%
# Import titanic dataset
gender_submission = pd.read_csv("../input/titanic/gender_submission.csv")
test = pd.read_csv("../input/titanic/test.csv")
train = pd.read_csv("../input/titanic/train.csv")

train_original = train.copy()
test_original = test.copy()

# %%
# Remove rows with no target variable in train
train, train_Y = get_target(train, 'Survived')

# Process test values for prediction
# Make dummy test values to be processed.
test_dummy = pd.Series(np.zeros(test.shape[0],)) 
test_dummy[0] = 1

train_X_full, test_X_full, train_Y_full, test_Y_full = engineer_features(train, test, train_Y, test_dummy)
cat_columns, num_columns = get_cat_num_columns_train(train_X_full)
train_X_full, test_X_full, train_Y_full, test_Y_full = encode_scale_features(train_X_full, test_X_full, train_Y_full, test_Y_full, cat_columns, num_columns)

# Feature selection using RandomForestClassifier
train_X_full, test_X_full, n_features, important_features = get_important_features(train_X_full, test_X_full, train_Y_full, 0.01)

# Transfer data to arrays so can be used by tensorflow
train_X_full, train_Y_full, test_X_full, test_Y_full = transfer_data_to_arrays(train_X_full, train_Y_full, test_X_full, test_Y_full)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:3509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train = train_original.copy()
train, train_Y = get_target(train, 'Survived')

# Get validation set separated
train_X, val_X, train_Y, val_Y = train_test_split(train, train_Y, test_size = 0.2, random_state=1)

# Process validation dataset and include important features identified previously
train_X, val_X, train_Y, val_Y = engineer_features(train_X, val_X, train_Y, val_Y)
train_X, val_X, train_Y, val_Y = encode_scale_features(train_X, val_X, train_Y, val_Y, cat_columns, num_columns)
train_X, val_X = keep_only_important_features(train_X, val_X, important_features)

# Transfer data to arrays so can be used by tensorflow
train_X, train_Y, val_X, val_Y = transfer_data_to_arrays(train_X, train_Y, val_X, val_Y)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:142: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:3509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
''' Implement Neural Network ''' 
# 2 classes, survived or did not survived
# Below features are those to be optimized
num_classes = 2
n_features = len(important_features)
batch_size = [1, 4, 8, 16, 32, 64, 128, 256]
dropout_rate = [0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9]
weight_constraint = [1,2,3,4,5]
epochs = [10, 20, 30, 50]
activation = ['softmax', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid', 'linear']
optimizer = ['Adam']
neurons = [5, 10, 20, 50, 100, 150, 200, 300]
learning_rate = [0.001, 0.01, 0.05, 0.1, 0.2, 0.5]
seed=7
np.random.seed(seed)

# %%
# Implement Randomized search 
# Function to create 2 layer neural network
def create_model_2layer(neurons=100, dropout_rate=0.5, activation='softmax', weight_constraint=1, learning_rate=0.001):
    model = Sequential()
    model.add(Dense(neurons, input_dim= 18, activation= activation, kernel_constraint= maxnorm(weight_constraint)))
    model.add(Dropout(dropout_rate))
    model.add(Dense(neurons, activation= activation))
    model.add(Dropout(dropout_rate))
    model.add(Dense(2, activation='softmax'))
    optimizer = Adam(lr=learning_rate)
    model.compile(loss = 'binary_crossentropy', optimizer = optimizer, metrics = ['accuracy'])
    return model

# %%
# Create randomized search model using KerasClassifier
model = KerasClassifier(build_fn = create_model_2layer, verbose=True)

param_random_2layer = dict(neurons=neurons, dropout_rate=dropout_rate, activation=activation
                  , weight_constraint=weight_constraint, learning_rate=learning_rate, epochs=epochs, batch_size=batch_size)

# Perform randomized search
start_time = time.time()
random2l = RandomizedSearchCV(estimator = model, param_distributions=param_random_2layer, cv=5, random_state=1, n_iter=20, n_jobs=-1)
random_result2l = random2l.fit(train_X, train_Y)
print('My code took', time.time() - start_time, 'to run')
parameters_2l = random_result2l.best_params_

accuracy_2layer = random_result2l.score(val_X, val_Y)
print('Accuracy of random search', accuracy_2layer)
# Out:
# /opt/conda/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Train on 712 samples
# Epoch 1/50
# 712/712 [==============================] - 1s 912us/sample - loss: 0.6886 - accuracy: 0.5857
# Epoch 2/50
# 712/712 [==============================] - 0s 28us/sample - loss: 0.6776 - accuracy: 0.6222
# Epoch 3/50
# 712/712 [==============================] - 0s 27us/sample - loss: 0.6689 - accuracy: 0.6222
# Epoch 4/50
# 712/712 [==============================] - 0s 26us/sample - loss: 0.6651 - accuracy: 0.6222
# Epoch 5/50
# 712/712 [==============================] - 0s 26us/sample - loss: 0.6633 - accuracy: 0.6222
# Epoch 6/50
# 712/712 [==============================] - 0s 26us/sample - loss: 0.6644 - accuracy: 0.6222
# Epoch 7/50
# 712/712 [==============================] - 0s 24us/sample - loss: 0.6635 - accuracy: 0.6222
# Epoch 8/50
# 712/712 [==============================] - 0s 25us/sample - loss: 0.6627 - accuracy: 0.6222
# Epoch 9/50
# 712/712 [==============================] - 0s 25us/sample - loss: 0.6624 - accuracy: 0.6222
# Epoch 10/50
# 712/712 [==============================] - 0s 27us/sample - loss: 0.6631 - accuracy: 0.6222
# Epoch 11/50
# 712/712 [==============================] - 0s 26us/sample - loss: 0.6603 - accuracy: 0.6222
# Epoch 12/50
# 712/712 [==============================] - 0s 27us/sample - loss: 0.6603 - accuracy: 0.6222
# Epoch 13/50
# 712/712 [==============================] - 0s 27us/sample - loss: 0.6595 - accuracy: 0.6222
# Epoch 14/50
# 712/712 [==============================] - 0s 26us/sample - loss: 0.6570 - accuracy: 0.6222
# Epoch 15/50
# 712/712 [==============================] - 0s 28us/sample - loss: 0.6560 - accuracy: 0.6222
# Epoch 16/50
# 712/712 [==============================] - 0s 26us/sample - loss: 0.6525 - accuracy: 0.6222
# Epoch 17/50
# 712/712 [==============================] - 0s 28us/sample - loss: 0.6490 - accuracy: 0.6222
# Epoch 18/50
# 712/712 [==============================] - 0s 26us/sample - loss: 0.6467 - accuracy: 0.6222
# Epoch 19/50
# 712/712 [==============================] - 0s 26us/sample - loss: 0.6407 - accuracy: 0.6222
# Epoch 20/50
# 712/712 [==============================] - 0s 25us/sample - loss: 0.6362 - accuracy: 0.6222
# Epoch 21/50
# 712/712 [==============================] - 0s 27us/sample - loss: 0.6274 - accuracy: 0.6222
# Epoch 22/50
# 712/712 [==============================] - 0s 26us/sample - loss: 0.6232 - accuracy: 0.6222
# Epoch 23/50
# 712/712 [==============================] - 0s 26us/sample - loss: 0.6145 - accuracy: 0.6278
# Epoch 24/50
# 712/712 [==============================] - 0s 28us/sample - loss: 0.6042 - accuracy: 0.6362
# Epoch 25/50
# 712/712 [==============================] - 0s 26us/sample - loss: 0.5951 - accuracy: 0.6503
# Epoch 26/50
# 712/712 [==============================] - 0s 26us/sample - loss: 0.5824 - accuracy: 0.6770
# Epoch 27/50
# 712/712 [==============================] - 0s 30us/sample - loss: 0.5724 - accuracy: 0.7037
# Epoch 28/50
# 712/712 [==============================] - 0s 26us/sample - loss: 0.5631 - accuracy: 0.7205
# Epoch 29/50
# 712/712 [==============================] - 0s 27us/sample - loss: 0.5571 - accuracy: 0.7303
# Epoch 30/50
# 712/712 [==============================] - 0s 26us/sample - loss: 0.5474 - accuracy: 0.7739
# Epoch 31/50
# 712/712 [==============================] - 0s 26us/sample - loss: 0.5279 - accuracy: 0.7795
# Epoch 32/50
# 712/712 [==============================] - 0s 26us/sample - loss: 0.5270 - accuracy: 0.7879
# Epoch 33/50
# 712/712 [==============================] - 0s 24us/sample - loss: 0.5246 - accuracy: 0.8006
# Epoch 34/50
# 712/712 [==============================] - 0s 24us/sample - loss: 0.5015 - accuracy: 0.8062
# Epoch 35/50
# 712/712 [==============================] - 0s 28us/sample - loss: 0.4999 - accuracy: 0.7978
# Epoch 36/50
# 712/712 [==============================] - 0s 26us/sample - loss: 0.4905 - accuracy: 0.8174
# Epoch 37/50
# 712/712 [==============================] - 0s 26us/sample - loss: 0.4947 - accuracy: 0.8090
# Epoch 38/50
# 712/712 [==============================] - 0s 25us/sample - loss: 0.4925 - accuracy: 0.8020
# Epoch 39/50
# 712/712 [==============================] - 0s 25us/sample - loss: 0.4897 - accuracy: 0.8090
# Epoch 40/50
# 712/712 [==============================] - 0s 24us/sample - loss: 0.4859 - accuracy: 0.8062
# Epoch 41/50
# 712/712 [==============================] - 0s 28us/sample - loss: 0.4921 - accuracy: 0.8062
# Epoch 42/50
# 712/712 [==============================] - 0s 25us/sample - loss: 0.4748 - accuracy: 0.8104
# Epoch 43/50
# 712/712 [==============================] - 0s 30us/sample - loss: 0.4742 - accuracy: 0.8174
# Epoch 44/50
# 712/712 [==============================] - 0s 31us/sample - loss: 0.4734 - accuracy: 0.8230
# Epoch 45/50
# 712/712 [==============================] - 0s 27us/sample - loss: 0.4666 - accuracy: 0.8076
# Epoch 46/50
# 712/712 [==============================] - 0s 27us/sample - loss: 0.4748 - accuracy: 0.8244
# Epoch 47/50
# 712/712 [==============================] - 0s 26us/sample - loss: 0.4621 - accuracy: 0.8160
# Epoch 48/50
# 712/712 [==============================] - 0s 27us/sample - loss: 0.4537 - accuracy: 0.8413
# Epoch 49/50
# 712/712 [==============================] - 0s 27us/sample - loss: 0.4375 - accuracy: 0.8287
# Epoch 50/50
# 712/712 [==============================] - 0s 27us/sample - loss: 0.4563 - accuracy: 0.8357
# My code took 376.32235050201416 to run
# 179/179 [==============================] - 0s 595us/sample - loss: 0.4916 - accuracy: 0.7989
# Accuracy of random search 0.79888266

# %%
# Implement Early stopping with best performing model
model = create_model_2layer(neurons=parameters_2l['neurons'],
                            dropout_rate=parameters_2l['dropout_rate'],
                            activation=parameters_2l['activation'],
                            weight_constraint=parameters_2l['weight_constraint'],
                            learning_rate=parameters_2l['learning_rate'])

# %%
# Define early stopping parameters
filepath="weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
es = EarlyStopping(monitor = 'val_accuracy', mode = 'max', verbose = 1, patience=50)
callbacks_list = [checkpoint, es]

model.fit(train_X, train_Y, batch_size=parameters_2l['batch_size'], epochs=150, validation_data=(val_X, val_Y), callbacks = callbacks_list)
# Out:
# Train on 712 samples, validate on 179 samples
# Epoch 1/150
# 256/712 [=========>....................] - ETA: 1s - loss: 0.6914 - accuracy: 0.5391
# Epoch 00001: val_accuracy improved from -inf to 0.59218, saving model to weights.best.hdf5
# 712/712 [==============================] - 1s 1ms/sample - loss: 0.6874 - accuracy: 0.5885 - val_loss: 0.6833 - val_accuracy: 0.5922
# Epoch 2/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6789 - accuracy: 0.6250
# Epoch 00002: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 39us/sample - loss: 0.6766 - accuracy: 0.6222 - val_loss: 0.6780 - val_accuracy: 0.5922
# Epoch 3/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6755 - accuracy: 0.6055
# Epoch 00003: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 39us/sample - loss: 0.6698 - accuracy: 0.6222 - val_loss: 0.6760 - val_accuracy: 0.5922
# Epoch 4/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6730 - accuracy: 0.6016
# Epoch 00004: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 37us/sample - loss: 0.6648 - accuracy: 0.6222 - val_loss: 0.6764 - val_accuracy: 0.5922
# Epoch 5/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6446 - accuracy: 0.6641
# Epoch 00005: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 39us/sample - loss: 0.6638 - accuracy: 0.6222 - val_loss: 0.6783 - val_accuracy: 0.5922
# Epoch 6/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6513 - accuracy: 0.6484
# Epoch 00006: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 41us/sample - loss: 0.6634 - accuracy: 0.6222 - val_loss: 0.6800 - val_accuracy: 0.5922
# Epoch 7/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6671 - accuracy: 0.6133
# Epoch 00007: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 37us/sample - loss: 0.6636 - accuracy: 0.6222 - val_loss: 0.6809 - val_accuracy: 0.5922
# Epoch 8/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6789 - accuracy: 0.5977
# Epoch 00008: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 40us/sample - loss: 0.6632 - accuracy: 0.6222 - val_loss: 0.6810 - val_accuracy: 0.5922
# Epoch 9/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6672 - accuracy: 0.6133
# Epoch 00009: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 37us/sample - loss: 0.6611 - accuracy: 0.6222 - val_loss: 0.6805 - val_accuracy: 0.5922
# Epoch 10/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6802 - accuracy: 0.5938
# Epoch 00010: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 39us/sample - loss: 0.6639 - accuracy: 0.6222 - val_loss: 0.6791 - val_accuracy: 0.5922
# Epoch 11/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6511 - accuracy: 0.6406
# Epoch 00011: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 37us/sample - loss: 0.6618 - accuracy: 0.6222 - val_loss: 0.6777 - val_accuracy: 0.5922
# Epoch 12/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6335 - accuracy: 0.6719
# Epoch 00012: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 38us/sample - loss: 0.6611 - accuracy: 0.6222 - val_loss: 0.6761 - val_accuracy: 0.5922
# Epoch 13/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6652 - accuracy: 0.6172
# Epoch 00013: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 39us/sample - loss: 0.6602 - accuracy: 0.6222 - val_loss: 0.6743 - val_accuracy: 0.5922
# Epoch 14/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6861 - accuracy: 0.5625
# Epoch 00014: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 36us/sample - loss: 0.6572 - accuracy: 0.6222 - val_loss: 0.6723 - val_accuracy: 0.5922
# Epoch 15/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6517 - accuracy: 0.6328
# Epoch 00015: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 39us/sample - loss: 0.6562 - accuracy: 0.6222 - val_loss: 0.6703 - val_accuracy: 0.5922
# Epoch 16/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6498 - accuracy: 0.6289
# Epoch 00016: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 48us/sample - loss: 0.6532 - accuracy: 0.6222 - val_loss: 0.6679 - val_accuracy: 0.5922
# Epoch 17/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6479 - accuracy: 0.6289
# Epoch 00017: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 48us/sample - loss: 0.6513 - accuracy: 0.6222 - val_loss: 0.6649 - val_accuracy: 0.5922
# Epoch 18/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6525 - accuracy: 0.6172
# Epoch 00018: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 47us/sample - loss: 0.6474 - accuracy: 0.6222 - val_loss: 0.6612 - val_accuracy: 0.5922
# Epoch 19/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6397 - accuracy: 0.6328
# Epoch 00019: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 38us/sample - loss: 0.6436 - accuracy: 0.6222 - val_loss: 0.6566 - val_accuracy: 0.5922
# Epoch 20/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6556 - accuracy: 0.5977
# Epoch 00020: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 38us/sample - loss: 0.6370 - accuracy: 0.6222 - val_loss: 0.6508 - val_accuracy: 0.5922
# Epoch 21/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6152 - accuracy: 0.6680
# Epoch 00021: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 39us/sample - loss: 0.6317 - accuracy: 0.6222 - val_loss: 0.6442 - val_accuracy: 0.5922
# Epoch 22/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6149 - accuracy: 0.6406
# Epoch 00022: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 40us/sample - loss: 0.6242 - accuracy: 0.6222 - val_loss: 0.6362 - val_accuracy: 0.5922
# Epoch 23/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.6188 - accuracy: 0.6289
# Epoch 00023: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 37us/sample - loss: 0.6169 - accuracy: 0.6278 - val_loss: 0.6271 - val_accuracy: 0.5922
# Epoch 24/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.5983 - accuracy: 0.6289
# Epoch 00024: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 37us/sample - loss: 0.6047 - accuracy: 0.6278 - val_loss: 0.6171 - val_accuracy: 0.5922
# Epoch 25/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.5998 - accuracy: 0.6523
# Epoch 00025: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 39us/sample - loss: 0.5963 - accuracy: 0.6657 - val_loss: 0.6065 - val_accuracy: 0.5922
# Epoch 26/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.5929 - accuracy: 0.6680
# Epoch 00026: val_accuracy did not improve from 0.59218
# 712/712 [==============================] - 0s 39us/sample - loss: 0.5843 - accuracy: 0.6798 - val_loss: 0.5955 - val_accuracy: 0.5922
# Epoch 27/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.5693 - accuracy: 0.7305
# Epoch 00027: val_accuracy improved from 0.59218 to 0.73184, saving model to weights.best.hdf5
# 712/712 [==============================] - 0s 66us/sample - loss: 0.5771 - accuracy: 0.7107 - val_loss: 0.5845 - val_accuracy: 0.7318
# Epoch 28/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.5452 - accuracy: 0.7539
# Epoch 00028: val_accuracy improved from 0.73184 to 0.75419, saving model to weights.best.hdf5
# 712/712 [==============================] - 0s 71us/sample - loss: 0.5645 - accuracy: 0.7360 - val_loss: 0.5737 - val_accuracy: 0.7542
# Epoch 29/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.5655 - accuracy: 0.7422
# Epoch 00029: val_accuracy improved from 0.75419 to 0.76536, saving model to weights.best.hdf5
# 712/712 [==============================] - 0s 69us/sample - loss: 0.5581 - accuracy: 0.7472 - val_loss: 0.5631 - val_accuracy: 0.7654
# Epoch 30/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.5463 - accuracy: 0.7695
# Epoch 00030: val_accuracy improved from 0.76536 to 0.78212, saving model to weights.best.hdf5
# 712/712 [==============================] - 0s 68us/sample - loss: 0.5406 - accuracy: 0.7725 - val_loss: 0.5530 - val_accuracy: 0.7821
# Epoch 31/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.5560 - accuracy: 0.7617
# Epoch 00031: val_accuracy improved from 0.78212 to 0.79330, saving model to weights.best.hdf5
# 712/712 [==============================] - 0s 68us/sample - loss: 0.5416 - accuracy: 0.7837 - val_loss: 0.5438 - val_accuracy: 0.7933
# Epoch 32/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.5373 - accuracy: 0.7656
# Epoch 00032: val_accuracy did not improve from 0.79330
# 712/712 [==============================] - 0s 38us/sample - loss: 0.5272 - accuracy: 0.7711 - val_loss: 0.5356 - val_accuracy: 0.7933
# Epoch 33/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.5501 - accuracy: 0.7930
# Epoch 00033: val_accuracy improved from 0.79330 to 0.79888, saving model to weights.best.hdf5
# 712/712 [==============================] - 0s 65us/sample - loss: 0.5186 - accuracy: 0.7963 - val_loss: 0.5276 - val_accuracy: 0.7989
# Epoch 34/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.5244 - accuracy: 0.8008
# Epoch 00034: val_accuracy improved from 0.79888 to 0.80447, saving model to weights.best.hdf5
# 712/712 [==============================] - 0s 67us/sample - loss: 0.5124 - accuracy: 0.8048 - val_loss: 0.5211 - val_accuracy: 0.8045
# Epoch 35/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.5365 - accuracy: 0.7500
# Epoch 00035: val_accuracy did not improve from 0.80447
# 712/712 [==============================] - 0s 41us/sample - loss: 0.5144 - accuracy: 0.7697 - val_loss: 0.5149 - val_accuracy: 0.8045
# Epoch 36/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4727 - accuracy: 0.8281
# Epoch 00036: val_accuracy improved from 0.80447 to 0.81006, saving model to weights.best.hdf5
# 712/712 [==============================] - 0s 72us/sample - loss: 0.5025 - accuracy: 0.8090 - val_loss: 0.5102 - val_accuracy: 0.8101
# Epoch 37/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4688 - accuracy: 0.8086
# Epoch 00037: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 39us/sample - loss: 0.4998 - accuracy: 0.8090 - val_loss: 0.5062 - val_accuracy: 0.8101
# Epoch 38/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4674 - accuracy: 0.8242
# Epoch 00038: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 40us/sample - loss: 0.4927 - accuracy: 0.8188 - val_loss: 0.5029 - val_accuracy: 0.8101
# Epoch 39/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4410 - accuracy: 0.8516
# Epoch 00039: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 36us/sample - loss: 0.4881 - accuracy: 0.8062 - val_loss: 0.5001 - val_accuracy: 0.8101
# Epoch 40/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.5407 - accuracy: 0.7891
# Epoch 00040: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 36us/sample - loss: 0.5021 - accuracy: 0.8118 - val_loss: 0.4979 - val_accuracy: 0.8101
# Epoch 41/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4726 - accuracy: 0.8086
# Epoch 00041: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 37us/sample - loss: 0.4689 - accuracy: 0.8146 - val_loss: 0.4969 - val_accuracy: 0.8045
# Epoch 42/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4784 - accuracy: 0.8125
# Epoch 00042: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 38us/sample - loss: 0.4739 - accuracy: 0.8230 - val_loss: 0.4965 - val_accuracy: 0.8045
# Epoch 43/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.5382 - accuracy: 0.7773
# Epoch 00043: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 38us/sample - loss: 0.4893 - accuracy: 0.8104 - val_loss: 0.4951 - val_accuracy: 0.8045
# Epoch 44/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4400 - accuracy: 0.8594
# Epoch 00044: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 38us/sample - loss: 0.4695 - accuracy: 0.8329 - val_loss: 0.4954 - val_accuracy: 0.8045
# Epoch 45/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4663 - accuracy: 0.8203
# Epoch 00045: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 36us/sample - loss: 0.4728 - accuracy: 0.8048 - val_loss: 0.4957 - val_accuracy: 0.7989
# Epoch 46/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.5046 - accuracy: 0.7891
# Epoch 00046: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 40us/sample - loss: 0.4637 - accuracy: 0.8188 - val_loss: 0.4953 - val_accuracy: 0.7989
# Epoch 47/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4827 - accuracy: 0.8086
# Epoch 00047: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 37us/sample - loss: 0.4673 - accuracy: 0.8230 - val_loss: 0.4945 - val_accuracy: 0.7933
# Epoch 48/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4290 - accuracy: 0.8438
# Epoch 00048: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 39us/sample - loss: 0.4360 - accuracy: 0.8441 - val_loss: 0.4946 - val_accuracy: 0.7933
# Epoch 49/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4121 - accuracy: 0.8711
# Epoch 00049: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 38us/sample - loss: 0.4514 - accuracy: 0.8343 - val_loss: 0.4943 - val_accuracy: 0.7933
# Epoch 50/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.3951 - accuracy: 0.8711
# Epoch 00050: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 37us/sample - loss: 0.4355 - accuracy: 0.8343 - val_loss: 0.4939 - val_accuracy: 0.7933
# Epoch 51/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4847 - accuracy: 0.8125
# Epoch 00051: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 39us/sample - loss: 0.4602 - accuracy: 0.8272 - val_loss: 0.4931 - val_accuracy: 0.7933
# Epoch 52/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4161 - accuracy: 0.8516
# Epoch 00052: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 39us/sample - loss: 0.4404 - accuracy: 0.8287 - val_loss: 0.4923 - val_accuracy: 0.7933
# Epoch 53/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4277 - accuracy: 0.8320
# Epoch 00053: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 38us/sample - loss: 0.4344 - accuracy: 0.8315 - val_loss: 0.4919 - val_accuracy: 0.7933
# Epoch 54/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4400 - accuracy: 0.8242
# Epoch 00054: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 39us/sample - loss: 0.4282 - accuracy: 0.8371 - val_loss: 0.4912 - val_accuracy: 0.7989
# Epoch 55/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4492 - accuracy: 0.8594
# Epoch 00055: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 38us/sample - loss: 0.4406 - accuracy: 0.8427 - val_loss: 0.4916 - val_accuracy: 0.7989
# Epoch 56/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4504 - accuracy: 0.8320
# Epoch 00056: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 37us/sample - loss: 0.4401 - accuracy: 0.8329 - val_loss: 0.4921 - val_accuracy: 0.7989
# Epoch 57/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4517 - accuracy: 0.8320
# Epoch 00057: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 35us/sample - loss: 0.4444 - accuracy: 0.8413 - val_loss: 0.4930 - val_accuracy: 0.7933
# Epoch 58/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4467 - accuracy: 0.8320
# Epoch 00058: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 38us/sample - loss: 0.4458 - accuracy: 0.8216 - val_loss: 0.4941 - val_accuracy: 0.7933
# Epoch 59/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4353 - accuracy: 0.8242
# Epoch 00059: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 37us/sample - loss: 0.4367 - accuracy: 0.8329 - val_loss: 0.4952 - val_accuracy: 0.7877
# Epoch 60/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4446 - accuracy: 0.8164
# Epoch 00060: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 38us/sample - loss: 0.4346 - accuracy: 0.8216 - val_loss: 0.4951 - val_accuracy: 0.7877
# Epoch 61/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4143 - accuracy: 0.8281
# Epoch 00061: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 44us/sample - loss: 0.4182 - accuracy: 0.8413 - val_loss: 0.4955 - val_accuracy: 0.7877
# Epoch 62/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4034 - accuracy: 0.8359
# Epoch 00062: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 39us/sample - loss: 0.4240 - accuracy: 0.8315 - val_loss: 0.4963 - val_accuracy: 0.7877
# Epoch 63/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4284 - accuracy: 0.8398
# Epoch 00063: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 39us/sample - loss: 0.4342 - accuracy: 0.8301 - val_loss: 0.4965 - val_accuracy: 0.7877
# Epoch 64/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4281 - accuracy: 0.8438
# Epoch 00064: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 39us/sample - loss: 0.4399 - accuracy: 0.8301 - val_loss: 0.4966 - val_accuracy: 0.7877
# Epoch 65/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4387 - accuracy: 0.8398
# Epoch 00065: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 39us/sample - loss: 0.4423 - accuracy: 0.8413 - val_loss: 0.4969 - val_accuracy: 0.7877
# Epoch 66/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4065 - accuracy: 0.8398
# Epoch 00066: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 40us/sample - loss: 0.4176 - accuracy: 0.8329 - val_loss: 0.4972 - val_accuracy: 0.7877
# Epoch 67/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4980 - accuracy: 0.7891
# Epoch 00067: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 38us/sample - loss: 0.4310 - accuracy: 0.8371 - val_loss: 0.4968 - val_accuracy: 0.7877
# Epoch 68/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.3934 - accuracy: 0.8750
# Epoch 00068: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 38us/sample - loss: 0.4222 - accuracy: 0.8455 - val_loss: 0.4979 - val_accuracy: 0.7877
# Epoch 69/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.3924 - accuracy: 0.8516
# Epoch 00069: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 39us/sample - loss: 0.4200 - accuracy: 0.8272 - val_loss: 0.4982 - val_accuracy: 0.7877
# Epoch 70/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4663 - accuracy: 0.8086
# Epoch 00070: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 38us/sample - loss: 0.4285 - accuracy: 0.8343 - val_loss: 0.4983 - val_accuracy: 0.7933
# Epoch 71/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4346 - accuracy: 0.8281
# Epoch 00071: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 39us/sample - loss: 0.4221 - accuracy: 0.8385 - val_loss: 0.4980 - val_accuracy: 0.7877
# Epoch 72/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.3872 - accuracy: 0.8672
# Epoch 00072: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 36us/sample - loss: 0.4331 - accuracy: 0.8287 - val_loss: 0.4973 - val_accuracy: 0.7877
# Epoch 73/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4465 - accuracy: 0.8242
# Epoch 00073: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 37us/sample - loss: 0.4291 - accuracy: 0.8385 - val_loss: 0.4961 - val_accuracy: 0.7877
# Epoch 74/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.3904 - accuracy: 0.8633
# Epoch 00074: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 38us/sample - loss: 0.4102 - accuracy: 0.8455 - val_loss: 0.4952 - val_accuracy: 0.7933
# Epoch 75/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4646 - accuracy: 0.8008
# Epoch 00075: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 35us/sample - loss: 0.4314 - accuracy: 0.8160 - val_loss: 0.4951 - val_accuracy: 0.7877
# Epoch 76/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4259 - accuracy: 0.8477
# Epoch 00076: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 37us/sample - loss: 0.4108 - accuracy: 0.8553 - val_loss: 0.4961 - val_accuracy: 0.7877
# Epoch 77/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.3982 - accuracy: 0.8594
# Epoch 00077: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 36us/sample - loss: 0.4176 - accuracy: 0.8483 - val_loss: 0.4966 - val_accuracy: 0.7821
# Epoch 78/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.3972 - accuracy: 0.8516
# Epoch 00078: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 38us/sample - loss: 0.4099 - accuracy: 0.8385 - val_loss: 0.4960 - val_accuracy: 0.7877
# Epoch 79/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.3941 - accuracy: 0.8398
# Epoch 00079: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 37us/sample - loss: 0.4352 - accuracy: 0.8315 - val_loss: 0.4952 - val_accuracy: 0.7877
# Epoch 80/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4440 - accuracy: 0.8242
# Epoch 00080: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 37us/sample - loss: 0.4186 - accuracy: 0.8315 - val_loss: 0.4952 - val_accuracy: 0.7877
# Epoch 81/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4578 - accuracy: 0.8242
# Epoch 00081: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 35us/sample - loss: 0.4054 - accuracy: 0.8427 - val_loss: 0.4956 - val_accuracy: 0.7877
# Epoch 82/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4295 - accuracy: 0.8477
# Epoch 00082: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 40us/sample - loss: 0.4154 - accuracy: 0.8441 - val_loss: 0.4959 - val_accuracy: 0.7877
# Epoch 83/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4443 - accuracy: 0.8281
# Epoch 00083: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 38us/sample - loss: 0.4100 - accuracy: 0.8385 - val_loss: 0.4963 - val_accuracy: 0.7821
# Epoch 84/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4577 - accuracy: 0.8047
# Epoch 00084: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 38us/sample - loss: 0.4137 - accuracy: 0.8371 - val_loss: 0.4961 - val_accuracy: 0.7821
# Epoch 85/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.4103 - accuracy: 0.8398
# Epoch 00085: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 40us/sample - loss: 0.4103 - accuracy: 0.8413 - val_loss: 0.4958 - val_accuracy: 0.7821
# Epoch 86/150
# 256/712 [=========>....................] - ETA: 0s - loss: 0.3902 - accuracy: 0.8359
# Epoch 00086: val_accuracy did not improve from 0.81006
# 712/712 [==============================] - 0s 40us/sample - loss: 0.4186 - accuracy: 0.8427 - val_loss: 0.4950 - val_accuracy: 0.7821
# Epoch 00086: early stopping

# %%
model_accuracy_early_stopping = model.evaluate(val_X, val_Y)
print('Accuracy of random search', model_accuracy_early_stopping)
# Out:
# 179/179 [==============================] - 0s 67us/sample - loss: 0.4950 - accuracy: 0.7821
# Accuracy of random search [0.49500492781234184, 0.7821229]
