# %% [markdown]
# <div class="list-group" id="list-tab" role="tablist">
# <h2 class="list-group-item list-group-item-action active" data-toggle="list" style='background:blue; border:0; color:white' role="tab" aria-controls="home"><center>Quick navigation</center></h2>
#
# * [1.Create New API Token](#1)
#
# * [2.Generate your dataset or model](#2)
#
# * [3.Create KAGGLE environment variables](#3)
#
# * [4.Create dataset-metadata file](#4)
#
# * [5. Create Dataset](#5)
#
# * [6.References](#6)

# %% [markdown]
# <a id="1"></a>
# <h2 class="list-group-item list-group-item-action active" data-toggle="list" style='background:blue; border:0; color:white' role="tab" aria-controls="home"><center>
# Create New API Token
#     </center></h2>

# %% [markdown]
# **Authentication**
# In order to use the Kaggle’s public API, you must first authenticate using an API token. From the site header, click on your user profile picture, then on “My Account” from the dropdown menu. This will take you to your account settings at https://www.kaggle.com/account. Scroll down to the section of the page labelled API:
#
# To create a new token, click on the “Create New API Token” button. This will download a fresh authentication token onto your machine.

# %% [markdown]
# ![](https://raw.githubusercontent.com/TarekSherif/NoteBookImages/master/Upload%20large%20models%20and%20datasets%20with%20kaggle%20API%20!/1.png)

# %% [markdown]
# copy **Authentication** from kaggle.json file

# %% [markdown]
# ![](https://raw.githubusercontent.com/TarekSherif/NoteBookImages/master/Upload%20large%20models%20and%20datasets%20with%20kaggle%20API%20!/2.png)

# %% [markdown]
# if you don't   installed  kaggle package
#
# !pip install kaggle

# %%
import os
import json

# %% [markdown]
# <a id="2"></a>
# <h2 class="list-group-item list-group-item-action active" data-toggle="list" style='background:blue; border:0; color:white' role="tab" aria-controls="home"><center>
# Generate your dataset or model
#     </center></h2>

# %%
data = {}
data['people'] = []
data['people'].append({
    'name': 'Scott',
    'website': 'stackabuse.com',
    'from': 'Nebraska'
})
data['people'].append({
    'name': 'Larry',
    'website': 'google.com',
    'from': 'Michigan'
})
data['people'].append({
    'name': 'Tim',
    'website': 'apple.com',
    'from': 'Alabama'
})

with open('data.json', 'w') as outfile:
    json.dump(data, outfile)

# %% [markdown]
# <a id="3"></a>
# <h2 class="list-group-item list-group-item-action active" data-toggle="list" style='background:blue; border:0; color:white' role="tab" aria-controls="home"><center>
# Create KAGGLE environment variables
#     </center></h2>

# %%
dataset_name="people"

API={"username":"tareksherif","key":"f4cf963ba526c529b3a9b0ea5058e6f0"}

# %%
os.environ['KAGGLE_USERNAME'] = API["username"]
os.environ['KAGGLE_KEY'] = API["key"]

# %% [markdown]
# <a id="4"></a>
#
# <h2 style='background:blue; border:0; color:white'><center> Create dataset-metadata file  </center><h2>

# %%
data = {
  "title": dataset_name,
  "id": os.environ['KAGGLE_USERNAME']+"/"+dataset_name,
  "licenses": [
    {
      "name": "CC0-1.0"
    }
  ]
}
 
with open('dataset-metadata.json', 'w') as outfile:
    json.dump(data, outfile)

# %% [markdown]
# <a id="5"></a>
#
# <h2 style='background:blue; border:0; color:white'><center>  Create Dataset  </center><h2>

# %% [markdown]
# **If you want to create a new dataset, you need to initiate metadata file at first. You could fulfill this by running kaggle datasets init as describe above.**

# %% [markdown]
# > usage: kaggle datasets create [-h] [-p FOLDER] [-u] [-q] [-t] [-r {skip,zip,tar}]
#
# > optional arguments:
#
# >   -h, --help            show this help message and exit
#
# >   -p FOLDER, --path FOLDER
# >                         Folder for upload, containing data files and a special dataset-metadata.json file (https://github.com/Kaggle/kaggle-api/wiki/Dataset-Metadata). Defaults to current working directory
#
# >   -u, --public          Create publicly (default is private)
#
# >   -q, --quiet           Suppress printing information about the upload/download progress
#
# >   -t, --keep-tabular    Do not convert tabular files to CSV (default is to convert)
#
# >   -r {skip,zip,tar}, --dir-mode {skip,zip,tar}
# >                         What to do with directories: "skip" - ignore; "zip" - compressed upload; "tar" - uncompressed upload

# %%
# !kaggle datasets create -p .
# Out:
# Starting upload for file data.json
# 100%|███████████████████████████████████████████| 204/204 [00:03<00:00, 54.3B/s]
# Upload successful: data.json (204B)
# Starting upload for file __notebook_source__.ipynb
# 100%|███████████████████████████████████████████| 263/263 [00:03<00:00, 67.8B/s]
# Upload successful: __notebook_source__.ipynb (263B)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/tareksherif/people

# %% [markdown]
# <a id="6"></a>
#
# <h2 style='background:blue; border:0; color:white'><center> References </center><h2>
#
#
# * https://www.kaggle.com/docs/api
# * https://github.com/Kaggle/kaggle-api

# %% [markdown]
# # Thankyou for Reading and Do Upvote If you liked !!!
